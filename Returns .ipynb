# %% [markdown]
# # For CLUSTER1

# %%
import yfinance as yf
import pandas as pd

# Input dictionary
date_ticker_dict = {
    '2017-04-01': ['APOLLOHOSP.NS',
  'BAYERCROP.NS',
  'CRISIL.NS',
  'FDC.NS',
  'GLENMARK.NS',
  'NAUKRI.NS',
  'ONGC.NS',
  'PERSISTENT.NS',
  'SWANENERGY.NS',
  'TANLA.NS',
  'TECHM.NS'],
 '2017-05-01': ['ABBOTINDIA.NS',
  'AJANTPHARM.NS',
  'AUROPHARMA.NS',
  'CIPLA.NS',
  'DIVISLAB.NS',
  'DRREDDY.NS',
  'ECLERX.NS',
  'INFY.NS',
  'LUPIN.NS',
  'MCDOWELL-N.NS',
  'MPHASIS.NS',
  'PFIZER.NS',
  'SANOFI.NS',
  'SUNPHARMA.NS',
  'TCS.NS
  'TECHM.NS'],
 '2017-06-01': ['ADANIPOWER.NS',
  'BSOFT.NS',
  'CIPLA.NS',
  'COALINDIA.NS',
  'CYIENT.NS',
  'GUJALKALI.NS',
  'IDFCFIRSTB.NS',
  'INFIBEAM.NS',
  'INGERRAND.NS',
  'IPCALAB.NS',
  'JUBLFOOD.NS',
  'JUSTDIAL.NS',
  'LUPIN.NS',
  'MAHABANK.NS',
  'MMTC.NS',
  'OLECTRA.NS',
  'PFC.NS',
  'PFIZER.NS',
  'POLYMED.NS',
  'RENUKA.NS',
  'SONATSOFTW.NS',
  'SWANENERGY.NS',
  'SYMPHONY.NS',
  'TATAELXSI.NS',
  'TECHM.NS',
  'TORNTPHARM.NS',
  'TORNTPOWER.NS',
  'TRIVENI.NS',
  'TV18BRDCST.NS',
  'WELSPUNLIV.NS'],
 '2017-07-01': ['BHEL.NS',
  'BLUESTARCO.NS',
  'BPCL.NS',
  'FORTIS.NS',
  'GAIL.NS',
  'GLENMARK.NS',
  'GUJALKALI.NS',
  'HFCL.NS',
  'IDFC.NS',
  'IOB.NS',
  'IOC.NS',
  'IRB.NS',
  'JBCHEPHARM.NS',
  'JKPAPER.NS',
  'MAHABANK.NS',
  'NMDC.NS',
  'PATANJALI.NS',
  'PFC.NS',
  'PNB.NS',
  'PRAJIND.NS',
  'RCF.NS',
  'RECLTD.NS',
  'RENUKA.NS',
  'TANLA.NS',
  'TORNTPOWER.NS',
  'TRIDENT.NS',
  'UCOBANK.NS'],
 '2017-08-01': ['BALAMINES.NS',
  'BLUEDART.NS',
  'COFORGE.NS',
  'CRISIL.NS',
  'FACT.NS',
  'FINCABLES.NS',
  'FORTIS.NS',
  'GAEL.NS',
  'GLAXO.NS',
  'GODFRYPHLP.NS',
  'IOC.NS',
  'ITC.NS',
  'JBCHEPHARM.NS',
  'LICHSGFIN.NS',
  'PETRONET.NS',
  'PIIND.NS',
  'RECLTD.NS',
  'SUNPHARMA.NS',
  'SUNTV.NS',
  'TATAMTRDVR.NS',
  'UCOBANK.NS',
  'VIPIND.NS',
  'ZENSARTECH.NS'],
 '2017-09-01': ['ABB.NS',
  'ABBOTINDIA.NS',
  'AIAENG.NS',
  'BOSCHLTD.NS',
  'EXIDEIND.NS',
  'GLENMARK.NS',
  'GODFRYPHLP.NS',
  'LUPIN.NS',
  'M&M.NS',
  'MRF.NS',
  'OFSS.NS',
  'PATANJALI.NS',
  'SKFINDIA.NS',
  'SUNTV.NS'],
 '2017-10-01': ['ADANIENT.NS',
  'BANKBARODA.NS',
  'BANKINDIA.NS',
  'CARBORUNIV.NS',
  'CENTRALBK.NS',
  'DLF.NS',
  'ENGINERSIN.NS',
  'GRANULES.NS',
  'HINDCOPPER.NS',
  'ICICIBANK.NS',
  'IDBI.NS',
  'IDEA.NS',
  'INDIANB.NS',
  'IOB.NS',
  'LINDEINDIA.NS',
  'NETWORK18.NS',
  'NMDC.NS',
  'PGHL.NS',
  'PRSMJOHNSN.NS',
  'RECLTD.NS',
  'SONATSOFTW.NS',
  'SUZLON.NS',
  'TANLA.NS',
  'TTML.NS',
  'UCOBANK.NS',
  'UNIONBANK.NS',
  'UPL.NS',
  'WELSPUNLIV.NS',
  'ZENSARTECH.NS'],
 '2017-11-01': ['CANFINHOME.NS',
  'LICHSGFIN.NS',
  'PIDILITIND.NS',
  'YESBANK.NS'],
 '2017-12-01': ['ACC.NS',
  'AMBUJACEM.NS',
  'BCG.NS',
  'GLENMARK.NS',
  'HINDALCO.NS',
  'INDIGO.NS',
  'KARURVYSYA.NS',
  'L&TFH.NS',
  'LICHSGFIN.NS',
  'SJVN.NS',
  'SUZLON.NS',
  'TRIVENI.NS',
  'USHAMART.NS',
  'VEDL.NS',
  'YESBANK.NS'],
 '2018-01-01': ['BALRAMCHIN.NS', 'CENTRALBK.NS', 'MCX.NS'],
 '2018-02-01': ['ACC.NS',
  'AEGISCHEM.NS',
  'APARINDS.NS',
  'ASIANPAINT.NS',
  'AUROPHARMA.NS',
  'BAJAJFINSV.NS',
  'BALRAMCHIN.NS',
  'BATAINDIA.NS',
  'BBTC.NS',
  'BEML.NS',
  'BOSCHLTD.NS',
  'CARBORUNIV.NS',
  'CERA.NS',
  'CGCL.NS',
  'DRREDDY.NS',
  'EICHERMOT.NS',
  'ENDURANCE.NS',
  'FEDERALBNK.NS',
  'HONAUT.NS',
  'INGERRAND.NS',
  'ITI.NS',
  'JBMA.NS',
  'JKLAKSHMI.NS',
  'KPRMILL.NS',
  'LICHSGFIN.NS',
  'MCDOWELL-N.NS',
  'MGL.NS',
  'MHRIL.NS',
  'MOTILALOFS.NS',
  'MUTHOOTFIN.NS',
  'NESTLEIND.NS',
  'NH.NS',
  'NTPC.NS',
  'PAGEIND.NS',
  'PATANJALI.NS',
  'PIIND.NS',
  'POLYMED.NS',
  'POLYPLEX.NS',
  'POWERGRID.NS',
  'SHREECEM.NS',
  'SRF.NS',
  'TATACOMM.NS',
  'TATAMOTORS.NS',
  'TATAMTRDVR.NS',
  'TVSMOTOR.NS'],
 '2018-03-01': ['ADANIPOWER.NS',
  'BAJAJ-AUTO.NS',
  'BANKBARODA.NS',
  'BCG.NS',
  'BEML.NS',
  'BLUEDART.NS',
  'BOSCHLTD.NS',
  'BPCL.NS',
  'CANBK.NS',
  'CARBORUNIV.NS',
  'CENTRALBK.NS',
  'CGCL.NS',
  'COLPAL.NS',
  'CUMMINSIND.NS',
  'DABUR.NS',
  'DEEPAKFERT.NS',
  'EIDPARRY.NS',
  'EMAMILTD.NS',
  'GESHIP.NS',
  'GLAXO.NS',
  'GODFRYPHLP.NS',
  'HINDCOPPER.NS',
  'IDFCFIRSTB.NS',
  'INGERRAND.NS',
  'JBMA.NS',
  'JKCEMENT.NS',
  'JYOTHYLAB.NS',
  'KARURVYSYA.NS',
  'KRBL.NS',
  'LICHSGFIN.NS',
  'MFSL.NS',
  'MOTHERSON.NS',
  'MOTILALOFS.NS',
  'NATCOPHARM.NS',
  'NLCINDIA.NS',
  'PFC.NS',
  'PNBHOUSING.NS',
  'PNCINFRA.NS',
  'PRAJIND.NS',
  'SBIN.NS',
  'SHREECEM.NS',
  'SIEMENS.NS',
  'SOLARINDS.NS',
  'SUZLON.NS',
  'TATAMOTORS.NS',
  'TATAMTRDVR.NS',
  'TATAPOWER.NS',
  'TIMKEN.NS',
  'TRIDENT.NS',
  'TTKPRESTIG.NS'],
 '2018-04-01': ['AARTIDRUGS.NS',
  'ACC.NS',
  'ADANIPORTS.NS',
  'ALKEM.NS',
  'AUROPHARMA.NS',
  'BAJAJ-AUTO.NS',
  'BANKINDIA.NS',
  'BBTC.NS',
  'BEL.NS',
  'BEML.NS',
  'BHEL.NS',
  'BIRLACORPN.NS',
  'CIPLA.NS',
  'DCMSHRIRAM.NS',
  'DEEPAKFERT.NS',
  'DELTACORP.NS',
  'DLF.NS',
  'ECLERX.NS',
  'EPL.NS',
  'FORTIS.NS',
  'GNFC.NS',
  'GRANULES.NS',
  'GRASIM.NS',
  'GSFC.NS',
  'HINDCOPPER.NS',
  'ICICIBANK.NS',
  'IDEA.NS',
  'IDFCFIRSTB.NS',
  'IGL.NS',
  'JBMA.NS',
  'JSL.NS',
  'JSWENERGY.NS',
  'KPRMILL.NS',
  'KRBL.NS',
  'LINDEINDIA.NS',
  'LUPIN.NS',
  'MCX.NS',
  'NH.NS',
  'PERSISTENT.NS',
  'PFC.NS',
  'PNB.NS',
  'RATNAMANI.NS',
  'SIEMENS.NS',
  'SPARC.NS',
  'SUZLON.NS',
  'TATAINVEST.NS',
  'TATAMOTORS.NS',
  'TATAPOWER.NS',
  'TATASTEEL.NS',
  'TIMKEN.NS',
  'TORNTPHARM.NS',
  'TORNTPOWER.NS',
  'TRITURBINE.NS',
  'UBL.NS',
  'UNIONBANK.NS',
  'VTL.NS',
  'WELCORP.NS',
  'WELSPUNLIV.NS'],
 '2018-05-01': ['BALRAMCHIN.NS',
  'BEL.NS',
  'BLUEDART.NS',
  'CANFINHOME.NS',
  'COROMANDEL.NS',
  'GSPL.NS',
  'HINDPETRO.NS',
  'INDUSTOWER.NS',
  'MAHABANK.NS',
  'MGL.NS',
  'MOTILALOFS.NS',
  'RAIN.NS',
  'RAJESHEXPO.NS',
  'TIMKEN.NS',
  'TTKPRESTIG.NS'],
 '2018-06-01': ['AARTIDRUGS.NS',
  'ACC.NS',
  'ADANIPOWER.NS',
  'ALLCARGO.NS',
  'ALOKINDS.NS',
  'APARINDS.NS',
  'APLAPOLLO.NS',
  'APOLLOHOSP.NS',
  'BEL.NS',
  'BEML.NS',
  'BHARATFORG.NS',
  'BLUESTARCO.NS',
  'CEATLTD.NS',
  'CENTURYPLY.NS',
  'CERA.NS',
  'CIPLA.NS',
  'CUMMINSIND.NS',
  'DCMSHRIRAM.NS',
  'DIVISLAB.NS',
  'EIDPARRY.NS',
  'FINPIPE.NS',
  'GAEL.NS',
  'GODFRYPHLP.NS',
  'IDFCFIRSTB.NS',
  'INDUSTOWER.NS',
  'IOB.NS',
  'KEC.NS',
  'KPRMILL.NS',
  'LICHSGFIN.NS',
  'MGL.NS',
  'MUTHOOTFIN.NS',
  'NAVINFLUOR.NS',
  'NBCC.NS',
  'NETWORK18.NS',
  'POLYMED.NS',
  'RAIN.NS',
  'RAJESHEXPO.NS',
  'RTNINDIA.NS',
  'SUZLON.NS',
  'SYMPHONY.NS',
  'TANLA.NS',
  'TATAMTRDVR.NS',
  'VEDL.NS',
  'VOLTAS.NS',
  'WIPRO.NS'],
 '2018-07-01': ['ADANIENT.NS',
  'AJANTPHARM.NS',
  'ALLCARGO.NS',
  'APOLLOTYRE.NS',
  'BALKRISIND.NS',
  'BANKINDIA.NS',
  'BEL.NS',
  'BHEL.NS',
  'CANFINHOME.NS',
  'CARBORUNIV.NS',
  'CASTROLIND.NS',
  'CENTURYPLY.NS',
  'CENTURYTEX.NS',
  'CESC.NS',
  'CGCL.NS',
  'CHAMBLFERT.NS',
  'CHOLAHLDNG.NS',
  'COROMANDEL.NS',
  'DEEPAKFERT.NS',
  'DLF.NS',
  'ENGINERSIN.NS',
  'EPL.NS',
  'FINPIPE.NS',
  'GILLETTE.NS',
  'GMRINFRA.NS',
  'GNFC.NS',
  'GSFC.NS',
  'HEROMOTOCO.NS',
  'HINDCOPPER.NS',
  'HINDZINC.NS',
  'ICICIPRULI.NS',
  'IDFC.NS',
  'IDFCFIRSTB.NS',
  'INDIGO.NS',
  'IOC.NS',
  'IRB.NS',
  'ITI.NS',
  'JBCHEPHARM.NS',
  'JINDALSAW.NS',
  'JMFINANCIL.NS',
  'JSL.NS',
  'JSWENERGY.NS',
  'JUBLPHARMA.NS',
  'L&TFH.NS',
  'LICHSGFIN.NS',
  'MAHABANK.NS',
  'MANAPPURAM.NS',
  'MFSL.NS',
  'MOTHERSON.NS',
  'NCC.NS',
  'ONGC.NS',
  'PNB.NS',
  'PRAJIND.NS',
  'RAIN.NS',
  'RAJESHEXPO.NS',
  'RAMCOCEM.NS',
  'RAYMOND.NS',
  'RECLTD.NS',
  'RTNINDIA.NS',
  'SAREGAMA.NS',
  'SJVN.NS',
  'SKFINDIA.NS',
  'SRF.NS',
  'STLTECH.NS',
  'SUNDARMFIN.NS',
  'SUNTECK.NS',
  'TATAPOWER.NS',
  'TTML.NS',
  'TVSMOTOR.NS',
  'UNIONBANK.NS',
  'VEDL.NS',
  'WELCORP.NS'],
 '2018-08-01': ['APARINDS.NS',
  'APLAPOLLO.NS',
  'ASHOKLEY.NS',
  'BRIGADE.NS',
  'EPL.NS',
  'JKCEMENT.NS',
  'JSL.NS',
  'KAJARIACER.NS',
  'QUESS.NS',
  'RAJESHEXPO.NS',
  'RATNAMANI.NS',
  'RAYMOND.NS',
  'SAREGAMA.NS',
  'SJVN.NS',
  'SUNDARMFIN.NS',
  'TATAMTRDVR.NS',
  'TVSMOTOR.NS',
  'ZFCVINDIA.NS'],
 '2018-09-01': ['AEGISCHEM.NS',
  'APOLLOTYRE.NS',
  'BSE.NS',
  'CENTURYPLY.NS',
  'HINDPETRO.NS',
  'IDEA.NS',
  'INDIGO.NS',
  'LAXMIMACH.NS',
  'LINDEINDIA.NS',
  'LUXIND.NS',
  'OBEROIRLTY.NS',
  'PRESTIGE.NS',
  'QUESS.NS',
  'SAREGAMA.NS',
  'SYMPHONY.NS',
  'TATACOMM.NS',
  'YESBANK.NS',
  'ZEEL.NS'],
 '2018-10-01': ['3MINDIA.NS',
  'AARTIIND.NS',
  'ADANIPOWER.NS',
  'AEGISCHEM.NS',
  'ALLCARGO.NS',
  'ASTRAL.NS',
  'AVANTIFEED.NS',
  'BAJAJFINSV.NS',
  'BHARTIARTL.NS',
  'BIRLACORPN.NS',
  'BLS.NS',
  'CENTURYTEX.NS',
  'CHOLAHLDNG.NS',
  'COFORGE.NS',
  'DELTACORP.NS',
  'DLF.NS',
  'EMAMILTD.NS',
  'EPL.NS',
  'FDC.NS',
  'FSL.NS',
  'GAEL.NS',
  'GLAXO.NS',
  'GNFC.NS',
  'GODREJCP.NS',
  'GODREJPROP.NS',
  'GPPL.NS',
  'GRAPHITE.NS',
  'HFCL.NS',
  'ICICIPRULI.NS',
  'IGL.NS',
  'INDIGO.NS',
  'INTELLECT.NS',
  'IOB.NS',
  'IPCALAB.NS',
  'JINDALSAW.NS',
  'JSL.NS',
  'JSWENERGY.NS',
  'JUSTDIAL.NS',
  'KOTAKBANK.NS',
  'KPRMILL.NS',
  'KRBL.NS',
  'LUXIND.NS',
  'M&M.NS',
  'M&MFIN.NS',
  'MAHLIFE.NS',
  'MASTEK.NS',
  'MCX.NS',
  'MFSL.NS',
  'MOTHERSON.NS',
  'NATIONALUM.NS',
  'NHPC.NS',
  'NLCINDIA.NS',
  'OBEROIRLTY.NS',
  'PATANJALI.NS',
  'PCBL.NS',
  'PHOENIXLTD.NS',
  'PNCINFRA.NS',
  'QUESS.NS',
  'RADICO.NS',
  'RAIN.NS',
  'RBLBANK.NS',
  'RCF.NS',
  'SAIL.NS',
  'SHARDACROP.NS',
  'SHOPERSTOP.NS',
  'SHRIRAMFIN.NS',
  'SOBHA.NS',
  'SOLARINDS.NS',
  'SPARC.NS',
  'SRF.NS',
  'STLTECH.NS',
  'SUNDRMFAST.NS',
  'SUNTECK.NS',
  'TATACOMM.NS',
  'TRENT.NS',
  'TTML.NS',
  'UCOBANK.NS',
  'VOLTAS.NS',
  'WELCORP.NS',
  'ZYDUSWELL.NS'],
 '2018-11-01': ['3MINDIA.NS',
  'ACC.NS',
  'ALKEM.NS',
  'APARINDS.NS',
  'APLAPOLLO.NS',
  'ASAHIINDIA.NS',
  'BAYERCROP.NS',
  'BHARTIARTL.NS',
  'BIRLACORPN.NS',
  'BLUEDART.NS',
  'CESC.NS',
  'CHOLAHLDNG.NS',
  'CRISIL.NS',
  'CYIENT.NS',
  'EICHERMOT.NS',
  'GODREJIND.NS',
  'GPIL.NS',
  'GRASIM.NS',
  'HDFCBANK.NS',
  'HEROMOTOCO.NS',
  'INDUSINDBK.NS',
  'JKLAKSHMI.NS',
  'JUBLFOOD.NS',
  'KANSAINER.NS',
  'LALPATHLAB.NS',
  'LAXMIMACH.NS',
  'MARUTI.NS',
  'MPHASIS.NS',
  'OFSS.NS',
  'PATANJALI.NS',
  'PNBHOUSING.NS',
  'QUESS.NS',
  'RAJESHEXPO.NS',
  'REDINGTON.NS',
  'RTNINDIA.NS',
  'SANOFI.NS',
  'SFL.NS',
  'SHREECEM.NS',
  'SPARC.NS',
  'SUNTECK.NS',
  'SYMPHONY.NS',
  'TATAINVEST.NS',
  'TATAMOTORS.NS',
  'ULTRACEMCO.NS',
  'UNOMINDA.NS',
  'YESBANK.NS',
  'ZYDUSWELL.NS'],
 '2018-12-01': ['ASAHIINDIA.NS',
  'AVANTIFEED.NS',
  'BSE.NS',
  'COALINDIA.NS',
  'CYIENT.NS',
  'DEEPAKFERT.NS',
  'DIXON.NS',
  'FDC.NS',
  'GPIL.NS',
  'HFCL.NS',
  'INFIBEAM.NS',
  'JINDALSTEL.NS',
  'JSWSTEEL.NS',
  'KRBL.NS',
  'MAHLIFE.NS',
  'MHRIL.NS',
  'NBCC.NS',
  'NETWORK18.NS',
  'NMDC.NS',
  'OIL.NS',
  'ONGC.NS',
  'QUESS.NS',
  'RAIN.NS',
  'RALLIS.NS',
  'RECLTD.NS',
  'RENUKA.NS',
  'SHARDACROP.NS',
  'SPARC.NS',
  'SUNDRMFAST.NS',
  'SUNPHARMA.NS',
  'SUPRAJIT.NS',
  'SUZLON.NS',
  'SYNGENE.NS',
  'TATAMOTORS.NS',
  'TATAMTRDVR.NS',
  'TEJASNET.NS',
  'YESBANK.NS'],
 '2019-01-01': ['FSL.NS', 'JSL.NS', 'KRBL.NS', 'NH.NS', 'RENUKA.NS'],
 '2019-02-01': ['ADANIENT.NS',
  'AEGISCHEM.NS',
  'BSOFT.NS',
  'CDSL.NS',
  'CENTRALBK.NS',
  'CENTURYPLY.NS',
  'CGPOWER.NS',
  'COALINDIA.NS',
  'FDC.NS',
  'GMRINFRA.NS',
  'GPPL.NS',
  'GSFC.NS',
  'HINDCOPPER.NS',
  'IDBI.NS',
  'INFIBEAM.NS',
  'IOB.NS',
  'JAMNAAUTO.NS',
  'JINDALSTEL.NS',
  'JKPAPER.NS',
  'JMFINANCIL.NS',
  'KPRMILL.NS',
  'MMTC.NS',
  'MOTHERSON.NS',
  'MRPL.NS',
  'NATIONALUM.NS',
  'NETWORK18.NS',
  'NIACL.NS',
  'OIL.NS',
  'POONAWALLA.NS',
  'RENUKA.NS',
  'SAIL.NS',
  'SJVN.NS',
  'TRIVENI.NS',
  'TTML.NS',
  'TV18BRDCST.NS',
  'VAIBHAVGBL.NS'],
 '2019-03-01': ['BANKBARODA.NS',
  'BIRLACORPN.NS',
  'BSOFT.NS',
  'CONCOR.NS',
  'FACT.NS',
  'FINPIPE.NS',
  'GESHIP.NS',
  'GICRE.NS',
  'GNFC.NS',
  'GSFC.NS',
  'GSPL.NS',
  'GUJALKALI.NS',
  'IDBI.NS',
  'IEX.NS',
  'IIFL.NS',
  'KSB.NS',
  'LAURUSLABS.NS',
  'LUXIND.NS',
  'MARICO.NS',
  'MCX.NS',
  'MOTILALOFS.NS',
  'NATIONALUM.NS',
  'NETWORK18.NS',
  'NLCINDIA.NS',
  'PNCINFRA.NS',
  'POLYMED.NS',
  'RADICO.NS',
  'RAIN.NS',
  'RALLIS.NS',
  'RCF.NS',
  'RTNINDIA.NS',
  'SHOPERSTOP.NS',
  'SJVN.NS',
  'SOLARINDS.NS',
  'TATAPOWER.NS',
  'THERMAX.NS',
  'TVSMOTOR.NS',
  'VAIBHAVGBL.NS',
  'VINATIORGA.NS',
  'VIPIND.NS',
  'ZENSARTECH.NS'],
 '2019-04-01': ['ABBOTINDIA.NS',
  'ALKEM.NS',
  'BIOCON.NS',
  'BOSCHLTD.NS',
  'CEATLTD.NS',
  'CIPLA.NS',
  'CRISIL.NS',
  'DABUR.NS',
  'ENDURANCE.NS',
  'GPIL.NS',
  'HINDUNILVR.NS',
  'KSB.NS',
  'LINDEINDIA.NS',
  'M&M.NS',
  'MAHLIFE.NS',
  'MARICO.NS',
  'MARUTI.NS',
  'MRF.NS',
  'SANOFI.NS',
  'SFL.NS',
  'TATAINVEST.NS',
  'THERMAX.NS',
  'TVSMOTOR.NS',
  'WIPRO.NS'],
 '2019-05-01': ['3MINDIA.NS',
  'ALKEM.NS',
  'ASAHIINDIA.NS',
  'ASTERDM.NS',
  'BAJAJHLDNG.NS',
  'BAYERCROP.NS',
  'BEML.NS',
  'BIOCON.NS',
  'BRITANNIA.NS',
  'CARBORUNIV.NS',
  'CCL.NS',
  'CEATLTD.NS',
  'CONCOR.NS',
  'CYIENT.NS',
  'DABUR.NS',
  'DMART.NS',
  'GLAXO.NS',
  'GODREJCP.NS',
  'GPIL.NS',
  'HEROMOTOCO.NS',
  'IBULHSGFIN.NS',
  'JUBLPHARMA.NS',
  'L&TFH.NS',
  'LAXMIMACH.NS',
  'M&M.NS',
  'MARUTI.NS',
  'NATCOPHARM.NS',
  'NH.NS',
  'PEL.NS',
  'PGHH.NS',
  'PHOENIXLTD.NS',
  'SHRIRAMFIN.NS',
  'SPARC.NS',
  'SUNDARMFIN.NS',
  'TATACHEM.NS',
  'TATACOMM.NS',
  'TIMKEN.NS',
  'WHIRLPOOL.NS'],
 '2019-06-01': ['AUROPHARMA.NS',
  'BALKRISIND.NS',
  'BLUEDART.NS',
  'ECLERX.NS',
  'EMAMILTD.NS',
  'ESCORTS.NS',
  'GLAXO.NS',
  'GLENMARK.NS',
  'GODFRYPHLP.NS',
  'HINDZINC.NS',
  'MOTHERSON.NS',
  'NIACL.NS',
  'PAGEIND.NS',
  'PERSISTENT.NS',
  'TORNTPHARM.NS',
  'YESBANK.NS'],
 '2019-07-01': ['AARTIDRUGS.NS',
  'APARINDS.NS',
  'AUROPHARMA.NS',
  'BLS.NS',
  'CGPOWER.NS',
  'CHOLAHLDNG.NS',
  'DELTACORP.NS',
  'EMAMILTD.NS',
  'ESCORTS.NS',
  'GSFC.NS',
  'HFCL.NS',
  'IDEA.NS',
  'IDFC.NS',
  'IRB.NS',
  'JBMA.NS',
  'JINDALSTEL.NS',
  'JKPAPER.NS',
  'JMFINANCIL.NS',
  'KARURVYSYA.NS',
  'KRBL.NS',
  'L&TFH.NS',
  'LAURUSLABS.NS',
  'NETWORK18.NS',
  'PATANJALI.NS',
  'PCBL.NS',
  'RAYMOND.NS',
  'RENUKA.NS',
  'RTNINDIA.NS',
  'SHARDACROP.NS',
  'TATACOMM.NS',
  'TECHM.NS',
  'TV18BRDCST.NS',
  'TVSMOTOR.NS',
  'YESBANK.NS'],
 '2019-08-01': ['ABB.NS',
  'ABCAPITAL.NS',
  'ABFRL.NS',
  'AJANTPHARM.NS',
  'ALOKINDS.NS',
  'APLAPOLLO.NS',
  'APOLLOTYRE.NS',
  'ASAHIINDIA.NS',
  'BAJAJ-AUTO.NS',
  'BAJAJFINSV.NS',
  'BALKRISIND.NS',
  'BIOCON.NS',
  'BLUESTARCO.NS',
  'BRITANNIA.NS',
  'CANBK.NS',
  'CASTROLIND.NS',
  'CERA.NS',
  'CHOLAHLDNG.NS',
  'COCHINSHIP.NS',
  'CONCOR.NS',
  'COROMANDEL.NS',
  'CRISIL.NS',
  'CUB.NS',
  'CYIENT.NS',
  'EICHERMOT.NS',
  'ELGIEQUIP.NS',
  'ENDURANCE.NS',
  'ESCORTS.NS',
  'EXIDEIND.NS',
  'FDC.NS',
  'FEDERALBNK.NS',
  'GLENMARK.NS',
  'GPIL.NS',
  'GRASIM.NS',
  'HDFCBANK.NS',
  'IBULHSGFIN.NS',
  'INDUSTOWER.NS',
  'JKPAPER.NS',
  'JUBLPHARMA.NS',
  'KSB.NS',
  'LUXIND.NS',
  'MANAPPURAM.NS',
  'NLCINDIA.NS',
  'PAGEIND.NS',
  'PFC.NS',
  'PFIZER.NS',
  'PNBHOUSING.NS',
  'POLYPLEX.NS',
  'PRAJIND.NS',
  'QUESS.NS',
  'RAMCOCEM.NS',
  'RAYMOND.NS',
  'SCHAEFFLER.NS',
  'SUNTECK.NS',
  'SUPRAJIT.NS',
  'TATAMOTORS.NS',
  'TIINDIA.NS',
  'TITAN.NS',
  'TV18BRDCST.NS',
  'TVSMOTOR.NS',
  'VINATIORGA.NS'],
 '2019-09-01': ['ALLCARGO.NS',
  'ALOKINDS.NS',
  'BANKBARODA.NS',
  'BANKINDIA.NS',
  'BHARATFORG.NS',
  'BHEL.NS',
  'CIEINDIA.NS',
  'COALINDIA.NS',
  'DEEPAKFERT.NS',
  'FEDERALBNK.NS',
  'GNFC.NS',
  'GODREJIND.NS',
  'GUJALKALI.NS',
  'IDEA.NS',
  'INDIACEM.NS',
  'INTELLECT.NS',
  'IOC.NS',
  'IRB.NS',
  'JAMNAAUTO.NS',
  'JBMA.NS',
  'JINDALSTEL.NS',
  'JYOTHYLAB.NS',
  'KARURVYSYA.NS',
  'LEMONTREE.NS',
  'LICHSGFIN.NS',
  'MASTEK.NS',
  'MRPL.NS',
  'NBCC.NS',
  'NCC.NS',
  'NMDC.NS',
  'OLECTRA.NS',
  'ONGC.NS',
  'PNBHOUSING.NS',
  'RAYMOND.NS',
  'RCF.NS',
  'RENUKA.NS',
  'RTNINDIA.NS',
  'SBIN.NS',
  'STLTECH.NS',
  'SUZLON.NS',
  'TATAMOTORS.NS',
  'TATAMTRDVR.NS',
  'TATASTEEL.NS',
  'TTML.NS',
  'UNIONBANK.NS',
  'YESBANK.NS'],
 '2019-10-01': ['CANBK.NS',
  'ECLERX.NS',
  'IOB.NS',
  'L&TFH.NS',
  'LICHSGFIN.NS',
  'MAHABANK.NS',
  'PATANJALI.NS',
  'PEL.NS',
  'PNBHOUSING.NS',
  'RECLTD.NS',
  'RENUKA.NS',
  'SAREGAMA.NS',
  'SPARC.NS',
  'UNIONBANK.NS',
  'ZEEL.NS'],
 '2019-11-01': ['AUROPHARMA.NS',
  'BCG.NS',
  'CCL.NS',
  'IBULHSGFIN.NS',
  'IDEA.NS',
  'INDIGO.NS',
  'RTNINDIA.NS',
  'SOBHA.NS',
  'TEJASNET.NS'],
 '2019-12-01': ['ALLCARGO.NS',
  'APARINDS.NS',
  'BEL.NS',
  'CCL.NS',
  'CENTURYTEX.NS',
  'CHAMBLFERT.NS',
  'CUMMINSIND.NS',
  'ELGIEQUIP.NS',
  'FSL.NS',
  'GILLETTE.NS',
  'GRINDWELL.NS',
  'HEROMOTOCO.NS',
  'INDIGO.NS',
  'INTELLECT.NS',
  'LT.NS',
  'M&M.NS',
  'MAHLIFE.NS',
  'OFSS.NS',
  'PATANJALI.NS',
  'PRSMJOHNSN.NS',
  'SIEMENS.NS',
  'SUZLON.NS',
  'SYMPHONY.NS',
  'TEAMLEASE.NS',
  'TRITURBINE.NS',
  'TTKPRESTIG.NS',
  'WIPRO.NS',
  'ZYDUSWELL.NS'],
 '2020-01-01': ['ABB.NS',
  'BHEL.NS',
  'CENTRALBK.NS',
  'CGPOWER.NS',
  'EIHOTEL.NS',
  'GILLETTE.NS',
  'GNFC.NS',
  'HINDUNILVR.NS',
  'INDIACEM.NS',
  'INDIGO.NS',
  'PATANJALI.NS',
  'PEL.NS',
  'PNBHOUSING.NS',
  'PRSMJOHNSN.NS',
  'SHARDACROP.NS',
  'SUNTV.NS',
  'TTML.NS',
  'VGUARD.NS',
  'VMART.NS',
  'WELSPUNLIV.NS',
  'YESBANK.NS',
  'ZENSARTECH.NS'],
 '2020-02-01': ['BEL.NS',
  'BOSCHLTD.NS',
  'CIPLA.NS',
  'COALINDIA.NS',
  'COLPAL.NS',
  'ENGINERSIN.NS',
  'GILLETTE.NS',
  'GLENMARK.NS',
  'HAVELLS.NS',
  'HINDALCO.NS',
  'HINDPETRO.NS',
  'HINDZINC.NS',
  'INDUSINDBK.NS',
  'IOC.NS',
  'JSWENERGY.NS',
  'KARURVYSYA.NS',
  'MARICO.NS',
  'OIL.NS',
  'ONGC.NS',
  'RELIANCE.NS',
  'SHRIRAMFIN.NS',
  'UNIONBANK.NS',
  'UPL.NS',
  'VEDL.NS',
  'WELSPUNLIV.NS'],
 '2020-03-01': ['3MINDIA.NS',
  'ABB.NS',
  'ADANIPORTS.NS',
  'APOLLOTYRE.NS',
  'ASHOKLEY.NS',
  'ATGL.NS',
  'AVANTIFEED.NS',
  'BAJAJ-AUTO.NS',
  'BALRAMCHIN.NS',
  'BATAINDIA.NS',
  'BHARATFORG.NS',
  'BPCL.NS',
  'BRITANNIA.NS',
  'BSE.NS',
  'CESC.NS',
  'CHAMBLFERT.NS',
  'COALINDIA.NS',
  'COLPAL.NS',
  'CONCOR.NS',
  'CRISIL.NS',
  'CUB.NS',
  'DALBHARAT.NS',
  'DCMSHRIRAM.NS',
  'DEEPAKFERT.NS',
  'DIXON.NS',
  'DLF.NS',
  'ECLERX.NS',
  'EIDPARRY.NS',
  'GAIL.NS',
  'GLAXO.NS',
  'GLENMARK.NS',
  'GPIL.NS',
  'GRASIM.NS',
  'GUJALKALI.NS',
  'HCLTECH.NS',
  'HDFCBANK.NS',
  'HDFCLIFE.NS',
  'HEG.NS',
  'HEROMOTOCO.NS',
  'ICICIBANK.NS',
  'ICICIGI.NS',
  'IDFCFIRSTB.NS',
  'INDUSINDBK.NS',
  'IOC.NS',
  'ITI.NS',
  'JSWSTEEL.NS',
  'JUSTDIAL.NS',
  'KPRMILL.NS',
  'MAHLIFE.NS',
  'MARICO.NS',
  'MARUTI.NS',
  'MGL.NS',
  'MHRIL.NS',
  'NBCC.NS',
  'NHPC.NS',
  'NMDC.NS',
  'NTPC.NS',
  'OFSS.NS',
  'OIL.NS',
  'PAGEIND.NS',
  'PCBL.NS',
  'PEL.NS',
  'PETRONET.NS',
  'PNBHOUSING.NS',
  'PNCINFRA.NS',
  'PRAJIND.NS',
  'PRESTIGE.NS',
  'QUESS.NS',
  'RECLTD.NS',
  'RELIANCE.NS',
  'RENUKA.NS',
  'SHOPERSTOP.NS',
  'SIEMENS.NS',
  'SKFINDIA.NS',
  'SUNPHARMA.NS',
  'SUNTECK.NS',
  'SUNTV.NS',
  'TATACOMM.NS',
  'TATASTEEL.NS',
  'TCS.NS',
  'TECHM.NS',
  'THERMAX.NS',
  'TRIVENI.NS',
  'UPL.NS',
  'VARROC.NS',
  'VIPIND.NS'],
 '2020-04-01': ['ADANIENT.NS',
  'ADANIPOWER.NS',
  'ALLCARGO.NS',
  'APLAPOLLO.NS',
  'ASHOKLEY.NS',
  'ATGL.NS',
  'BANKBARODA.NS',
  'CENTRALBK.NS',
  'CENTURYPLY.NS',
  'CENTURYTEX.NS',
  'CGPOWER.NS',
  'FSL.NS',
  'GPIL.NS',
  'HINDCOPPER.NS',
  'HUDCO.NS',
  'IDBI.NS',
  'IEX.NS',
  'INFIBEAM.NS',
  'IOB.NS',
  'IOC.NS',
  'IRB.NS',
  'JAMNAAUTO.NS',
  'JINDALSAW.NS',
  'JKPAPER.NS',
  'JMFINANCIL.NS',
  'JSL.NS',
  'JSWENERGY.NS',
  'KNRCON.NS',
  'LAURUSLABS.NS',
  'MAHABANK.NS',
  'MMTC.NS',
  'MOTHERSON.NS',
  'NBCC.NS',
  'NETWORK18.NS',
  'PCBL.NS',
  'PRAJIND.NS',
  'RAIN.NS',
  'RECLTD.NS',
  'REDINGTON.NS',
  'SAIL.NS',
  'TATAPOWER.NS',
  'TATASTEEL.NS',
  'TRITURBINE.NS',
  'TRIVENI.NS',
  'TTML.NS',
  'UNIONBANK.NS',
  'VBL.NS',
  'WELSPUNLIV.NS',
  'ZENSARTECH.NS'],
 '2020-05-01': ['ASTERDM.NS',
  'AUBANK.NS',
  'BANKBARODA.NS',
  'BANKINDIA.NS',
  'BIRLACORPN.NS',
  'BLS.NS',
  'BRIGADE.NS',
  'CANBK.NS',
  'CENTURYTEX.NS',
  'CHOLAHLDNG.NS',
  'CYIENT.NS',
  'DELTACORP.NS',
  'EIHOTEL.NS',
  'ELGIEQUIP.NS',
  'IDFCFIRSTB.NS',
  'IIFL.NS',
  'JKLAKSHMI.NS',
  'LUXIND.NS',
  'M&MFIN.NS',
  'MHRIL.NS',
  'PERSISTENT.NS',
  'PNB.NS',
  'PNBHOUSING.NS',
  'RATNAMANI.NS',
  'SUNTECK.NS',
  'TATAPOWER.NS',
  'TRIVENI.NS',
  'UNIONBANK.NS',
  'VARROC.NS',
  'VIPIND.NS',
  'VTL.NS',
  'ZENSARTECH.NS'],
 '2020-06-01': ['AAVAS.NS',
  'ALKEM.NS',
  'ASTERDM.NS',
  'AUBANK.NS',
  'BAJAJFINSV.NS',
  'BAJFINANCE.NS',
  'BANKBARODA.NS',
  'BANKINDIA.NS',
  'BRIGADE.NS',
  'CANFINHOME.NS',
  'CENTURYPLY.NS',
  'CHOLAHLDNG.NS',
  'COCHINSHIP.NS',
  'CREDITACC.NS',
  'CYIENT.NS',
  'FORTIS.NS',
  'GILLETTE.NS',
  'IDFC.NS',
  'INDIANB.NS',
  'INDUSINDBK.NS',
  'JINDALSAW.NS',
  'KARURVYSYA.NS',
  'LEMONTREE.NS',
  'M&MFIN.NS',
  'MAHABANK.NS',
  'MAHLIFE.NS',
  'OLECTRA.NS',
  'PFC.NS',
  'PNB.NS',
  'PNBHOUSING.NS',
  'RAJESHEXPO.NS',
  'RAYMOND.NS',
  'SBIN.NS',
  'SCHAEFFLER.NS',
  'SUNTECK.NS',
  'SUPRAJIT.NS',
  'TEAMLEASE.NS',
  'TEJASNET.NS',
  'UNIONBANK.NS',
  'VARROC.NS',
  'VIPIND.NS',
  'WELCORP.NS'],
 '2020-07-01': ['PATANJALI.NS'],
 '2020-08-01': ['ALOKINDS.NS', 'PATANJALI.NS'],
 '2020-09-01': ['3MINDIA.NS',
  'ACC.NS',
  'AJANTPHARM.NS',
  'APLLTD.NS',
  'AUROPHARMA.NS',
  'BHARTIARTL.NS',
  'BIOCON.NS',
  'BOSCHLTD.NS',
  'COLPAL.NS',
  'DABUR.NS',
  'DRREDDY.NS',
  'GODREJCP.NS',
  'GSPL.NS',
  'HAL.NS',
  'HDFCLIFE.NS',
  'HINDUNILVR.NS',
  'ICICIGI.NS',
  'ICICIPRULI.NS',
  'IGL.NS',
  'JKLAKSHMI.NS',
  'LALPATHLAB.NS',
  'MCDOWELL-N.NS',
  'MGL.NS',
  'MRF.NS',
  'NESTLEIND.NS',
  'PAGEIND.NS',
  'PGHH.NS',
  'RAJESHEXPO.NS',
  'SBILIFE.NS',
  'SHREECEM.NS',
  'SWANENERGY.NS',
  'ULTRACEMCO.NS'],
 '2020-10-01': ['BCG.NS',
  'BHARTIARTL.NS',
  'BHEL.NS',
  'BPCL.NS',
  'CASTROLIND.NS',
  'CENTRALBK.NS',
  'COALINDIA.NS',
  'GICRE.NS',
  'GMMPFAUDLR.NS',
  'IOC.NS',
  'ITC.NS',
  'MGL.NS',
  'MMTC.NS',
  'MRPL.NS',
  'PNB.NS',
  'SUZLON.NS',
  'UNIONBANK.NS',
  'YESBANK.NS',
  'ZFCVINDIA.NS'],
 '2020-11-01': ['3MINDIA.NS',
  'ABBOTINDIA.NS',
  'ALKEM.NS',
  'AUROPHARMA.NS',
  'BAJAJ-AUTO.NS',
  'BAJAJFINSV.NS',
  'BAJAJHLDNG.NS',
  'BAYERCROP.NS',
  'BBTC.NS',
  'BDL.NS',
  'BIOCON.NS',
  'BOSCHLTD.NS',
  'BRITANNIA.NS',
  'BSE.NS',
  'CCL.NS',
  'CENTURYTEX.NS',
  'EICHERMOT.NS',
  'FORTIS.NS',
  'GALAXYSURF.NS',
  'GICRE.NS',
  'GLAXO.NS',
  'GMMPFAUDLR.NS',
  'GODREJCP.NS',
  'GODREJIND.NS',
  'HDFCAMC.NS',
  'HEROMOTOCO.NS',
  'HINDUNILVR.NS',
  'ICICIPRULI.NS',
  'IIFL.NS',
  'INGERRAND.NS',
  'ITC.NS',
  'KSB.NS',
  'LUPIN.NS',
  'MCDOWELL-N.NS',
  'MGL.NS',
  'MOTILALOFS.NS',
  'NIACL.NS',
  'RELIANCE.NS',
  'SANOFI.NS',
  'SBILIFE.NS',
  'SOLARINDS.NS',
  'SPARC.NS',
  'SUNPHARMA.NS',
  'TORNTPHARM.NS',
  'UBL.NS',
  'UPL.NS',
  'VBL.NS',
  'VIPIND.NS'],
 '2020-12-01': ['ALOKINDS.NS'],
 '2021-01-01': ['PATANJALI.NS'],
 '2021-02-01': ['AARTIIND.NS',
  'ABFRL.NS',
  'ACC.NS',
  'AMBUJACEM.NS',
  'APLLTD.NS',
  'ASIANPAINT.NS',
  'BATAINDIA.NS',
  'BAYERCROP.NS',
  'BBTC.NS',
  'BERGEPAINT.NS',
  'BRITANNIA.NS',
  'CDSL.NS',
  'CHOLAHLDNG.NS',
  'COFORGE.NS',
  'CREDITACC.NS',
  'CUB.NS',
  'DABUR.NS',
  'EPL.NS',
  'ESCORTS.NS',
  'FINEORG.NS',
  'GILLETTE.NS',
  'GLAXO.NS',
  'GLENMARK.NS',
  'GMMPFAUDLR.NS',
  'GODFRYPHLP.NS',
  'GODREJPROP.NS',
  'GRANULES.NS',
  'GSPL.NS',
  'HINDUNILVR.NS',
  'INDIGO.NS',
  'JKLAKSHMI.NS',
  'LINDEINDIA.NS',
  'M&MFIN.NS',
  'MARUTI.NS',
  'MCDOWELL-N.NS',
  'MCX.NS',
  'MUTHOOTFIN.NS',
  'NATCOPHARM.NS',
  'NAUKRI.NS',
  'NAVINFLUOR.NS',
  'NESTLEIND.NS',
  'PEL.NS',
  'PETRONET.NS',
  'RALLIS.NS',
  'RAMCOCEM.NS',
  'RATNAMANI.NS',
  'RELIANCE.NS',
  'SANOFI.NS',
  'SHREECEM.NS',
  'SWSOLAR.NS',
  'SYNGENE.NS',
  'TATACONSUM.NS',
  'TITAN.NS',
  'TORNTPHARM.NS',
  'TORNTPOWER.NS',
  'TRENT.NS',
  'ZFCVINDIA.NS',
  'ZYDUSLIFE.NS'],
 '2021-03-01': ['AARTIDRUGS.NS',
  'AIAENG.NS',
  'ALKEM.NS',
  'ALOKINDS.NS',
  'ASIANPAINT.NS',
  'ASTERDM.NS',
  'AUROPHARMA.NS',
  'AVANTIFEED.NS',
  'BATAINDIA.NS',
  'BBTC.NS',
  'BERGEPAINT.NS',
  'BIOCON.NS',
  'BRITANNIA.NS',
  'BSOFT.NS',
  'CCL.NS',
  'CREDITACC.NS',
  'DABUR.NS',
  'DIVISLAB.NS',
  'DRREDDY.NS',
  'EICHERMOT.NS',
  'EPL.NS',
  'FDC.NS',
  'FINEORG.NS',
  'GLENMARK.NS',
  'GODFRYPHLP.NS',
  'GODREJCP.NS',
  'HINDUNILVR.NS',
  'ICICIPRULI.NS',
  'IGL.NS',
  'IPCALAB.NS',
  'KOTAKBANK.NS',
  'LTIM.NS',
  'MARUTI.NS',
  'MCDOWELL-N.NS',
  'MCX.NS',
  'NATCOPHARM.NS',
  'NESTLEIND.NS',
  'OFSS.NS',
  'PFIZER.NS',
  'PGHL.NS',
  'RALLIS.NS',
  'SPARC.NS',
  'TCS.NS',
  'TORNTPHARM.NS',
  'UBL.NS',
  'UJJIVANSFB.NS',
  'ZYDUSLIFE.NS'],
 '2021-04-01': ['ASTERDM.NS',
  'BAJAJHLDNG.NS',
  'BATAINDIA.NS',
  'BBTC.NS',
  'BHARTIARTL.NS',
  'BOSCHLTD.NS',
  'CREDITACC.NS',
  'CRISIL.NS',
  'CUB.NS',
  'EIDPARRY.NS',
  'EIHOTEL.NS',
  'EXIDEIND.NS',
  'FEDERALBNK.NS',
  'GMRINFRA.NS',
  'GRANULES.NS',
  'IBULHSGFIN.NS',
  'INGERRAND.NS',
  'ISEC.NS',
  'ITI.NS',
  'JMFINANCIL.NS',
  'JUBLPHARMA.NS',
  'KOTAKBANK.NS',
  'KRBL.NS',
  'LEMONTREE.NS',
  'M&M.NS',
  'MANAPPURAM.NS',
  'MARUTI.NS',
  'MHRIL.NS',
  'MRF.NS',
  'NAUKRI.NS',
  'PETRONET.NS',
  'PGHL.NS',
  'RALLIS.NS',
  'RBLBANK.NS',
  'VARROC.NS',
  'VIPIND.NS',
  'WHIRLPOOL.NS'],
 '2021-05-01': ['ADANIGREEN.NS',
  'AUBANK.NS',
  'BERGEPAINT.NS',
  'BIOCON.NS',
  'BORORENEW.NS',
  'BOSCHLTD.NS',
  'BRITANNIA.NS',
  'CEATLTD.NS',
  'CHALET.NS',
  'COLPAL.NS',
  'CREDITACC.NS',
  'DLF.NS',
  'EIHOTEL.NS',
  'ENDURANCE.NS',
  'ESCORTS.NS',
  'EXIDEIND.NS',
  'GMRINFRA.NS',
  'GODFRYPHLP.NS',
  'GODREJCP.NS',
  'GPPL.NS',
  'HAVELLS.NS',
  'HCLTECH.NS',
  'HDFCAMC.NS',
  'HDFCLIFE.NS',
  'HEROMOTOCO.NS',
  'IDEA.NS',
  'INFIBEAM.NS',
  'ITC.NS',
  'ITI.NS',
  'JMFINANCIL.NS',
  'KEC.NS',
  'L&TFH.NS',
  'LT.NS',
  'M&M.NS',
  'M&MFIN.NS',
  'MARUTI.NS',
  'MCDOWELL-N.NS',
  'NESTLEIND.NS',
  'NLCINDIA.NS',
  'OLECTRA.NS',
  'ORIENTELEC.NS',
  'PRESTIGE.NS',
  'RAYMOND.NS',
  'RBLBANK.NS',
  'SANOFI.NS',
  'SUNTECK.NS',
  'TCS.NS',
  'UCOBANK.NS',
  'UJJIVANSFB.NS',
  'ZEEL.NS'],
 '2021-06-01': ['AMBER.NS', 'SWSOLAR.NS'],
 '2021-07-01': ['3MINDIA.NS',
  'ATGL.NS',
  'CHOLAFIN.NS',
  'INDIAMART.NS',
  'JUBLPHARMA.NS',
  'KOTAKBANK.NS',
  'MRF.NS',
  'PAGEIND.NS',
  'SHREECEM.NS',
  'SYMPHONY.NS'],
 '2021-08-01': ['AARTIDRUGS.NS',
  'ADANIPOWER.NS',
  'BANDHANBNK.NS',
  'BHEL.NS',
  'ENGINERSIN.NS',
  'GAIL.NS',
  'GICRE.NS',
  'HUDCO.NS',
  'IDEA.NS',
  'IDFCFIRSTB.NS',
  'INFIBEAM.NS',
  'IOC.NS',
  'IRCON.NS',
  'JUBLPHARMA.NS',
  'KARURVYSYA.NS',
  'MAHABANK.NS',
  'MRPL.NS',
  'RBLBANK.NS',
  'RVNL.NS',
  'SUZLON.NS',
  'TATAMOTORS.NS',
  'UJJIVANSFB.NS',
  'VARROC.NS',
  'YESBANK.NS',
  'ZEEL.NS'],
 '2021-09-01': ['AARTIDRUGS.NS',
  'AAVAS.NS',
  'ABCAPITAL.NS',
  'AUBANK.NS',
  'BANKINDIA.NS',
  'BHEL.NS',
  'BIOCON.NS',
  'BOSCHLTD.NS',
  'CENTRALBK.NS',
  'COCHINSHIP.NS',
  'COROMANDEL.NS',
  'CSBBANK.NS',
  'EIHOTEL.NS',
  'FACT.NS',
  'FINCABLES.NS',
  'GMMPFAUDLR.NS',
  'GPIL.NS',
  'GRANULES.NS',
  'GSFC.NS',
  'HINDCOPPER.NS',
  'HUDCO.NS',
  'IBULHSGFIN.NS',
  'IDEA.NS',
  'INDIACEM.NS',
  'INDIANB.NS',
  'INDUSTOWER.NS',
  'INGERRAND.NS',
  'IOB.NS',
  'ITI.NS',
  'JINDALSTEL.NS',
  'KARURVYSYA.NS',
  'L&TFH.NS',
  'LEMONTREE.NS',
  'MANAPPURAM.NS',
  'MINDACORP.NS',
  'MMTC.NS',
  'MRPL.NS',
  'NATCOPHARM.NS',
  'NBCC.NS',
  'NLCINDIA.NS',
  'NMDC.NS',
  'PNB.NS',
  'RALLIS.NS',
  'RCF.NS',
  'RENUKA.NS',
  'RVNL.NS',
  'SJVN.NS',
  'STLTECH.NS',
  'SUNTV.NS',
  'SUZLON.NS',
  'TATAMOTORS.NS',
  'TV18BRDCST.NS',
  'TVSMOTOR.NS',
  'UCOBANK.NS',
  'UPL.NS',
  'VAIBHAVGBL.NS',
  'WELCORP.NS',
  'ZYDUSLIFE.NS'],
 '2021-10-01': ['AARTIDRUGS.NS',
  'AUROPHARMA.NS',
  'AVANTIFEED.NS',
  'BANKINDIA.NS',
  'BAYERCROP.NS',
  'BBTC.NS',
  'DIVISLAB.NS',
  'GLAXO.NS',
  'GLENMARK.NS',
  'GRANULES.NS',
  'GUJGASLTD.NS',
  'HDFCAMC.NS',
  'HINDCOPPER.NS',
  'HINDZINC.NS',
  'JKLAKSHMI.NS',
  'LUPIN.NS',
  'LUXIND.NS',
  'METROPOLIS.NS',
  'NATCOPHARM.NS',
  'NMDC.NS',
  'PFIZER.NS',
  'SANOFI.NS',
  'SYNGENE.NS',
  'THERMAX.NS',
  'UPL.NS',
  'VAIBHAVGBL.NS'],
 '2021-11-01': ['AARTIDRUGS.NS',
  'ABCAPITAL.NS',
  'AEGISCHEM.NS',
  'ALKEM.NS',
  'BALAMINES.NS',
  'BBTC.NS',
  'BERGEPAINT.NS',
  'BRITANNIA.NS',
  'CEATLTD.NS',
  'CENTURYTEX.NS',
  'EICHERMOT.NS',
  'EPL.NS',
  'FACT.NS',
  'FDC.NS',
  'GICRE.NS',
  'HAPPSTMNDS.NS',
  'HEROMOTOCO.NS',
  'ICICIPRULI.NS',
  'IGL.NS',
  'INDIAMART.NS',
  'IPCALAB.NS',
  'JUBLPHARMA.NS',
  'KANSAINER.NS',
  'LAURUSLABS.NS',
  'MGL.NS',
  'NAVINFLUOR.NS',
  'NCC.NS',
  'PCBL.NS',
  'RALLIS.NS',
  'SPARC.NS',
  'TCS.NS',
  'ZYDUSLIFE.NS'],
 '2021-12-01': ['ANGELONE.NS',
  'APOLLOTYRE.NS',
  'ASHOKLEY.NS',
  'AUBANK.NS',
  'AVANTIFEED.NS',
  'BALAMINES.NS',
  'BALKRISIND.NS',
  'BANKINDIA.NS',
  'BAYERCROP.NS',
  'BHARATFORG.NS',
  'CEATLTD.NS',
  'COALINDIA.NS',
  'COROMANDEL.NS',
  'CSBBANK.NS',
  'CUB.NS',
  'DEEPAKNTR.NS',
  'EICHERMOT.NS',
  'EIHOTEL.NS',
  'EPL.NS',
  'ERIS.NS',
  'EXIDEIND.NS',
  'FDC.NS',
  'FEDERALBNK.NS',
  'GALAXYSURF.NS',
  'GESHIP.NS',
  'GILLETTE.NS',
  'HAPPSTMNDS.NS',
  'HDFCBANK.NS',
  'HEG.NS',
  'HINDALCO.NS',
  'HINDCOPPER.NS',
  'HONAUT.NS',
  'HUDCO.NS',
  'ICICIPRULI.NS',
  'IDFCFIRSTB.NS',
  'INFIBEAM.NS',
  'ITI.NS',
  'JINDALSTEL.NS',
  'JSWENERGY.NS',
  'JSWSTEEL.NS',
  'JUBLPHARMA.NS',
  'L&TFH.NS',
  'LEMONTREE.NS',
  'LICHSGFIN.NS',
  'M&MFIN.NS',
  'MANAPPURAM.NS',
  'MHRIL.NS',
  'MPHASIS.NS',
  'NBCC.NS',
  'NCC.NS',
  'PCBL.NS',
  'PFC.NS',
  'PIDILITIND.NS',
  'PNB.NS',
  'RALLIS.NS',
  'RAMCOCEM.NS',
  'RCF.NS',
  'ROSSARI.NS',
  'SAIL.NS',
  'SBICARD.NS',
  'SHREECEM.NS',
  'SPARC.NS',
  'SUNDARMFIN.NS',
  'SWANENERGY.NS',
  'UBL.NS',
  'UCOBANK.NS',
  'UJJIVANSFB.NS',
  'UPL.NS',
  'ZYDUSLIFE.NS',
  'ZYDUSWELL.NS'],
 '2022-01-01': ['ASTERDM.NS',
  'AUBANK.NS',
  'BANDHANBNK.NS',
  'BANKINDIA.NS',
  'CAMS.NS',
  'CANFINHOME.NS',
  'CASTROLIND.NS',
  'CHOLAFIN.NS',
  'CHOLAHLDNG.NS',
  'CUB.NS',
  'FEDERALBNK.NS',
  'GILLETTE.NS',
  'GODFRYPHLP.NS',
  'GODREJPROP.NS',
  'GPIL.NS',
  'HAL.NS',
  'HDFCLIFE.NS',
  'HUDCO.NS',
  'ICICIPRULI.NS',
  'IGL.NS',
  'INDIAMART.NS',
  'INDUSINDBK.NS',
  'INDUSTOWER.NS',
  'IOC.NS',
  'JYOTHYLAB.NS',
  'KOTAKBANK.NS',
  'M&MFIN.NS',
  'MGL.NS',
  'NAM-INDIA.NS',
  'OFSS.NS',
  'PATANJALI.NS',
  'PNBHOUSING.NS',
  'PNCINFRA.NS',
  'PRINCEPIPE.NS',
  'SHRIRAMFIN.NS',
  'SUNTV.NS',
  'TATAINVEST.NS',
  'VGUARD.NS',
  'WHIRLPOOL.NS',
  'ZYDUSWELL.NS'],
 '2022-02-01': ['BLUESTARCO.NS',
  'DABUR.NS',
  'DIVISLAB.NS',
  'DMART.NS',
  'DRREDDY.NS',
  'GLAXO.NS',
  'HAPPSTMNDS.NS',
  'HAVELLS.NS',
  'HCLTECH.NS',
  'HDFCAMC.NS',
  'HDFCLIFE.NS',
  'HEG.NS',
  'INFIBEAM.NS',
  'LALPATHLAB.NS',
  'MGL.NS',
  'OFSS.NS',
  'ORIENTELEC.NS',
  'PFIZER.NS',
  'PNBHOUSING.NS',
  'QUESS.NS',
  'RAMCOCEM.NS',
  'RELAXO.NS',
  'SHREECEM.NS',
  'TECHM.NS',
  'VAIBHAVGBL.NS',
  'VGUARD.NS',
  'WIPRO.NS',
  'ZENSARTECH.NS',
  'ZYDUSLIFE.NS',
  'ZYDUSWELL.NS'],
 '2022-03-01': ['3MINDIA.NS',
  'AARTIDRUGS.NS',
  'AEGISCHEM.NS',
  'AMBUJACEM.NS',
  'APOLLOTYRE.NS',
  'BAYERCROP.NS',
  'BCG.NS',
  'BIRLACORPN.NS',
  'BSE.NS',
  'CASTROLIND.NS',
  'CEATLTD.NS',
  'CENTRALBK.NS',
  'COCHINSHIP.NS',
  'CUB.NS',
  'CYIENT.NS',
  'DALBHARAT.NS',
  'DRREDDY.NS',
  'FINCABLES.NS',
  'FINPIPE.NS',
  'GICRE.NS',
  'GODREJCP.NS',
  'GODREJIND.NS',
  'GPPL.NS',
  'GUJGASLTD.NS',
  'HAPPSTMNDS.NS',
  'HDFCAMC.NS',
  'HINDUNILVR.NS',
  'HUDCO.NS',
  'ICICIPRULI.NS',
  'INDIAMART.NS',
  'INDUSTOWER.NS',
  'IRCON.NS',
  'ITI.NS',
  'JBMA.NS',
  'JKCEMENT.NS',
  'JUBLFOOD.NS',
  'KRBL.NS',
  'LUPIN.NS',
  'LUXIND.NS',
  'MCX.NS',
  'MGL.NS',
  'NAM-INDIA.NS',
  'NESTLEIND.NS',
  'NIACL.NS',
  'OLECTRA.NS',
  'PEL.NS',
  'PGHL.NS',
  'RALLIS.NS',
  'RAMCOCEM.NS',
  'RITES.NS',
  'SAREGAMA.NS',
  'SBILIFE.NS',
  'STLTECH.NS',
  'SUNTV.NS',
  'SUPRAJIT.NS',
  'SWSOLAR.NS',
  'TTKPRESTIG.NS',
  'TTML.NS',
  'ULTRACEMCO.NS',
  'UPL.NS',
  'VAIBHAVGBL.NS',
  'VGUARD.NS',
  'WELCORP.NS',
  'WELSPUNLIV.NS',
  'ZEEL.NS',
  'ZYDUSLIFE.NS'],
 '2022-04-01': ['3MINDIA.NS',
  'AARTIDRUGS.NS',
  'AIAENG.NS',
  'BBTC.NS',
  'CAMS.NS',
  'CEATLTD.NS',
  'CIEINDIA.NS',
  'ELGIEQUIP.NS',
  'EMAMILTD.NS',
  'ESCORTS.NS',
  'FINCABLES.NS',
  'GILLETTE.NS',
  'GODREJIND.NS',
  'GUJGASLTD.NS',
  'HUDCO.NS',
  'INDIAMART.NS',
  'IRCON.NS',
  'JKCEMENT.NS',
  'JUBLFOOD.NS',
  'JUBLPHARMA.NS',
  'JUSTDIAL.NS',
  'LUXIND.NS',
  'MAHABANK.NS',
  'MANAPPURAM.NS',
  'MFSL.NS',
  'MRF.NS',
  'NATCOPHARM.NS',
  'NBCC.NS',
  'NCC.NS',
  'NIACL.NS',
  'PETRONET.NS',
  'PNBHOUSING.NS',
  'RELAXO.NS',
  'ROSSARI.NS',
  'SOBHA.NS',
  'VAIBHAVGBL.NS',
  'VTL.NS',
  'WHIRLPOOL.NS',
  'ZYDUSLIFE.NS'],
 '2022-05-01': ['AAVAS.NS',
  'AJANTPHARM.NS',
  'ALKEM.NS',
  'ATUL.NS',
  'AUROPHARMA.NS',
  'BAJAJFINSV.NS',
  'BRIGADE.NS',
  'CERA.NS',
  'DELTACORP.NS',
  'GRANULES.NS',
  'GUJGASLTD.NS',
  'HAPPSTMNDS.NS',
  'HEG.NS',
  'IGL.NS',
  'INFIBEAM.NS',
  'JSL.NS',
  'MPHASIS.NS',
  'NATIONALUM.NS',
  'RAIN.NS',
  'RAJESHEXPO.NS',
  'RALLIS.NS',
  'RBLBANK.NS',
  'SAREGAMA.NS',
  'SOBHA.NS',
  'TATACOMM.NS',
  'TV18BRDCST.NS',
  'UNIONBANK.NS',
  'VTL.NS',
  'ZEEL.NS',
  'ZENSARTECH.NS'],
 '2022-06-01': ['AARTIIND.NS',
  'ADANIGREEN.NS',
  'ALKYLAMINE.NS',
  'AMBER.NS',
  'ASIANPAINT.NS',
  'ASTRAL.NS',
  'ATUL.NS',
  'BAJAJFINSV.NS',
  'BERGEPAINT.NS',
  'BIRLACORPN.NS',
  'BPCL.NS',
  'BSOFT.NS',
  'CANFINHOME.NS',
  'CHAMBLFERT.NS',
  'CSBBANK.NS',
  'DALBHARAT.NS',
  'ECLERX.NS',
  'EMAMILTD.NS',
  'FDC.NS',
  'FORTIS.NS',
  'GLAND.NS',
  'GLENMARK.NS',
  'GMMPFAUDLR.NS',
  'GPIL.NS',
  'GRAPHITE.NS',
  'GRASIM.NS',
  'HAPPSTMNDS.NS',
  'HFCL.NS',
  'HINDALCO.NS',
  'IBULHSGFIN.NS',
  'IDBI.NS',
  'IDFC.NS',
  'INDIACEM.NS',
  'INFIBEAM.NS',
  'IOC.NS',
  'JBMA.NS',
  'JUBLPHARMA.NS',
  'JUSTDIAL.NS',
  'LALPATHLAB.NS',
  'LINDEINDIA.NS',
  'LTIM.NS',
  'LTTS.NS',
  'LUXIND.NS',
  'MANAPPURAM.NS',
  'MOTILALOFS.NS',
  'MUTHOOTFIN.NS',
  'NATCOPHARM.NS',
  'NATIONALUM.NS',
  'NIACL.NS',
  'OBEROIRLTY.NS',
  'PNBHOUSING.NS',
  'PRSMJOHNSN.NS',
  'REDINGTON.NS',
  'RELAXO.NS',
  'RITES.NS',
  'ROSSARI.NS',
  'SHREECEM.NS',
  'SOBHA.NS',
  'SPARC.NS',
  'SUNPHARMA.NS',
  'SUVENPHAR.NS',
  'SYMPHONY.NS',
  'TATACOMM.NS',
  'TATASTEEL.NS',
  'TEAMLEASE.NS',
  'TIINDIA.NS',
  'TRITURBINE.NS',
  'VIPIND.NS',
  'VOLTAS.NS',
  'WIPRO.NS'],
 '2022-07-01': ['ABCAPITAL.NS',
  'ALKYLAMINE.NS',
  'ALLCARGO.NS',
  'BANDHANBNK.NS',
  'BERGEPAINT.NS',
  'BLUESTARCO.NS',
  'BSE.NS',
  'CANFINHOME.NS',
  'DEEPAKNTR.NS',
  'DELTACORP.NS',
  'EQUITASBNK.NS',
  'ESCORTS.NS',
  'FACT.NS',
  'GPIL.NS',
  'GSPL.NS',
  'GUJGASLTD.NS',
  'HFCL.NS',
  'HINDALCO.NS',
  'HINDZINC.NS',
  'IBULHSGFIN.NS',
  'IEX.NS',
  'INDIAMART.NS',
  'INDUSINDBK.NS',
  'IRCON.NS',
  'IRCTC.NS',
  'ISEC.NS',
  'JINDALSTEL.NS',
  'JSL.NS',
  'JSWENERGY.NS',
  'JUBLPHARMA.NS',
  'JUSTDIAL.NS',
  'KANSAINER.NS',
  'KPRMILL.NS',
  'LAURUSLABS.NS',
  'LTTS.NS',
  'LUXIND.NS',
  'MANAPPURAM.NS',
  'MUTHOOTFIN.NS',
  'NBCC.NS',
  'NCC.NS',
  'NMDC.NS',
  'OBEROIRLTY.NS',
  'RALLIS.NS',
  'RBLBANK.NS',
  'SAIL.NS',
  'SFL.NS',
  'SHREECEM.NS',
  'SUZLON.NS',
  'SYMPHONY.NS',
  'TANLA.NS',
  'TATACHEM.NS',
  'TATASTEEL.NS',
  'TECHM.NS',
  'TITAN.NS',
  'TRIDENT.NS',
  'UPL.NS',
  'VARROC.NS',
  'VTL.NS',
  'WIPRO.NS'],
 '2022-08-01': ['ALOKINDS.NS',
  'APLLTD.NS',
  'BEML.NS',
  'BIOCON.NS',
  'CRISIL.NS',
  'DRREDDY.NS',
  'FINPIPE.NS',
  'GUJGASLTD.NS',
  'IEX.NS',
  'IGL.NS',
  'INTELLECT.NS',
  'MCDOWELL-N.NS',
  'MOTILALOFS.NS',
  'NETWORK18.NS',
  'NIACL.NS',
  'OIL.NS',
  'ORIENTELEC.NS',
  'SANOFI.NS',
  'STLTECH.NS',
  'SUZLON.NS',
  'SWSOLAR.NS',
  'TTML.NS',
  'TV18BRDCST.NS',
  'VAIBHAVGBL.NS',
  'ZENSARTECH.NS'],
 '2022-09-01': ['APLLTD.NS',
  'BALKRISIND.NS',
  'BORORENEW.NS',
  'GAEL.NS',
  'INTELLECT.NS',
  'IPCALAB.NS',
  'MASTEK.NS',
  'MPHASIS.NS',
  'NATCOPHARM.NS',
  'SANOFI.NS',
  'SHARDACROP.NS',
  'TANLA.NS',
  'ZENSARTECH.NS'],
 '2022-10-01': ['AARTIIND.NS',
  'AUROPHARMA.NS',
  'BALAMINES.NS',
  'BALKRISIND.NS',
  'BAYERCROP.NS',
  'BERGEPAINT.NS',
  'BOSCHLTD.NS',
  'BPCL.NS',
  'BSE.NS',
  'CENTURYTEX.NS',
  'CYIENT.NS',
  'GALAXYSURF.NS',
  'GLAND.NS',
  'GNFC.NS',
  'GODREJIND.NS',
  'GODREJPROP.NS',
  'HDFCAMC.NS',
  'HEG.NS',
  'HINDPETRO.NS',
  'ICICIGI.NS',
  'KPRMILL.NS',
  'LUXIND.NS',
  'M&MFIN.NS',
  'MFSL.NS',
  'MINDACORP.NS',
  'MOTILALOFS.NS',
  'NAUKRI.NS',
  'OFSS.NS',
  'PIIND.NS',
  'POLYPLEX.NS',
  'RAIN.NS',
  'RALLIS.NS',
  'RELIANCE.NS',
  'SAREGAMA.NS',
  'SHRIRAMFIN.NS',
  'TATAMOTORS.NS',
  'TCS.NS',
  'TECHM.NS',
  'THERMAX.NS',
  'UPL.NS',
  'USHAMART.NS',
  'UTIAMC.NS',
  'VOLTAS.NS',
  'WHIRLPOOL.NS',
  'WIPRO.NS'],
 '2022-11-01': ['AARTIIND.NS',
  'AMBER.NS',
  'ATUL.NS',
  'AVANTIFEED.NS',
  'BALAMINES.NS',
  'BALRAMCHIN.NS',
  'BANDHANBNK.NS',
  'BERGEPAINT.NS',
  'BSOFT.NS',
  'CENTURYPLY.NS',
  'CROMPTON.NS',
  'CYIENT.NS',
  'EPL.NS',
  'GSFC.NS',
  'JINDALSAW.NS',
  'LAURUSLABS.NS',
  'MAHLIFE.NS',
  'MFSL.NS',
  'MOTHERSON.NS',
  'MOTILALOFS.NS',
  'MPHASIS.NS',
  'OLECTRA.NS',
  'PEL.NS',
  'POWERINDIA.NS',
  'QUESS.NS',
  'SANOFI.NS',
  'SBICARD.NS',
  'SCHAEFFLER.NS',
  'SUNTECK.NS',
  'SUVENPHAR.NS',
  'TEAMLEASE.NS',
  'TV18BRDCST.NS',
  'VINATIORGA.NS'],
 '2022-12-01': ['AMBER.NS',
  'ASTRAL.NS',
  'AUROPHARMA.NS',
  'AVANTIFEED.NS',
  'BAJFINANCE.NS',
  'CAMS.NS',
  'CENTURYPLY.NS',
  'CHOLAHLDNG.NS',
  'DCMSHRIRAM.NS',
  'GAEL.NS',
  'GRINDWELL.NS',
  'JUBLFOOD.NS',
  'LAURUSLABS.NS',
  'MOTILALOFS.NS',
  'NATCOPHARM.NS',
  'OLECTRA.NS',
  'POWERINDIA.NS',
  'SCHAEFFLER.NS',
  'SFL.NS',
  'TEAMLEASE.NS',
  'THERMAX.NS',
  'VOLTAS.NS'],
 '2023-01-01': ['3MINDIA.NS',
  'AAVAS.NS',
  'ABFRL.NS',
  'ADANIPORTS.NS',
  'AFFLE.NS',
  'ALKEM.NS',
  'ALKYLAMINE.NS',
  'AMBER.NS',
  'ANGELONE.NS',
  'APLLTD.NS',
  'ASAHIINDIA.NS',
  'AUROPHARMA.NS',
  'AVANTIFEED.NS',
  'BALAMINES.NS',
  'BATAINDIA.NS',
  'BCG.NS',
  'BERGEPAINT.NS',
  'BIOCON.NS',
  'BSE.NS',
  'CENTURYPLY.NS',
  'CENTURYTEX.NS',
  'CIPLA.NS',
  'COLPAL.NS',
  'COROMANDEL.NS',
  'CROMPTON.NS',
  'DEEPAKFERT.NS',
  'DEEPAKNTR.NS',
  'DIXON.NS',
  'DRREDDY.NS',
  'ELGIEQUIP.NS',
  'ENDURANCE.NS',
  'ERIS.NS',
  'FDC.NS',
  'GMMPFAUDLR.NS',
  'GNFC.NS',
  'GRANULES.NS',
  'HAPPSTMNDS.NS',
  'ICICIPRULI.NS',
  'INGERRAND.NS',
  'IRCTC.NS',
  'JUBLFOOD.NS',
  'KOTAKBANK.NS',
  'LALPATHLAB.NS',
  'LAXMIMACH.NS',
  'MAHLIFE.NS',
  'MARUTI.NS',
  'METROPOLIS.NS',
  'NAM-INDIA.NS',
  'NAVINFLUOR.NS',
  'PAGEIND.NS',
  'PGHL.NS',
  'PIDILITIND.NS',
  'POLYPLEX.NS',
  'PRAJIND.NS',
  'PRSMJOHNSN.NS',
  'ROSSARI.NS',
  'ROUTE.NS',
  'RTNINDIA.NS',
  'SKFINDIA.NS',
  'SPARC.NS',
  'SWSOLAR.NS',
  'TATACHEM.NS',
  'TATACONSUM.NS',
  'TATAELXSI.NS',
  'TATAMOTORS.NS',
  'TATAPOWER.NS',
  'TIMKEN.NS',
  'TORNTPHARM.NS',
  'TORNTPOWER.NS',
  'TRENT.NS',
  'TTKPRESTIG.NS',
  'UNOMINDA.NS',
  'UPL.NS',
  'VAIBHAVGBL.NS',
  'VIPIND.NS',
  'VOLTAS.NS',
  'ZEEL.NS',
  'ZFCVINDIA.NS',
  'ZYDUSWELL.NS'],
 '2023-02-01': ['ABFRL.NS',
  'ALOKINDS.NS',
  'APLLTD.NS',
  'ASTERDM.NS',
  'AXISBANK.NS',
  'BAJFINANCE.NS',
  'BALAMINES.NS',
  'BATAINDIA.NS',
  'BAYERCROP.NS',
  'BCG.NS',
  'BERGEPAINT.NS',
  'BIRLACORPN.NS',
  'BORORENEW.NS',
  'BSE.NS',
  'CDSL.NS',
  'CESC.NS',
  'CIPLA.NS',
  'COLPAL.NS',
  'CUB.NS',
  'DEEPAKNTR.NS',
  'DLF.NS',
  'DMART.NS',
  'ELGIEQUIP.NS',
  'ERIS.NS',
  'GLENMARK.NS',
  'GRANULES.NS',
  'GRASIM.NS',
  'GUJALKALI.NS',
  'ICICIBANK.NS',
  'ICICIGI.NS',
  'INDIACEM.NS',
  'INDUSINDBK.NS',
  'INDUSTOWER.NS',
  'JMFINANCIL.NS',
  'JSWENERGY.NS',
  'JUBLFOOD.NS',
  'KOTAKBANK.NS',
  'LTTS.NS',
  'NATCOPHARM.NS',
  'PAGEIND.NS',
  'PRESTIGE.NS',
  'RALLIS.NS',
  'RELAXO.NS',
  'RELIANCE.NS',
  'ROSSARI.NS',
  'SANOFI.NS',
  'SBICARD.NS',
  'SBIN.NS',
  'SYNGENE.NS',
  'TANLA.NS',
  'TATACONSUM.NS',
  'TEAMLEASE.NS',
  'TORNTPOWER.NS',
  'TRENT.NS',
  'TTML.NS',
  'UNOMINDA.NS',
  'VARROC.NS',
  'WELSPUNLIV.NS',
  'WHIRLPOOL.NS',
  'YESBANK.NS'],
 '2023-03-01': ['360ONE.NS',
  'ALKYLAMINE.NS',
  'AMBUJACEM.NS',
  'ATUL.NS',
  'AVANTIFEED.NS',
  'AXISBANK.NS',
  'BAJAJFINSV.NS',
  'BALAMINES.NS',
  'BAYERCROP.NS',
  'BCG.NS',
  'BHARATFORG.NS',
  'BHARTIARTL.NS',
  'BLUEDART.NS',
  'CASTROLIND.NS',
  'CDSL.NS',
  'CUB.NS',
  'DCMSHRIRAM.NS',
  'DIVISLAB.NS',
  'DMART.NS',
  'FINEORG.NS',
  'GESHIP.NS',
  'GODREJPROP.NS',
  'GRANULES.NS',
  'GRASIM.NS',
  'GRINDWELL.NS',
  'HDFCAMC.NS',
  'HDFCLIFE.NS',
  'HEG.NS',
  'HEROMOTOCO.NS',
  'HFCL.NS',
  'HINDALCO.NS',
  'HINDPETRO.NS',
  'HINDUNILVR.NS',
  'ICICIGI.NS',
  'ICICIPRULI.NS',
  'INDIACEM.NS',
  'INDIANB.NS',
  'INDIGO.NS',
  'INDUSINDBK.NS',
  'IPCALAB.NS',
  'ITI.NS',
  'JKLAKSHMI.NS',
  'JSWSTEEL.NS',
  'JUBLFOOD.NS',
  'JYOTHYLAB.NS',
  'KRBL.NS',
  'LAXMIMACH.NS',
  'LICHSGFIN.NS',
  'LUPIN.NS',
  'MANAPPURAM.NS',
  'MMTC.NS',
  'MRF.NS',
  'MUTHOOTFIN.NS',
  'NESTLEIND.NS',
  'PAGEIND.NS',
  'PATANJALI.NS',
  'PEL.NS',
  'PFIZER.NS',
  'PNCINFRA.NS',
  'POLYPLEX.NS',
  'PRINCEPIPE.NS',
  'QUESS.NS',
  'RAIN.NS',
  'RAJESHEXPO.NS',
  'RALLIS.NS',
  'RCF.NS',
  'RELAXO.NS',
  'RENUKA.NS',
  'RHIM.NS',
  'RVNL.NS',
  'SBILIFE.NS',
  'SBIN.NS',
  'STLTECH.NS',
  'SUNPHARMA.NS',
  'SUNTECK.NS',
  'SUNTV.NS',
  'TATACONSUM.NS',
  'TATAELXSI.NS',
  'TATASTEEL.NS',
  'TORNTPHARM.NS',
  'TRIDENT.NS',
  'UNIONBANK.NS',
  'UTIAMC.NS',
  'VIPIND.NS',
  'VMART.NS',
  'WELCORP.NS',
  'ZEEL.NS'],
 '2023-04-01': ['ABFRL.NS',
  'ACC.NS',
  'ATGL.NS',
  'AVANTIFEED.NS',
  'BALAMINES.NS',
  'BANDHANBNK.NS',
  'BBTC.NS',
  'BORORENEW.NS',
  'CDSL.NS',
  'CUB.NS',
  'DEEPAKFERT.NS',
  'ERIS.NS',
  'GILLETTE.NS',
  'GODREJPROP.NS',
  'GUJALKALI.NS',
  'GUJGASLTD.NS',
  'HEG.NS',
  'IEX.NS',
  'INDUSTOWER.NS',
  'IRCTC.NS',
  'ISEC.NS',
  'JUBLPHARMA.NS',
  'KANSAINER.NS',
  'LAURUSLABS.NS',
  'LAXMIMACH.NS',
  'LICHSGFIN.NS',
  'M&M.NS',
  'MMTC.NS',
  'PNBHOUSING.NS',
  'PRINCEPIPE.NS',
  'RAJESHEXPO.NS',
  'ROSSARI.NS',
  'STLTECH.NS',
  'SUNTECK.NS',
  'TATAELXSI.NS',
  'TATAPOWER.NS',
  'TEAMLEASE.NS',
  'UBL.NS',
  'VIPIND.NS',
  'WIPRO.NS'],
 '2023-05-01': ['RAJESHEXPO.NS', 'RALLIS.NS', 'SUMICHEM.NS'],
 '2023-06-01': ['AAVAS.NS',
  'ALLCARGO.NS',
  'ATGL.NS',
  'CUB.NS',
  'DEEPAKFERT.NS',
  'EIDPARRY.NS',
  'GMRINFRA.NS',
  'INDIANB.NS',
  'JINDALSTEL.NS',
  'ONGC.NS',
  'RENUKA.NS',
  'STLTECH.NS',
  'SUNTECK.NS',
  'VMART.NS'],
 '2023-07-01': ['AEGISCHEM.NS',
  'ATGL.NS',
  'CHAMBLFERT.NS',
  'EIDPARRY.NS',
  'GAEL.NS',
  'IEX.NS',
  'JKPAPER.NS',
  'KRBL.NS',
  'NMDC.NS',
  'OIL.NS',
  'PAGEIND.NS',
  'RHIM.NS',
  'SBICARD.NS',
  'SHREECEM.NS',
  'SRF.NS',
  'STLTECH.NS',
  'VOLTAS.NS',
  'ZEEL.NS'],
 '2023-08-01': ['ALKYLAMINE.NS',
  'BLUEDART.NS',
  'BRITANNIA.NS',
  'DALBHARAT.NS',
  'DCMSHRIRAM.NS',
  'DEEPAKFERT.NS',
  'FINEORG.NS',
  'FLUOROCHEM.NS',
  'HINDUNILVR.NS',
  'NAVINFLUOR.NS',
  'POWERINDIA.NS',
  'SRF.NS',
  'SWANENERGY.NS',
  'TATAELXSI.NS'],
 '2023-09-01': ['BLUEDART.NS',
  'BORORENEW.NS',
  'BPCL.NS',
  'BRITANNIA.NS',
  'CUMMINSIND.NS',
  'DELTACORP.NS',
  'HDFCBANK.NS',
  'HINDPETRO.NS',
  'HINDUNILVR.NS',
  'HONAUT.NS',
  'KOTAKBANK.NS',
  'PGHL.NS',
  'RELIANCE.NS',
  'SBICARD.NS',
  'SHOPERSTOP.NS',
  'TORNTPHARM.NS',
  'VEDL.NS'],
 '2023-10-01': ['ABB.NS',
  'AEGISCHEM.NS',
  'ALKYLAMINE.NS',
  'APOLLOTYRE.NS',
  'ASIANPAINT.NS',
  'ATGL.NS',
  'BATAINDIA.NS',
  'BDL.NS',
  'CEATLTD.NS',
  'EPL.NS',
  'GALAXYSURF.NS',
  'GUJGASLTD.NS',
  'HAPPSTMNDS.NS',
  'HDFCBANK.NS',
  'HINDUNILVR.NS',
  'INDIAMART.NS',
  'KAJARIACER.NS',
  'KOTAKBANK.NS',
  'NAUKRI.NS',
  'PIDILITIND.NS',
  'PIIND.NS',
  'POWERINDIA.NS',
  'RALLIS.NS',
  'RAYMOND.NS',
  'RELIANCE.NS',
  'SAREGAMA.NS',
  'SBICARD.NS',
  'SHARDACROP.NS',
  'SHOPERSTOP.NS',
  'SRF.NS',
  'SUPRAJIT.NS',
  'TIMKEN.NS',
  'VEDL.NS'],
 '2023-11-01': ['AARTIDRUGS.NS',
  'AARTIIND.NS',
  'ALLCARGO.NS',
  'APLLTD.NS',
  'ASHOKLEY.NS',
  'ATGL.NS',
  'AUBANK.NS',
  'BALAMINES.NS',
  'BANDHANBNK.NS',
  'BATAINDIA.NS',
  'BEML.NS',
  'BRITANNIA.NS',
  'CAMS.NS',
  'CARBORUNIV.NS',
  'CCL.NS',
  'COROMANDEL.NS',
  'CROMPTON.NS',
  'DCMSHRIRAM.NS',
  'DEEPAKNTR.NS',
  'EIDPARRY.NS',
  'ENGINERSIN.NS',
  'EPL.NS',
  'FINCABLES.NS',
  'FINPIPE.NS',
  'GLAXO.NS',
  'GSPL.NS',
  'GUJGASLTD.NS',
  'HAL.NS',
  'HAPPSTMNDS.NS',
  'HAVELLS.NS',
  'HDFCBANK.NS',
  'HFCL.NS',
  'HINDZINC.NS',
  'ICICIBANK.NS',
  'IDBI.NS',
  'IDFC.NS',
  'IDFCFIRSTB.NS',
  'INDHOTEL.NS',
  'INDIACEM.NS',
  'INDIAMART.NS',
  'ITC.NS',
  'JBMA.NS',
  'JINDALSTEL.NS',
  'JSWSTEEL.NS',
  'KEI.NS',
  'KRBL.NS',
  'LAURUSLABS.NS',
  'LAXMIMACH.NS',
  'LTTS.NS',
  'M&M.NS',
  'MAHLIFE.NS',
  'MPHASIS.NS',
  'PNCINFRA.NS',
  'POONAWALLA.NS',
  'PRINCEPIPE.NS',
  'RAIN.NS',
  'REDINGTON.NS',
  'SAIL.NS',
  'SAREGAMA.NS',
  'SBICARD.NS',
  'SCHAEFFLER.NS',
  'SHARDACROP.NS',
  'SHOPERSTOP.NS',
  'SKFINDIA.NS',
  'STLTECH.NS',
  'SUPRAJIT.NS',
  'TATACHEM.NS',
  'TATASTEEL.NS',
  'TEAMLEASE.NS',
  'TECHM.NS',
  'TIMKEN.NS',
  'USHAMART.NS',
  'VIPIND.NS',
  'WIPRO.NS',
  'YESBANK.NS',
  'ZYDUSLIFE.NS'],
 '2023-12-01': ['CHOLAHLDNG.NS',
  'FINEORG.NS',
  'SKFINDIA.NS',
  'TEJASNET.NS',
  'THERMAX.NS',
  'VINATIORGA.NS'],
 '2024-01-01': ['APLAPOLLO.NS',
  'CERA.NS',
  'ESCORTS.NS',
  'LUXIND.NS',
  'SAFARI.NS',
  'TTKPRESTIG.NS',
  'WHIRLPOOL.NS'],
 '2024-02-01': ['ASAHIINDIA.NS',
  'ATUL.NS',
  'BAJFINANCE.NS',
  'COROMANDEL.NS',
  'DIVISLAB.NS',
  'DMART.NS',
  'HDFCBANK.NS',
  'ITC.NS',
  'JUBLFOOD.NS',
  'LAURUSLABS.NS',
  'LAXMIMACH.NS',
  'LTIM.NS',
  'LUXIND.NS',
  'OBEROIRLTY.NS',
  'ORIENTELEC.NS',
  'PIIND.NS',
  'POLYCAB.NS',
  'POLYPLEX.NS',
  'PRAJIND.NS',
  'SBICARD.NS',
  'SHARDACROP.NS',
  'SRF.NS',
  'TEJASNET.NS',
  'TRITURBINE.NS',
  'UPL.NS',
  'VIPIND.NS',
  'WHIRLPOOL.NS']
}
# Initialize lists to store results
ticker_list = []
percentage_returns = []
first_day_closes = []
last_day_closes = []
start_dates = []  # List to store the start dates
end_dates = []    # List to store the end dates

# Loop through the dictionary and download data for each date-ticker pair
for start_date, tickers in date_ticker_dict.items():
    end_date = pd.to_datetime(start_date) + pd.DateOffset(months=1) - pd.DateOffset(days=1)  # Last day of the month

    # Loop through tickers in this iteration
    for ticker in tickers:
        # Download historical stock data using yfinance for the specified ticker and dates
        try:
            stocks = yf.download(ticker, start=start_date, end=end_date)

            # Extracting the closing prices on the first and last day
            first_day_close = stocks['Close'].iloc[0]
            last_day_close = stocks['Close'].iloc[-1]

            # Calculating percentage return for this ticker
            percentage_return = ((last_day_close - first_day_close) / first_day_close) * 100

            # Appending the results to the lists
            ticker_list.append(ticker)
            percentage_returns.append(percentage_return)
            first_day_closes.append(first_day_close)
            last_day_closes.append(last_day_close)
            start_dates.append(pd.to_datetime(start_date))
            end_dates.append(end_date)  # Append end date for each ticker
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

# Creating a DataFrame with ticker symbols, percentage returns, and capital information
returns_df = pd.DataFrame({
    'Start_Date': start_dates,
    'End_Date': end_dates,
    'Ticker': ticker_list,
    'Percentage_Return': percentage_returns,
    'First_Day_Close': first_day_closes,
    'Last_Day_Close': last_day_closes,
})

# Assuming an initial investment of $10,000 for each stock
initial_investment = 10000

# Calculating the capital at the last day
returns_df['Capital_At_Last_Day'] = initial_investment * (1 + returns_df['Percentage_Return'] / 100)

# Calculating the difference between capital at the last day and capital required
returns_df['Capital_Difference'] = returns_df['Capital_At_Last_Day'] - initial_investment

# Total amount invested
total_invested = initial_investment * len(returns_df)

# Total amount returned
total_returned = returns_df['Capital_At_Last_Day'].sum()

# Calculate percentage return
percentage_return = ((total_returned - total_invested) / total_invested) * 100

# Displaying the DataFrame with ticker names, percentage returns, and capital information
print(returns_df[['Start_Date', 'End_Date', 'Ticker', 'Percentage_Return', 'First_Day_Close', 'Last_Day_Close']])

# Display total amount invested and total amount returned in percentage
print("\nTotal Amount Invested: $", total_invested)
print("Total Amount Returned: $", total_returned)
print("Percentage Return: ", percentage_return, "%")

returns_df.to_csv('stock_Cluster2.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %% [markdown]
# # FOR CLUSTER 2

# %%
# import yfinance as yf
import pandas as pd

# Input dictionary
date_ticker_dict =  {
    '2017-04-01': ['AARTIDRUGS.NS', 'ALOKINDS.NS', 'ASHOKLEY.NS', 'BCG.NS', 'BSOFT.NS', 'HFCL.NS', 'IDEA.NS', 'IDFCFIRSTB.NS', 'INTELLECT.NS', 'RENUKA.NS', 'SONATSOFTW.NS', 'TTML.NS'],
'2017-05-01': ['AARTIDRUGS.NS', 'ADANIPOWER.NS', 'ALKEM.NS', 'BCG.NS', 'BSOFT.NS', 'COALINDIA.NS', 'ELGIEQUIP.NS', 'FDC.NS', 'HCLTECH.NS', 'HINDZINC.NS', 'IDEA.NS', 'JBCHEPHARM.NS', 'JUSTDIAL.NS', 'NMDC.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'TANLA.NS', 'TATASTEEL.NS', 'ZENSARTECH.NS'],
'2017-06-01': ['ABBOTINDIA.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'BANKINDIA.NS', 'BEML.NS', 'BIOCON.NS', 'BLUEDART.NS', 'CRISIL.NS', 'DIVISLAB.NS', 'DRREDDY.NS', 'FDC.NS', 'GESHIP.NS', 'GLAXO.NS', 'GMRINFRA.NS', 'GPPL.NS', 'GUJALKALI.NS', 'HFCL.NS', 'HINDZINC.NS', 'IDEA.NS', 'IOB.NS', 'IRB.NS', 'ITI.NS', 'JINDALSAW.NS', 'LALPATHLAB.NS', 'MCX.NS', 'MINDACORP.NS', 'OFSS.NS', 'OIL.NS', 'ONGC.NS', 'POLYPLEX.NS', 'PRAJIND.NS', 'RATNAMANI.NS', 'SAIL.NS', 'SANOFI.NS', 'SJVN.NS', 'TATAPOWER.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'YESBANK.NS', 'ZENSARTECH.NS'],
'2017-07-01': ['ACC.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'APARINDS.NS', 'ASIANPAINT.NS', 'BAJAJ-AUTO.NS', 'BALAMINES.NS', 'BANKBARODA.NS', 'BEL.NS', 'CANBK.NS', 'DCMSHRIRAM.NS', 'EICHERMOT.NS', 'FACT.NS', 'GAEL.NS', 'GNFC.NS', 'GRANULES.NS', 'GSFC.NS', 'GUJGASLTD.NS', 'IDFC.NS', 'INDIANB.NS', 'JBMA.NS', 'JUBLPHARMA.NS', 'JYOTHYLAB.NS', 'KRBL.NS', 'LT.NS', 'MMTC.NS', 'MRPL.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'PRAJIND.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SHREECEM.NS', 'SRF.NS', 'SWANENERGY.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TECHM.NS', 'THERMAX.NS', 'TRENT.NS', 'TRIVENI.NS', 'UCOBANK.NS', 'ULTRACEMCO.NS', 'UNIONBANK.NS', 'VGUARD.NS', 'VIPIND.NS', 'ZEEL.NS', 'ZFCVINDIA.NS'],
'2017-08-01': ['ABB.NS', 'ALLCARGO.NS', 'ASTRAL.NS', 'BCG.NS', 'CASTROLIND.NS', 'CCL.NS', 'CENTRALBK.NS', 'COALINDIA.NS', 'CONCOR.NS', 'EXIDEIND.NS', 'FDC.NS', 'GESHIP.NS', 'GRANULES.NS', 'INDHOTEL.NS', 'INTELLECT.NS', 'IOB.NS', 'IPCALAB.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'JUSTDIAL.NS', 'LALPATHLAB.NS', 'MINDACORP.NS', 'NCC.NS', 'NHPC.NS', 'NLCINDIA.NS', 'PFC.NS', 'PNCINFRA.NS', 'PRAJIND.NS', 'RELAXO.NS', 'SHARDACROP.NS', 'SRF.NS', 'SUPREMEIND.NS', 'SWANENERGY.NS', 'TATACOMM.NS', 'TATAMOTORS.NS', 'TORNTPOWER.NS', 'TTKPRESTIG.NS', 'VGUARD.NS', 'WELSPUNLIV.NS'],
'2017-09-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'ALOKINDS.NS', 'BCG.NS', 'BHEL.NS', 'BIOCON.NS', 'CENTURYPLY.NS', 'COALINDIA.NS', 'COFORGE.NS', 'FORTIS.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'INFY.NS', 'INGERRAND.NS', 'ITC.NS', 'JKLAKSHMI.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'MAHABANK.NS', 'MARICO.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'NCC.NS', 'NETWORK18.NS', 'NH.NS', 'NHPC.NS', 'NLCINDIA.NS', 'ONGC.NS', 'PIIND.NS', 'PNCINFRA.NS', 'POLYMED.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RALLIS.NS', 'SBIN.NS', 'SHARDACROP.NS', 'SIEMENS.NS', 'SUNPHARMA.NS', 'SUZLON.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TANLA.NS', 'TORNTPHARM.NS', 'TRITURBINE.NS', 'TTML.NS', 'UBL.NS', 'UCOBANK.NS', 'UNIONBANK.NS'],
'2017-10-01': ['ACC.NS', 'ADANIENT.NS', 'ADANIPORTS.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ASIANPAINT.NS', 'AUROPHARMA.NS', 'BALRAMCHIN.NS', 'BANKINDIA.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BPCL.NS', 'BRIGADE.NS', 'CANFINHOME.NS', 'CHOLAFIN.NS', 'COLPAL.NS', 'CRISIL.NS', 'CROMPTON.NS', 'ELGIEQUIP.NS', 'FORTIS.NS', 'GLENMARK.NS', 'GODREJIND.NS', 'GSFC.NS', 'HINDUNILVR.NS', 'IIFL.NS', 'INDIACEM.NS', 'INDIGO.NS', 'INGERRAND.NS', 'JKCEMENT.NS', 'JUBLPHARMA.NS', 'LALPATHLAB.NS', 'LICHSGFIN.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MHRIL.NS', 'NCC.NS', 'PEL.NS', 'PIDILITIND.NS', 'RELIANCE.NS', 'SUPREMEIND.NS', 'TATAELXSI.NS', 'TATAMTRDVR.NS', 'TCS.NS', 'TITAN.NS', 'ULTRACEMCO.NS', 'VOLTAS.NS', 'WIPRO.NS', 'ZYDUSLIFE.NS'],
'2017-11-01': ['APOLLOHOSP.NS', 'BAJAJFINSV.NS', 'BAYERCROP.NS', 'BCG.NS', 'BOSCHLTD.NS', 'CEATLTD.NS', 'FORTIS.NS', 'GODFRYPHLP.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'INDUSINDBK.NS', 'INFIBEAM.NS', 'ITC.NS', 'JUBLPHARMA.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KEC.NS', 'MAHLIFE.NS', 'MCX.NS', 'OFSS.NS', 'PFIZER.NS', 'RENUKA.NS', 'SHARDACROP.NS', 'SUPRAJIT.NS', 'WELSPUNLIV.NS'],
'2017-12-01': ['ADANIPORTS.NS', 'ASIANPAINT.NS', 'AUROPHARMA.NS', 'BAJFINANCE.NS', 'BATAINDIA.NS', 'BLS.NS', 'COLPAL.NS', 'CONCOR.NS', 'CUMMINSIND.NS', 'DEEPAKFERT.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'FEDERALBNK.NS', 'GLAXO.NS', 'GODFRYPHLP.NS', 'HCLTECH.NS', 'HEROMOTOCO.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'ICICIPRULI.NS', 'IDFCFIRSTB.NS', 'INDUSTOWER.NS', 'IOC.NS', 'ITC.NS', 'KOTAKBANK.NS', 'KPRMILL.NS', 'MCX.NS', 'MFSL.NS', 'MOTILALOFS.NS', 'MRPL.NS', 'MUTHOOTFIN.NS', 'PFC.NS', 'POWERGRID.NS', 'RAJESHEXPO.NS', 'RECLTD.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TRIDENT.NS', 'UPL.NS', 'WELCORP.NS'],
'2018-01-01': ['BANKBARODA.NS', 'BANKINDIA.NS', 'CASTROLIND.NS', 'CCL.NS', 'COALINDIA.NS', 'IOB.NS', 'IOC.NS', 'KRBL.NS', 'LICHSGFIN.NS', 'MAHABANK.NS', 'NBCC.NS', 'PATANJALI.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'REDINGTON.NS', 'RTNINDIA.NS', 'TRIVENI.NS', 'UCOBANK.NS', 'UNIONBANK.NS'],
'2018-02-01': ['AARTIDRUGS.NS', 'ABFRL.NS', 'ADANIPOWER.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'APOLLOTYRE.NS', 'ASTRAL.NS', 'BAJFINANCE.NS', 'BANKBARODA.NS', 'BCG.NS', 'BEL.NS', 'BERGEPAINT.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CASTROLIND.NS', 'CCL.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CESC.NS', 'CIPLA.NS', 'CROMPTON.NS', 'ENGINERSIN.NS', 'EPL.NS', 'FORTIS.NS', 'GESHIP.NS', 'GRINDWELL.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'IDEA.NS', 'IDFC.NS', 'IGL.NS', 'INDIACEM.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'IOB.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'KANSAINER.NS', 'L&TFH.NS', 'LAURUSLABS.NS', 'MANAPPURAM.NS', 'MOTHERSON.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NESTLEIND.NS', 'NHPC.NS', 'NLCINDIA.NS', 'OIL.NS', 'PFC.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'QUESS.NS', 'RBLBANK.NS', 'REDINGTON.NS', 'RELAXO.NS', 'RENUKA.NS', 'SAREGAMA.NS', 'SFL.NS', 'SHARDACROP.NS', 'SJVN.NS', 'SPARC.NS', 'SUNDRMFAST.NS', 'SUZLON.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'TATAPOWER.NS', 'TRENT.NS', 'TRITURBINE.NS', 'TTKPRESTIG.NS', 'TTML.NS', 'UNIONBANK.NS', 'VINATIORGA.NS', 'VOLTAS.NS', 'VTL.NS', 'WELSPUNLIV.NS'],
'2018-03-01': ['AARTIDRUGS.NS', 'ABFRL.NS', 'ACC.NS', 'AEGISCHEM.NS', 'AIAENG.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'AXISBANK.NS', 'BALRAMCHIN.NS', 'BEL.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'CEATLTD.NS', 'CENTURYTEX.NS', 'CGPOWER.NS', 'CONCOR.NS', 'CROMPTON.NS', 'DLF.NS', 'EPL.NS', 'EXIDEIND.NS', 'FACT.NS', 'FEDERALBNK.NS', 'GLENMARK.NS', 'GNFC.NS', 'GODREJIND.NS', 'GRANULES.NS', 'GSFC.NS', 'HAVELLS.NS', 'ICICIBANK.NS', 'IDEA.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDIACEM.NS', 'INDIANB.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JSWENERGY.NS', 'JUSTDIAL.NS', 'KANSAINER.NS', 'KSB.NS', 'L&TFH.NS', 'LUPIN.NS', 'M&MFIN.NS', 'MAHLIFE.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'MUTHOOTFIN.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NTPC.NS', 'PEL.NS', 'PNCINFRA.NS', 'PRAJIND.NS', 'RALLIS.NS', 'RATNAMANI.NS', 'RCF.NS', 'SAIL.NS', 'SHARDACROP.NS', 'SPARC.NS', 'SUNPHARMA.NS', 'SWANENERGY.NS', 'TATAINVEST.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TTML.NS', 'VINATIORGA.NS', 'WELSPUNLIV.NS', 'WIPRO.NS', 'ZYDUSLIFE.NS'],
'2018-04-01': ['ADANIENT.NS', 'ALKYLAMINE.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APOLLOHOSP.NS', 'ASAHIINDIA.NS', 'AVANTIFEED.NS', 'AXISBANK.NS', 'BALAMINES.NS', 'BCG.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'CANBK.NS', 'CCL.NS', 'CEATLTD.NS', 'CENTURYTEX.NS', 'CGCL.NS', 'CGPOWER.NS', 'CIEINDIA.NS', 'CRISIL.NS', 'DRREDDY.NS', 'EIHOTEL.NS', 'FDC.NS', 'FEDERALBNK.NS', 'GAIL.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GUJALKALI.NS', 'HAVELLS.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'IDFC.NS', 'INDIACEM.NS', 'INFIBEAM.NS', 'INTELLECT.NS', 'IOC.NS', 'ITC.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JMFINANCIL.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'LAURUSLABS.NS', 'MFSL.NS', 'MGL.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'MRPL.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NBCC.NS', 'OFSS.NS', 'OIL.NS', 'OLECTRA.NS', 'PATANJALI.NS', 'PEL.NS', 'PETRONET.NS', 'POLYPLEX.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RAJESHEXPO.NS', 'RAYMOND.NS', 'RCF.NS', 'RECLTD.NS', 'RELIANCE.NS', 'SAIL.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SFL.NS', 'SOBHA.NS', 'STLTECH.NS', 'SUNPHARMA.NS', 'SUNTV.NS', 'SWANENERGY.NS', 'TANLA.NS', 'TATACONSUM.NS', 'THERMAX.NS', 'TTML.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VEDL.NS', 'WIPRO.NS', 'ZYDUSLIFE.NS'],
'2018-05-01': ['ADANIPOWER.NS', 'BANKINDIA.NS', 'BCG.NS', 'BEML.NS', 'BIRLACORPN.NS', 'BPCL.NS', 'CERA.NS', 'CRISIL.NS', 'DELTACORP.NS', 'EIDPARRY.NS', 'FDC.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'IGL.NS', 'IOC.NS', 'JKLAKSHMI.NS', 'KAJARIACER.NS', 'KRBL.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'MAHABANK.NS', 'MARUTI.NS', 'MRPL.NS', 'NH.NS', 'PATANJALI.NS', 'PETRONET.NS', 'PNB.NS', 'PNCINFRA.NS', 'RALLIS.NS', 'REDINGTON.NS', 'RTNINDIA.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TTML.NS', 'UNIONBANK.NS', 'VTL.NS', 'WIPRO.NS'],
'2018-06-01': ['3MINDIA.NS', 'ABB.NS', 'ADANIENT.NS', 'ALKEM.NS', 'APOLLOTYRE.NS', 'AUROPHARMA.NS', 'BAJAJ-AUTO.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BANKINDIA.NS', 'BHARTIARTL.NS', 'BLUEDART.NS', 'BRIGADE.NS', 'CANFINHOME.NS', 'CASTROLIND.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'CROMPTON.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'DRREDDY.NS', 'FDC.NS', 'FEDERALBNK.NS', 'GESHIP.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HCLTECH.NS', 'HEROMOTOCO.NS', 'HFCL.NS', 'IDFC.NS', 'IGL.NS', 'INDIACEM.NS', 'IPCALAB.NS', 'IRB.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JUBLPHARMA.NS', 'LUXIND.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MARUTI.NS', 'MASTEK.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'NATIONALUM.NS', 'NHPC.NS', 'OIL.NS', 'PEL.NS', 'PNB.NS', 'PNBHOUSING.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'RCF.NS', 'RELIANCE.NS', 'SOBHA.NS', 'SRF.NS', 'SUNTECK.NS', 'THERMAX.NS', 'TITAN.NS', 'TRENT.NS', 'TRIDENT.NS', 'TTKPRESTIG.NS', 'TV18BRDCST.NS', 'TVSMOTOR.NS', 'UCOBANK.NS', 'ULTRACEMCO.NS', 'VAIBHAVGBL.NS', 'VGUARD.NS', 'WELCORP.NS', 'ZEEL.NS', 'ZFCVINDIA.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2018-07-01': ['ABB.NS', 'ABFRL.NS', 'ALKEM.NS', 'ASAHIINDIA.NS', 'ATUL.NS', 'AVANTIFEED.NS', 'AXISBANK.NS', 'BALAMINES.NS', 'BALRAMCHIN.NS', 'BCG.NS', 'BPCL.NS', 'CANBK.NS', 'CCL.NS', 'CENTRALBK.NS', 'CERA.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'COALINDIA.NS', 'DELTACORP.NS', 'DIVISLAB.NS', 'EICHERMOT.NS', 'ESCORTS.NS', 'FACT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FORTIS.NS', 'GAEL.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GRANULES.NS', 'GRASIM.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IGL.NS', 'IIFL.NS', 'INDHOTEL.NS', 'INFIBEAM.NS', 'INGERRAND.NS', 'JAMNAAUTO.NS', 'JINDALSTEL.NS', 'JKPAPER.NS', 'KEC.NS', 'KEI.NS', 'KSB.NS', 'LAURUSLABS.NS', 'LINDEINDIA.NS', 'LT.NS', 'LTTS.NS', 'MASTEK.NS', 'MCX.NS', 'MMTC.NS', 'MUTHOOTFIN.NS', 'NATIONALUM.NS', 'NETWORK18.NS', 'NH.NS', 'NLCINDIA.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'OIL.NS', 'PATANJALI.NS', 'PFC.NS', 'PNBHOUSING.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'SIEMENS.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'SYMPHONY.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TECHM.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'TTKPRESTIG.NS', 'TV18BRDCST.NS', 'UBL.NS', 'UCOBANK.NS', 'VOLTAS.NS', 'WIPRO.NS', 'ZEEL.NS', 'ZFCVINDIA.NS'],
'2018-08-01': ['APOLLOHOSP.NS', 'BAJAJ-AUTO.NS', 'BAYERCROP.NS', 'BIOCON.NS', 'CANFINHOME.NS', 'CCL.NS', 'CERA.NS', 'CHAMBLFERT.NS', 'COALINDIA.NS', 'CYIENT.NS', 'EICHERMOT.NS', 'FACT.NS', 'GNFC.NS', 'HEROMOTOCO.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'INDUSTOWER.NS', 'IRB.NS', 'JMFINANCIL.NS', 'KEC.NS', 'KOTAKBANK.NS', 'KRBL.NS', 'LAURUSLABS.NS', 'LAXMIMACH.NS', 'LINDEINDIA.NS', 'MCDOWELL-N.NS', 'MHRIL.NS', 'NATCOPHARM.NS', 'NBCC.NS', 'NHPC.NS', 'OFSS.NS', 'PATANJALI.NS', 'PHOENIXLTD.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'SCHAEFFLER.NS', 'SKFINDIA.NS', 'SUNTV.NS', 'SWANENERGY.NS', 'TATACONSUM.NS', 'TATAMOTORS.NS', 'TEAMLEASE.NS', 'TV18BRDCST.NS', 'UBL.NS', 'ZEEL.NS'],
'2018-09-01': ['APLAPOLLO.NS', 'AVANTIFEED.NS', 'BCG.NS', 'BLUEDART.NS', 'BPCL.NS', 'BSE.NS', 'CANFINHOME.NS', 'CDSL.NS', 'CHOLAHLDNG.NS', 'DEEPAKFERT.NS', 'FEDERALBNK.NS', 'GNFC.NS', 'GODREJPROP.NS', 'HDFCBANK.NS', 'ICICIPRULI.NS', 'INDUSINDBK.NS', 'IOC.NS', 'JAMNAAUTO.NS', 'JMFINANCIL.NS', 'KEC.NS', 'LAURUSLABS.NS', 'MANAPPURAM.NS', 'MFSL.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTILALOFS.NS', 'POLYMED.NS', 'RAIN.NS', 'RENUKA.NS', 'SOBHA.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SUZLON.NS', 'TATACONSUM.NS', 'TATAMTRDVR.NS', 'TIMKEN.NS', 'TRIVENI.NS', 'TV18BRDCST.NS'],
'2018-10-01': ['AARTIDRUGS.NS', 'AJANTPHARM.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'APARINDS.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BHEL.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'CCL.NS', 'CERA.NS', 'CGCL.NS', 'COALINDIA.NS', 'COLPAL.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FINCABLES.NS', 'FORTIS.NS', 'GMRINFRA.NS', 'GODFRYPHLP.NS', 'GPIL.NS', 'GRANULES.NS', 'GSPL.NS', 'HAVELLS.NS', 'ICICIBANK.NS', 'INDIACEM.NS', 'INDUSTOWER.NS', 'INGERRAND.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JYOTHYLAB.NS', 'KANSAINER.NS', 'KEI.NS', 'LT.NS', 'MARICO.NS', 'MGL.NS', 'MRPL.NS', 'MUTHOOTFIN.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'NETWORK18.NS', 'OLECTRA.NS', 'PERSISTENT.NS', 'PFC.NS', 'PGHL.NS', 'PIDILITIND.NS', 'PRESTIGE.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RTNINDIA.NS', 'SBIN.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATAPOWER.NS', 'TEAMLEASE.NS', 'TEJASNET.NS', 'THERMAX.NS', 'TITAN.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'VBL.NS', 'VINATIORGA.NS', 'VMART.NS', 'VTL.NS', 'WELSPUNLIV.NS'],
'2018-11-01': ['ABCAPITAL.NS', 'ADANIPORTS.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'AUBANK.NS', 'BAJAJFINSV.NS', 'BALAMINES.NS', 'BEML.NS', 'BHEL.NS', 'BLS.NS', 'BLUESTARCO.NS', 'BPCL.NS', 'BSOFT.NS', 'CENTURYPLY.NS', 'CESC.NS', 'COALINDIA.NS', 'DABUR.NS', 'DEEPAKFERT.NS', 'ERIS.NS', 'FDC.NS', 'GNFC.NS', 'GODREJCP.NS', 'GPIL.NS', 'GPPL.NS', 'GUJALKALI.NS', 'GUJGASLTD.NS', 'HINDCOPPER.NS', 'HUDCO.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IIFL.NS', 'INDIACEM.NS', 'INGERRAND.NS', 'ITC.NS', 'ITI.NS', 'JBMA.NS', 'JINDALSTEL.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JSWSTEEL.NS', 'JUBLPHARMA.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'L&TFH.NS', 'LICHSGFIN.NS', 'M&M.NS', 'MAHLIFE.NS', 'MFSL.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'NBCC.NS', 'NETWORK18.NS', 'NTPC.NS', 'ONGC.NS', 'PIDILITIND.NS', 'POONAWALLA.NS', 'PRESTIGE.NS', 'RALLIS.NS', 'RELIANCE.NS', 'SAIL.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SUNDRMFAST.NS', 'SUPREMEIND.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TRENT.NS', 'TRITURBINE.NS', 'TTML.NS', 'ZYDUSLIFE.NS'],
'2018-12-01': ['AARTIDRUGS.NS', 'ABCAPITAL.NS', 'AEGISCHEM.NS', 'ALKEM.NS', 'BALKRISIND.NS', 'BANKBARODA.NS', 'BEL.NS', 'BHARATFORG.NS', 'BSOFT.NS', 'CERA.NS', 'CESC.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'DCMSHRIRAM.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'ENDURANCE.NS', 'EPL.NS', 'ERIS.NS', 'FINCABLES.NS', 'FSL.NS', 'GPPL.NS', 'GRANULES.NS', 'HINDCOPPER.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IDEA.NS', 'INDUSTOWER.NS', 'JAMNAAUTO.NS', 'KPRMILL.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LTIM.NS', 'LUXIND.NS', 'MASTEK.NS', 'MOTILALOFS.NS', 'MRPL.NS', 'NH.NS', 'OFSS.NS', 'PFC.NS', 'PFIZER.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'RAJESHEXPO.NS', 'RCF.NS', 'RELAXO.NS', 'SFL.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SWANENERGY.NS', 'TANLA.NS', 'TATASTEEL.NS', 'TIMKEN.NS', 'TV18BRDCST.NS', 'UNOMINDA.NS', 'ZENSARTECH.NS'],
'2019-01-01': ['APLAPOLLO.NS', 'ASHOKLEY.NS', 'BALKRISIND.NS', 'BCG.NS', 'BHARATFORG.NS', 'CDSL.NS', 'CESC.NS', 'CIPLA.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'FINCABLES.NS', 'HEG.NS', 'INFIBEAM.NS', 'JKPAPER.NS', 'KPRMILL.NS', 'LAXMIMACH.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NLCINDIA.NS', 'OIL.NS', 'PHOENIXLTD.NS', 'QUESS.NS', 'RAIN.NS', 'RAJESHEXPO.NS', 'RELAXO.NS', 'STLTECH.NS', 'SUNPHARMA.NS', 'SWANENERGY.NS', 'TATAMTRDVR.NS', 'TCS.NS', 'TEJASNET.NS', 'TRITURBINE.NS', 'WELCORP.NS'],
'2019-02-01': ['ADANIPORTS.NS', 'ADANIPOWER.NS', 'AEGISCHEM.NS', 'APLAPOLLO.NS', 'AUBANK.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BBTC.NS', 'BEML.NS', 'BHEL.NS', 'BLUESTARCO.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CDSL.NS', 'COCHINSHIP.NS', 'CROMPTON.NS', 'DELTACORP.NS', 'DLF.NS', 'DMART.NS', 'EIDPARRY.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'ERIS.NS', 'ESCORTS.NS', 'FINPIPE.NS', 'FORTIS.NS', 'GAEL.NS', 'GNFC.NS', 'GODREJIND.NS', 'GPIL.NS', 'GUJALKALI.NS', 'HDFCLIFE.NS', 'IDFC.NS', 'IIFL.NS', 'INDIACEM.NS', 'INDIANB.NS', 'IRB.NS', 'JBMA.NS', 'JINDALSTEL.NS', 'JSWSTEEL.NS', 'JYOTHYLAB.NS', 'KSB.NS', 'L&TFH.NS', 'LUXIND.NS', 'MASTEK.NS', 'MCX.NS', 'MFSL.NS', 'NCC.NS', 'NH.NS', 'NTPC.NS', 'ONGC.NS', 'PCBL.NS', 'POLYPLEX.NS', 'PRESTIGE.NS', 'RAIN.NS', 'RALLIS.NS', 'RATNAMANI.NS', 'RHIM.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'SWANENERGY.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAPOWER.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'TVSMOTOR.NS', 'USHAMART.NS', 'VGUARD.NS', 'ZEEL.NS'],
'2019-03-01': ['ADANIENT.NS', 'ALOKINDS.NS', 'BANKINDIA.NS', 'BLS.NS', 'BSOFT.NS', 'CENTRALBK.NS', 'CGCL.NS', 'CGPOWER.NS', 'COCHINSHIP.NS', 'EIDPARRY.NS', 'ENGINERSIN.NS', 'EXIDEIND.NS', 'FORTIS.NS', 'FSL.NS', 'GPPL.NS', 'GSFC.NS', 'GUJGASLTD.NS', 'HFCL.NS', 'HINDALCO.NS', 'IDEA.NS', 'IDFC.NS', 'IEX.NS', 'INFIBEAM.NS', 'JAMNAAUTO.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JYOTHYLAB.NS', 'L&TFH.NS', 'MAHABANK.NS', 'MAHLIFE.NS', 'MMTC.NS', 'MRPL.NS', 'NBCC.NS', 'NHPC.NS', 'NIACL.NS', 'PCBL.NS', 'SAREGAMA.NS', 'STLTECH.NS', 'SUPRAJIT.NS', 'TEJASNET.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TTML.NS', 'UNIONBANK.NS', 'WELSPUNLIV.NS'],
'2019-04-01': ['BSOFT.NS', 'GRAPHITE.NS', 'HEG.NS', 'IDBI.NS', 'IDEA.NS', 'MCDOWELL-N.NS', 'RAIN.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'SHOPERSTOP.NS', 'STLTECH.NS', 'TATAMTRDVR.NS', 'TTML.NS'],
'2019-05-01': ['3MINDIA.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'ALOKINDS.NS', 'APOLLOTYRE.NS', 'BAJAJHLDNG.NS', 'BALKRISIND.NS', 'BAYERCROP.NS', 'BHARATFORG.NS', 'BIOCON.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'CARBORUNIV.NS', 'CEATLTD.NS', 'COLPAL.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'CYIENT.NS', 'DABUR.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'EXIDEIND.NS', 'FACT.NS', 'FINCABLES.NS', 'GLAXO.NS', 'GODREJCP.NS', 'HEROMOTOCO.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'INDUSINDBK.NS', 'JUBLPHARMA.NS', 'JYOTHYLAB.NS', 'LAXMIMACH.NS', 'M&M.NS', 'M&MFIN.NS', 'MARUTI.NS', 'MINDACORP.NS', 'NATCOPHARM.NS', 'NETWORK18.NS', 'NH.NS', 'NIACL.NS', 'PEL.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'SHRIRAMFIN.NS', 'SUNDARMFIN.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TIMKEN.NS', 'USHAMART.NS', 'WHIRLPOOL.NS'],
'2019-06-01': ['AARTIDRUGS.NS', 'ALOKINDS.NS', 'APLLTD.NS', 'BALAMINES.NS', 'BBTC.NS', 'BIOCON.NS', 'CCL.NS', 'CEATLTD.NS', 'COLPAL.NS', 'GICRE.NS', 'GMRINFRA.NS', 'INDUSTOWER.NS', 'IOB.NS', 'ITC.NS', 'JSWSTEEL.NS', 'LAURUSLABS.NS', 'LUPIN.NS', 'MINDACORP.NS', 'POLYMED.NS', 'QUESS.NS', 'RADICO.NS', 'RHIM.NS', 'RTNINDIA.NS', 'SFL.NS', 'SPARC.NS', 'STLTECH.NS', 'SUNPHARMA.NS', 'TATACOMM.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TV18BRDCST.NS', 'USHAMART.NS'],
'2019-07-01': ['AARTIDRUGS.NS', 'ABCAPITAL.NS', 'AEGISCHEM.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'ALOKINDS.NS', 'ASAHIINDIA.NS', 'ASIANPAINT.NS', 'ASTERDM.NS', 'BAJAJ-AUTO.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BAYERCROP.NS', 'BIOCON.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'BSOFT.NS', 'CCL.NS', 'CDSL.NS', 'CEATLTD.NS', 'COLPAL.NS', 'CYIENT.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'ENDURANCE.NS', 'ERIS.NS', 'EXIDEIND.NS', 'GAIL.NS', 'GMRINFRA.NS', 'GRANULES.NS', 'HEG.NS', 'HINDCOPPER.NS', 'IBULHSGFIN.NS', 'IDFC.NS', 'IEX.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'ITC.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JUBLFOOD.NS', 'JYOTHYLAB.NS', 'KRBL.NS', 'LAXMIMACH.NS', 'LEMONTREE.NS', 'LUXIND.NS', 'M&MFIN.NS', 'MARUTI.NS', 'MFSL.NS', 'MGL.NS', 'MINDACORP.NS', 'MRPL.NS', 'OFSS.NS', 'PEL.NS', 'QUESS.NS', 'RELIANCE.NS', 'SCHAEFFLER.NS', 'SUNDRMFAST.NS', 'SUNTECK.NS', 'SUNTV.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TTKPRESTIG.NS', 'UNOMINDA.NS', 'VMART.NS', 'VTL.NS', 'WIPRO.NS', 'ZEEL.NS', 'ZYDUSLIFE.NS'],
'2019-08-01': ['ADANIENT.NS', 'ADANIPORTS.NS', 'ALLCARGO.NS', 'AMBUJACEM.NS', 'ASHOKLEY.NS', 'AVANTIFEED.NS', 'BANKBARODA.NS', 'BCG.NS', 'BLS.NS', 'BSOFT.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'GESHIP.NS', 'GPIL.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'IEX.NS', 'INDIACEM.NS', 'INFIBEAM.NS', 'IOB.NS', 'IOC.NS', 'IRB.NS', 'JINDALSTEL.NS', 'JSL.NS', 'JSWSTEEL.NS', 'KPRMILL.NS', 'KRBL.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NTPC.NS', 'OIL.NS', 'PATANJALI.NS', 'PNB.NS', 'PNCINFRA.NS', 'RAIN.NS', 'RECLTD.NS', 'RTNINDIA.NS', 'SAIL.NS', 'STLTECH.NS', 'SUZLON.NS', 'TATAPOWER.NS', 'TRIDENT.NS', 'TTML.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VEDL.NS', 'VIPIND.NS', 'YESBANK.NS'],
'2019-09-01': ['3MINDIA.NS', 'AARTIDRUGS.NS', 'ABB.NS', 'ABFRL.NS', 'AEGISCHEM.NS', 'ALOKINDS.NS', 'APLLTD.NS', 'ASAHIINDIA.NS', 'ATUL.NS', 'AXISBANK.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BANDHANBNK.NS', 'BAYERCROP.NS', 'BDL.NS', 'BIRLACORPN.NS', 'BLS.NS', 'BORORENEW.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CGCL.NS', 'CHOLAHLDNG.NS', 'DCMSHRIRAM.NS', 'EXIDEIND.NS', 'FINCABLES.NS', 'GICRE.NS', 'GLENMARK.NS', 'GODREJCP.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'HEG.NS', 'HINDCOPPER.NS', 'IBULHSGFIN.NS', 'IEX.NS', 'IIFL.NS', 'ITC.NS', 'ITI.NS', 'JSWSTEEL.NS', 'KAJARIACER.NS', 'KOTAKBANK.NS', 'KRBL.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'LT.NS', 'M&M.NS', 'MOTHERSON.NS', 'NAUKRI.NS', 'NLCINDIA.NS', 'OIL.NS', 'PFC.NS', 'PFIZER.NS', 'PGHH.NS', 'PGHL.NS', 'PNB.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'PRAJIND.NS', 'RAIN.NS', 'SCHAEFFLER.NS', 'SHARDACROP.NS', 'SHRIRAMFIN.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'TANLA.NS', 'TATACOMM.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'VEDL.NS', 'WIPRO.NS'],
'2019-10-01': ['ABCAPITAL.NS', 'AEGISCHEM.NS', 'AUROPHARMA.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BCG.NS', 'BHEL.NS', 'CENTRALBK.NS', 'CESC.NS', 'CGPOWER.NS', 'CUMMINSIND.NS', 'DLF.NS', 'FSL.NS', 'GODREJIND.NS', 'GPIL.NS', 'HEG.NS', 'HFCL.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'INDIACEM.NS', 'IPCALAB.NS', 'IRB.NS', 'JKLAKSHMI.NS', 'KRBL.NS', 'LAXMIMACH.NS', 'LTIM.NS', 'LTTS.NS', 'LUPIN.NS', 'MMTC.NS', 'NBCC.NS', 'NCC.NS', 'NETWORK18.NS', 'NH.NS', 'NHPC.NS', 'NTPC.NS', 'OIL.NS', 'PFC.NS', 'PNB.NS', 'POLYPLEX.NS', 'PRSMJOHNSN.NS', 'RAJESHEXPO.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'SAIL.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SOBHA.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'TANLA.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TEJASNET.NS', 'TTML.NS', 'WIPRO.NS'],
'2019-11-01': ['BLS.NS', 'CIEINDIA.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'GLENMARK.NS', 'INDIANB.NS', 'INFY.NS', 'JBCHEPHARM.NS', 'JKLAKSHMI.NS', 'JUSTDIAL.NS', 'KARURVYSYA.NS', 'MARICO.NS', 'PATANJALI.NS', 'PNCINFRA.NS', 'POONAWALLA.NS', 'SAREGAMA.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SOLARINDS.NS', 'STLTECH.NS', 'SUZLON.NS', 'TANLA.NS', 'UBL.NS', 'ZEEL.NS'],
'2019-12-01': ['ALLCARGO.NS', 'APOLLOTYRE.NS', 'ASIANPAINT.NS', 'AUROPHARMA.NS', 'BAJAJHLDNG.NS', 'BATAINDIA.NS', 'BBTC.NS', 'BEL.NS', 'BSE.NS', 'CCL.NS', 'CENTURYTEX.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'ELGIEQUIP.NS', 'FSL.NS', 'GALAXYSURF.NS', 'GNFC.NS', 'GODREJPROP.NS', 'GRINDWELL.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HFCL.NS', 'HINDPETRO.NS', 'INDIGO.NS', 'INFY.NS', 'IOC.NS', 'ITC.NS', 'JUSTDIAL.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'MHRIL.NS', 'MPHASIS.NS', 'MRPL.NS', 'NTPC.NS', 'OIL.NS', 'OLECTRA.NS', 'ONGC.NS', 'PIDILITIND.NS', 'PNBHOUSING.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'SHOPERSTOP.NS', 'SIEMENS.NS', 'SOBHA.NS', 'STLTECH.NS', 'SUNTECK.NS', 'SWANENERGY.NS', 'SYNGENE.NS', 'TCS.NS', 'THERMAX.NS', 'TITAN.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'TTKPRESTIG.NS', 'VARROC.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'VMART.NS', 'ZENSARTECH.NS'],
'2020-01-01': ['ABB.NS', 'ACC.NS', 'ADANIPORTS.NS', 'AMBUJACEM.NS', 'APOLLOTYRE.NS', 'BANDHANBNK.NS', 'BBTC.NS', 'BDL.NS', 'BEL.NS', 'BLS.NS', 'BRITANNIA.NS', 'CASTROLIND.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CESC.NS', 'CROMPTON.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'FINPIPE.NS', 'FORTIS.NS', 'FSL.NS', 'GAEL.NS', 'GICRE.NS', 'GSFC.NS', 'HAL.NS', 'HAVELLS.NS', 'HINDPETRO.NS', 'HUDCO.NS', 'ICICIPRULI.NS', 'INDHOTEL.NS', 'INDIGO.NS', 'IOC.NS', 'ITC.NS', 'JINDALSAW.NS', 'JSWENERGY.NS', 'KEI.NS', 'LT.NS', 'M&MFIN.NS', 'MARICO.NS', 'MRPL.NS', 'NBCC.NS', 'NETWORK18.NS', 'NIACL.NS', 'OIL.NS', 'OLECTRA.NS', 'PETRONET.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RAJESHEXPO.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'RCF.NS', 'SFL.NS', 'SOBHA.NS', 'STLTECH.NS', 'TTKPRESTIG.NS', 'TV18BRDCST.NS', 'UNIONBANK.NS', 'USHAMART.NS', 'VARROC.NS', 'VOLTAS.NS', 'YESBANK.NS', 'ZENSARTECH.NS'],
'2020-02-01': ['ADANIPORTS.NS', 'APARINDS.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BDL.NS', 'BHEL.NS', 'BPCL.NS', 'CANBK.NS', 'CESC.NS', 'CGPOWER.NS', 'COCHINSHIP.NS', 'CRISIL.NS', 'DCMSHRIRAM.NS', 'DELTACORP.NS', 'EICHERMOT.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'GAIL.NS', 'GESHIP.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GUJALKALI.NS', 'HDFCBANK.NS', 'ICICIGI.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDIANB.NS', 'IOB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JSWSTEEL.NS', 'KANSAINER.NS', 'LAXMIMACH.NS', 'LEMONTREE.NS', 'LUPIN.NS', 'MARUTI.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NMDC.NS', 'NTPC.NS', 'PETRONET.NS', 'PGHH.NS', 'PNBHOUSING.NS', 'POWERGRID.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RENUKA.NS', 'SANOFI.NS', 'SKFINDIA.NS', 'TATASTEEL.NS', 'TCS.NS', 'TEJASNET.NS', 'TRIDENT.NS', 'USHAMART.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZENSARTECH.NS'],
'2020-03-01': ['ADANIGREEN.NS', 'BCG.NS', 'BLS.NS', 'CENTURYTEX.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'COCHINSHIP.NS', 'CUB.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DEEPAKFERT.NS', 'DLF.NS', 'ECLERX.NS', 'EIHOTEL.NS', 'GAIL.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODREJIND.NS', 'GPIL.NS', 'GSPL.NS', 'HAL.NS', 'IDEA.NS', 'IDFC.NS', 'INDIGO.NS', 'INDUSTOWER.NS', 'IRB.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'KNRCON.NS', 'KRBL.NS', 'LEMONTREE.NS', 'LINDEINDIA.NS', 'MHRIL.NS', 'MMTC.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RBLBANK.NS', 'RENUKA.NS', 'SJVN.NS', 'SPARC.NS', 'TANLA.NS', 'TATACONSUM.NS', 'TRIDENT.NS', 'TV18BRDCST.NS', 'USHAMART.NS', 'VGUARD.NS', 'VIPIND.NS', 'WELSPUNLIV.NS', 'YESBANK.NS'],
'2020-04-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'ABB.NS', 'AEGISCHEM.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BAYERCROP.NS', 'BDL.NS', 'BORORENEW.NS', 'BSOFT.NS', 'CCL.NS', 'CDSL.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'COFORGE.NS', 'CRISIL.NS', 'CROMPTON.NS', 'DEEPAKFERT.NS', 'EIDPARRY.NS', 'ENGINERSIN.NS', 'FINPIPE.NS', 'FORTIS.NS', 'GAEL.NS', 'GAIL.NS', 'GESHIP.NS', 'GLENMARK.NS', 'GNFC.NS', 'GPPL.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HAL.NS', 'IDEA.NS', 'INDUSTOWER.NS', 'JBMA.NS', 'KANSAINER.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'LUPIN.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NH.NS', 'NTPC.NS', 'OFSS.NS', 'OIL.NS', 'ONGC.NS', 'PEL.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PIIND.NS', 'POLYMED.NS', 'SFL.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TECHM.NS', 'TRENT.NS', 'TRIDENT.NS', 'TV18BRDCST.NS', 'USHAMART.NS', 'VINATIORGA.NS', 'YESBANK.NS'],
'2020-05-01': ['AAVAS.NS', 'ABB.NS', 'ABCAPITAL.NS', 'ADANIENT.NS', 'ADANIPOWER.NS', 'AMBER.NS', 'APOLLOTYRE.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BALRAMCHIN.NS', 'BHEL.NS', 'BLUESTARCO.NS', 'BORORENEW.NS', 'CARBORUNIV.NS', 'CERA.NS', 'CHOLAFIN.NS', 'COCHINSHIP.NS', 'CUMMINSIND.NS', 'DALBHARAT.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'ENDURANCE.NS', 'FEDERALBNK.NS', 'FINPIPE.NS', 'GMRINFRA.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GRASIM.NS', 'GSFC.NS', 'HAL.NS', 'IDBI.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'INDUSINDBK.NS', 'INTELLECT.NS', 'IOC.NS', 'JAMNAAUTO.NS', 'JMFINANCIL.NS', 'KAJARIACER.NS', 'KEC.NS', 'KEI.NS', 'LAXMIMACH.NS', 'M&MFIN.NS', 'MOTILALOFS.NS', 'NAM-INDIA.NS', 'NBCC.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RAMCOCEM.NS', 'RBLBANK.NS', 'REDINGTON.NS', 'RHIM.NS', 'RITES.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SUPRAJIT.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'TEJASNET.NS', 'THERMAX.NS', 'UBL.NS', 'USHAMART.NS', 'VOLTAS.NS', 'WELSPUNLIV.NS'],
'2020-06-01': ['ABCAPITAL.NS', 'ALLCARGO.NS', 'BLS.NS', 'BLUESTARCO.NS', 'BORORENEW.NS', 'BSE.NS', 'CANBK.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CESC.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'ENGINERSIN.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'FSL.NS', 'GAEL.NS', 'GESHIP.NS', 'GNFC.NS', 'GPIL.NS', 'GRAPHITE.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HFCL.NS', 'HINDPETRO.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'INTELLECT.NS', 'IOB.NS', 'IRB.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JKPAPER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JYOTHYLAB.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'L&TFH.NS', 'MINDACORP.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NCC.NS', 'NHPC.NS', 'NLCINDIA.NS', 'OIL.NS', 'PCBL.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RBLBANK.NS', 'RECLTD.NS', 'RENUKA.NS', 'RVNL.NS', 'SJVN.NS', 'SOBHA.NS', 'SWANENERGY.NS', 'TATAMTRDVR.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'UCOBANK.NS', 'USHAMART.NS', 'YESBANK.NS', 'ZENSARTECH.NS'],
'2020-07-01': ['AARTIIND.NS', 'ABBOTINDIA.NS', 'AJANTPHARM.NS', 'ASHOKLEY.NS', 'BATAINDIA.NS', 'BHARATFORG.NS', 'BLUESTARCO.NS', 'CERA.NS', 'CHALET.NS', 'COALINDIA.NS', 'CUB.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'EIHOTEL.NS', 'ERIS.NS', 'EXIDEIND.NS', 'FINEORG.NS', 'GRAPHITE.NS', 'GRINDWELL.NS', 'HDFCAMC.NS', 'HEG.NS', 'IGL.NS', 'KSB.NS', 'METROPOLIS.NS', 'NH.NS', 'PFIZER.NS', 'PIDILITIND.NS', 'PIIND.NS', 'RAJESHEXPO.NS', 'RELAXO.NS', 'SHOPERSTOP.NS', 'TORNTPHARM.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'VTL.NS', 'YESBANK.NS'],
'2020-08-01': ['ABCAPITAL.NS', 'APARINDS.NS', 'BCG.NS', 'CESC.NS', 'CHALET.NS', 'DMART.NS', 'ENGINERSIN.NS', 'GODFRYPHLP.NS', 'GRAPHITE.NS', 'GUJALKALI.NS', 'HEG.NS', 'HONAUT.NS', 'IGL.NS', 'IIFL.NS', 'INDIACEM.NS', 'INDUSTOWER.NS', 'INGERRAND.NS', 'KPRMILL.NS', 'MRF.NS', 'NAM-INDIA.NS', 'NTPC.NS', 'OLECTRA.NS', 'PRAJIND.NS', 'RAJESHEXPO.NS', 'RAYMOND.NS', 'RELAXO.NS', 'TATAMTRDVR.NS', 'TRITURBINE.NS', 'UBL.NS', 'VGUARD.NS', 'ZEEL.NS'],
'2020-09-01': ['ALOKINDS.NS', 'BORORENEW.NS', 'CASTROLIND.NS', 'CESC.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FINCABLES.NS', 'GAIL.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'INDIACEM.NS', 'IOC.NS', 'JKPAPER.NS', 'JUSTDIAL.NS', 'KRBL.NS', 'MANAPPURAM.NS', 'MMTC.NS', 'MRPL.NS', 'NETWORK18.NS', 'OIL.NS', 'PETRONET.NS', 'RCF.NS', 'RECLTD.NS', 'SHARDACROP.NS', 'SUZLON.NS', 'TRIDENT.NS', 'TV18BRDCST.NS', 'YESBANK.NS'],
'2020-10-01': ['3MINDIA.NS', 'ABB.NS', 'APARINDS.NS', 'BAJAJHLDNG.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BDL.NS', 'BEL.NS', 'BEML.NS', 'BLS.NS', 'BORORENEW.NS', 'CANBK.NS', 'CHALET.NS', 'CONCOR.NS', 'ENGINERSIN.NS', 'FEDERALBNK.NS', 'GAIL.NS', 'GESHIP.NS', 'HAL.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'IGL.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'INGERRAND.NS', 'IOB.NS', 'IRCON.NS', 'JKPAPER.NS', 'KARURVYSYA.NS', 'KEI.NS', 'KOTAKBANK.NS', 'KSB.NS', 'MAHABANK.NS', 'MCDOWELL-N.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NETWORK18.NS', 'NHPC.NS', 'NIACL.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NTPC.NS', 'OIL.NS', 'OLECTRA.NS', 'ONGC.NS', 'ORIENTELEC.NS', 'PEL.NS', 'PETRONET.NS', 'PFC.NS', 'POWERGRID.NS', 'RCF.NS', 'RECLTD.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'RVNL.NS', 'SAIL.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SFL.NS', 'SHARDACROP.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'TATASTEEL.NS', 'THERMAX.NS', 'TORNTPOWER.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UBL.NS', 'UCOBANK.NS'],
'2020-11-01': ['AARTIDRUGS.NS', 'ALOKINDS.NS', 'AVANTIFEED.NS', 'BANKINDIA.NS', 'BCG.NS', 'BEL.NS', 'BHEL.NS', 'BLS.NS', 'CANBK.NS', 'CESC.NS', 'COALINDIA.NS', 'ELGIEQUIP.NS', 'FEDERALBNK.NS', 'GAIL.NS', 'GRAPHITE.NS', 'HEG.NS', 'HINDCOPPER.NS', 'HUDCO.NS', 'IDEA.NS', 'INDIANB.NS', 'IOB.NS', 'IRCON.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JKPAPER.NS', 'JYOTHYLAB.NS', 'KPITTECH.NS', 'KRBL.NS', 'MAHABANK.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NHPC.NS', 'NLCINDIA.NS', 'OIL.NS', 'OLECTRA.NS', 'ONGC.NS', 'PATANJALI.NS', 'PNB.NS', 'RCF.NS', 'RVNL.NS', 'SUNTV.NS', 'TATAPOWER.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'USHAMART.NS', 'VEDL.NS', 'YESBANK.NS'],
'2020-12-01': ['ABBOTINDIA.NS', 'AJANTPHARM.NS', 'BAYERCROP.NS', 'BCG.NS', 'BLS.NS', 'BPCL.NS', 'CESC.NS', 'CIPLA.NS', 'DABUR.NS', 'GLENMARK.NS', 'INFIBEAM.NS', 'KRBL.NS', 'LUPIN.NS', 'MCX.NS', 'MUTHOOTFIN.NS', 'NETWORK18.NS', 'OFSS.NS', 'POLYPLEX.NS', 'RAJESHEXPO.NS', 'RELIANCE.NS', 'RTNINDIA.NS', 'TORNTPHARM.NS', 'UPL.NS'],
'2021-01-01': ['3MINDIA.NS', 'AARTIDRUGS.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'AUBANK.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'CEATLTD.NS', 'CRISIL.NS', 'EPL.NS', 'ESCORTS.NS', 'FDC.NS', 'FINEORG.NS', 'GLENMARK.NS', 'GRANULES.NS', 'IPCALAB.NS', 'JKCEMENT.NS', 'KRBL.NS', 'METROPOLIS.NS', 'MOTILALOFS.NS', 'PFIZER.NS', 'PIIND.NS', 'POLYPLEX.NS', 'PRESTIGE.NS', 'RAMCOCEM.NS', 'RELIANCE.NS', 'TRENT.NS', 'ZFCVINDIA.NS'],
'2021-02-01': ['AARTIDRUGS.NS', 'ABCAPITAL.NS', 'ALOKINDS.NS', 'BLUESTARCO.NS', 'CGPOWER.NS', 'COALINDIA.NS', 'ENGINERSIN.NS', 'GICRE.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GPPL.NS', 'GUJALKALI.NS', 'HINDALCO.NS', 'IBULHSGFIN.NS', 'INFIBEAM.NS', 'ITI.NS', 'JINDALSAW.NS', 'JUSTDIAL.NS', 'KANSAINER.NS', 'KARURVYSYA.NS', 'MANAPPURAM.NS', 'MOTHERSON.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NTPC.NS', 'ONGC.NS', 'PATANJALI.NS', 'PFC.NS', 'PNBHOUSING.NS', 'POLYPLEX.NS', 'RBLBANK.NS', 'RENUKA.NS', 'RHIM.NS', 'SAIL.NS', 'SUNDARMFIN.NS', 'SUNTECK.NS', 'TATASTEEL.NS', 'TV18BRDCST.NS', 'USHAMART.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'YESBANK.NS'],
'2021-03-01': ['ABBOTINDIA.NS', 'AIAENG.NS', 'ALKEM.NS', 'APLLTD.NS', 'AUROPHARMA.NS', 'AVANTIFEED.NS', 'BALKRISIND.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BIOCON.NS', 'BRITANNIA.NS', 'BSOFT.NS', 'CCL.NS', 'CHALET.NS', 'CIPLA.NS', 'CREDITACC.NS', 'DABUR.NS', 'EICHERMOT.NS', 'EPL.NS', 'FINEORG.NS', 'GILLETTE.NS', 'GLENMARK.NS', 'GODFRYPHLP.NS', 'GRANULES.NS', 'GUJALKALI.NS', 'HCLTECH.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'IGL.NS', 'IPCALAB.NS', 'ISEC.NS', 'KOTAKBANK.NS', 'KRBL.NS', 'LTIM.NS', 'MARICO.NS', 'MCX.NS', 'METROPOLIS.NS', 'NATCOPHARM.NS', 'NH.NS', 'OFSS.NS', 'PFIZER.NS', 'PGHL.NS', 'PIDILITIND.NS', 'RITES.NS', 'RTNINDIA.NS', 'SYNGENE.NS', 'TCS.NS', 'TECHM.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'UBL.NS', 'ZEEL.NS', 'ZYDUSLIFE.NS'],
'2021-04-01': ['ALOKINDS.NS', 'HFCL.NS', 'IDEA.NS', 'JSL.NS', 'PATANJALI.NS', 'RENUKA.NS', 'SUZLON.NS', 'TTML.NS', 'YESBANK.NS'],
'2021-05-01': ['360ONE.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BCG.NS', 'BLS.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CANBK.NS', 'CENTRALBK.NS', 'CHAMBLFERT.NS', 'DELTACORP.NS', 'ENGINERSIN.NS', 'FINCABLES.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IDFCFIRSTB.NS', 'INDIACEM.NS', 'INDIANB.NS', 'IOB.NS', 'IRB.NS', 'KANSAINER.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'KRBL.NS', 'LEMONTREE.NS', 'MANAPPURAM.NS', 'MHRIL.NS', 'NBCC.NS', 'NCC.NS', 'NIACL.NS', 'NTPC.NS', 'PFC.NS', 'PNB.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'RECLTD.NS', 'RITES.NS', 'RVNL.NS', 'SHOPERSTOP.NS', 'SJVN.NS', 'SUPRAJIT.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TRIDENT.NS', 'UNIONBANK.NS', 'VGUARD.NS', 'VTL.NS', 'YESBANK.NS', 'ZENSARTECH.NS'],
'2021-06-01': ['CEATLTD.NS', 'CUMMINSIND.NS', 'GRANULES.NS', 'IIFL.NS', 'INDIAMART.NS', 'INDUSTOWER.NS', 'LINDEINDIA.NS', 'NAUKRI.NS', 'OLECTRA.NS', 'PGHL.NS', 'SYMPHONY.NS', 'YESBANK.NS'],
'2021-07-01': ['AARTIDRUGS.NS', 'ABCAPITAL.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'BHARTIARTL.NS', 'BLUESTARCO.NS', 'COCHINSHIP.NS', 'DLF.NS', 'ELGIEQUIP.NS', 'ENGINERSIN.NS', 'EXIDEIND.NS', 'GAIL.NS', 'GRAPHITE.NS', 'HAVELLS.NS', 'HEROMOTOCO.NS', 'HINDCOPPER.NS', 'IDFCFIRSTB.NS', 'INDIAMART.NS', 'INDUSTOWER.NS', 'IPCALAB.NS', 'ITC.NS', 'KARURVYSYA.NS', 'LUPIN.NS', 'M&M.NS', 'M&MFIN.NS', 'MGL.NS', 'MRF.NS', 'PAGEIND.NS', 'PETRONET.NS', 'SANOFI.NS', 'SBICARD.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SOBHA.NS', 'SUVENPHAR.NS', 'TANLA.NS', 'TIINDIA.NS', 'VAIBHAVGBL.NS', 'VARROC.NS', 'WELCORP.NS', 'YESBANK.NS'],
'2021-08-01': ['3MINDIA.NS', 'AAVAS.NS', 'ABCAPITAL.NS', 'ADANIPORTS.NS', 'AEGISCHEM.NS', 'AIAENG.NS', 'ATGL.NS', 'AUROPHARMA.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BBTC.NS', 'BIOCON.NS', 'BLUEDART.NS', 'BPCL.NS', 'BRITANNIA.NS', 'CASTROLIND.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'CONCOR.NS', 'CREDITACC.NS', 'DIXON.NS', 'EICHERMOT.NS', 'EPL.NS', 'EXIDEIND.NS', 'GLENMARK.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HINDUNILVR.NS', 'HINDZINC.NS', 'ICICIGI.NS', 'INDIAMART.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'KOTAKBANK.NS', 'L&TFH.NS', 'LUPIN.NS', 'M&M.NS', 'M&MFIN.NS', 'MARUTI.NS', 'MRF.NS', 'NATCOPHARM.NS', 'PETRONET.NS', 'PGHH.NS', 'RELIANCE.NS', 'SIEMENS.NS', 'SUNDRMFAST.NS', 'SUPREMEIND.NS', 'TCS.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TVSMOTOR.NS', 'WELCORP.NS', 'ZYDUSLIFE.NS'],
'2021-09-01': ['AAVAS.NS', 'ABCAPITAL.NS', 'AUBANK.NS', 'AVANTIFEED.NS', 'BANDHANBNK.NS', 'BANKINDIA.NS', 'BIOCON.NS', 'CENTRALBK.NS', 'CGCL.NS', 'COCHINSHIP.NS', 'COROMANDEL.NS', 'DRREDDY.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'EPL.NS', 'FACT.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'FSL.NS', 'GNFC.NS', 'GPIL.NS', 'GRANULES.NS', 'HUDCO.NS', 'IDEA.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'IOB.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'KARURVYSYA.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'LICHSGFIN.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MRPL.NS', 'NATCOPHARM.NS', 'NBCC.NS', 'NCC.NS', 'NLCINDIA.NS', 'NMDC.NS', 'PNB.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'SAIL.NS', 'SJVN.NS', 'STLTECH.NS', 'SUZLON.NS', 'TATAMOTORS.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UPL.NS', 'VINATIORGA.NS', 'WELCORP.NS', 'ZYDUSLIFE.NS'],
'2021-10-01': ['ACC.NS', 'AIAENG.NS', 'ALKYLAMINE.NS', 'AMBUJACEM.NS', 'APLAPOLLO.NS', 'AXISBANK.NS', 'BANDHANBNK.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'CCL.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'ENDURANCE.NS', 'GICRE.NS', 'GODREJCP.NS', 'GRAPHITE.NS', 'GSPL.NS', 'IGL.NS', 'INFIBEAM.NS', 'JINDALSAW.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JSWSTEEL.NS', 'JUBLPHARMA.NS', 'KNRCON.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'MFSL.NS', 'MGL.NS', 'MUTHOOTFIN.NS', 'NAVINFLUOR.NS', 'NH.NS', 'PNBHOUSING.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'PRSMJOHNSN.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'REDINGTON.NS', 'RELAXO.NS', 'RTNINDIA.NS', 'SAIL.NS', 'SBICARD.NS', 'SHRIRAMFIN.NS', 'SUMICHEM.NS', 'SUNDARMFIN.NS', 'SWANENERGY.NS', 'TATACONSUM.NS', 'TATASTEEL.NS', 'UJJIVANSFB.NS', 'ULTRACEMCO.NS', 'ZYDUSLIFE.NS'],
'2021-11-01': ['ADANIENT.NS', 'ADANIPORTS.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'ASTERDM.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BALRAMCHIN.NS', 'BPCL.NS', 'CENTURYTEX.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CSBBANK.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DEEPAKNTR.NS', 'DRREDDY.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'EXIDEIND.NS', 'FORTIS.NS', 'GAEL.NS', 'GALAXYSURF.NS', 'GESHIP.NS', 'GODREJCP.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GSPL.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HONAUT.NS', 'IBULHSGFIN.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'INDIAMART.NS', 'INTELLECT.NS', 'JBCHEPHARM.NS', 'JMFINANCIL.NS', 'JUBLFOOD.NS', 'JUBLPHARMA.NS', 'JYOTHYLAB.NS', 'KNRCON.NS', 'KPITTECH.NS', 'L&TFH.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'LUPIN.NS', 'LUXIND.NS', 'MASTEK.NS', 'MFSL.NS', 'MMTC.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NAUKRI.NS', 'NIACL.NS', 'OFSS.NS', 'PIDILITIND.NS', 'PIIND.NS', 'PNCINFRA.NS', 'POWERINDIA.NS', 'PRSMJOHNSN.NS', 'ROUTE.NS', 'RTNINDIA.NS', 'SUMICHEM.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUVENPHAR.NS', 'TATACOMM.NS', 'TORNTPHARM.NS', 'WELSPUNLIV.NS'],
'2021-12-01': ['360ONE.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'ADANIPORTS.NS', 'AJANTPHARM.NS', 'ALOKINDS.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'AUROPHARMA.NS', 'BAJFINANCE.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BATAINDIA.NS', 'BERGEPAINT.NS', 'BHEL.NS', 'BLS.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'CANFINHOME.NS', 'CASTROLIND.NS', 'CENTURYTEX.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'CONCOR.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DALBHARAT.NS', 'DCMSHRIRAM.NS', 'DELTACORP.NS', 'DLF.NS', 'FACT.NS', 'FEDERALBNK.NS', 'FSL.NS', 'GAEL.NS', 'GODREJCP.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GPPL.NS', 'GRANULES.NS', 'GRASIM.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HDFCLIFE.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIANB.NS', 'INDIGO.NS', 'INTELLECT.NS', 'IOC.NS', 'ITC.NS', 'ITI.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JUBLFOOD.NS', 'KARURVYSYA.NS', 'KEC.NS', 'KRBL.NS', 'LT.NS', 'LUPIN.NS', 'M&M.NS', 'MAHABANK.NS', 'MARICO.NS', 'MARUTI.NS', 'MAZDOCK.NS', 'MCX.NS', 'MFSL.NS', 'MHRIL.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MRF.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NIACL.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'PATANJALI.NS', 'PEL.NS', 'PETRONET.NS', 'PNB.NS', 'PNCINFRA.NS', 'PRAJIND.NS', 'RAIN.NS', 'RBLBANK.NS', 'RCF.NS', 'RECLTD.NS', 'RENUKA.NS', 'ROUTE.NS', 'SBIN.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPREMEIND.NS', 'SUVENPHAR.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'TRENT.NS', 'UCOBANK.NS', 'VINATIORGA.NS', 'WESTLIFE.NS', 'WHIRLPOOL.NS', 'YESBANK.NS'],
'2022-01-01': ['360ONE.NS', 'ADANIPOWER.NS', 'ASHOKLEY.NS', 'BANKBARODA.NS', 'BHEL.NS', 'BLS.NS', 'CANBK.NS', 'CENTRALBK.NS', 'CHALET.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'EQUITASBNK.NS', 'GAIL.NS', 'GPPL.NS', 'GSPL.NS', 'HINDPETRO.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'IIFL.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'IOB.NS', 'IRCON.NS', 'ITC.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'KARURVYSYA.NS', 'KRBL.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'LICHSGFIN.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MRPL.NS', 'NCC.NS', 'NHPC.NS', 'NIACL.NS', 'NTPC.NS', 'PETRONET.NS', 'PFC.NS', 'PNB.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RITES.NS', 'RTNINDIA.NS', 'SAIL.NS', 'TATASTEEL.NS', 'UCOBANK.NS', 'UJJIVANSFB.NS', 'UNIONBANK.NS'],
'2022-02-01': ['AARTIDRUGS.NS', 'AEGISCHEM.NS', 'ALLCARGO.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'AUROPHARMA.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BERGEPAINT.NS', 'BIRLACORPN.NS', 'CAMS.NS', 'CEATLTD.NS', 'CENTURYPLY.NS', 'CIEINDIA.NS', 'COFORGE.NS', 'CRISIL.NS', 'CYIENT.NS', 'DALBHARAT.NS', 'DEEPAKNTR.NS', 'ECLERX.NS', 'ENDURANCE.NS', 'EPL.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'FINCABLES.NS', 'FSL.NS', 'GLAND.NS', 'GODREJCP.NS', 'GODREJPROP.NS', 'GRANULES.NS', 'HINDUNILVR.NS', 'IBULHSGFIN.NS', 'ICICIGI.NS', 'IDEA.NS', 'IEX.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INFY.NS', 'ISEC.NS', 'JKLAKSHMI.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'KRBL.NS', 'L&TFH.NS', 'LTIM.NS', 'LTTS.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'MASTEK.NS', 'MAXHEALTH.NS', 'MCX.NS', 'MOTILALOFS.NS', 'MRF.NS', 'NAM-INDIA.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'PATANJALI.NS', 'PEL.NS', 'PETRONET.NS', 'PGHH.NS', 'PIDILITIND.NS', 'PRINCEPIPE.NS', 'RADICO.NS', 'RALLIS.NS', 'RATNAMANI.NS', 'ROSSARI.NS', 'SAIL.NS', 'SKFINDIA.NS', 'SONATSOFTW.NS', 'SUPREMEIND.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TATASTEEL.NS', 'TITAN.NS', 'TRENT.NS', 'TTML.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'VGUARD.NS', 'VOLTAS.NS', 'WESTLIFE.NS', 'ZEEL.NS', 'ZFCVINDIA.NS'],
'2022-03-01': ['ABCAPITAL.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'BANKINDIA.NS', 'BHEL.NS', 'BPCL.NS', 'CESC.NS', 'CIEINDIA.NS', 'CSBBANK.NS', 'ENGINERSIN.NS', 'EQUITASBNK.NS', 'EXIDEIND.NS', 'FACT.NS', 'FDC.NS', 'FORTIS.NS', 'FSL.NS', 'HINDPETRO.NS', 'IDBI.NS', 'IDEA.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'IOB.NS', 'IRB.NS', 'JINDALSAW.NS', 'L&TFH.NS', 'LICHSGFIN.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MAZDOCK.NS', 'MOTHERSON.NS', 'MRPL.NS', 'NBCC.NS', 'NCC.NS', 'NETWORK18.NS', 'NHPC.NS', 'PNB.NS', 'PNBHOUSING.NS', 'PRSMJOHNSN.NS', 'RAIN.NS', 'RBLBANK.NS', 'RCF.NS', 'RTNINDIA.NS', 'RVNL.NS', 'SPARC.NS', 'TATAMTRDVR.NS', 'TRIDENT.NS', 'UCOBANK.NS', 'UJJIVANSFB.NS', 'UNIONBANK.NS'],
'2022-04-01': ['ABCAPITAL.NS', 'ALOKINDS.NS', 'APOLLOTYRE.NS', 'BANKINDIA.NS', 'BHEL.NS', 'BIOCON.NS', 'CENTRALBK.NS', 'CESC.NS', 'COCHINSHIP.NS', 'CROMPTON.NS', 'CSBBANK.NS', 'ENGINERSIN.NS', 'EQUITASBNK.NS', 'EXIDEIND.NS', 'FINPIPE.NS', 'FSL.NS', 'GICRE.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'IDEA.NS', 'IDFCFIRSTB.NS', 'IIFL.NS', 'INFIBEAM.NS', 'IOB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JINDALSAW.NS', 'KARURVYSYA.NS', 'KRBL.NS', 'MAZDOCK.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MRPL.NS', 'NHPC.NS', 'NLCINDIA.NS', 'PNB.NS', 'PRSMJOHNSN.NS', 'RALLIS.NS', 'RBLBANK.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RTNINDIA.NS', 'RVNL.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SUNTECK.NS', 'SUZLON.NS', 'SWSOLAR.NS', 'TATAMTRDVR.NS', 'UCOBANK.NS', 'UNIONBANK.NS'],
'2022-05-01': ['AARTIDRUGS.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'BANKINDIA.NS', 'BCG.NS', 'BHEL.NS', 'CENTRALBK.NS', 'CSBBANK.NS', 'ENGINERSIN.NS', 'EPL.NS', 'EXIDEIND.NS', 'FACT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'FSL.NS', 'GMRINFRA.NS', 'HFCL.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'IDEA.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDIACEM.NS', 'INFIBEAM.NS', 'IOB.NS', 'IRB.NS', 'IRCON.NS', 'ITI.NS', 'JINDALSAW.NS', 'KARURVYSYA.NS', 'KEC.NS', 'MAHABANK.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NAM-INDIA.NS', 'NBCC.NS', 'NETWORK18.NS', 'OIL.NS', 'PCBL.NS', 'PNB.NS', 'RECLTD.NS', 'RTNINDIA.NS', 'RVNL.NS', 'SAIL.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SUZLON.NS', 'TATASTEEL.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TTML.NS', 'UCOBANK.NS', 'UNOMINDA.NS', 'VGUARD.NS', 'YESBANK.NS', 'ZYDUSLIFE.NS'],
'2022-06-01': ['ABCAPITAL.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'BANKBARODA.NS', 'BCG.NS', 'CESC.NS', 'EIHOTEL.NS', 'EXIDEIND.NS', 'FEDERALBNK.NS', 'FSL.NS', 'GAIL.NS', 'GPPL.NS', 'GSPL.NS', 'HFCL.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'IOC.NS', 'IRB.NS', 'IRCON.NS', 'ITI.NS', 'JINDALSAW.NS', 'JMFINANCIL.NS', 'KARURVYSYA.NS', 'KRBL.NS', 'L&TFH.NS', 'MHRIL.NS', 'MMTC.NS', 'NAM-INDIA.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NETWORK18.NS', 'ONGC.NS', 'PCBL.NS', 'PNB.NS', 'PRSMJOHNSN.NS', 'RBLBANK.NS', 'RECLTD.NS', 'RVNL.NS', 'SJVN.NS', 'STLTECH.NS', 'SUZLON.NS', 'TRIDENT.NS', 'TTML.NS', 'UCOBANK.NS', 'UJJIVANSFB.NS', 'USHAMART.NS', 'VARROC.NS', 'YESBANK.NS'],
'2022-07-01': ['AARTIIND.NS', 'ABFRL.NS', 'ADANIPORTS.NS', 'AMBER.NS', 'ANGELONE.NS', 'APOLLOTYRE.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'AXISBANK.NS', 'BAJFINANCE.NS', 'BALRAMCHIN.NS', 'BERGEPAINT.NS', 'BHEL.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BPCL.NS', 'CANBK.NS', 'CEATLTD.NS', 'CESC.NS', 'CHOLAHLDNG.NS', 'COLPAL.NS', 'CONCOR.NS', 'CYIENT.NS', 'DMART.NS', 'ECLERX.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'EPL.NS', 'EXIDEIND.NS', 'FINPIPE.NS', 'GAIL.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HAPPSTMNDS.NS', 'HAVELLS.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'IDFCFIRSTB.NS', 'INDIACEM.NS', 'INDIGO.NS', 'JINDALSAW.NS', 'KOTAKBANK.NS', 'L&TFH.NS', 'LUPIN.NS', 'MAHABANK.NS', 'MARICO.NS', 'MASTEK.NS', 'MAZDOCK.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NLCINDIA.NS', 'PEL.NS', 'PFIZER.NS', 'PNB.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'RAIN.NS', 'RCF.NS', 'RELAXO.NS', 'RITES.NS', 'RVNL.NS', 'SAIL.NS', 'SAREGAMA.NS', 'STLTECH.NS', 'SUVENPHAR.NS', 'SWSOLAR.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAPOWER.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TV18BRDCST.NS', 'UNIONBANK.NS', 'UTIAMC.NS', 'VARROC.NS', 'VTL.NS', 'ZEEL.NS', 'ZENSARTECH.NS'],
'2022-08-01': ['AARTIDRUGS.NS', 'ALOKINDS.NS', 'AUBANK.NS', 'BANDHANBNK.NS', 'BCG.NS', 'BEML.NS', 'BORORENEW.NS', 'BSOFT.NS', 'CENTRALBK.NS', 'CGCL.NS', 'GICRE.NS', 'GLENMARK.NS', 'GODREJIND.NS', 'GPPL.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HCLTECH.NS', 'HINDZINC.NS', 'IDEA.NS', 'IOC.NS', 'IRCON.NS', 'JBMA.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'LUXIND.NS', 'M&MFIN.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MCDOWELL-N.NS', 'MGL.NS', 'MOTILALOFS.NS', 'MRPL.NS', 'NAM-INDIA.NS', 'NATIONALUM.NS', 'NLCINDIA.NS', 'NMDC.NS', 'ONGC.NS', 'PETRONET.NS', 'POLYMED.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'QUESS.NS', 'RBLBANK.NS', 'REDINGTON.NS', 'RELAXO.NS', 'RHIM.NS', 'RTNINDIA.NS', 'RVNL.NS', 'SUMICHEM.NS', 'SWANENERGY.NS', 'SYNGENE.NS', 'TATAPOWER.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'VEDL.NS', 'VIPIND.NS', 'WELSPUNLIV.NS', 'WIPRO.NS'],
'2022-09-01': ['ABBOTINDIA.NS', 'ALKEM.NS', 'ALOKINDS.NS', 'AMBER.NS', 'APLAPOLLO.NS', 'AUROPHARMA.NS', 'BBTC.NS', 'BCG.NS', 'BIOCON.NS', 'BORORENEW.NS', 'BSOFT.NS', 'COFORGE.NS', 'DIVISLAB.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'GAEL.NS', 'GLAND.NS', 'GLENMARK.NS', 'GODFRYPHLP.NS', 'HCLTECH.NS', 'INDUSTOWER.NS', 'INFY.NS', 'INTELLECT.NS', 'JBMA.NS', 'KEC.NS', 'LUXIND.NS', 'METROPOLIS.NS', 'OFSS.NS', 'ORIENTELEC.NS', 'PGHH.NS', 'PGHL.NS', 'POLYPLEX.NS', 'PRINCEPIPE.NS', 'QUESS.NS', 'TCS.NS', 'TRIDENT.NS', 'TTML.NS', 'WIPRO.NS'],
'2022-10-01': ['ADANIPORTS.NS', 'AUROPHARMA.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BAYERCROP.NS', 'BCG.NS', 'BHARATFORG.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'CENTURYTEX.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'COALINDIA.NS', 'COFORGE.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'DLF.NS', 'ELGIEQUIP.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FINPIPE.NS', 'FORTIS.NS', 'GALAXYSURF.NS', 'HDFCAMC.NS', 'HDFCLIFE.NS', 'INFY.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JSWSTEEL.NS', 'LAURUSLABS.NS', 'LUXIND.NS', 'MCX.NS', 'MFSL.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NETWORK18.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'OLECTRA.NS', 'ONGC.NS', 'PERSISTENT.NS', 'PIIND.NS', 'POWERGRID.NS', 'PRINCEPIPE.NS', 'SOBHA.NS', 'TATAPOWER.NS', 'TECHM.NS', 'THERMAX.NS', 'TRIDENT.NS', 'TTML.NS', 'UTIAMC.NS', 'VARROC.NS', 'VOLTAS.NS'],
'2022-11-01': ['AAVAS.NS', 'ADANIPOWER.NS', 'AFFLE.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'BBTC.NS', 'BCG.NS', 'BIOCON.NS', 'BPCL.NS', 'BSE.NS', 'CESC.NS', 'CHOLAFIN.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'ECLERX.NS', 'ENDURANCE.NS', 'FINPIPE.NS', 'GAEL.NS', 'GALAXYSURF.NS', 'GLAXO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GPIL.NS', 'GRAPHITE.NS', 'HAPPSTMNDS.NS', 'HAVELLS.NS', 'HEG.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'ICICIPRULI.NS', 'IDEA.NS', 'IEX.NS', 'INDUSTOWER.NS', 'KAJARIACER.NS', 'KNRCON.NS', 'LINDEINDIA.NS', 'MASTEK.NS', 'MINDACORP.NS', 'MMTC.NS', 'NAM-INDIA.NS', 'NATIONALUM.NS', 'NETWORK18.NS', 'OFSS.NS', 'PCBL.NS', 'PEL.NS', 'PGHL.NS', 'PIDILITIND.NS', 'PNCINFRA.NS', 'REDINGTON.NS', 'RELAXO.NS', 'RENUKA.NS', 'ROSSARI.NS', 'ROUTE.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'TANLA.NS', 'TRIDENT.NS', 'TTKPRESTIG.NS', 'TTML.NS', 'UTIAMC.NS', 'VARROC.NS', 'VOLTAS.NS', 'WELCORP.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'YESBANK.NS'],
'2022-12-01': ['AARTIIND.NS', 'AAVAS.NS', 'ABB.NS', 'ADANIPOWER.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'ALOKINDS.NS', 'APLLTD.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BEML.NS', 'BLUEDART.NS', 'BORORENEW.NS', 'BSE.NS', 'CESC.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CSBBANK.NS', 'DEEPAKFERT.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DMART.NS', 'ERIS.NS', 'FLUOROCHEM.NS', 'GALAXYSURF.NS', 'GLAND.NS', 'GLAXO.NS', 'GNFC.NS', 'GRANULES.NS', 'GUJALKALI.NS', 'HAPPSTMNDS.NS', 'ICICIPRULI.NS', 'IDEA.NS', 'INDIAMART.NS', 'INTELLECT.NS', 'IPCALAB.NS', 'KANSAINER.NS', 'LINDEINDIA.NS', 'LUXIND.NS', 'MAHLIFE.NS', 'METROPOLIS.NS', 'NAVINFLUOR.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'PEL.NS', 'POLYCAB.NS', 'POLYPLEX.NS', 'PRAJIND.NS', 'RAMCOCEM.NS', 'SAFARI.NS', 'SHOPERSTOP.NS', 'SIEMENS.NS', 'SRF.NS', 'SUNDARMFIN.NS', 'SUNTV.NS', 'TATACHEM.NS', 'TATAELXSI.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS', 'VMART.NS', 'WESTLIFE.NS', 'WHIRLPOOL.NS', 'ZYDUSWELL.NS'],
'2023-01-01': ['ACC.NS', 'ADANIGREEN.NS', 'ADANIPOWER.NS', 'AIAENG.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BANDHANBNK.NS', 'BBTC.NS', 'BEL.NS', 'BHARTIARTL.NS', 'BLS.NS', 'BLUESTARCO.NS', 'BORORENEW.NS', 'BRIGADE.NS', 'CAMS.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'CERA.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'CUB.NS', 'DABUR.NS', 'DLF.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'FINEORG.NS', 'FLUOROCHEM.NS', 'FSL.NS', 'GLAXO.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'GUJGASLTD.NS', 'HAL.NS', 'HCLTECH.NS', 'HFCL.NS', 'HINDUNILVR.NS', 'ICICIBANK.NS', 'IDEA.NS', 'IEX.NS', 'IGL.NS', 'INDIACEM.NS', 'INDUSTOWER.NS', 'INFY.NS', 'ISEC.NS', 'ITC.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JKCEMENT.NS', 'JMFINANCIL.NS', 'JSWENERGY.NS', 'KEI.NS', 'KPRMILL.NS', 'LTIM.NS', 'LTTS.NS', 'LUXIND.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'MGL.NS', 'MINDACORP.NS', 'MRPL.NS', 'NATCOPHARM.NS', 'NESTLEIND.NS', 'NHPC.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'ORIENTELEC.NS', 'PATANJALI.NS', 'PCBL.NS', 'POLYCAB.NS', 'POLYMED.NS', 'POWERGRID.NS', 'RADICO.NS', 'RAIN.NS', 'RELAXO.NS', 'RELIANCE.NS', 'RITES.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SFL.NS', 'SJVN.NS', 'SOBHA.NS', 'SRF.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'TANLA.NS', 'TATAINVEST.NS', 'TATAMTRDVR.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'TEJASNET.NS', 'THERMAX.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TTML.NS', 'VINATIORGA.NS', 'WHIRLPOOL.NS', 'ZENSARTECH.NS'],
'2023-02-01': ['AAVAS.NS', 'ABBOTINDIA.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'ANGELONE.NS', 'APOLLOHOSP.NS', 'ASAHIINDIA.NS', 'BBTC.NS', 'BEL.NS', 'BHARTIARTL.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'CREDITACC.NS', 'CUB.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DELTACORP.NS', 'DIVISLAB.NS', 'EIHOTEL.NS', 'EPL.NS', 'FLUOROCHEM.NS', 'GILLETTE.NS', 'GNFC.NS', 'GODREJPROP.NS', 'GRAPHITE.NS', 'GUJGASLTD.NS', 'HAPPSTMNDS.NS', 'HFCL.NS', 'HONAUT.NS', 'IBULHSGFIN.NS', 'ICICIPRULI.NS', 'IDEA.NS', 'INGERRAND.NS', 'IRCTC.NS', 'ISEC.NS', 'JKCEMENT.NS', 'JSWSTEEL.NS', 'JUBLPHARMA.NS', 'KAJARIACER.NS', 'KEC.NS', 'KSB.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MASTEK.NS', 'MMTC.NS', 'MOTILALOFS.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'PCBL.NS', 'PHOENIXLTD.NS', 'POLYPLEX.NS', 'POWERINDIA.NS', 'PRAJIND.NS', 'RAMCOCEM.NS', 'RBLBANK.NS', 'RENUKA.NS', 'RHIM.NS', 'SAREGAMA.NS', 'SBILIFE.NS', 'SFL.NS', 'SHOPERSTOP.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SPARC.NS', 'SRF.NS', 'SUMICHEM.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TTKPRESTIG.NS', 'TV18BRDCST.NS', 'UBL.NS', 'UTIAMC.NS', 'VARROC.NS', 'VBL.NS', 'VGUARD.NS', 'VTL.NS', 'WELCORP.NS', 'YESBANK.NS', 'ZEEL.NS'],
'2023-03-01': ['AARTIIND.NS', 'ADANIPORTS.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'APLLTD.NS', 'ASAHIINDIA.NS', 'AUBANK.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BHARATFORG.NS', 'BHEL.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BLS.NS', 'BPCL.NS', 'BSOFT.NS', 'CANBK.NS', 'CENTRALBK.NS', 'CHOLAHLDNG.NS', 'COCHINSHIP.NS', 'CROMPTON.NS', 'CSBBANK.NS', 'DABUR.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'DIXON.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'EXIDEIND.NS', 'FACT.NS', 'FORTIS.NS', 'GICRE.NS', 'GODREJIND.NS', 'GPIL.NS', 'GRASIM.NS', 'HUDCO.NS', 'IDBI.NS', 'IDEA.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IIFL.NS', 'INFY.NS', 'IOB.NS', 'IOC.NS', 'IRCON.NS', 'IRCTC.NS', 'ISEC.NS', 'JAMNAAUTO.NS', 'JINDALSTEL.NS', 'JMFINANCIL.NS', 'JUSTDIAL.NS', 'KANSAINER.NS', 'KEC.NS', 'L&TFH.NS', 'M&M.NS', 'MAHABANK.NS', 'MFSL.NS', 'MINDACORP.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NAUKRI.NS', 'NBCC.NS', 'NESTLEIND.NS', 'NETWORK18.NS', 'NHPC.NS', 'NIACL.NS', 'NMDC.NS', 'PIDILITIND.NS', 'PNB.NS', 'RAYMOND.NS', 'REDINGTON.NS', 'RELIANCE.NS', 'SAREGAMA.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'TCS.NS', 'TITAN.NS', 'TV18BRDCST.NS', 'UJJIVANSFB.NS', 'UPL.NS', 'WELSPUNLIV.NS', 'WESTLIFE.NS', 'WHIRLPOOL.NS', 'WIPRO.NS'],
'2023-04-01': ['ALLCARGO.NS', 'ALOKINDS.NS', 'BHEL.NS', 'BIOCON.NS', 'BSOFT.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CESC.NS', 'CHAMBLFERT.NS', 'DELTACORP.NS', 'FACT.NS', 'FSL.NS', 'GICRE.NS', 'GSFC.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'INFIBEAM.NS', 'IOB.NS', 'IRB.NS', 'ITI.NS', 'JMFINANCIL.NS', 'L&TFH.NS', 'MAHABANK.NS', 'MOTHERSON.NS', 'NAM-INDIA.NS', 'NETWORK18.NS', 'NIACL.NS', 'PNB.NS', 'RAIN.NS', 'RALLIS.NS', 'RBLBANK.NS', 'RCF.NS', 'RTNINDIA.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATASTEEL.NS', 'TRIDENT.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'VEDL.NS', 'WELSPUNLIV.NS', 'YESBANK.NS'],
'2023-05-01': ['3MINDIA.NS', 'AFFLE.NS', 'AIAENG.NS', 'ATUL.NS', 'BALAMINES.NS', 'BEML.NS', 'BLUEDART.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GMMPFAUDLR.NS', 'GPIL.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'LTIM.NS', 'MPHASIS.NS', 'PGHL.NS', 'SCHAEFFLER.NS', 'SFL.NS', 'SHREECEM.NS', 'SKFINDIA.NS', 'SWANENERGY.NS', 'TATACHEM.NS', 'TECHM.NS', 'UTIAMC.NS', 'ZEEL.NS'],
'2023-06-01': ['AARTIIND.NS', 'ABFRL.NS', 'AEGISCHEM.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'ATUL.NS', 'BALAMINES.NS', 'BANKINDIA.NS', 'BOSCHLTD.NS', 'CASTROLIND.NS', 'CHAMBLFERT.NS', 'DRREDDY.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'GAEL.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GILLETTE.NS', 'GPIL.NS', 'GPPL.NS', 'GRANULES.NS', 'GUJALKALI.NS', 'HDFCBANK.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'IPCALAB.NS', 'JAMNAAUTO.NS', 'JSWSTEEL.NS', 'KRBL.NS', 'KSB.NS', 'LT.NS', 'MANAPPURAM.NS', 'NMDC.NS', 'PAGEIND.NS', 'PGHH.NS', 'RAJESHEXPO.NS', 'RALLIS.NS', 'RCF.NS', 'SFL.NS', 'SOLARINDS.NS', 'SUMICHEM.NS', 'SWSOLAR.NS', 'TTKPRESTIG.NS', 'UPL.NS', 'VAIBHAVGBL.NS', 'VEDL.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'ZYDUSWELL.NS'],
'2023-07-01': ['AARTIIND.NS', 'ADANIGREEN.NS', 'ALLCARGO.NS', 'AMBUJACEM.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BANKINDIA.NS', 'BORORENEW.NS', 'CANBK.NS', 'CUB.NS', 'DEEPAKFERT.NS', 'GAIL.NS', 'GLAND.NS', 'GMMPFAUDLR.NS', 'GODFRYPHLP.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HFCL.NS', 'HINDZINC.NS', 'INDIAMART.NS', 'IRB.NS', 'IRCTC.NS', 'JKLAKSHMI.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'MCX.NS', 'NATIONALUM.NS', 'NAVINFLUOR.NS', 'NBCC.NS', 'PETRONET.NS', 'PFIZER.NS', 'POLYPLEX.NS', 'RAJESHEXPO.NS', 'RATNAMANI.NS', 'RITES.NS', 'SOLARINDS.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'THERMAX.NS', 'UPL.NS', 'VEDL.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'ZYDUSWELL.NS'],
'2023-08-01': ['AARTIIND.NS', 'ALKYLAMINE.NS', 'ALOKINDS.NS', 'AUBANK.NS', 'BLUEDART.NS', 'BRITANNIA.NS', 'CCL.NS', 'DALBHARAT.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DELTACORP.NS', 'FINEORG.NS', 'HFCL.NS', 'HINDUNILVR.NS', 'IEX.NS', 'IGL.NS', 'M&MFIN.NS', 'NAVINFLUOR.NS', 'NETWORK18.NS', 'ORIENTELEC.NS', 'POWERINDIA.NS', 'RAJESHEXPO.NS', 'SRF.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TATAELXSI.NS', 'TRIDENT.NS'],
'2023-09-01': ['ADANIGREEN.NS', 'ALKEM.NS', 'ALLCARGO.NS', 'AMBUJACEM.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'ATGL.NS', 'BALKRISIND.NS', 'BANKBARODA.NS', 'BLUEDART.NS', 'BORORENEW.NS', 'CUB.NS', 'CUMMINSIND.NS', 'EPL.NS', 'GODREJCP.NS', 'GUJGASLTD.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'INDIGO.NS', 'ITC.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'PETRONET.NS', 'PGHL.NS', 'RAJESHEXPO.NS', 'REDINGTON.NS', 'RELIANCE.NS', 'SBICARD.NS', 'SBIN.NS', 'SHOPERSTOP.NS', 'TANLA.NS', 'TORNTPHARM.NS', 'UPL.NS'],
'2023-10-01': ['AARTIDRUGS.NS', 'ADANIENT.NS', 'AMBUJACEM.NS', 'ASHOKLEY.NS', 'AUBANK.NS', 'BERGEPAINT.NS', 'BLS.NS', 'BORORENEW.NS', 'BPCL.NS', 'BRIGADE.NS', 'CASTROLIND.NS', 'CENTURYPLY.NS', 'CIEINDIA.NS', 'CREDITACC.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'EIHOTEL.NS', 'GODREJCP.NS', 'GODREJPROP.NS', 'GRINDWELL.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'INDIGO.NS', 'INGERRAND.NS', 'JBMA.NS', 'JKLAKSHMI.NS', 'JSWSTEEL.NS', 'JUSTDIAL.NS', 'KANSAINER.NS', 'MARICO.NS', 'ORIENTELEC.NS', 'PATANJALI.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'QUESS.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'REDINGTON.NS', 'RELAXO.NS', 'ROSSARI.NS', 'SAREGAMA.NS', 'SIEMENS.NS', 'SYMPHONY.NS', 'TIINDIA.NS', 'VTL.NS', 'WIPRO.NS'],
'2023-11-01': ['3MINDIA.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'AFFLE.NS', 'APLAPOLLO.NS', 'APOLLOHOSP.NS', 'ASTRAL.NS', 'AUROPHARMA.NS', 'AVANTIFEED.NS', 'BAJFINANCE.NS', 'BAYERCROP.NS', 'BDL.NS', 'BHARATFORG.NS', 'BORORENEW.NS', 'CEATLTD.NS', 'CENTURYPLY.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'CONCOR.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DMART.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'FLUOROCHEM.NS', 'GESHIP.NS', 'GLAND.NS', 'GLENMARK.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HINDUNILVR.NS', 'ICICIPRULI.NS', 'INGERRAND.NS', 'JUBLFOOD.NS', 'JUBLPHARMA.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'LTIM.NS', 'LUXIND.NS', 'MARICO.NS', 'MASTEK.NS', 'METROPOLIS.NS', 'MGL.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NH.NS', 'OFSS.NS', 'PAGEIND.NS', 'PEL.NS', 'PIIND.NS', 'POLYCAB.NS', 'POWERINDIA.NS', 'RAJESHEXPO.NS', 'RAYMOND.NS', 'RELIANCE.NS', 'RHIM.NS', 'RITES.NS', 'SFL.NS', 'SRF.NS', 'SUNPHARMA.NS', 'TANLA.NS', 'TATACOMM.NS', 'TATAPOWER.NS', 'TCS.NS', 'UNOMINDA.NS', 'UTIAMC.NS', 'VEDL.NS', 'ZENSARTECH.NS', 'ZYDUSWELL.NS'],
'2023-12-01': ['AAVAS.NS', 'ABCAPITAL.NS', 'ALKYLAMINE.NS', 'AVANTIFEED.NS', 'BAJFINANCE.NS', 'BALAMINES.NS', 'CHOLAFIN.NS', 'GODFRYPHLP.NS', 'HONAUT.NS', 'INDIAMART.NS', 'INDIANB.NS', 'JKPAPER.NS', 'KEC.NS', 'KRBL.NS', 'LAXMIMACH.NS', 'LINDEINDIA.NS', 'LUXIND.NS', 'MMTC.NS', 'PAGEIND.NS', 'PEL.NS', 'PETRONET.NS', 'PGHH.NS', 'RAIN.NS', 'ROSSARI.NS', 'SBICARD.NS', 'SHARDACROP.NS', 'TANLA.NS', 'TIMKEN.NS', 'VIPIND.NS', 'VMART.NS', 'WHIRLPOOL.NS'],
'2024-01-01': ['CARBORUNIV.NS', 'CIEINDIA.NS', 'CREDITACC.NS', 'HDFCLIFE.NS', 'IIFL.NS', 'JINDALSAW.NS', 'KAJARIACER.NS', 'KEC.NS', 'KNRCON.NS', 'LINDEINDIA.NS', 'MHRIL.NS', 'RAJESHEXPO.NS', 'RENUKA.NS', 'SKFINDIA.NS', 'STLTECH.NS', 'SUNTECK.NS', 'SYNGENE.NS', 'TRIVENI.NS', 'USHAMART.NS', 'VAIBHAVGBL.NS', 'VIPIND.NS', 'WELSPUNLIV.NS', 'WESTLIFE.NS'],
'2024-02-01': ['AAVAS.NS', 'ALKYLAMINE.NS', 'APLAPOLLO.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BANDHANBNK.NS', 'BCG.NS', 'BERGEPAINT.NS', 'CDSL.NS', 'CREDITACC.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CSBBANK.NS', 'CUB.NS', 'CYIENT.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'DIXON.NS', 'EICHERMOT.NS', 'EMAMILTD.NS', 'EPL.NS', 'FEDERALBNK.NS', 'HAPPSTMNDS.NS', 'HAVELLS.NS', 'HEG.NS', 'HINDUNILVR.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDIAMART.NS', 'INDUSINDBK.NS', 'KPRMILL.NS', 'MARUTI.NS', 'MFSL.NS', 'PEL.NS', 'PIDILITIND.NS', 'PNBHOUSING.NS', 'POLYMED.NS', 'RAJESHEXPO.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RHIM.NS', 'ROUTE.NS', 'SAREGAMA.NS', 'SFL.NS', 'SOLARINDS.NS', 'STLTECH.NS', 'SUMICHEM.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'TANLA.NS', 'TATACHEM.NS', 'TEAMLEASE.NS', 'TRIVENI.NS', 'UJJIVANSFB.NS', 'WESTLIFE.NS'],

    
 }
# Initialize lists to store results
ticker_list = []
percentage_returns = []
first_day_closes = []
last_day_closes = []
start_dates = []  # List to store the start dates
end_dates = []    # List to store the end dates

# Loop through the dictionary and download data for each date-ticker pair
for start_date, tickers in date_ticker_dict.items():
    end_date = pd.to_datetime(start_date) + pd.DateOffset(months=1) - pd.DateOffset(days=1)  # Last day of the month

    # Loop through tickers in this iteration
    for ticker in tickers:
        # Download historical stock data using yfinance for the specified ticker and dates
        try:
            stocks = yf.download(ticker, start=start_date, end=end_date)

            # Extracting the closing prices on the first and last day
            first_day_close = stocks['Close'].iloc[0]
            last_day_close = stocks['Close'].iloc[-1]

            # Calculating percentage return for this ticker
            percentage_return = ((last_day_close - first_day_close) / first_day_close) * 100

            # Appending the results to the lists
            ticker_list.append(ticker)
            percentage_returns.append(percentage_return)
            first_day_closes.append(first_day_close)
            last_day_closes.append(last_day_close)
            start_dates.append(pd.to_datetime(start_date))
            end_dates.append(end_date)  # Append end date for each ticker
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

# Creating a DataFrame with ticker symbols, percentage returns, and capital information
returns_df = pd.DataFrame({
    'Start_Date': start_dates,
    'End_Date': end_dates,
    'Ticker': ticker_list,
    'Percentage_Return': percentage_returns,
    'First_Day_Close': first_day_closes,
    'Last_Day_Close': last_day_closes,
})

# Assuming an initial investment of $10,000 for each stock
initial_investment = 10000

# Calculating the capital at the last day
returns_df['Capital_At_Last_Day'] = initial_investment * (1 + returns_df['Percentage_Return'] / 100)

# Calculating the difference between capital at the last day and capital required
returns_df['Capital_Difference'] = returns_df['Capital_At_Last_Day'] - initial_investment

# Total amount invested
total_invested = initial_investment * len(returns_df)

# Total amount returned
total_returned = returns_df['Capital_At_Last_Day'].sum()

# Calculate percentage return
percentage_return = ((total_returned - total_invested) / total_invested) * 100

# Displaying the DataFrame with ticker names, percentage returns, and capital information
print(returns_df[['Start_Date', 'End_Date', 'Ticker', 'Percentage_Return', 'First_Day_Close', 'Last_Day_Close']])

# Display total amount invested and total amount returned in percentage
print("\nTotal Amount Invested: $", total_invested)
print("Total Amount Returned: $", total_returned)
print("Percentage Return: ", percentage_return, "%")

returns_df.to_csv('stock_Cluster2.csv', index=False)

# %% [markdown]
# # CLUSTER 3

# %%
# import yfinance as yf
import pandas as pd

# Input dictionary
date_ticker_dict =  {

    '2017-04-01': ['AARTIIND.NS', 'AJANTPHARM.NS', 'AUROPHARMA.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BALRAMCHIN.NS', 'CHOLAFIN.NS', 'COALINDIA.NS', 'COROMANDEL.NS', 'CYIENT.NS', 'ENGINERSIN.NS', 'EPL.NS', 'FORTIS.NS', 'HEROMOTOCO.NS', 'HINDCOPPER.NS', 'ICICIBANK.NS', 'IDBI.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'LALPATHLAB.NS', 'LUPIN.NS', 'M&M.NS', 'MASTEK.NS', 'MCDOWELL-N.NS', 'MMTC.NS', 'MPHASIS.NS', 'NBCC.NS', 'NCC.NS', 'NETWORK18.NS', 'NH.NS', 'NMDC.NS', 'PIIND.NS', 'PRAJIND.NS', 'RHIM.NS', 'SPARC.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TATAELXSI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TCS.NS', 'UBL.NS', 'USHAMART.NS', 'WELCORP.NS'],
'2017-05-01': ['3MINDIA.NS', 'ADANIENT.NS', 'AIAENG.NS', 'ALOKINDS.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'BIOCON.NS', 'CRISIL.NS', 'DELTACORP.NS', 'GPIL.NS', 'GPPL.NS', 'HINDCOPPER.NS', 'ICICIBANK.NS', 'JINDALSTEL.NS', 'JUBLFOOD.NS', 'JUBLPHARMA.NS', 'LALPATHLAB.NS', 'MANAPPURAM.NS', 'NATIONALUM.NS', 'NTPC.NS', 'OFSS.NS', 'OIL.NS', 'ONGC.NS', 'PATANJALI.NS', 'PERSISTENT.NS', 'RADICO.NS', 'RALLIS.NS', 'RENUKA.NS', 'RHIM.NS', 'SAIL.NS', 'SHRIRAMFIN.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TATAELXSI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TORNTPHARM.NS', 'TRENT.NS', 'TV18BRDCST.NS', 'UBL.NS', 'VTL.NS', 'WELCORP.NS', 'WIPRO.NS', 'ZYDUSLIFE.NS'],
'2017-06-01': ['ALKEM.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'APOLLOHOSP.NS', 'AUROPHARMA.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BATAINDIA.NS', 'BEL.NS', 'BLUESTARCO.NS', 'CENTRALBK.NS', 'CENTURYTEX.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'CUMMINSIND.NS', 'DEEPAKFERT.NS', 'DELTACORP.NS', 'DLF.NS', 'ECLERX.NS', 'ENGINERSIN.NS', 'EXIDEIND.NS', 'FINCABLES.NS', 'FORTIS.NS', 'GPIL.NS', 'GRANULES.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HINDCOPPER.NS', 'IDFC.NS', 'INDIANB.NS', 'JBMA.NS', 'JKPAPER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'JYOTHYLAB.NS', 'KRBL.NS', 'KSB.NS', 'LINDEINDIA.NS', 'MANAPPURAM.NS', 'MFSL.NS', 'NATIONALUM.NS', 'NAVINFLUOR.NS', 'NCC.NS', 'NHPC.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'PAGEIND.NS', 'PGHL.NS', 'PIIND.NS', 'PNB.NS', 'RADICO.NS', 'RAYMOND.NS', 'RECLTD.NS', 'RELAXO.NS', 'RHIM.NS', 'RTNINDIA.NS', 'SAREGAMA.NS', 'SCHAEFFLER.NS', 'SHARDACROP.NS', 'SHREECEM.NS', 'SOBHA.NS', 'SPARC.NS', 'SRF.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'SUZLON.NS', 'SYNGENE.NS', 'TIMKEN.NS', 'TRENT.NS', 'TRIDENT.NS', 'USHAMART.NS', 'VGUARD.NS', 'VTL.NS', 'ZEEL.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2017-07-01': ['AEGISCHEM.NS', 'AIAENG.NS', 'ALKEM.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'ASAHIINDIA.NS', 'ATUL.NS', 'BAJAJFINSV.NS', 'BALRAMCHIN.NS', 'BANKINDIA.NS', 'BATAINDIA.NS', 'BCG.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BIOCON.NS', 'BOSCHLTD.NS', 'CASTROLIND.NS', 'CCL.NS', 'CERA.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHOLAHLDNG.NS', 'CONCOR.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DELTACORP.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'EPL.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'FDC.NS', 'HAVELLS.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'IBULHSGFIN.NS', 'INDIACEM.NS', 'INFY.NS', 'IPCALAB.NS', 'IRB.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JUBLFOOD.NS', 'KAJARIACER.NS', 'LINDEINDIA.NS', 'M&M.NS', 'NATIONALUM.NS', 'NCC.NS', 'NHPC.NS', 'NLCINDIA.NS', 'NTPC.NS', 'OFSS.NS', 'PGHL.NS', 'PNCINFRA.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'RADICO.NS', 'SHARDACROP.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'STLTECH.NS', 'SUNPHARMA.NS', 'SUZLON.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAPOWER.NS', 'TCS.NS', 'TIMKEN.NS', 'TORNTPHARM.NS', 'TV18BRDCST.NS', 'UBL.NS', 'WELSPUNLIV.NS'],
'2017-08-01': ['3MINDIA.NS', 'ABFRL.NS', 'AEGISCHEM.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'APARINDS.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'BAJAJ-AUTO.NS', 'BALKRISIND.NS', 'BANKBARODA.NS', 'BBTC.NS', 'BERGEPAINT.NS', 'CANFINHOME.NS', 'CERA.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'DLF.NS', 'ECLERX.NS', 'ENGINERSIN.NS', 'EPL.NS', 'ESCORTS.NS', 'FINPIPE.NS', 'GAIL.NS', 'GPPL.NS', 'GUJALKALI.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HEROMOTOCO.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'INDIACEM.NS', 'INGERRAND.NS', 'JKPAPER.NS', 'JUBLPHARMA.NS', 'KPRMILL.NS', 'KSB.NS', 'LINDEINDIA.NS', 'MAHABANK.NS', 'MAHLIFE.NS', 'MOTILALOFS.NS', 'MRF.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NH.NS', 'OFSS.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PIDILITIND.NS', 'PRSMJOHNSN.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'SCHAEFFLER.NS', 'SKFINDIA.NS', 'SUNDRMFAST.NS', 'SUNTECK.NS', 'SUZLON.NS', 'SYNGENE.NS', 'TATAPOWER.NS', 'TECHM.NS', 'TIMKEN.NS', 'TRITURBINE.NS', 'ULTRACEMCO.NS', 'ZFCVINDIA.NS'],
'2017-09-01': ['ABFRL.NS', 'ALKEM.NS', 'APLLTD.NS', 'APOLLOTYRE.NS', 'ATUL.NS', 'AXISBANK.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BANKINDIA.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BLUEDART.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'CERA.NS', 'CGPOWER.NS', 'CIEINDIA.NS', 'CUB.NS', 'CUMMINSIND.NS', 'DLF.NS', 'ECLERX.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'FEDERALBNK.NS', 'GLAXO.NS', 'GMRINFRA.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GRANULES.NS', 'GRINDWELL.NS', 'HCLTECH.NS', 'HINDCOPPER.NS', 'INTELLECT.NS', 'JAMNAAUTO.NS', 'JKCEMENT.NS', 'JUBLPHARMA.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'KPRMILL.NS', 'KSB.NS', 'LICHSGFIN.NS', 'LT.NS', 'LTIM.NS', 'MCX.NS', 'MFSL.NS', 'MMTC.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'NBCC.NS', 'PEL.NS', 'PERSISTENT.NS', 'PFC.NS', 'PNB.NS', 'RECLTD.NS', 'SANOFI.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SUNDARMFIN.NS', 'SUPRAJIT.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATAELXSI.NS', 'TATAPOWER.NS', 'THERMAX.NS', 'TTKPRESTIG.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'WELSPUNLIV.NS', 'ZEEL.NS', 'ZENSARTECH.NS', 'ZFCVINDIA.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2017-10-01': ['AARTIDRUGS.NS', 'ABFRL.NS', 'ADANIPOWER.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'BCG.NS', 'BEL.NS', 'BERGEPAINT.NS', 'CESC.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'EIHOTEL.NS', 'EPL.NS', 'EXIDEIND.NS', 'FACT.NS', 'GMRINFRA.NS', 'GPIL.NS', 'GPPL.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'INFIBEAM.NS', 'IOC.NS', 'IRB.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'KPRMILL.NS', 'MANAPPURAM.NS', 'MMTC.NS', 'MRPL.NS', 'NLCINDIA.NS', 'PFC.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'RCF.NS', 'RHIM.NS', 'SAREGAMA.NS', 'SONATSOFTW.NS', 'TATAPOWER.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TV18BRDCST.NS', 'VGUARD.NS'],
'2017-11-01': ['3MINDIA.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'AIAENG.NS', 'APARINDS.NS', 'APLLTD.NS', 'APOLLOTYRE.NS', 'ASIANPAINT.NS', 'BAJFINANCE.NS', 'BEML.NS', 'BIOCON.NS', 'BLUEDART.NS', 'BRIGADE.NS', 'CENTRALBK.NS', 'CESC.NS', 'COLPAL.NS', 'CRISIL.NS', 'CUB.NS', 'CUMMINSIND.NS', 'EXIDEIND.NS', 'FACT.NS', 'GESHIP.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'HDFCBANK.NS', 'HINDPETRO.NS', 'HINDUNILVR.NS', 'IBULHSGFIN.NS', 'IDFCFIRSTB.NS', 'IIFL.NS', 'INGERRAND.NS', 'IOC.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LUPIN.NS', 'LUXIND.NS', 'M&M.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'MFSL.NS', 'OLECTRA.NS', 'PEL.NS', 'PERSISTENT.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'POONAWALLA.NS', 'QUESS.NS', 'RAJESHEXPO.NS', 'RBLBANK.NS', 'RCF.NS', 'SIEMENS.NS', 'SUPREMEIND.NS', 'TANLA.NS', 'TATACOMM.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TORNTPHARM.NS', 'TRENT.NS', 'TRITURBINE.NS', 'UNOMINDA.NS', 'UPL.NS'],
'2017-12-01': ['ASAHIINDIA.NS', 'ASHOKLEY.NS', 'BAJAJHLDNG.NS', 'BALRAMCHIN.NS', 'BEML.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CENTRALBK.NS', 'CENTURYTEX.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'CIPLA.NS', 'COALINDIA.NS', 'DEEPAKNTR.NS', 'FINPIPE.NS', 'GODREJIND.NS', 'GRANULES.NS', 'GRASIM.NS', 'GSFC.NS', 'HAVELLS.NS', 'IBULHSGFIN.NS', 'INDIACEM.NS', 'INDUSINDBK.NS', 'INGERRAND.NS', 'IOB.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'JSWSTEEL.NS', 'KRBL.NS', 'LAXMIMACH.NS', 'MARICO.NS', 'MGL.NS', 'MHRIL.NS', 'NATIONALUM.NS', 'NAVINFLUOR.NS', 'NH.NS', 'PATANJALI.NS', 'PETRONET.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'PNB.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'PRSMJOHNSN.NS', 'RAMCOCEM.NS', 'RBLBANK.NS', 'RCF.NS', 'TATACOMM.NS', 'TCS.NS', 'UCOBANK.NS', 'ULTRACEMCO.NS', 'VINATIORGA.NS', 'WIPRO.NS'],
'2018-01-01': ['ASAHIINDIA.NS', 'ASHOKLEY.NS', 'AUROPHARMA.NS', 'AVANTIFEED.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BATAINDIA.NS', 'BCG.NS', 'BEL.NS', 'BEML.NS', 'BPCL.NS', 'BRITANNIA.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CGCL.NS', 'DCMSHRIRAM.NS', 'EIHOTEL.NS', 'FEDERALBNK.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GUJGASLTD.NS', 'HFCL.NS', 'HINDPETRO.NS', 'IBULHSGFIN.NS', 'ICICIPRULI.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'ITC.NS', 'ITI.NS', 'JSL.NS', 'KOTAKBANK.NS', 'L&TFH.NS', 'MAHLIFE.NS', 'MGL.NS', 'MHRIL.NS', 'MMTC.NS', 'NTPC.NS', 'OLECTRA.NS', 'PFC.NS', 'PNB.NS', 'PNBHOUSING.NS', 'PRSMJOHNSN.NS', 'RBLBANK.NS', 'RECLTD.NS', 'RENUKA.NS', 'SBIN.NS', 'SHARDACROP.NS', 'SJVN.NS', 'TATACOMM.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TTML.NS', 'VINATIORGA.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'YESBANK.NS', 'ZYDUSLIFE.NS'],
'2018-02-01': ['AARTIIND.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'APLAPOLLO.NS', 'ATUL.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BHARATFORG.NS', 'BIRLACORPN.NS', 'BPCL.NS', 'BRITANNIA.NS', 'CEATLTD.NS', 'CENTURYTEX.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'CONCOR.NS', 'CUMMINSIND.NS', 'DEEPAKFERT.NS', 'DIVISLAB.NS', 'FDC.NS', 'FINPIPE.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GNFC.NS', 'GODREJIND.NS', 'GPPL.NS', 'GRANULES.NS', 'GRASIM.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HINDALCO.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'JKPAPER.NS', 'JSL.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KEC.NS', 'KRBL.NS', 'LAXMIMACH.NS', 'LUPIN.NS', 'M&MFIN.NS', 'MARICO.NS', 'MINDACORP.NS', 'MRF.NS', 'NCC.NS', 'NMDC.NS', 'PEL.NS', 'PGHH.NS', 'PNB.NS', 'PRAJIND.NS', 'RAIN.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RECLTD.NS', 'SAIL.NS', 'SCHAEFFLER.NS', 'SHOPERSTOP.NS', 'SHRIRAMFIN.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SUNDARMFIN.NS', 'SUPRAJIT.NS', 'SYMPHONY.NS', 'TIMKEN.NS', 'TORNTPHARM.NS', 'UPL.NS', 'VIPIND.NS', 'VMART.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2018-03-01': ['ADANIPORTS.NS', 'ALKYLAMINE.NS', 'APLAPOLLO.NS', 'AVANTIFEED.NS', 'BALAMINES.NS', 'BERGEPAINT.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'CESC.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'GAIL.NS', 'GMRINFRA.NS', 'GPPL.NS', 'GRAPHITE.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'INDUSTOWER.NS', 'ITC.NS', 'ITI.NS', 'JINDALSAW.NS', 'KPRMILL.NS', 'LINDEINDIA.NS', 'MANAPPURAM.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NETWORK18.NS', 'NHPC.NS', 'ONGC.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'PRSMJOHNSN.NS', 'RBLBANK.NS', 'RELAXO.NS', 'RENUKA.NS', 'RHIM.NS', 'SAREGAMA.NS', 'SOBHA.NS', 'SUNTECK.NS', 'SUPRAJIT.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATASTEEL.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'TVSMOTOR.NS', 'UNOMINDA.NS', 'UPL.NS', 'USHAMART.NS', 'VAIBHAVGBL.NS', 'VIPIND.NS', 'VTL.NS', 'YESBANK.NS', 'ZENSARTECH.NS'],
'2018-04-01': ['3MINDIA.NS', 'ABBOTINDIA.NS', 'APLAPOLLO.NS', 'ASIANPAINT.NS', 'ATUL.NS', 'BAJAJHLDNG.NS', 'BALKRISIND.NS', 'BANKBARODA.NS', 'BLUESTARCO.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CHOLAHLDNG.NS', 'CONCOR.NS', 'CUB.NS', 'DABUR.NS', 'DEEPAKNTR.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'ESCORTS.NS', 'FACT.NS', 'FINCABLES.NS', 'GAEL.NS', 'GODREJIND.NS', 'GRINDWELL.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HINDZINC.NS', 'ICICIPRULI.NS', 'IIFL.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'INFY.NS', 'ITI.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JSWSTEEL.NS', 'JUSTDIAL.NS', 'KOTAKBANK.NS', 'KSB.NS', 'L&TFH.NS', 'LALPATHLAB.NS', 'MAHLIFE.NS', 'MCDOWELL-N.NS', 'MHRIL.NS', 'MMTC.NS', 'NATIONALUM.NS', 'NAVINFLUOR.NS', 'NCC.NS', 'ONGC.NS', 'PCBL.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'RAIN.NS', 'RAMCOCEM.NS', 'REDINGTON.NS', 'RENUKA.NS', 'RHIM.NS', 'RTNINDIA.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SHREECEM.NS', 'SJVN.NS', 'SUNDRMFAST.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATAELXSI.NS', 'TCS.NS', 'VAIBHAVGBL.NS', 'VGUARD.NS', 'VIPIND.NS', 'YESBANK.NS'],
'2018-05-01': ['ABFRL.NS', 'ADANIENT.NS', 'AJANTPHARM.NS', 'APOLLOHOSP.NS', 'AXISBANK.NS', 'BHEL.NS', 'BLS.NS', 'CANBK.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CGCL.NS', 'DRREDDY.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FINPIPE.NS', 'GAIL.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'HINDCOPPER.NS', 'ICICIBANK.NS', 'INDIACEM.NS', 'INGERRAND.NS', 'IOB.NS', 'ITI.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JSL.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'LAURUSLABS.NS', 'MINDACORP.NS', 'NAVINFLUOR.NS', 'NETWORK18.NS', 'NLCINDIA.NS', 'OLECTRA.NS', 'ONGC.NS', 'PFC.NS', 'POLYPLEX.NS', 'RCF.NS', 'RECLTD.NS', 'RENUKA.NS', 'RHIM.NS', 'SAIL.NS', 'SANOFI.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SFL.NS', 'SJVN.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'TATACOMM.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATASTEEL.NS', 'THERMAX.NS', 'TRIDENT.NS', 'TV18BRDCST.NS', 'UNOMINDA.NS', 'UPL.NS', 'WELCORP.NS', 'WELSPUNLIV.NS'],
'2018-06-01': ['AARTIIND.NS', 'ALKYLAMINE.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BCG.NS', 'BIRLACORPN.NS', 'BOSCHLTD.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CESC.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CYIENT.NS', 'DEEPAKFERT.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'EPL.NS', 'FACT.NS', 'FORTIS.NS', 'GMRINFRA.NS', 'GSPL.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IDEA.NS', 'IIFL.NS', 'INDIGO.NS', 'INGERRAND.NS', 'JSL.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KNRCON.NS', 'L&TFH.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LINDEINDIA.NS', 'LUPIN.NS', 'MINDACORP.NS', 'NCC.NS', 'NMDC.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'OLECTRA.NS', 'ONGC.NS', 'PCBL.NS', 'PETRONET.NS', 'PFC.NS', 'PGHH.NS', 'PIIND.NS', 'RALLIS.NS', 'RECLTD.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SUNPHARMA.NS', 'SUPRAJIT.NS', 'SWANENERGY.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TTML.NS', 'UNIONBANK.NS', 'UPL.NS', 'USHAMART.NS', 'WHIRLPOOL.NS'],
'2018-07-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'ACC.NS', 'ADANIPORTS.NS', 'AIAENG.NS', 'ALKYLAMINE.NS', 'AMBUJACEM.NS', 'BAJAJFINSV.NS', 'BBTC.NS', 'BERGEPAINT.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BLS.NS', 'COLPAL.NS', 'CONCOR.NS', 'CROMPTON.NS', 'CUB.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'DMART.NS', 'ECLERX.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'ENDURANCE.NS', 'FSL.NS', 'GPIL.NS', 'GRINDWELL.NS', 'GSPL.NS', 'HCLTECH.NS', 'HFCL.NS', 'HINDALCO.NS', 'IDEA.NS', 'INDUSTOWER.NS', 'INTELLECT.NS', 'ITC.NS', 'JSWSTEEL.NS', 'KARURVYSYA.NS', 'KPRMILL.NS', 'M&MFIN.NS', 'MCDOWELL-N.NS', 'MGL.NS', 'MINDACORP.NS', 'NAUKRI.NS', 'NTPC.NS', 'OLECTRA.NS', 'PCBL.NS', 'PIDILITIND.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RCF.NS', 'RELAXO.NS', 'RHIM.NS', 'SBIN.NS', 'SFL.NS', 'SHOPERSTOP.NS', 'SOLARINDS.NS', 'TANLA.NS', 'TATAINVEST.NS', 'TATASTEEL.NS', 'TIMKEN.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'VINATIORGA.NS', 'VTL.NS', 'WHIRLPOOL.NS', 'ZYDUSLIFE.NS'],
'2018-08-01': ['AARTIIND.NS', 'ABFRL.NS', 'AEGISCHEM.NS', 'ALKYLAMINE.NS', 'AUROPHARMA.NS', 'AVANTIFEED.NS', 'BAJAJHLDNG.NS', 'BLUESTARCO.NS', 'BPCL.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CHOLAHLDNG.NS', 'COLPAL.NS', 'CRISIL.NS', 'CUMMINSIND.NS', 'DEEPAKFERT.NS', 'DRREDDY.NS', 'ECLERX.NS', 'FINCABLES.NS', 'FORTIS.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GPPL.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'IDEA.NS', 'IIFL.NS', 'INGERRAND.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'KANSAINER.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'KSB.NS', 'LT.NS', 'LUPIN.NS', 'MAHLIFE.NS', 'MMTC.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NCC.NS', 'NETWORK18.NS', 'NMDC.NS', 'NTPC.NS', 'OIL.NS', 'OLECTRA.NS', 'PGHL.NS', 'PRAJIND.NS', 'RAIN.NS', 'RCF.NS', 'REDINGTON.NS', 'RENUKA.NS', 'SAIL.NS', 'SFL.NS', 'SIEMENS.NS', 'SOBHA.NS', 'SPARC.NS', 'SRF.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'SUZLON.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'TIMKEN.NS', 'TRIDENT.NS', 'UNOMINDA.NS', 'VEDL.NS', 'VMART.NS', 'VTL.NS'],
'2018-09-01': ['ALKYLAMINE.NS', 'APARINDS.NS', 'ASIANPAINT.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BEL.NS', 'BEML.NS', 'BIRLACORPN.NS', 'BLS.NS', 'BLUESTARCO.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'CENTRALBK.NS', 'CERA.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'ENGINERSIN.NS', 'ESCORTS.NS', 'GAEL.NS', 'GPPL.NS', 'GUJGASLTD.NS', 'HEROMOTOCO.NS', 'HFCL.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'JBMA.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'KARURVYSYA.NS', 'KEI.NS', 'KOTAKBANK.NS', 'KSB.NS', 'LICHSGFIN.NS', 'MARUTI.NS', 'MASTEK.NS', 'MGL.NS', 'MOTHERSON.NS', 'MRF.NS', 'MRPL.NS', 'NATCOPHARM.NS', 'NBCC.NS', 'NLCINDIA.NS', 'PATANJALI.NS', 'PCBL.NS', 'PERSISTENT.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'PIIND.NS', 'RAMCOCEM.NS', 'RCF.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'SOLARINDS.NS', 'SWANENERGY.NS', 'TATAINVEST.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TITAN.NS', 'VAIBHAVGBL.NS'],
'2018-10-01': ['ADANIENT.NS', 'AMBUJACEM.NS', 'APOLLOHOSP.NS', 'BALRAMCHIN.NS', 'BATAINDIA.NS', 'CHAMBLFERT.NS', 'CIEINDIA.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CUB.NS', 'DABUR.NS', 'ERIS.NS', 'EXIDEIND.NS', 'GESHIP.NS', 'GLENMARK.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'HDFCBANK.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'IOC.NS', 'ITC.NS', 'JUBLPHARMA.NS', 'KEC.NS', 'KSB.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LINDEINDIA.NS', 'MPHASIS.NS', 'NAVINFLUOR.NS', 'NH.NS', 'PETRONET.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'RAJESHEXPO.NS', 'RATNAMANI.NS', 'RENUKA.NS', 'RHIM.NS', 'SCHAEFFLER.NS', 'SJVN.NS', 'SUPRAJIT.NS', 'SYNGENE.NS', 'TATACONSUM.NS', 'TATASTEEL.NS', 'TORNTPHARM.NS', 'TRIVENI.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS', 'UPL.NS', 'ZENSARTECH.NS', 'ZYDUSLIFE.NS'],
'2018-11-01': ['ABFRL.NS', 'ALLCARGO.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'AVANTIFEED.NS', 'BANKBARODA.NS', 'BCG.NS', 'BERGEPAINT.NS', 'CARBORUNIV.NS', 'CDSL.NS', 'CHAMBLFERT.NS', 'COCHINSHIP.NS', 'CROMPTON.NS', 'CUB.NS', 'DEEPAKNTR.NS', 'DLF.NS', 'ELGIEQUIP.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FSL.NS', 'GMRINFRA.NS', 'GRANULES.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'ICICIPRULI.NS', 'IDEA.NS', 'INDIANB.NS', 'IOC.NS', 'IPCALAB.NS', 'IRB.NS', 'JAMNAAUTO.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'KEI.NS', 'KPRMILL.NS', 'KRBL.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'MMTC.NS', 'NCC.NS', 'NH.NS', 'NMDC.NS', 'OIL.NS', 'OLECTRA.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'RCF.NS', 'RENUKA.NS', 'RHIM.NS', 'SAREGAMA.NS', 'SONATSOFTW.NS', 'SUZLON.NS', 'SYNGENE.NS', 'TANLA.NS', 'TATACOMM.NS', 'TATASTEEL.NS', 'TEJASNET.NS', 'TV18BRDCST.NS', 'VEDL.NS', 'VTL.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'ZENSARTECH.NS'],
'2018-12-01': ['ABFRL.NS', 'APLAPOLLO.NS', 'ASHOKLEY.NS', 'AUBANK.NS', 'BALAMINES.NS', 'BCG.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'CDSL.NS', 'CENTURYPLY.NS', 'CGPOWER.NS', 'CIEINDIA.NS', 'CRISIL.NS', 'DEEPAKNTR.NS', 'EICHERMOT.NS', 'EMAMILTD.NS', 'FACT.NS', 'GAIL.NS', 'GESHIP.NS', 'GLAXO.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'HCLTECH.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'ICICIPRULI.NS', 'IIFL.NS', 'INDIANB.NS', 'INGERRAND.NS', 'INTELLECT.NS', 'IOC.NS', 'JBCHEPHARM.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'LAURUSLABS.NS', 'LTTS.NS', 'MGL.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NATCOPHARM.NS', 'OLECTRA.NS', 'PATANJALI.NS', 'PCBL.NS', 'PEL.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PGHL.NS', 'PNB.NS', 'PNBHOUSING.NS', 'RAMCOCEM.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SHOPERSTOP.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SUPREMEIND.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TTML.NS', 'UBL.NS', 'UCOBANK.NS', 'VEDL.NS', 'WELSPUNLIV.NS', 'WHIRLPOOL.NS', 'ZYDUSWELL.NS'],
'2019-01-01': ['ABCAPITAL.NS', 'AEGISCHEM.NS', 'ASAHIINDIA.NS', 'AUROPHARMA.NS', 'BALAMINES.NS', 'BHARTIARTL.NS', 'BIRLACORPN.NS', 'BLS.NS', 'BLUESTARCO.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CENTURYPLY.NS', 'CYIENT.NS', 'DIXON.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'FORTIS.NS', 'GNFC.NS', 'GPIL.NS', 'GRANULES.NS', 'GRASIM.NS', 'GSPL.NS', 'GUJALKALI.NS', 'HCLTECH.NS', 'HDFCLIFE.NS', 'HUDCO.NS', 'ICICIPRULI.NS', 'IDEA.NS', 'INDUSTOWER.NS', 'INFY.NS', 'INTELLECT.NS', 'JAMNAAUTO.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'JUBLPHARMA.NS', 'KEI.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LUPIN.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MRPL.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'PCBL.NS', 'PNBHOUSING.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'RHIM.NS', 'SAIL.NS', 'SHARDACROP.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SRF.NS', 'SUNTECK.NS', 'SUZLON.NS', 'SYNGENE.NS', 'TANLA.NS', 'TATAMOTORS.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TRIVENI.NS', 'TTML.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'WELSPUNLIV.NS', 'YESBANK.NS', 'ZENSARTECH.NS', 'ZYDUSLIFE.NS'],
'2019-02-01': ['ALKYLAMINE.NS', 'ALLCARGO.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'ASAHIINDIA.NS', 'AVANTIFEED.NS', 'BAJAJFINSV.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BEL.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BPCL.NS', 'BSE.NS', 'CCL.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'COLPAL.NS', 'CONCOR.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'FACT.NS', 'FEDERALBNK.NS', 'FSL.NS', 'GAIL.NS', 'GESHIP.NS', 'GLENMARK.NS', 'GRINDWELL.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HDFCBANK.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IEX.NS', 'IPCALAB.NS', 'ITC.NS', 'JKCEMENT.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'KANSAINER.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'LAURUSLABS.NS', 'LICHSGFIN.NS', 'MAHLIFE.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MUTHOOTFIN.NS', 'NHPC.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'PIDILITIND.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'POLYMED.NS', 'POWERGRID.NS', 'RAMCOCEM.NS', 'RELAXO.NS', 'RTNINDIA.NS', 'SBILIFE.NS', 'SHOPERSTOP.NS', 'SRF.NS', 'SUNPHARMA.NS', 'TATAMTRDVR.NS', 'TATASTEEL.NS', 'THERMAX.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VIPIND.NS', 'VOLTAS.NS', 'WELSPUNLIV.NS', 'YESBANK.NS', 'ZENSARTECH.NS'],
'2019-03-01': ['ALLCARGO.NS', 'APLLTD.NS', 'ASHOKLEY.NS', 'ASTRAL.NS', 'AUBANK.NS', 'AVANTIFEED.NS', 'BALAMINES.NS', 'BCG.NS', 'BERGEPAINT.NS', 'BHEL.NS', 'BIOCON.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'BSE.NS', 'CANBK.NS', 'CDSL.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CHAMBLFERT.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'CUB.NS', 'DEEPAKFERT.NS', 'DLF.NS', 'DMART.NS', 'EIHOTEL.NS', 'EMAMILTD.NS', 'ESCORTS.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'GAEL.NS', 'GODFRYPHLP.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GPIL.NS', 'HDFCBANK.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'HUDCO.NS', 'ICICIBANK.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'INDIGO.NS', 'INDUSTOWER.NS', 'INTELLECT.NS', 'IOB.NS', 'IRB.NS', 'ITC.NS', 'ITI.NS', 'JBMA.NS', 'JMFINANCIL.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'KEI.NS', 'KNRCON.NS', 'KPRMILL.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'LT.NS', 'LTIM.NS', 'LTTS.NS', 'M&MFIN.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'PNB.NS', 'PNBHOUSING.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'RENUKA.NS', 'SAIL.NS', 'SBILIFE.NS', 'SIEMENS.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'TATAMTRDVR.NS', 'TEAMLEASE.NS', 'TORNTPOWER.NS', 'TTKPRESTIG.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'USHAMART.NS', 'VEDL.NS', 'VTL.NS', 'WELCORP.NS', 'WHIRLPOOL.NS'],
'2019-04-01': ['ADANIENT.NS', 'ADANIPOWER.NS', 'AEGISCHEM.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'AUBANK.NS', 'BCG.NS', 'BLS.NS', 'DEEPAKFERT.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'EPL.NS', 'FACT.NS', 'FORTIS.NS', 'FSL.NS', 'GNFC.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'IEX.NS', 'INFIBEAM.NS', 'IOB.NS', 'IRB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'MAHABANK.NS', 'MINDACORP.NS', 'MMTC.NS', 'NATIONALUM.NS', 'NETWORK18.NS', 'NHPC.NS', 'PCBL.NS', 'PNCINFRA.NS', 'POLYMED.NS', 'RADICO.NS', 'RALLIS.NS', 'RCF.NS', 'SAIL.NS', 'SAREGAMA.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATACONSUM.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'VBL.NS', 'WELSPUNLIV.NS'],
'2019-05-01': ['AARTIDRUGS.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'AEGISCHEM.NS', 'ALLCARGO.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'ASHOKLEY.NS', 'ATUL.NS', 'BANKBARODA.NS', 'BBTC.NS', 'BEL.NS', 'BIRLACORPN.NS', 'BOSCHLTD.NS', 'CANBK.NS', 'CGPOWER.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'CUMMINSIND.NS', 'DEEPAKFERT.NS', 'DELTACORP.NS', 'DLF.NS', 'EICHERMOT.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'ESCORTS.NS', 'GICRE.NS', 'GODREJIND.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HFCL.NS', 'IDFCFIRSTB.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'IOB.NS', 'JKPAPER.NS', 'JSL.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'KNRCON.NS', 'KRBL.NS', 'KSB.NS', 'LICHSGFIN.NS', 'LINDEINDIA.NS', 'MFSL.NS', 'MOTHERSON.NS', 'MPHASIS.NS', 'NAVINFLUOR.NS', 'NBCC.NS', 'NCC.NS', 'NLCINDIA.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'PAGEIND.NS', 'PFIZER.NS', 'PNB.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'QUESS.NS', 'RAYMOND.NS', 'RCF.NS', 'RENUKA.NS', 'SAREGAMA.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SKFINDIA.NS', 'SONATSOFTW.NS', 'SUNTV.NS', 'TATAELXSI.NS', 'THERMAX.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'UNIONBANK.NS', 'ZFCVINDIA.NS', 'ZYDUSLIFE.NS'],
'2019-06-01': ['ASHOKLEY.NS', 'BCG.NS', 'CASTROLIND.NS', 'CGPOWER.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'GAEL.NS', 'GNFC.NS', 'GPPL.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'IDBI.NS', 'IDEA.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IRB.NS', 'JBMA.NS', 'JINDALSTEL.NS', 'JKPAPER.NS', 'JSL.NS', 'JUBLFOOD.NS', 'KARURVYSYA.NS', 'MAHABANK.NS', 'MMTC.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NCC.NS', 'NETWORK18.NS', 'NLCINDIA.NS', 'OLECTRA.NS', 'PCBL.NS', 'PNB.NS', 'RENUKA.NS', 'SAIL.NS', 'SAREGAMA.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATASTEEL.NS', 'TORNTPOWER.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VEDL.NS', 'WELSPUNLIV.NS'],
'2019-07-01': ['ACC.NS', 'AMBUJACEM.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'AVANTIFEED.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BCG.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BIRLACORPN.NS', 'CARBORUNIV.NS', 'CENTURYTEX.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'DIVISLAB.NS', 'DIXON.NS', 'ELGIEQUIP.NS', 'FINCABLES.NS', 'FSL.NS', 'GESHIP.NS', 'GICRE.NS', 'GODREJCP.NS', 'GPIL.NS', 'GUJALKALI.NS', 'HCLTECH.NS', 'HEROMOTOCO.NS', 'HINDZINC.NS', 'HUDCO.NS', 'ICICIGI.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'IGL.NS', 'INDIANB.NS', 'INDIGO.NS', 'INFY.NS', 'IPCALAB.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'LUPIN.NS', 'MAHLIFE.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NAVINFLUOR.NS', 'NCC.NS', 'OIL.NS', 'OLECTRA.NS', 'ORIENTELEC.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PNB.NS', 'PNBHOUSING.NS', 'POLYPLEX.NS', 'PRSMJOHNSN.NS', 'RADICO.NS', 'RAIN.NS', 'RAMCOCEM.NS', 'RBLBANK.NS', 'SHRIRAMFIN.NS', 'STLTECH.NS', 'SUNPHARMA.NS', 'SUPRAJIT.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TEAMLEASE.NS', 'TIINDIA.NS', 'TORNTPHARM.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'VIPIND.NS', 'ZFCVINDIA.NS'],
'2019-08-01': ['ACC.NS', 'ALKEM.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'BAJAJHLDNG.NS', 'BALRAMCHIN.NS', 'BDL.NS', 'BHARTIARTL.NS', 'BIRLACORPN.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CENTURYTEX.NS', 'CESC.NS', 'CHOLAFIN.NS', 'CUMMINSIND.NS', 'DEEPAKNTR.NS', 'DLF.NS', 'DRREDDY.NS', 'GILLETTE.NS', 'GODREJIND.NS', 'GPPL.NS', 'GRANULES.NS', 'HCLTECH.NS', 'HINDUNILVR.NS', 'IGL.NS', 'INDHOTEL.NS', 'INDUSINDBK.NS', 'ITC.NS', 'JKLAKSHMI.NS', 'JSWENERGY.NS', 'JUBLFOOD.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KEC.NS', 'KNRCON.NS', 'LAURUSLABS.NS', 'LICHSGFIN.NS', 'MAHLIFE.NS', 'MCX.NS', 'MGL.NS', 'MUTHOOTFIN.NS', 'NATCOPHARM.NS', 'NH.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'ORIENTELEC.NS', 'PETRONET.NS', 'PHOENIXLTD.NS', 'PIIND.NS', 'PRESTIGE.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'SFL.NS', 'SRF.NS', 'SUPREMEIND.NS', 'SYMPHONY.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TIMKEN.NS', 'UNOMINDA.NS', 'VOLTAS.NS', 'ZYDUSLIFE.NS'],
'2019-09-01': ['AARTIIND.NS', 'ACC.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'BAJAJFINSV.NS', 'BALRAMCHIN.NS', 'BCG.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BSOFT.NS', 'CDSL.NS', 'CENTRALBK.NS', 'CRISIL.NS', 'DEEPAKNTR.NS', 'DLF.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'EPL.NS', 'FACT.NS', 'FDC.NS', 'FINPIPE.NS', 'FORTIS.NS', 'FSL.NS', 'GAIL.NS', 'GESHIP.NS', 'GMRINFRA.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GRANULES.NS', 'GSFC.NS', 'HAL.NS', 'HDFCBANK.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'ICICIBANK.NS', 'IDBI.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'IOB.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'KPRMILL.NS', 'KSB.NS', 'LAURUSLABS.NS', 'LUPIN.NS', 'LUXIND.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MAHLIFE.NS', 'MANAPPURAM.NS', 'MHRIL.NS', 'MMTC.NS', 'MOTILALOFS.NS', 'MUTHOOTFIN.NS', 'NATIONALUM.NS', 'NETWORK18.NS', 'NTPC.NS', 'OFSS.NS', 'PATANJALI.NS', 'PCBL.NS', 'PERSISTENT.NS', 'POWERGRID.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'RECLTD.NS', 'RITES.NS', 'SHOPERSTOP.NS', 'SKFINDIA.NS', 'SONATSOFTW.NS', 'SUNDARMFIN.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UPL.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'ZENSARTECH.NS', 'ZYDUSLIFE.NS'],
'2019-10-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'AJANTPHARM.NS', 'AMBUJACEM.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'ASAHIINDIA.NS', 'ASTERDM.NS', 'AUBANK.NS', 'AXISBANK.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BLS.NS', 'BOSCHLTD.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CHAMBLFERT.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'DCMSHRIRAM.NS', 'DELTACORP.NS', 'GILLETTE.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GSFC.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IDEA.NS', 'INDUSINDBK.NS', 'INFIBEAM.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'JUSTDIAL.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'KPRMILL.NS', 'LEMONTREE.NS', 'M&M.NS', 'M&MFIN.NS', 'MASTEK.NS', 'MOTHERSON.NS', 'MPHASIS.NS', 'MRPL.NS', 'NAUKRI.NS', 'NIACL.NS', 'NLCINDIA.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'ONGC.NS', 'PCBL.NS', 'PERSISTENT.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'RAIN.NS', 'RTNINDIA.NS', 'SANOFI.NS', 'SHREECEM.NS', 'SJVN.NS', 'SRF.NS', 'SYNGENE.NS', 'TATASTEEL.NS', 'TCS.NS', 'TORNTPHARM.NS', 'TRIDENT.NS', 'VBL.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'ZENSARTECH.NS', 'ZYDUSLIFE.NS'],
'2019-11-01': ['ABB.NS', 'ABCAPITAL.NS', 'ADANIPORTS.NS', 'AEGISCHEM.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'ASTRAL.NS', 'BIRLACORPN.NS', 'BSOFT.NS', 'CANFINHOME.NS', 'CESC.NS', 'CGPOWER.NS', 'CHOLAHLDNG.NS', 'CROMPTON.NS', 'CUB.NS', 'ECLERX.NS', 'EIHOTEL.NS', 'EPL.NS', 'FEDERALBNK.NS', 'FSL.NS', 'GAEL.NS', 'GMMPFAUDLR.NS', 'GPIL.NS', 'GRAPHITE.NS', 'GSPL.NS', 'HEG.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'IIFL.NS', 'INDUSINDBK.NS', 'INTELLECT.NS', 'IRB.NS', 'JKPAPER.NS', 'JSL.NS', 'JSWSTEEL.NS', 'KEC.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'KRBL.NS', 'LAXMIMACH.NS', 'LTTS.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'MHRIL.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'NBCC.NS', 'NCC.NS', 'NHPC.NS', 'OBEROIRLTY.NS', 'PEL.NS', 'PNBHOUSING.NS', 'POLYMED.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'RALLIS.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RENUKA.NS', 'SFL.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SUNTECK.NS', 'SUPREMEIND.NS', 'SWANENERGY.NS', 'TATAPOWER.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'TTML.NS', 'ULTRACEMCO.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VEDL.NS', 'VMART.NS', 'VTL.NS'],
'2019-12-01': ['ABB.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'AIAENG.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'ATUL.NS', 'BHEL.NS', 'BLUESTARCO.NS', 'BORORENEW.NS', 'BRITANNIA.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'CERA.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'COLPAL.NS', 'CROMPTON.NS', 'DABUR.NS', 'DEEPAKNTR.NS', 'DMART.NS', 'EIHOTEL.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'ESCORTS.NS', 'FACT.NS', 'FINCABLES.NS', 'FINEORG.NS', 'FINPIPE.NS', 'FORTIS.NS', 'GAIL.NS', 'GSPL.NS', 'HAVELLS.NS', 'HDFCLIFE.NS', 'HINDUNILVR.NS', 'IEX.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIANB.NS', 'IRB.NS', 'JINDALSAW.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JUBLPHARMA.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KEI.NS', 'KNRCON.NS', 'KRBL.NS', 'KSB.NS', 'LAURUSLABS.NS', 'LAXMIMACH.NS', 'LTTS.NS', 'MANAPPURAM.NS', 'MINDACORP.NS', 'MMTC.NS', 'MUTHOOTFIN.NS', 'NLCINDIA.NS', 'NMDC.NS', 'PAGEIND.NS', 'PGHL.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RENUKA.NS', 'RITES.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TRIVENI.NS', 'TTML.NS', 'UBL.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VAIBHAVGBL.NS', 'VEDL.NS', 'VTL.NS', 'WELSPUNLIV.NS', 'ZEEL.NS'],
'2020-01-01': ['3MINDIA.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'ASAHIINDIA.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'BAJAJ-AUTO.NS', 'BAJAJHLDNG.NS', 'BAYERCROP.NS', 'BEML.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'BSE.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'COLPAL.NS', 'CONCOR.NS', 'CREDITACC.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DABUR.NS', 'DMART.NS', 'DRREDDY.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'GAIL.NS', 'GLAXO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'HINDZINC.NS', 'HONAUT.NS', 'JKLAKSHMI.NS', 'JUSTDIAL.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KSB.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'LTTS.NS', 'LUPIN.NS', 'LUXIND.NS', 'M&M.NS', 'MCDOWELL-N.NS', 'NAUKRI.NS', 'ONGC.NS', 'ORIENTELEC.NS', 'PGHH.NS', 'PIIND.NS', 'QUESS.NS', 'RELIANCE.NS', 'SBILIFE.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SOLARINDS.NS', 'SUNDARMFIN.NS', 'SUNPHARMA.NS', 'SYMPHONY.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TCS.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'TITAN.NS', 'TRITURBINE.NS', 'ULTRACEMCO.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'WIPRO.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2020-02-01': ['ABB.NS', 'ABBOTINDIA.NS', 'ABCAPITAL.NS', 'ADANIPOWER.NS', 'AMBUJACEM.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'AXISBANK.NS', 'BALAMINES.NS', 'BANKINDIA.NS', 'BCG.NS', 'BEML.NS', 'BHARATFORG.NS', 'BLS.NS', 'CENTRALBK.NS', 'CGCL.NS', 'CUB.NS', 'CUMMINSIND.NS', 'FINPIPE.NS', 'GPIL.NS', 'GPPL.NS', 'GRAPHITE.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'IBULHSGFIN.NS', 'ICICIBANK.NS', 'IDEA.NS', 'INDHOTEL.NS', 'INDIGO.NS', 'ITC.NS', 'JBMA.NS', 'JKPAPER.NS', 'JSL.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'L&TFH.NS', 'LICHSGFIN.NS', 'MCX.NS', 'MFSL.NS', 'MMTC.NS', 'MOTILALOFS.NS', 'NCC.NS', 'NHPC.NS', 'OLECTRA.NS', 'PCBL.NS', 'PEL.NS', 'PNB.NS', 'POONAWALLA.NS', 'RAIN.NS', 'RAMCOCEM.NS', 'REDINGTON.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SHARDACROP.NS', 'SIEMENS.NS', 'SJVN.NS', 'STLTECH.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TTKPRESTIG.NS', 'TTML.NS', 'UBL.NS', 'UCOBANK.NS', 'ZEEL.NS'],
'2020-03-01': ['AAVAS.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'ASIANPAINT.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'BAJFINANCE.NS', 'BDL.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BLUESTARCO.NS', 'BORORENEW.NS', 'CARBORUNIV.NS', 'CDSL.NS', 'CENTURYPLY.NS', 'CERA.NS', 'EPL.NS', 'FEDERALBNK.NS', 'FINEORG.NS', 'FINPIPE.NS', 'FSL.NS', 'HAVELLS.NS', 'IBULHSGFIN.NS', 'ICICIPRULI.NS', 'IIFL.NS', 'INDHOTEL.NS', 'INGERRAND.NS', 'JSL.NS', 'JUBLFOOD.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'LAURUSLABS.NS', 'LAXMIMACH.NS', 'LTTS.NS', 'M&MFIN.NS', 'MASTEK.NS', 'MPHASIS.NS', 'NETWORK18.NS', 'NH.NS', 'PGHL.NS', 'RAIN.NS', 'REDINGTON.NS', 'RELAXO.NS', 'RHIM.NS', 'RITES.NS', 'SHOPERSTOP.NS', 'SOLARINDS.NS', 'TATACHEM.NS', 'TIMKEN.NS', 'TTML.NS', 'TVSMOTOR.NS', 'UBL.NS', 'UNOMINDA.NS', 'VOLTAS.NS', 'ZEEL.NS', 'ZYDUSLIFE.NS'],
'2020-04-01': ['3MINDIA.NS', 'AIAENG.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'AMBER.NS', 'APLLTD.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'ATUL.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'BLUEDART.NS', 'BPCL.NS', 'BRITANNIA.NS', 'CEATLTD.NS', 'CERA.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'COROMANDEL.NS', 'DABUR.NS', 'DIXON.NS', 'ESCORTS.NS', 'FDC.NS', 'FINEORG.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'HDFCLIFE.NS', 'HINDPETRO.NS', 'HONAUT.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'IGL.NS', 'INDIGO.NS', 'INFY.NS', 'INGERRAND.NS', 'ITC.NS', 'JUBLFOOD.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'MFSL.NS', 'MGL.NS', 'MRF.NS', 'ORIENTELEC.NS', 'PFIZER.NS', 'PGHH.NS', 'PGHL.NS', 'PIDILITIND.NS', 'RALLIS.NS', 'RELAXO.NS', 'RELIANCE.NS', 'RITES.NS', 'SUNPHARMA.NS', 'TATACONSUM.NS', 'TCS.NS', 'TIMKEN.NS', 'TTKPRESTIG.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2020-05-01': ['AEGISCHEM.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APOLLOHOSP.NS', 'ASAHIINDIA.NS', 'ASTRAL.NS', 'ATGL.NS', 'AXISBANK.NS', 'BANDHANBNK.NS', 'BDL.NS', 'BEML.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'CANFINHOME.NS', 'CCL.NS', 'CDSL.NS', 'CEATLTD.NS', 'CENTURYPLY.NS', 'CGCL.NS', 'COFORGE.NS', 'CONCOR.NS', 'CREDITACC.NS', 'CROMPTON.NS', 'CUB.NS', 'DLF.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'ESCORTS.NS', 'FINCABLES.NS', 'FINEORG.NS', 'FORTIS.NS', 'GAEL.NS', 'GICRE.NS', 'GILLETTE.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GPIL.NS', 'HDFCAMC.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'HINDUNILVR.NS', 'IBULHSGFIN.NS', 'ICICIBANK.NS', 'INDIGO.NS', 'INDUSTOWER.NS', 'INGERRAND.NS', 'IRB.NS', 'ITC.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'KRBL.NS', 'KSB.NS', 'L&TFH.NS', 'LINDEINDIA.NS', 'LT.NS', 'LTTS.NS', 'M&M.NS', 'MAHABANK.NS', 'MARICO.NS', 'MASTEK.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MINDACORP.NS', 'MPHASIS.NS', 'NATIONALUM.NS', 'NCC.NS', 'NH.NS', 'ORIENTELEC.NS', 'PAGEIND.NS', 'PCBL.NS', 'PEL.NS', 'PNCINFRA.NS', 'POWERGRID.NS', 'RADICO.NS', 'RAIN.NS', 'RECLTD.NS', 'SAREGAMA.NS', 'SBILIFE.NS', 'SHARDACROP.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'SUNDARMFIN.NS', 'TATASTEEL.NS', 'TIINDIA.NS', 'TITAN.NS', 'TRENT.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'VGUARD.NS', 'VMART.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZEEL.NS', 'ZFCVINDIA.NS'],
'2020-06-01': ['3MINDIA.NS', 'AARTIIND.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'ASAHIINDIA.NS', 'ASTRAL.NS', 'ATUL.NS', 'AXISBANK.NS', 'BAJAJHLDNG.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BEML.NS', 'BOSCHLTD.NS', 'CARBORUNIV.NS', 'CENTURYTEX.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'CRISIL.NS', 'CUB.NS', 'CUMMINSIND.NS', 'DMART.NS', 'ECLERX.NS', 'EMAMILTD.NS', 'EPL.NS', 'FINEORG.NS', 'GALAXYSURF.NS', 'GLAXO.NS', 'GODFRYPHLP.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HDFCAMC.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'ICICIBANK.NS', 'INDHOTEL.NS', 'INDIGO.NS', 'IPCALAB.NS', 'JMFINANCIL.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KEC.NS', 'KEI.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'KRBL.NS', 'KSB.NS', 'LALPATHLAB.NS', 'LICHSGFIN.NS', 'LINDEINDIA.NS', 'LTTS.NS', 'LUXIND.NS', 'MOTILALOFS.NS', 'MRF.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NH.NS', 'OBEROIRLTY.NS', 'ORIENTELEC.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'POLYCAB.NS', 'QUESS.NS', 'RATNAMANI.NS', 'RHIM.NS', 'RITES.NS', 'RTNINDIA.NS', 'SAREGAMA.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SONATSOFTW.NS', 'SUNDRMFAST.NS', 'TECHM.NS', 'THERMAX.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TRENT.NS', 'TTKPRESTIG.NS', 'VBL.NS', 'VMART.NS', 'VOLTAS.NS', 'VTL.NS', 'ZYDUSWELL.NS'],
'2020-07-01': ['ABFRL.NS', 'ADANIPOWER.NS', 'AEGISCHEM.NS', 'AIAENG.NS', 'ALKEM.NS', 'APARINDS.NS', 'APOLLOHOSP.NS', 'ASAHIINDIA.NS', 'ATUL.NS', 'AXISBANK.NS', 'BERGEPAINT.NS', 'BHARTIARTL.NS', 'BLUEDART.NS', 'CENTURYTEX.NS', 'CHOLAHLDNG.NS', 'COFORGE.NS', 'CUMMINSIND.NS', 'DLF.NS', 'DMART.NS', 'DRREDDY.NS', 'ELGIEQUIP.NS', 'EPL.NS', 'FORTIS.NS', 'FSL.NS', 'GESHIP.NS', 'GILLETTE.NS', 'GUJALKALI.NS', 'HCLTECH.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'IIFL.NS', 'INDHOTEL.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'IRCON.NS', 'JMFINANCIL.NS', 'JSWSTEEL.NS', 'KNRCON.NS', 'LALPATHLAB.NS', 'LEMONTREE.NS', 'LICHSGFIN.NS', 'LTTS.NS', 'M&MFIN.NS', 'MCDOWELL-N.NS', 'NHPC.NS', 'NIACL.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'OIL.NS', 'ONGC.NS', 'PFC.NS', 'PGHH.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'PNBHOUSING.NS', 'PRAJIND.NS', 'RAYMOND.NS', 'SBIN.NS', 'SIEMENS.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SYMPHONY.NS', 'TATAMTRDVR.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'TITAN.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'UNOMINDA.NS', 'VMART.NS', 'ZEEL.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2020-08-01': ['ADANIPORTS.NS', 'ADANIPOWER.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'AVANTIFEED.NS', 'BANKBARODA.NS', 'BATAINDIA.NS', 'BHARTIARTL.NS', 'BLUESTARCO.NS', 'BORORENEW.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'COALINDIA.NS', 'CREDITACC.NS', 'CUB.NS', 'DELTACORP.NS', 'DLF.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'GAIL.NS', 'GICRE.NS', 'GLAXO.NS', 'GODREJIND.NS', 'GRINDWELL.NS', 'GSPL.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HFCL.NS', 'HINDPETRO.NS', 'IBULHSGFIN.NS', 'ICICIBANK.NS', 'IDEA.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'ISEC.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JSL.NS', 'JUSTDIAL.NS', 'L&TFH.NS', 'LICHSGFIN.NS', 'LT.NS', 'MANAPPURAM.NS', 'MCDOWELL-N.NS', 'MGL.NS', 'MHRIL.NS', 'MINDACORP.NS', 'NBCC.NS', 'NCC.NS', 'NESTLEIND.NS', 'NIACL.NS', 'OBEROIRLTY.NS', 'ONGC.NS', 'PCBL.NS', 'PETRONET.NS', 'PFC.NS', 'PIDILITIND.NS', 'PNB.NS', 'PNCINFRA.NS', 'PRSMJOHNSN.NS', 'RCF.NS', 'RECLTD.NS', 'RITES.NS', 'SFL.NS', 'SHOPERSTOP.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'STLTECH.NS', 'SUNTV.NS', 'SUZLON.NS', 'SYMPHONY.NS', 'TRENT.NS', 'TTML.NS', 'UNIONBANK.NS', 'UNOMINDA.NS', 'VINATIORGA.NS', 'WHIRLPOOL.NS'],
'2020-09-01': ['3MINDIA.NS', 'AARTIIND.NS', 'AAVAS.NS', 'ALKEM.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'ASTERDM.NS', 'AUBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BALKRISIND.NS', 'BANDHANBNK.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BBTC.NS', 'BDL.NS', 'BEML.NS', 'BERGEPAINT.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'BRITANNIA.NS', 'CANFINHOME.NS', 'CCL.NS', 'CEATLTD.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'DMART.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'ESCORTS.NS', 'FDC.NS', 'FORTIS.NS', 'GESHIP.NS', 'GICRE.NS', 'GODFRYPHLP.NS', 'GRINDWELL.NS', 'HAVELLS.NS', 'HDFCAMC.NS', 'IBULHSGFIN.NS', 'INDUSTOWER.NS', 'INGERRAND.NS', 'IPCALAB.NS', 'ISEC.NS', 'JKCEMENT.NS', 'KSB.NS', 'LT.NS', 'LUPIN.NS', 'MCX.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NAVINFLUOR.NS', 'PEL.NS', 'PIDILITIND.NS', 'PIIND.NS', 'POLYMED.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'RITES.NS', 'SANOFI.NS', 'SFL.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SYMPHONY.NS', 'TATACHEM.NS', 'THERMAX.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'UBL.NS', 'VBL.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'WHIRLPOOL.NS'],
'2020-10-01': ['AARTIIND.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ADANIPOWER.NS', 'ALKEM.NS', 'APLLTD.NS', 'ASAHIINDIA.NS', 'ASTERDM.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BAYERCROP.NS', 'BBTC.NS', 'BHARATFORG.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CHOLAHLDNG.NS', 'COROMANDEL.NS', 'CUMMINSIND.NS', 'DIVISLAB.NS', 'DLF.NS', 'EIDPARRY.NS', 'EPL.NS', 'FACT.NS', 'FINCABLES.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'HDFCAMC.NS', 'HINDUNILVR.NS', 'HINDZINC.NS', 'HUDCO.NS', 'ICICIBANK.NS', 'ICICIPRULI.NS', 'IIFL.NS', 'INDIACEM.NS', 'INDUSINDBK.NS', 'INFIBEAM.NS', 'IRB.NS', 'ISEC.NS', 'ITI.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'JUBLPHARMA.NS', 'L&TFH.NS', 'LICHSGFIN.NS', 'LT.NS', 'M&M.NS', 'M&MFIN.NS', 'MARUTI.NS', 'MHRIL.NS', 'MOTILALOFS.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NESTLEIND.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'POLYCAB.NS', 'RADICO.NS', 'RAIN.NS', 'RAJESHEXPO.NS', 'RALLIS.NS', 'RBLBANK.NS', 'SBILIFE.NS', 'SHREECEM.NS', 'SOLARINDS.NS', 'SPARC.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SWANENERGY.NS', 'SWSOLAR.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAPOWER.NS', 'TEAMLEASE.NS', 'TRITURBINE.NS', 'VBL.NS', 'VIPIND.NS'],
'2020-11-01': ['360ONE.NS', 'AARTIIND.NS', 'ABCAPITAL.NS', 'ADANIPOWER.NS', 'AEGISCHEM.NS', 'AFFLE.NS', 'AIAENG.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'APARINDS.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'BALKRISIND.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BATAINDIA.NS', 'BEML.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BPCL.NS', 'BSOFT.NS', 'CHALET.NS', 'CHOLAHLDNG.NS', 'CIPLA.NS', 'COFORGE.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CUMMINSIND.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DLF.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'EPL.NS', 'ERIS.NS', 'EXIDEIND.NS', 'FACT.NS', 'FINCABLES.NS', 'GESHIP.NS', 'GILLETTE.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GODFRYPHLP.NS', 'GSPL.NS', 'GUJALKALI.NS', 'GUJGASLTD.NS', 'HINDALCO.NS', 'ICICIGI.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'IRB.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JUBLFOOD.NS', 'JUBLPHARMA.NS', 'KARURVYSYA.NS', 'KEC.NS', 'KEI.NS', 'LEMONTREE.NS', 'LICHSGFIN.NS', 'M&M.NS', 'M&MFIN.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'MHRIL.NS', 'NETWORK18.NS', 'NMDC.NS', 'PEL.NS', 'PERSISTENT.NS', 'PFC.NS', 'PHOENIXLTD.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RHIM.NS', 'RITES.NS', 'SAIL.NS', 'SBIN.NS', 'SFL.NS', 'SHOPERSTOP.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SONATSOFTW.NS', 'STLTECH.NS', 'SUPRAJIT.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TEAMLEASE.NS', 'TITAN.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TTKPRESTIG.NS', 'UNOMINDA.NS', 'VARROC.NS', 'VTL.NS', 'WELCORP.NS', 'ZEEL.NS', 'ZENSARTECH.NS'],
'2020-12-01': ['APLLTD.NS', 'ATUL.NS', 'AUBANK.NS', 'BBTC.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BRITANNIA.NS', 'CDSL.NS', 'COFORGE.NS', 'COLPAL.NS', 'CRISIL.NS', 'DMART.NS', 'DRREDDY.NS', 'EPL.NS', 'ERIS.NS', 'FDC.NS', 'FINEORG.NS', 'GMMPFAUDLR.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'HCLTECH.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'ICICIPRULI.NS', 'IIFL.NS', 'INDIAMART.NS', 'INDIGO.NS', 'INFY.NS', 'IPCALAB.NS', 'IRCTC.NS', 'ISEC.NS', 'JBCHEPHARM.NS', 'JUBLPHARMA.NS', 'LTTS.NS', 'MARICO.NS', 'MARUTI.NS', 'MCDOWELL-N.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'NATCOPHARM.NS', 'PEL.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PGHH.NS', 'PIDILITIND.NS', 'PIIND.NS', 'POLYMED.NS', 'RADICO.NS', 'RITES.NS', 'SANOFI.NS', 'SBILIFE.NS', 'SOLARINDS.NS', 'SUNPHARMA.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'TCS.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'TTKPRESTIG.NS', 'UBL.NS', 'VINATIORGA.NS', 'VTL.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2021-01-01': ['360ONE.NS', 'ABCAPITAL.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APLLTD.NS', 'APOLLOTYRE.NS', 'AVANTIFEED.NS', 'BALAMINES.NS', 'BBTC.NS', 'BHARATFORG.NS', 'BIRLACORPN.NS', 'BLS.NS', 'BPCL.NS', 'CASTROLIND.NS', 'COLPAL.NS', 'CONCOR.NS', 'CREDITACC.NS', 'CUB.NS', 'DEEPAKFERT.NS', 'EIHOTEL.NS', 'GAEL.NS', 'GESHIP.NS', 'GICRE.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODREJIND.NS', 'GSFC.NS', 'HEROMOTOCO.NS', 'IDFC.NS', 'INDHOTEL.NS', 'IRCON.NS', 'IRCTC.NS', 'ISEC.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JMFINANCIL.NS', 'KEC.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MCDOWELL-N.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NETWORK18.NS', 'ORIENTELEC.NS', 'PEL.NS', 'PETRONET.NS', 'PNB.NS', 'PNBHOUSING.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'RADICO.NS', 'RALLIS.NS', 'REDINGTON.NS', 'SAFARI.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SUNDRMFAST.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'SWANENERGY.NS', 'TORNTPOWER.NS', 'TRIVENI.NS', 'TV18BRDCST.NS', 'TVSMOTOR.NS', 'UCOBANK.NS', 'UPL.NS', 'VGUARD.NS', 'WELSPUNLIV.NS'],
'2021-02-01': ['360ONE.NS', 'ADANIGREEN.NS', 'AFFLE.NS', 'AIAENG.NS', 'ALLCARGO.NS', 'ASAHIINDIA.NS', 'ASTERDM.NS', 'ATUL.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'AVANTIFEED.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BALRAMCHIN.NS', 'BDL.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'BPCL.NS', 'BRIGADE.NS', 'BSE.NS', 'CANFINHOME.NS', 'CHALET.NS', 'CHOLAFIN.NS', 'COCHINSHIP.NS', 'CRISIL.NS', 'CSBBANK.NS', 'DEEPAKFERT.NS', 'DMART.NS', 'FLUOROCHEM.NS', 'FSL.NS', 'GALAXYSURF.NS', 'GESHIP.NS', 'GNFC.NS', 'GODREJCP.NS', 'GRINDWELL.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HINDPETRO.NS', 'ICICIPRULI.NS', 'IGL.NS', 'INDIACEM.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFY.NS', 'ITC.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JSWSTEEL.NS', 'KEI.NS', 'KRBL.NS', 'KSB.NS', 'L&TFH.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LUPIN.NS', 'M&M.NS', 'MASTEK.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGL.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'NIACL.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'PAGEIND.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PNB.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'RAIN.NS', 'RAJESHEXPO.NS', 'RAYMOND.NS', 'RECLTD.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SHOPERSTOP.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SRF.NS', 'SUNTV.NS', 'SWANENERGY.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATAPOWER.NS', 'TECHM.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TTKPRESTIG.NS', 'VBL.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'ZYDUSWELL.NS'],
'2021-03-01': ['AJANTPHARM.NS', 'ALLCARGO.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BANDHANBNK.NS', 'BHARTIARTL.NS', 'BOSCHLTD.NS', 'BSE.NS', 'CANFINHOME.NS', 'COFORGE.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'CUB.NS', 'DELTACORP.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'ESCORTS.NS', 'FINPIPE.NS', 'FORTIS.NS', 'GAEL.NS', 'GLAXO.NS', 'HDFCAMC.NS', 'HEROMOTOCO.NS', 'INDIACEM.NS', 'INDIGO.NS', 'INFY.NS', 'IRB.NS', 'ITC.NS', 'JSL.NS', 'JYOTHYLAB.NS', 'KANSAINER.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LEMONTREE.NS', 'LUPIN.NS', 'M&M.NS', 'MOTILALOFS.NS', 'MRF.NS', 'NAUKRI.NS', 'OBEROIRLTY.NS', 'PAGEIND.NS', 'PIIND.NS', 'RBLBANK.NS', 'RECLTD.NS', 'SBILIFE.NS', 'SHRIRAMFIN.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SWSOLAR.NS', 'TIMKEN.NS', 'TV18BRDCST.NS', 'USHAMART.NS', 'VARROC.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZYDUSWELL.NS'],
'2021-04-01': ['ABB.NS', 'ADANIGREEN.NS', 'ALLCARGO.NS', 'APOLLOTYRE.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BDL.NS', 'BEL.NS', 'BHARATFORG.NS', 'BSE.NS', 'CASTROLIND.NS', 'CCL.NS', 'CENTRALBK.NS', 'CENTURYTEX.NS', 'CHAMBLFERT.NS', 'CSBBANK.NS', 'DELTACORP.NS', 'DIXON.NS', 'DLF.NS', 'DMART.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'ESCORTS.NS', 'FDC.NS', 'FINCABLES.NS', 'FINEORG.NS', 'FLUOROCHEM.NS', 'GAEL.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GSFC.NS', 'HAL.NS', 'HAVELLS.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HINDZINC.NS', 'HUDCO.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IGL.NS', 'INDIAMART.NS', 'INDIANB.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'IPCALAB.NS', 'IRB.NS', 'JINDALSAW.NS', 'KEC.NS', 'L&TFH.NS', 'LT.NS', 'LUPIN.NS', 'M&MFIN.NS', 'MCX.NS', 'MOTILALOFS.NS', 'MRPL.NS', 'MUTHOOTFIN.NS', 'NATCOPHARM.NS', 'NCC.NS', 'NH.NS', 'NLCINDIA.NS', 'ONGC.NS', 'PCBL.NS', 'PEL.NS', 'PFC.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'PNB.NS', 'PNBHOUSING.NS', 'RAIN.NS', 'RAJESHEXPO.NS', 'RECLTD.NS', 'RELIANCE.NS', 'RHIM.NS', 'RITES.NS', 'RVNL.NS', 'SAFARI.NS', 'SANOFI.NS', 'SBILIFE.NS', 'SFL.NS', 'SHOPERSTOP.NS', 'SOBHA.NS', 'SRF.NS', 'STLTECH.NS', 'SUNTV.NS', 'SWANENERGY.NS', 'SYNGENE.NS', 'TANLA.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'TEJASNET.NS', 'TRENT.NS', 'UNIONBANK.NS', 'WESTLIFE.NS', 'WIPRO.NS', 'ZEEL.NS', 'ZYDUSLIFE.NS'],
'2021-05-01': ['3MINDIA.NS', 'AAVAS.NS', 'ABB.NS', 'AIAENG.NS', 'ALKEM.NS', 'AMBER.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'BAJAJHLDNG.NS', 'BANDHANBNK.NS', 'BATAINDIA.NS', 'BBTC.NS', 'BDL.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BPCL.NS', 'CERA.NS', 'CHOLAHLDNG.NS', 'COFORGE.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DMART.NS', 'EICHERMOT.NS', 'EMAMILTD.NS', 'EPL.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GMMPFAUDLR.NS', 'GODREJPROP.NS', 'HAL.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'ICICIGI.NS', 'IGL.NS', 'IIFL.NS', 'INDIAMART.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INFY.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JUBLFOOD.NS', 'KAJARIACER.NS', 'KOTAKBANK.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'LTIM.NS', 'MCX.NS', 'MGL.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NH.NS', 'OBEROIRLTY.NS', 'PAGEIND.NS', 'PEL.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'QUESS.NS', 'RAMCOCEM.NS', 'RELAXO.NS', 'RELIANCE.NS', 'SBICARD.NS', 'SBIN.NS', 'SFL.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SOLARINDS.NS', 'SUNDRMFAST.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TANLA.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'VARROC.NS', 'VBL.NS', 'VIPIND.NS', 'VMART.NS', 'VOLTAS.NS', 'WESTLIFE.NS', 'WHIRLPOOL.NS'],
'2021-06-01': ['3MINDIA.NS', 'AARTIDRUGS.NS', 'ABCAPITAL.NS', 'ADANIPOWER.NS', 'AFFLE.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'ASTERDM.NS', 'AUBANK.NS', 'BANDHANBNK.NS', 'BAYERCROP.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'CERA.NS', 'CHOLAFIN.NS', 'COCHINSHIP.NS', 'CREDITACC.NS', 'DABUR.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'EPL.NS', 'ESCORTS.NS', 'FINEORG.NS', 'GICRE.NS', 'GODREJIND.NS', 'GSPL.NS', 'GUJALKALI.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'ICICIGI.NS', 'IDEA.NS', 'IEX.NS', 'IPCALAB.NS', 'JBMA.NS', 'JINDALSTEL.NS', 'KANSAINER.NS', 'KEC.NS', 'KRBL.NS', 'M&M.NS', 'M&MFIN.NS', 'MCX.NS', 'NCC.NS', 'PFIZER.NS', 'PGHH.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RAMCOCEM.NS', 'RITES.NS', 'SANOFI.NS', 'SHREECEM.NS', 'SUNPHARMA.NS', 'SUPRAJIT.NS', 'SUVENPHAR.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TEJASNET.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TVSMOTOR.NS', 'UJJIVANSFB.NS', 'UNIONBANK.NS', 'VAIBHAVGBL.NS', 'WHIRLPOOL.NS', 'ZYDUSWELL.NS'],
'2021-07-01': ['360ONE.NS', 'ADANIPOWER.NS', 'AEGISCHEM.NS', 'APARINDS.NS', 'APLLTD.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'AVANTIFEED.NS', 'BAJAJ-AUTO.NS', 'BANKINDIA.NS', 'BDL.NS', 'BHEL.NS', 'BLUEDART.NS', 'BORORENEW.NS', 'BOSCHLTD.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CEATLTD.NS', 'CGPOWER.NS', 'COALINDIA.NS', 'CUB.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'FINEORG.NS', 'GESHIP.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GMMPFAUDLR.NS', 'GUJALKALI.NS', 'HAL.NS', 'HDFCAMC.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HINDALCO.NS', 'HONAUT.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IDFC.NS', 'IIFL.NS', 'INDIGO.NS', 'INTELLECT.NS', 'IOC.NS', 'JBMA.NS', 'JINDALSTEL.NS', 'JMFINANCIL.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'L&TFH.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'LINDEINDIA.NS', 'MAHABANK.NS', 'MCX.NS', 'NHPC.NS', 'ONGC.NS', 'PGHH.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'RBLBANK.NS', 'RELIANCE.NS', 'SHARDACROP.NS', 'SIEMENS.NS', 'SJVN.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'SYNGENE.NS', 'TVSMOTOR.NS', 'UJJIVANSFB.NS', 'VBL.NS', 'VEDL.NS', 'VMART.NS', 'VOLTAS.NS', 'ZEEL.NS', 'ZFCVINDIA.NS'],
'2021-08-01': ['ALOKINDS.NS', 'APOLLOTYRE.NS', 'ASIANPAINT.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BEML.NS', 'CEATLTD.NS', 'CENTRALBK.NS', 'CGPOWER.NS', 'CHALET.NS', 'COALINDIA.NS', 'COLPAL.NS', 'EIHOTEL.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GODREJIND.NS', 'IDBI.NS', 'INDIACEM.NS', 'INDIANB.NS', 'INTELLECT.NS', 'IOB.NS', 'ITC.NS', 'ITI.NS', 'JUSTDIAL.NS', 'LEMONTREE.NS', 'MCDOWELL-N.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NBCC.NS', 'NCC.NS', 'NETWORK18.NS', 'NHPC.NS', 'NIACL.NS', 'NLCINDIA.NS', 'ONGC.NS', 'PATANJALI.NS', 'PNB.NS', 'PNBHOUSING.NS', 'POWERGRID.NS', 'PRINCEPIPE.NS', 'PRSMJOHNSN.NS', 'RENUKA.NS', 'SHARDACROP.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'TATAMTRDVR.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'TTKPRESTIG.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VGUARD.NS'],
'2021-09-01': ['ABFRL.NS', 'ALOKINDS.NS', 'AMBER.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'BAJAJ-AUTO.NS', 'BANKBARODA.NS', 'BAYERCROP.NS', 'BBTC.NS', 'BORORENEW.NS', 'CASTROLIND.NS', 'CDSL.NS', 'CEATLTD.NS', 'CENTURYPLY.NS', 'CERA.NS', 'CHALET.NS', 'CUB.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DIXON.NS', 'EIDPARRY.NS', 'ENGINERSIN.NS', 'ERIS.NS', 'FDC.NS', 'FINEORG.NS', 'FINPIPE.NS', 'GAIL.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GODFRYPHLP.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GRAPHITE.NS', 'GUJALKALI.NS', 'HEROMOTOCO.NS', 'HFCL.NS', 'HINDZINC.NS', 'HONAUT.NS', 'IDFC.NS', 'INDHOTEL.NS', 'INDUSINDBK.NS', 'INTELLECT.NS', 'IRCON.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JMFINANCIL.NS', 'JSWSTEEL.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KPRMILL.NS', 'KRBL.NS', 'MARUTI.NS', 'MOTILALOFS.NS', 'NETWORK18.NS', 'NTPC.NS', 'PATANJALI.NS', 'PGHL.NS', 'PNBHOUSING.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RAJESHEXPO.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TANLA.NS', 'TATAMTRDVR.NS', 'TRIVENI.NS', 'TTML.NS', 'UNIONBANK.NS', 'VGUARD.NS', 'VOLTAS.NS', 'ZFCVINDIA.NS'],
'2021-10-01': ['360ONE.NS', '3MINDIA.NS', 'ABCAPITAL.NS', 'ADANIENT.NS', 'ADANIPORTS.NS', 'APARINDS.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'ASAHIINDIA.NS', 'ASIANPAINT.NS', 'AUBANK.NS', 'BAJAJ-AUTO.NS', 'BDL.NS', 'BIOCON.NS', 'BPCL.NS', 'BSOFT.NS', 'CEATLTD.NS', 'CGCL.NS', 'CHOLAFIN.NS', 'COCHINSHIP.NS', 'CONCOR.NS', 'CRISIL.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DEEPAKFERT.NS', 'DRREDDY.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'EPL.NS', 'EXIDEIND.NS', 'FDC.NS', 'FINCABLES.NS', 'FINEORG.NS', 'FORTIS.NS', 'FSL.NS', 'GAEL.NS', 'GILLETTE.NS', 'GMMPFAUDLR.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'ICICIBANK.NS', 'ICICIPRULI.NS', 'IIFL.NS', 'INFY.NS', 'IPCALAB.NS', 'JINDALSTEL.NS', 'JMFINANCIL.NS', 'JYOTHYLAB.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'MRF.NS', 'NESTLEIND.NS', 'NIACL.NS', 'OFSS.NS', 'ORIENTELEC.NS', 'PAGEIND.NS', 'PEL.NS', 'PGHL.NS', 'PIIND.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'RHIM.NS', 'SAREGAMA.NS', 'SFL.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SUVENPHAR.NS', 'TANLA.NS', 'TATACOMM.NS', 'TECHM.NS', 'TORNTPHARM.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS', 'VARROC.NS', 'VEDL.NS', 'WIPRO.NS'],
'2021-11-01': ['AARTIIND.NS', 'ABBOTINDIA.NS', 'ADANIPOWER.NS', 'AIAENG.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'ASIANPAINT.NS', 'AVANTIFEED.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BANDHANBNK.NS', 'BANKINDIA.NS', 'BHARATFORG.NS', 'BIOCON.NS', 'BLS.NS', 'BSOFT.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CCL.NS', 'CENTRALBK.NS', 'CESC.NS', 'CIPLA.NS', 'COALINDIA.NS', 'CRISIL.NS', 'CROMPTON.NS', 'DALBHARAT.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'ECLERX.NS', 'ELGIEQUIP.NS', 'FINCABLES.NS', 'FLUOROCHEM.NS', 'FSL.NS', 'GAIL.NS', 'GLENMARK.NS', 'GUJGASLTD.NS', 'HAL.NS', 'HDFCBANK.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IDEA.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INFY.NS', 'IOB.NS', 'ISEC.NS', 'ITC.NS', 'ITI.NS', 'JINDALSAW.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JSWSTEEL.NS', 'KRBL.NS', 'LICHSGFIN.NS', 'MAXHEALTH.NS', 'MCX.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NMDC.NS', 'NTPC.NS', 'PEL.NS', 'PETRONET.NS', 'PFC.NS', 'PGHL.NS', 'POLYCAB.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'QUESS.NS', 'RAIN.NS', 'RATNAMANI.NS', 'RBLBANK.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RENUKA.NS', 'RHIM.NS', 'ROSSARI.NS', 'SAIL.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SHARDACROP.NS', 'SONATSOFTW.NS', 'SRF.NS', 'STLTECH.NS', 'SUNPHARMA.NS', 'SUPREMEIND.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATASTEEL.NS', 'TEAMLEASE.NS', 'TEJASNET.NS', 'TRENT.NS', 'VARROC.NS', 'VBL.NS', 'VEDL.NS', 'VINATIORGA.NS', 'WELCORP.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZENSARTECH.NS'],
'2021-12-01': ['3MINDIA.NS', 'AARTIIND.NS', 'ABFRL.NS', 'ADANIPOWER.NS', 'AIAENG.NS', 'ALKEM.NS', 'APARINDS.NS', 'ASIANPAINT.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ATUL.NS', 'BAJAJFINSV.NS', 'BEL.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'BLUESTARCO.NS', 'CANBK.NS', 'CENTRALBK.NS', 'CERA.NS', 'CESC.NS', 'CGCL.NS', 'CHALET.NS', 'CROMPTON.NS', 'DABUR.NS', 'DEEPAKFERT.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DRREDDY.NS', 'ECLERX.NS', 'EMAMILTD.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'FINPIPE.NS', 'GICRE.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODREJIND.NS', 'GRINDWELL.NS', 'GSPL.NS', 'HAL.NS', 'HCLTECH.NS', 'HFCL.NS', 'IBULHSGFIN.NS', 'IGL.NS', 'IIFL.NS', 'INDIAMART.NS', 'INDUSTOWER.NS', 'INFY.NS', 'IOB.NS', 'IPCALAB.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'ISEC.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JSL.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'KSB.NS', 'LAURUSLABS.NS', 'LAXMIMACH.NS', 'LUXIND.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MCDOWELL-N.NS', 'NATCOPHARM.NS', 'NETWORK18.NS', 'ONGC.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'PIIND.NS', 'POLYCAB.NS', 'PRESTIGE.NS', 'PRINCEPIPE.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RELAXO.NS', 'RELIANCE.NS', 'RHIM.NS', 'RITES.NS', 'RTNINDIA.NS', 'RVNL.NS', 'SAFARI.NS', 'SANOFI.NS', 'SBILIFE.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SJVN.NS', 'STLTECH.NS', 'SUMICHEM.NS', 'SUZLON.NS', 'SWSOLAR.NS', 'TATACOMM.NS', 'TATAELXSI.NS', 'TATAMOTORS.NS', 'TCS.NS', 'TEAMLEASE.NS', 'TTKPRESTIG.NS', 'TV18BRDCST.NS', 'ULTRACEMCO.NS', 'UNIONBANK.NS', 'USHAMART.NS', 'VARROC.NS', 'VBL.NS', 'VGUARD.NS', 'VIPIND.NS', 'VMART.NS', 'VOLTAS.NS', 'WELSPUNLIV.NS', 'WIPRO.NS', 'ZENSARTECH.NS'],
'2022-01-01': ['ACC.NS', 'ADANIGREEN.NS', 'AMBUJACEM.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BATAINDIA.NS', 'BDL.NS', 'BEML.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BLUEDART.NS', 'BPCL.NS', 'CERA.NS', 'CHOLAFIN.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CRISIL.NS', 'DALBHARAT.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DELTACORP.NS', 'DIVISLAB.NS', 'DMART.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'FINCABLES.NS', 'GESHIP.NS', 'GRASIM.NS', 'GUJGASLTD.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'HINDZINC.NS', 'ICICIGI.NS', 'IRCTC.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'JUBLPHARMA.NS', 'KSB.NS', 'LAXMIMACH.NS', 'LUXIND.NS', 'M&M.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MCX.NS', 'MOTILALOFS.NS', 'MRF.NS', 'NAUKRI.NS', 'OBEROIRLTY.NS', 'PHOENIXLTD.NS', 'RATNAMANI.NS', 'RELIANCE.NS', 'ROSSARI.NS', 'ROUTE.NS', 'SBICARD.NS', 'SBIN.NS', 'SHOPERSTOP.NS', 'SOLARINDS.NS', 'SUNDARMFIN.NS', 'SUPREMEIND.NS', 'SUVENPHAR.NS', 'SWSOLAR.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAMTRDVR.NS', 'TEJASNET.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS', 'VIPIND.NS', 'VMART.NS', 'WESTLIFE.NS', 'ZEEL.NS'],
'2022-02-01': ['3MINDIA.NS', 'AARTIIND.NS', 'ABCAPITAL.NS', 'ADANIENT.NS', 'ADANIPORTS.NS', 'ALKYLAMINE.NS', 'AMBUJACEM.NS', 'APOLLOTYRE.NS', 'ASTERDM.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BHEL.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'CDSL.NS', 'CENTURYTEX.NS', 'CESC.NS', 'CGPOWER.NS', 'COCHINSHIP.NS', 'COLPAL.NS', 'CROMPTON.NS', 'DLF.NS', 'EICHERMOT.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'FDC.NS', 'FORTIS.NS', 'GILLETTE.NS', 'GLENMARK.NS', 'GODFRYPHLP.NS', 'GODREJIND.NS', 'GPPL.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GSPL.NS', 'HDFCBANK.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'HINDZINC.NS', 'ICICIPRULI.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'INDUSTOWER.NS', 'IPCALAB.NS', 'IRCON.NS', 'ITI.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JMFINANCIL.NS', 'JYOTHYLAB.NS', 'KEI.NS', 'KOTAKBANK.NS', 'KSB.NS', 'LAURUSLABS.NS', 'LT.NS', 'LUPIN.NS', 'MAHLIFE.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'NAVINFLUOR.NS', 'NBCC.NS', 'NETWORK18.NS', 'NHPC.NS', 'PFC.NS', 'PGHL.NS', 'POLYMED.NS', 'RAIN.NS', 'RBLBANK.NS', 'RELIANCE.NS', 'RTNINDIA.NS', 'SAFARI.NS', 'SANOFI.NS', 'SBICARD.NS', 'SFL.NS', 'SHRIRAMFIN.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SYMPHONY.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TCS.NS', 'TEJASNET.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TORNTPOWER.NS', 'TTKPRESTIG.NS', 'UJJIVANSFB.NS', 'USHAMART.NS', 'VEDL.NS', 'VINATIORGA.NS', 'VMART.NS', 'WELSPUNLIV.NS', 'WHIRLPOOL.NS', 'YESBANK.NS'],
'2022-03-01': ['360ONE.NS', 'ABFRL.NS', 'ADANIPORTS.NS', 'AXISBANK.NS', 'BALRAMCHIN.NS', 'BLS.NS', 'BORORENEW.NS', 'BSE.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CENTURYPLY.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'CONCOR.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'FEDERALBNK.NS', 'GMRINFRA.NS', 'GRAPHITE.NS', 'GSFC.NS', 'GSPL.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'HINDZINC.NS', 'IDFC.NS', 'IIFL.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'IOC.NS', 'IRCTC.NS', 'ITC.NS', 'JAMNAAUTO.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JSWSTEEL.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'MAXHEALTH.NS', 'MMTC.NS', 'NLCINDIA.NS', 'ONGC.NS', 'PATANJALI.NS', 'PFC.NS', 'PHOENIXLTD.NS', 'POONAWALLA.NS', 'PRESTIGE.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RENUKA.NS', 'SAIL.NS', 'SHOPERSTOP.NS', 'SJVN.NS', 'SUMICHEM.NS', 'SUVENPHAR.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TATAPOWER.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'USHAMART.NS', 'YESBANK.NS'],
'2022-04-01': ['AAVAS.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'APARINDS.NS', 'APOLLOHOSP.NS', 'ASAHIINDIA.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BORORENEW.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CHOLAHLDNG.NS', 'COFORGE.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DIXON.NS', 'DMART.NS', 'EICHERMOT.NS', 'ERIS.NS', 'GALAXYSURF.NS', 'GLAND.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'HAPPSTMNDS.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HDFCLIFE.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'HINDZINC.NS', 'HONAUT.NS', 'IGL.NS', 'INDUSTOWER.NS', 'IRCTC.NS', 'ISEC.NS', 'JBCHEPHARM.NS', 'JSWENERGY.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'KPRMILL.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LT.NS', 'LUPIN.NS', 'MARUTI.NS', 'MAXHEALTH.NS', 'METROPOLIS.NS', 'MOTILALOFS.NS', 'MUTHOOTFIN.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'OLECTRA.NS', 'ONGC.NS', 'ORIENTELEC.NS', 'PEL.NS', 'PFIZER.NS', 'PGHH.NS', 'POLYCAB.NS', 'PRINCEPIPE.NS', 'RADICO.NS', 'RAIN.NS', 'RAJESHEXPO.NS', 'RAMCOCEM.NS', 'ROUTE.NS', 'SUNDARMFIN.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TTKPRESTIG.NS', 'UNOMINDA.NS', 'ZENSARTECH.NS', 'ZYDUSWELL.NS'],
'2022-05-01': ['ABB.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'AFFLE.NS', 'BAJAJHLDNG.NS', 'BAYERCROP.NS', 'BEML.NS', 'BHARATFORG.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'BRITANNIA.NS', 'CAMS.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CIPLA.NS', 'COALINDIA.NS', 'COFORGE.NS', 'CONCOR.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DALBHARAT.NS', 'DLF.NS', 'DRREDDY.NS', 'ERIS.NS', 'ESCORTS.NS', 'FLUOROCHEM.NS', 'FORTIS.NS', 'GALAXYSURF.NS', 'GLAND.NS', 'GLAXO.NS', 'GMMPFAUDLR.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GRINDWELL.NS', 'HINDZINC.NS', 'HONAUT.NS', 'ICICIGI.NS', 'INDIGO.NS', 'INTELLECT.NS', 'IPCALAB.NS', 'JBMA.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JSWENERGY.NS', 'JUBLFOOD.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'LUPIN.NS', 'MARUTI.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'NH.NS', 'OFSS.NS', 'ORIENTELEC.NS', 'PEL.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PIDILITIND.NS', 'PNCINFRA.NS', 'POLYCAB.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'PRINCEPIPE.NS', 'RADICO.NS', 'RATNAMANI.NS', 'REDINGTON.NS', 'ROSSARI.NS', 'SBILIFE.NS', 'SBIN.NS', 'SFL.NS', 'SKFINDIA.NS', 'SRF.NS', 'SUNDARMFIN.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATAELXSI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TEAMLEASE.NS', 'TITAN.NS', 'ULTRACEMCO.NS', 'VIPIND.NS', 'WESTLIFE.NS', 'WHIRLPOOL.NS'],
'2022-06-01': ['360ONE.NS', 'AARTIDRUGS.NS', 'AAVAS.NS', 'ADANIPORTS.NS', 'AFFLE.NS', 'AJANTPHARM.NS', 'ANGELONE.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'AUBANK.NS', 'AVANTIFEED.NS', 'AXISBANK.NS', 'BAJFINANCE.NS', 'BALRAMCHIN.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'BLUESTARCO.NS', 'BSE.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CEATLTD.NS', 'COFORGE.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'ERIS.NS', 'FINCABLES.NS', 'GILLETTE.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GODREJPROP.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HEG.NS', 'HINDZINC.NS', 'ICICIGI.NS', 'INFY.NS', 'INTELLECT.NS', 'IRCTC.NS', 'JKCEMENT.NS', 'JSWENERGY.NS', 'MAZDOCK.NS', 'MCDOWELL-N.NS', 'MGL.NS', 'MPHASIS.NS', 'NH.NS', 'OFSS.NS', 'OLECTRA.NS', 'PEL.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PGHL.NS', 'PIDILITIND.NS', 'PNCINFRA.NS', 'POLYCAB.NS', 'POLYMED.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'PRINCEPIPE.NS', 'RADICO.NS', 'RAMCOCEM.NS', 'RHIM.NS', 'ROUTE.NS', 'SANOFI.NS', 'SBIN.NS', 'SOLARINDS.NS', 'SONATSOFTW.NS', 'SUPREMEIND.NS', 'SWSOLAR.NS', 'TANLA.NS', 'TATACHEM.NS', 'TCS.NS', 'TEJASNET.NS', 'THERMAX.NS', 'TITAN.NS', 'TORNTPOWER.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'ZENSARTECH.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2022-07-01': ['ADANIPOWER.NS', 'AEGISCHEM.NS', 'ALOKINDS.NS', 'ASTERDM.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BORORENEW.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'COCHINSHIP.NS', 'CROMPTON.NS', 'DLF.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'FDC.NS', 'FSL.NS', 'GICRE.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GPPL.NS', 'IDEA.NS', 'IDFC.NS', 'IGL.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'IOB.NS', 'IOC.NS', 'IRB.NS', 'JBMA.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'LEMONTREE.NS', 'LICHSGFIN.NS', 'MHRIL.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NETWORK18.NS', 'NHPC.NS', 'NTPC.NS', 'OLECTRA.NS', 'ORIENTELEC.NS', 'PCBL.NS', 'PFC.NS', 'PNBHOUSING.NS', 'PRSMJOHNSN.NS', 'REDINGTON.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'SUMICHEM.NS', 'TATAMTRDVR.NS', 'TTML.NS', 'UCOBANK.NS', 'UJJIVANSFB.NS', 'WELSPUNLIV.NS', 'YESBANK.NS'],
'2022-08-01': ['AFFLE.NS', 'AMBER.NS', 'ANGELONE.NS', 'AUROPHARMA.NS', 'AVANTIFEED.NS', 'BAJAJ-AUTO.NS', 'BBTC.NS', 'BHARTIARTL.NS', 'BLUESTARCO.NS', 'BSE.NS', 'CDSL.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'DCMSHRIRAM.NS', 'DIXON.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'FDC.NS', 'GAEL.NS', 'GILLETTE.NS', 'GPIL.NS', 'GUJALKALI.NS', 'HDFCLIFE.NS', 'ICICIGI.NS', 'JKLAKSHMI.NS', 'JSWENERGY.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'KEI.NS', 'LAURUSLABS.NS', 'LUPIN.NS', 'MAXHEALTH.NS', 'METROPOLIS.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'NH.NS', 'OFSS.NS', 'PEL.NS', 'PFIZER.NS', 'POLYPLEX.NS', 'POWERINDIA.NS', 'PRINCEPIPE.NS', 'RAJESHEXPO.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RELIANCE.NS', 'SFL.NS', 'SHREECEM.NS', 'SOLARINDS.NS', 'SUPRAJIT.NS', 'SUVENPHAR.NS', 'SYMPHONY.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'TEJASNET.NS', 'THERMAX.NS', 'UTIAMC.NS', 'VGUARD.NS', 'VMART.NS', 'VOLTAS.NS', 'VTL.NS', 'ZYDUSWELL.NS'],
'2022-09-01': ['AARTIDRUGS.NS', 'ANGELONE.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BPCL.NS', 'BSE.NS', 'CAMS.NS', 'CHALET.NS', 'CREDITACC.NS', 'CRISIL.NS', 'DRREDDY.NS', 'GAIL.NS', 'GLAXO.NS', 'GRAPHITE.NS', 'HINDPETRO.NS', 'IEX.NS', 'IOC.NS', 'JAMNAAUTO.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'MCX.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MRPL.NS', 'MUTHOOTFIN.NS', 'OIL.NS', 'PEL.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PNBHOUSING.NS', 'RAJESHEXPO.NS', 'RENUKA.NS', 'SAREGAMA.NS', 'SUNTECK.NS', 'SWANENERGY.NS', 'TATAELXSI.NS', 'TEAMLEASE.NS', 'TRIVENI.NS', 'VGUARD.NS', 'VIPIND.NS', 'VOLTAS.NS', 'ZYDUSWELL.NS'],
'2022-10-01': ['ASHOKLEY.NS', 'BANKINDIA.NS', 'BEL.NS', 'CANBK.NS', 'CASTROLIND.NS', 'CESC.NS', 'DELTACORP.NS', 'EXIDEIND.NS', 'FDC.NS', 'FSL.NS', 'GAEL.NS', 'GAIL.NS', 'GMRINFRA.NS', 'GPIL.NS', 'GPPL.NS', 'GSPL.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'IDEA.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'IOB.NS', 'IRCON.NS', 'ITI.NS', 'JINDALSAW.NS', 'JSL.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'L&TFH.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'NHPC.NS', 'NIACL.NS', 'NTPC.NS', 'PCBL.NS', 'PNB.NS', 'PNCINFRA.NS', 'RBLBANK.NS', 'RCF.NS', 'REDINGTON.NS', 'RTNINDIA.NS', 'SAIL.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'STLTECH.NS', 'SUZLON.NS', 'TATASTEEL.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'WELSPUNLIV.NS', 'YESBANK.NS'],
'2022-11-01': ['3MINDIA.NS', 'ABB.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'AUBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BATAINDIA.NS', 'BIRLACORPN.NS', 'BORORENEW.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CDSL.NS', 'CHOLAHLDNG.NS', 'CREDITACC.NS', 'CSBBANK.NS', 'DCMSHRIRAM.NS', 'DIVISLAB.NS', 'DMART.NS', 'EMAMILTD.NS', 'FLUOROCHEM.NS', 'GILLETTE.NS', 'GMMPFAUDLR.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'ICICIGI.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'IPCALAB.NS', 'JBMA.NS', 'KPRMILL.NS', 'LICHSGFIN.NS', 'LTTS.NS', 'LUXIND.NS', 'MUTHOOTFIN.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'OBEROIRLTY.NS', 'ORIENTELEC.NS', 'PAGEIND.NS', 'PGHH.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RADICO.NS', 'RAIN.NS', 'RAMCOCEM.NS', 'RHIM.NS', 'SAREGAMA.NS', 'SFL.NS', 'SHRIRAMFIN.NS', 'SRF.NS', 'SUMICHEM.NS', 'SUPRAJIT.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAMOTORS.NS', 'THERMAX.NS', 'TIMKEN.NS', 'TORNTPOWER.NS', 'TRIVENI.NS', 'UBL.NS', 'UNOMINDA.NS', 'VTL.NS'],
'2022-12-01': ['3MINDIA.NS', 'AARTIDRUGS.NS', 'ABFRL.NS', 'ADANIGREEN.NS', 'ALKEM.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'ASTERDM.NS', 'ATUL.NS', 'BALAMINES.NS', 'BANDHANBNK.NS', 'BCG.NS', 'BEL.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BRIGADE.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CHAMBLFERT.NS', 'DEEPAKNTR.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'FDC.NS', 'FINEORG.NS', 'GILLETTE.NS', 'GUJGASLTD.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INFIBEAM.NS', 'INGERRAND.NS', 'ISEC.NS', 'ITC.NS', 'JAMNAAUTO.NS', 'JSWENERGY.NS', 'JUSTDIAL.NS', 'KEC.NS', 'KEI.NS', 'KPRMILL.NS', 'LALPATHLAB.NS', 'LICHSGFIN.NS', 'LTIM.NS', 'MARICO.NS', 'MARUTI.NS', 'MFSL.NS', 'MPHASIS.NS', 'NAUKRI.NS', 'NH.NS', 'PGHL.NS', 'POONAWALLA.NS', 'PRINCEPIPE.NS', 'RATNAMANI.NS', 'RELAXO.NS', 'RITES.NS', 'ROUTE.NS', 'SAREGAMA.NS', 'SBICARD.NS', 'SHARDACROP.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SUMICHEM.NS', 'SUNDRMFAST.NS', 'TATAINVEST.NS', 'TATAPOWER.NS', 'TRIDENT.NS', 'TTML.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VAIBHAVGBL.NS', 'VARROC.NS', 'VGUARD.NS', 'ZFCVINDIA.NS', 'ZYDUSLIFE.NS'],
'2023-01-01': ['360ONE.NS', 'ADANIENT.NS', 'AJANTPHARM.NS', 'APLAPOLLO.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'ATUL.NS', 'BAJAJ-AUTO.NS', 'BEML.NS', 'BIRLACORPN.NS', 'BSOFT.NS', 'CANFINHOME.NS', 'CESC.NS', 'CGCL.NS', 'CHALET.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'CONCOR.NS', 'CREDITACC.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'DELTACORP.NS', 'DIVISLAB.NS', 'DMART.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'GILLETTE.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GODREJCP.NS', 'GRAPHITE.NS', 'GUJALKALI.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'HINDCOPPER.NS', 'HONAUT.NS', 'INDHOTEL.NS', 'INDIAMART.NS', 'INFIBEAM.NS', 'INTELLECT.NS', 'JKPAPER.NS', 'JUBLPHARMA.NS', 'KANSAINER.NS', 'KRBL.NS', 'KSB.NS', 'LEMONTREE.NS', 'LT.NS', 'LUPIN.NS', 'M&M.NS', 'MARICO.NS', 'MASTEK.NS', 'MAZDOCK.NS', 'MCX.NS', 'MHRIL.NS', 'MMTC.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NAUKRI.NS', 'NETWORK18.NS', 'OFSS.NS', 'PEL.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'PIIND.NS', 'PRESTIGE.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'SAFARI.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SUNDARMFIN.NS', 'SUNPHARMA.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TCS.NS', 'TIINDIA.NS', 'TRIVENI.NS', 'TV18BRDCST.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'VARROC.NS', 'VMART.NS', 'VTL.NS', 'WIPRO.NS'],
'2023-02-01': ['360ONE.NS', 'ABB.NS', 'ABCAPITAL.NS', 'AMBER.NS', 'AUBANK.NS', 'AVANTIFEED.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BHEL.NS', 'BRIGADE.NS', 'CANBK.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CGCL.NS', 'CHOLAFIN.NS', 'COCHINSHIP.NS', 'CROMPTON.NS', 'DABUR.NS', 'DALBHARAT.NS', 'EIDPARRY.NS', 'EQUITASBNK.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FORTIS.NS', 'GAIL.NS', 'GESHIP.NS', 'GMRINFRA.NS', 'GODREJIND.NS', 'GPPL.NS', 'GSFC.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'HINDUNILVR.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'INDHOTEL.NS', 'IOB.NS', 'IPCALAB.NS', 'IRB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JKLAKSHMI.NS', 'KANSAINER.NS', 'KNRCON.NS', 'KRBL.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'LUPIN.NS', 'MANAPPURAM.NS', 'MAXHEALTH.NS', 'MCX.NS', 'METROPOLIS.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MRPL.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NBCC.NS', 'NETWORK18.NS', 'NH.NS', 'NIACL.NS', 'NLCINDIA.NS', 'ONGC.NS', 'ORIENTELEC.NS', 'PETRONET.NS', 'PFC.NS', 'PNB.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'RAIN.NS', 'RCF.NS', 'RTNINDIA.NS', 'SCHAEFFLER.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'SUNDARMFIN.NS', 'TATACHEM.NS', 'TECHM.NS', 'TEJASNET.NS', 'TRITURBINE.NS', 'UJJIVANSFB.NS', 'UNIONBANK.NS', 'VAIBHAVGBL.NS', 'VMART.NS', 'VOLTAS.NS'],
'2023-03-01': ['AAVAS.NS', 'ABBOTINDIA.NS', 'AFFLE.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'AMBER.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BANDHANBNK.NS', 'BBTC.NS', 'BEL.NS', 'BORORENEW.NS', 'CAMS.NS', 'CENTURYPLY.NS', 'COALINDIA.NS', 'COLPAL.NS', 'DALBHARAT.NS', 'DLF.NS', 'DRREDDY.NS', 'ECLERX.NS', 'EMAMILTD.NS', 'ERIS.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FINPIPE.NS', 'GAEL.NS', 'GALAXYSURF.NS', 'GLAND.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GSFC.NS', 'HAPPSTMNDS.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'ICICIBANK.NS', 'INFIBEAM.NS', 'JBCHEPHARM.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'LT.NS', 'MARICO.NS', 'MARUTI.NS', 'MAXHEALTH.NS', 'MAZDOCK.NS', 'MCX.NS', 'METROPOLIS.NS', 'MPHASIS.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NCC.NS', 'NLCINDIA.NS', 'PCBL.NS', 'PIIND.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RBLBANK.NS', 'RECLTD.NS', 'RITES.NS', 'SAIL.NS', 'SBICARD.NS', 'SFL.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SPARC.NS', 'SRF.NS', 'SUMICHEM.NS', 'SUNDARMFIN.NS', 'SUVENPHAR.NS', 'TATACHEM.NS', 'TATAMOTORS.NS', 'TATAPOWER.NS', 'TEJASNET.NS', 'TIMKEN.NS', 'TRENT.NS', 'TRIVENI.NS', 'TTKPRESTIG.NS', 'UCOBANK.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'VTL.NS', 'ZYDUSWELL.NS'],
'2023-04-01': ['360ONE.NS', 'AARTIIND.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'AMBUJACEM.NS', 'APLLTD.NS', 'ASHOKLEY.NS', 'BANKINDIA.NS', 'BEML.NS', 'BLUESTARCO.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CENTURYTEX.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'ELGIEQUIP.NS', 'ENGINERSIN.NS', 'EXIDEIND.NS', 'FDC.NS', 'FORTIS.NS', 'GAEL.NS', 'GPIL.NS', 'GSPL.NS', 'HINDALCO.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IGL.NS', 'INDIACEM.NS', 'INTELLECT.NS', 'IOC.NS', 'JAMNAAUTO.NS', 'JINDALSTEL.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JUBLFOOD.NS', 'JYOTHYLAB.NS', 'KEC.NS', 'KNRCON.NS', 'KRBL.NS', 'M&MFIN.NS', 'MAHLIFE.NS', 'MAXHEALTH.NS', 'MCDOWELL-N.NS', 'METROPOLIS.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NHPC.NS', 'NLCINDIA.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'ONGC.NS', 'PCBL.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'PRESTIGE.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RENUKA.NS', 'RHIM.NS', 'SAIL.NS', 'SBIN.NS', 'SPARC.NS', 'SUMICHEM.NS', 'SUPRAJIT.NS', 'SUVENPHAR.NS', 'SWSOLAR.NS', 'TATACONSUM.NS', 'TATAMTRDVR.NS', 'TRIVENI.NS', 'UJJIVANSFB.NS', 'UNIONBANK.NS', 'UNOMINDA.NS', 'VTL.NS'],
'2023-05-01': ['360ONE.NS', 'ABFRL.NS', 'ACC.NS', 'ALKYLAMINE.NS', 'AMBER.NS', 'APLAPOLLO.NS', 'AVANTIFEED.NS', 'AXISBANK.NS', 'BAYERCROP.NS', 'CERA.NS', 'CESC.NS', 'CIPLA.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DIXON.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'ELGIEQUIP.NS', 'FINEORG.NS', 'FINPIPE.NS', 'FORTIS.NS', 'GODFRYPHLP.NS', 'GUJGASLTD.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HINDCOPPER.NS', 'HINDZINC.NS', 'ICICIGI.NS', 'INDIACEM.NS', 'ISEC.NS', 'JKPAPER.NS', 'KARURVYSYA.NS', 'KEC.NS', 'LAURUSLABS.NS', 'LAXMIMACH.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MOTILALOFS.NS', 'NH.NS', 'NTPC.NS', 'OIL.NS', 'PATANJALI.NS', 'PNCINFRA.NS', 'QUESS.NS', 'RADICO.NS', 'RAMCOCEM.NS', 'REDINGTON.NS', 'RHIM.NS', 'ROUTE.NS', 'SAIL.NS', 'SHARDACROP.NS', 'SOLARINDS.NS', 'STLTECH.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUVENPHAR.NS', 'SWSOLAR.NS', 'TCS.NS', 'TIINDIA.NS', 'TTML.NS', 'TV18BRDCST.NS', 'VEDL.NS', 'VIPIND.NS', 'WHIRLPOOL.NS', 'YESBANK.NS'],
'2023-06-01': ['360ONE.NS', 'AARTIDRUGS.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'APLLTD.NS', 'ASHOKLEY.NS', 'BALRAMCHIN.NS', 'BLUESTARCO.NS', 'CENTRALBK.NS', 'CESC.NS', 'COCHINSHIP.NS', 'CROMPTON.NS', 'CSBBANK.NS', 'DMART.NS', 'EPL.NS', 'FACT.NS', 'FINPIPE.NS', 'FORTIS.NS', 'GMMPFAUDLR.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GSFC.NS', 'HFCL.NS', 'IEX.NS', 'IGL.NS', 'IIFL.NS', 'INFY.NS', 'IOB.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'KPRMILL.NS', 'LINDEINDIA.NS', 'MMTC.NS', 'NHPC.NS', 'NTPC.NS', 'OIL.NS', 'PETRONET.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'RAIN.NS', 'RHIM.NS', 'RITES.NS', 'RTNINDIA.NS', 'SAIL.NS', 'SAREGAMA.NS', 'SHARDACROP.NS', 'SJVN.NS', 'SPARC.NS', 'SUPRAJIT.NS', 'TATACHEM.NS', 'TATASTEEL.NS', 'TEAMLEASE.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'TTML.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VGUARD.NS', 'VOLTAS.NS', 'VTL.NS', 'ZEEL.NS', 'ZYDUSLIFE.NS'],
'2023-07-01': ['ABFRL.NS', 'ADANIPOWER.NS', 'BPCL.NS', 'CESC.NS', 'COALINDIA.NS', 'FEDERALBNK.NS', 'FINPIPE.NS', 'FSL.NS', 'GICRE.NS', 'GMRINFRA.NS', 'GSFC.NS', 'HINDALCO.NS', 'HUDCO.NS', 'IDEA.NS', 'IGL.NS', 'INDIACEM.NS', 'IOB.NS', 'IRCON.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'LEMONTREE.NS', 'MAHABANK.NS', 'MARICO.NS', 'MINDACORP.NS', 'MMTC.NS', 'NCC.NS', 'NETWORK18.NS', 'NIACL.NS', 'ONGC.NS', 'ORIENTELEC.NS', 'PNB.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'RAIN.NS', 'RCF.NS', 'RENUKA.NS', 'RVNL.NS', 'SAIL.NS', 'SBIN.NS', 'TATASTEEL.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VAIBHAVGBL.NS', 'WELSPUNLIV.NS', 'WIPRO.NS', 'YESBANK.NS'],
'2023-08-01': ['ANGELONE.NS', 'ATGL.NS', 'ATUL.NS', 'AXISBANK.NS', 'BAJFINANCE.NS', 'BALAMINES.NS', 'BANDHANBNK.NS', 'BAYERCROP.NS', 'BCG.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'CANFINHOME.NS', 'CERA.NS', 'COALINDIA.NS', 'DEEPAKNTR.NS', 'DIXON.NS', 'EICHERMOT.NS', 'ELGIEQUIP.NS', 'GMMPFAUDLR.NS', 'GNFC.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GSFC.NS', 'GSPL.NS', 'GUJALKALI.NS', 'HAPPSTMNDS.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HINDPETRO.NS', 'IOC.NS', 'IRB.NS', 'JUBLFOOD.NS', 'JUBLPHARMA.NS', 'KOTAKBANK.NS', 'LTIM.NS', 'MASTEK.NS', 'METROPOLIS.NS', 'NESTLEIND.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'PIDILITIND.NS', 'PIIND.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RAMCOCEM.NS', 'REDINGTON.NS', 'ROSSARI.NS', 'ROUTE.NS', 'SAFARI.NS', 'SBICARD.NS', 'SHREECEM.NS', 'STLTECH.NS', 'SUMICHEM.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'TIINDIA.NS', 'VBL.NS', 'VEDL.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'ZYDUSWELL.NS'],
'2023-09-01': ['360ONE.NS', 'ABBOTINDIA.NS', 'ABCAPITAL.NS', 'ADANIENT.NS', 'AFFLE.NS', 'ASIANPAINT.NS', 'AUBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BATAINDIA.NS', 'BBTC.NS', 'BDL.NS', 'BHARTIARTL.NS', 'BIRLACORPN.NS', 'BLUESTARCO.NS', 'BOSCHLTD.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CDSL.NS', 'CEATLTD.NS', 'COALINDIA.NS', 'CONCOR.NS', 'DABUR.NS', 'DIVISLAB.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'ELGIEQUIP.NS', 'GRANULES.NS', 'GRASIM.NS', 'GSPL.NS', 'HEROMOTOCO.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'IDBI.NS', 'IEX.NS', 'INDUSINDBK.NS', 'INFIBEAM.NS', 'JSWSTEEL.NS', 'JUSTDIAL.NS', 'KARURVYSYA.NS', 'LUXIND.NS', 'M&MFIN.NS', 'METROPOLIS.NS', 'MGL.NS', 'MUTHOOTFIN.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'OIL.NS', 'PATANJALI.NS', 'PFIZER.NS', 'PIDILITIND.NS', 'PIIND.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'RADICO.NS', 'RAMCOCEM.NS', 'SCHAEFFLER.NS', 'SFL.NS', 'SHARDACROP.NS', 'SHREECEM.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TATAMOTORS.NS', 'TCS.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TRITURBINE.NS', 'UBL.NS', 'UNIONBANK.NS', 'UTIAMC.NS', 'YESBANK.NS'],
'2023-10-01': ['360ONE.NS', 'AARTIIND.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ADANIGREEN.NS', 'ALLCARGO.NS', 'BCG.NS', 'CANFINHOME.NS', 'CHAMBLFERT.NS', 'CUB.NS', 'ENGINERSIN.NS', 'EXIDEIND.NS', 'GPPL.NS', 'GSPL.NS', 'HDFCLIFE.NS', 'ICICIPRULI.NS', 'IEX.NS', 'IGL.NS', 'INDIACEM.NS', 'IOC.NS', 'ISEC.NS', 'ITC.NS', 'JAMNAAUTO.NS', 'JUBLPHARMA.NS', 'KRBL.NS', 'MAXHEALTH.NS', 'MCDOWELL-N.NS', 'MGL.NS', 'MOTHERSON.NS', 'NETWORK18.NS', 'PEL.NS', 'PRESTIGE.NS', 'PRINCEPIPE.NS', 'PRSMJOHNSN.NS', 'RAIN.NS', 'SAIL.NS', 'SFL.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'STLTECH.NS', 'SUMICHEM.NS', 'SWSOLAR.NS', 'TANLA.NS', 'TATACHEM.NS', 'TRIDENT.NS', 'TTKPRESTIG.NS', 'TV18BRDCST.NS', 'UNOMINDA.NS', 'UPL.NS', 'VIPIND.NS', 'WESTLIFE.NS', 'YESBANK.NS', 'ZYDUSLIFE.NS'],
'2023-11-01': ['ABCAPITAL.NS', 'ABFRL.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'ASAHIINDIA.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BCG.NS', 'BEL.NS', 'BERGEPAINT.NS', 'BHEL.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CESC.NS', 'CHALET.NS', 'CIEINDIA.NS', 'COCHINSHIP.NS', 'CSBBANK.NS', 'EXIDEIND.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FORTIS.NS', 'FSL.NS', 'GAIL.NS', 'GMRINFRA.NS', 'GPPL.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IEX.NS', 'INDUSTOWER.NS', 'IOB.NS', 'IOC.NS', 'IRCTC.NS', 'JAMNAAUTO.NS', 'JMFINANCIL.NS', 'JSL.NS', 'KEC.NS', 'KNRCON.NS', 'LEMONTREE.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NCC.NS', 'NETWORK18.NS', 'NHPC.NS', 'ORIENTELEC.NS', 'PRAJIND.NS', 'RBLBANK.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'RVNL.NS', 'SBIN.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UJJIVANSFB.NS'],
'2023-12-01': ['AARTIDRUGS.NS', 'ACC.NS', 'ALLCARGO.NS', 'AMBER.NS', 'APLLTD.NS', 'ASAHIINDIA.NS', 'ASIANPAINT.NS', 'ATUL.NS', 'BANKBARODA.NS', 'BBTC.NS', 'BCG.NS', 'BERGEPAINT.NS', 'BIOCON.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'CENTRALBK.NS', 'CGCL.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'CROMPTON.NS', 'DABUR.NS', 'DELTACORP.NS', 'EMAMILTD.NS', 'EPL.NS', 'EQUITASBNK.NS', 'ESCORTS.NS', 'FINPIPE.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'HAPPSTMNDS.NS', 'HAVELLS.NS', 'HEG.NS', 'HFCL.NS', 'HINDZINC.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IIFL.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'IOB.NS', 'ITC.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JMFINANCIL.NS', 'JUSTDIAL.NS', 'KOTAKBANK.NS', 'LEMONTREE.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MGL.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NAVINFLUOR.NS', 'OFSS.NS', 'OIL.NS', 'ORIENTELEC.NS', 'POLYPLEX.NS', 'RBLBANK.NS', 'RENUKA.NS', 'RITES.NS', 'ROUTE.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'STLTECH.NS', 'SUNDRMFAST.NS', 'SUPRAJIT.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TEAMLEASE.NS', 'TRIDENT.NS', 'TTKPRESTIG.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UPL.NS', 'VEDL.NS', 'VOLTAS.NS', 'ZEEL.NS', 'ZYDUSWELL.NS'],
'2024-01-01': ['AARTIDRUGS.NS', 'AAVAS.NS', 'ABBOTINDIA.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'AEGISCHEM.NS', 'AMBER.NS', 'APLLTD.NS', 'ASTRAL.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BLUESTARCO.NS', 'BSE.NS', 'CAMS.NS', 'CANFINHOME.NS', 'CCL.NS', 'CENTURYTEX.NS', 'CGCL.NS', 'CHOLAHLDNG.NS', 'CUB.NS', 'DALBHARAT.NS', 'FDC.NS', 'FINPIPE.NS', 'GAEL.NS', 'GALAXYSURF.NS', 'GMMPFAUDLR.NS', 'GODFRYPHLP.NS', 'HONAUT.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'INDIAMART.NS', 'INDIANB.NS', 'JSWENERGY.NS', 'KPRMILL.NS', 'LALPATHLAB.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MARUTI.NS', 'MFSL.NS', 'PEL.NS', 'PGHH.NS', 'PIIND.NS', 'PNBHOUSING.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PRAJIND.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RELAXO.NS', 'SBICARD.NS', 'SHOPERSTOP.NS', 'SUMICHEM.NS', 'SUNDRMFAST.NS', 'SYMPHONY.NS', 'TRIDENT.NS', 'TTML.NS', 'UJJIVANSFB.NS', 'UPL.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'VTL.NS', 'ZFCVINDIA.NS'],
'2024-02-01': ['360ONE.NS', 'ABCAPITAL.NS', 'AFFLE.NS', 'ALLCARGO.NS', 'ANGELONE.NS', 'ASHOKLEY.NS', 'BALRAMCHIN.NS', 'BIOCON.NS', 'BSE.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'DABUR.NS', 'DCMSHRIRAM.NS', 'EQUITASBNK.NS', 'FINEORG.NS', 'FINPIPE.NS', 'GMMPFAUDLR.NS', 'GNFC.NS', 'IDEA.NS', 'IEX.NS', 'IIFL.NS', 'JSWSTEEL.NS', 'KAJARIACER.NS', 'KPITTECH.NS', 'KRBL.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'M&M.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'METROPOLIS.NS', 'MUTHOOTFIN.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'PAGEIND.NS', 'PGHH.NS', 'PRINCEPIPE.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RAMCOCEM.NS', 'RENUKA.NS', 'ROSSARI.NS', 'SAFARI.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'SUVENPHAR.NS', 'TATACOMM.NS', 'TTML.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'ZENSARTECH.NS'],

    
 }
# Initialize lists to store results
ticker_list = []
percentage_returns = []
first_day_closes = []
last_day_closes = []
start_dates = []  # List to store the start dates
end_dates = []    # List to store the end dates

# Loop through the dictionary and download data for each date-ticker pair
for start_date, tickers in date_ticker_dict.items():
    end_date = pd.to_datetime(start_date) + pd.DateOffset(months=1) - pd.DateOffset(days=1)  # Last day of the month

    # Loop through tickers in this iteration
    for ticker in tickers:
        # Download historical stock data using yfinance for the specified ticker and dates
        try:
            stocks = yf.download(ticker, start=start_date, end=end_date)

            # Extracting the closing prices on the first and last day
            first_day_close = stocks['Close'].iloc[0]
            last_day_close = stocks['Close'].iloc[-1]

            # Calculating percentage return for this ticker
            percentage_return = ((last_day_close - first_day_close) / first_day_close) * 100

            # Appending the results to the lists
            ticker_list.append(ticker)
            percentage_returns.append(percentage_return)
            first_day_closes.append(first_day_close)
            last_day_closes.append(last_day_close)
            start_dates.append(pd.to_datetime(start_date))
            end_dates.append(end_date)  # Append end date for each ticker
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

# Creating a DataFrame with ticker symbols, percentage returns, and capital information
returns_df = pd.DataFrame({
    'Start_Date': start_dates,
    'End_Date': end_dates,
    'Ticker': ticker_list,
    'Percentage_Return': percentage_returns,
    'First_Day_Close': first_day_closes,
    'Last_Day_Close': last_day_closes,
})

# Assuming an initial investment of $10,000 for each stock
initial_investment = 10000

# Calculating the capital at the last day
returns_df['Capital_At_Last_Day'] = initial_investment * (1 + returns_df['Percentage_Return'] / 100)

# Calculating the difference between capital at the last day and capital required
returns_df['Capital_Difference'] = returns_df['Capital_At_Last_Day'] - initial_investment

# Total amount invested
total_invested = initial_investment * len(returns_df)

# Total amount returned
total_returned = returns_df['Capital_At_Last_Day'].sum()

# Calculate percentage return
percentage_return = ((total_returned - total_invested) / total_invested) * 100

# Displaying the DataFrame with ticker names, percentage returns, and capital information
print(returns_df[['Start_Date', 'End_Date', 'Ticker', 'Percentage_Return', 'First_Day_Close', 'Last_Day_Close']])

# Display total amount invested and total amount returned in percentage
print("\nTotal Amount Invested: $", total_invested)
print("Total Amount Returned: $", total_returned)
print("Percentage Return: ", percentage_return, "%")

returns_df.to_csv('stock_Cluster3.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %% [markdown]
# # For cluster 4

# %%
import yfinance as yf
import pandas as pd

# Input dictionary
date_ticker_dict =  {
    
    '2017-04-01': ['ABFRL.NS', 'AEGISCHEM.NS', 'ALLCARGO.NS', 'BEL.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BPCL.NS', 'CIPLA.NS', 'DABUR.NS', 'DEEPAKFERT.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'GAIL.NS', 'GLAXO.NS', 'GMRINFRA.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GRASIM.NS', 'GSPL.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'IDFC.NS', 'IGL.NS', 'INDIACEM.NS', 'INDIANB.NS', 'INFY.NS', 'IOB.NS', 'IRB.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'JUSTDIAL.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MARUTI.NS', 'MFSL.NS', 'MINDACORP.NS', 'MRPL.NS', 'NTPC.NS', 'OIL.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'SAIL.NS', 'SRF.NS', 'STLTECH.NS', 'SUNPHARMA.NS', 'TATASTEEL.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UPL.NS', 'VAIBHAVGBL.NS', 'VTL.NS', 'WELSPUNLIV.NS', 'ZENSARTECH.NS'],
'2017-05-01': ['ADANIPORTS.NS', 'AEGISCHEM.NS', 'APLLTD.NS', 'ATUL.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJHLDNG.NS', 'BHARTIARTL.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'CCL.NS', 'CENTURYPLY.NS', 'COROMANDEL.NS', 'DABUR.NS', 'DEEPAKFERT.NS', 'EMAMILTD.NS', 'EXIDEIND.NS', 'GLENMARK.NS', 'GODFRYPHLP.NS', 'HINDPETRO.NS', 'IPCALAB.NS', 'ITC.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JSL.NS', 'KSB.NS', 'MCX.NS', 'MMTC.NS', 'NAUKRI.NS', 'NH.NS', 'NHPC.NS', 'PAGEIND.NS', 'PETRONET.NS', 'PGHH.NS', 'PGHL.NS', 'PIIND.NS', 'POLYMED.NS', 'RAMCOCEM.NS', 'SAREGAMA.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SUNDARMFIN.NS', 'SUPRAJIT.NS', 'SWANENERGY.NS', 'TITAN.NS', 'TTKPRESTIG.NS', 'ZEEL.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2017-06-01': ['ABB.NS', 'ADANIPORTS.NS', 'AIAENG.NS', 'APOLLOTYRE.NS', 'AXISBANK.NS', 'BALKRISIND.NS', 'BBTC.NS', 'BCG.NS', 'BERGEPAINT.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'CANBK.NS', 'CASTROLIND.NS', 'CESC.NS', 'CIEINDIA.NS', 'COLPAL.NS', 'CONCOR.NS', 'DABUR.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'EPL.NS', 'FACT.NS', 'GAEL.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GODREJPROP.NS', 'GRAPHITE.NS', 'GSFC.NS', 'HAVELLS.NS', 'HEG.NS', 'INDIACEM.NS', 'INDUSTOWER.NS', 'INFY.NS', 'INTELLECT.NS', 'IOC.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JSWSTEEL.NS', 'KANSAINER.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'L&TFH.NS', 'LUXIND.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MRPL.NS', 'NBCC.NS', 'NESTLEIND.NS', 'NETWORK18.NS', 'NLCINDIA.NS', 'PETRONET.NS', 'PHOENIXLTD.NS', 'PNCINFRA.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RAIN.NS', 'RALLIS.NS', 'RCF.NS', 'RELIANCE.NS', 'SBIN.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'STLTECH.NS', 'SUPREMEIND.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'THERMAX.NS', 'TITAN.NS', 'TRITURBINE.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'VEDL.NS', 'VIPIND.NS', 'VMART.NS', 'WELCORP.NS', 'ZYDUSLIFE.NS'],
'2017-07-01': ['3MINDIA.NS', 'AARTIDRUGS.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'ADANIPOWER.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'BAJAJHLDNG.NS', 'BBTC.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CENTURYTEX.NS', 'CHAMBLFERT.NS', 'CROMPTON.NS', 'CUB.NS', 'DLF.NS', 'ECLERX.NS', 'FEDERALBNK.NS', 'GESHIP.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GPPL.NS', 'HCLTECH.NS', 'IGL.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INGERRAND.NS', 'INTELLECT.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JKLAKSHMI.NS', 'JSWENERGY.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'M&MFIN.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MASTEK.NS', 'MCX.NS', 'MPHASIS.NS', 'MRF.NS', 'NAVINFLUOR.NS', 'NH.NS', 'PETRONET.NS', 'PGHL.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'REDINGTON.NS', 'RELAXO.NS', 'RELIANCE.NS', 'RHIM.NS', 'SAIL.NS', 'SANOFI.NS', 'SHOPERSTOP.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SPARC.NS', 'SUNTV.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TTKPRESTIG.NS', 'TTML.NS', 'USHAMART.NS', 'VOLTAS.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZYDUSWELL.NS'],
'2017-08-01': ['ADANIENT.NS', 'AIAENG.NS', 'APLAPOLLO.NS', 'AXISBANK.NS', 'BHARATFORG.NS', 'BHEL.NS', 'BLS.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'CENTURYPLY.NS', 'CGPOWER.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'COLPAL.NS', 'CROMPTON.NS', 'CYIENT.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'FEDERALBNK.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODREJPROP.NS', 'IDEA.NS', 'IDFC.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'IRB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KEI.NS', 'KNRCON.NS', 'MASTEK.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MMTC.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NETWORK18.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'OIL.NS', 'OLECTRA.NS', 'ONGC.NS', 'PCBL.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RHIM.NS', 'SHOPERSTOP.NS', 'SHRIRAMFIN.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'SUPRAJIT.NS', 'TANLA.NS', 'TCS.NS', 'TEAMLEASE.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UNIONBANK.NS', 'VAIBHAVGBL.NS', 'VMART.NS', 'VTL.NS', 'WHIRLPOOL.NS'],
'2017-09-01': ['ADANIPORTS.NS', 'AEGISCHEM.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'AUROPHARMA.NS', 'BAJAJ-AUTO.NS', 'CCL.NS', 'CENTRALBK.NS', 'CHOLAFIN.NS', 'CIPLA.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'CROMPTON.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'ESCORTS.NS', 'FACT.NS', 'FINPIPE.NS', 'GAIL.NS', 'GESHIP.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'ICICIBANK.NS', 'IDEA.NS', 'INDIGO.NS', 'JINDALSTEL.NS', 'JSWENERGY.NS', 'KARURVYSYA.NS', 'MANAPPURAM.NS', 'MCDOWELL-N.NS', 'MINDACORP.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'OIL.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'POWERGRID.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'RENUKA.NS', 'SAIL.NS', 'SJVN.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'SRF.NS', 'SUNDRMFAST.NS', 'TCS.NS', 'TIMKEN.NS', 'TV18BRDCST.NS', 'USHAMART.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'VOLTAS.NS', 'WHIRLPOOL.NS'],
'2017-10-01': ['AARTIIND.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'APLAPOLLO.NS', 'AXISBANK.NS', 'BAJFINANCE.NS', 'BATAINDIA.NS', 'BSOFT.NS', 'CIEINDIA.NS', 'COROMANDEL.NS', 'CUB.NS', 'CUMMINSIND.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DELTACORP.NS', 'DRREDDY.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'ESCORTS.NS', 'FEDERALBNK.NS', 'FINPIPE.NS', 'GAEL.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'IDFC.NS', 'INDUSINDBK.NS', 'INTELLECT.NS', 'IPCALAB.NS', 'JAMNAAUTO.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KEC.NS', 'KOTAKBANK.NS', 'KSB.NS', 'L&TFH.NS', 'LUPIN.NS', 'LUXIND.NS', 'MAHLIFE.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NH.NS', 'NTPC.NS', 'PETRONET.NS', 'PHOENIXLTD.NS', 'PNCINFRA.NS', 'RATNAMANI.NS', 'REDINGTON.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'SOLARINDS.NS', 'SPARC.NS', 'SRF.NS', 'STLTECH.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUPRAJIT.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TATACOMM.NS', 'TATASTEEL.NS', 'TRENT.NS', 'TRIDENT.NS', 'UBL.NS', 'UNOMINDA.NS', 'VAIBHAVGBL.NS', 'VEDL.NS', 'WELCORP.NS'],
'2017-11-01': ['AARTIDRUGS.NS', 'AJANTPHARM.NS', 'AMBUJACEM.NS', 'AUROPHARMA.NS', 'BALKRISIND.NS', 'BERGEPAINT.NS', 'BLS.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'CROMPTON.NS', 'CUB.NS', 'CYIENT.NS', 'ECLERX.NS', 'GLENMARK.NS', 'GPPL.NS', 'GSPL.NS', 'HINDZINC.NS', 'IDFC.NS', 'INDHOTEL.NS', 'INFY.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'JSWSTEEL.NS', 'JYOTHYLAB.NS', 'KPRMILL.NS', 'L&TFH.NS', 'M&MFIN.NS', 'MHRIL.NS', 'MOTILALOFS.NS', 'MUTHOOTFIN.NS', 'NESTLEIND.NS', 'NETWORK18.NS', 'NH.NS', 'NHPC.NS', 'POWERGRID.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'REDINGTON.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TIMKEN.NS', 'TRIVENI.NS', 'UCOBANK.NS', 'USHAMART.NS', 'VEDL.NS', 'VMART.NS', 'VTL.NS', 'WIPRO.NS', 'ZYDUSLIFE.NS'],
'2017-12-01': ['3MINDIA.NS', 'AARTIIND.NS', 'ABB.NS', 'ADANIENT.NS', 'AEGISCHEM.NS', 'ALOKINDS.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'AVANTIFEED.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BANKBARODA.NS', 'BBTC.NS', 'BERGEPAINT.NS', 'BHEL.NS', 'BLUESTARCO.NS', 'CASTROLIND.NS', 'CCL.NS', 'CEATLTD.NS', 'CGCL.NS', 'CGPOWER.NS', 'CIEINDIA.NS', 'COFORGE.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'EPL.NS', 'FACT.NS', 'FORTIS.NS', 'GAEL.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODREJCP.NS', 'GPPL.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HFCL.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IDEA.NS', 'IDFC.NS', 'IIFL.NS', 'INTELLECT.NS', 'IPCALAB.NS', 'IRB.NS', 'JAMNAAUTO.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'JYOTHYLAB.NS', 'KANSAINER.NS', 'LT.NS', 'M&M.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MMTC.NS', 'NATCOPHARM.NS', 'NBCC.NS', 'NHPC.NS', 'NMDC.NS', 'NTPC.NS', 'OIL.NS', 'OLECTRA.NS', 'ONGC.NS', 'PCBL.NS', 'PERSISTENT.NS', 'POLYMED.NS', 'RELIANCE.NS', 'RTNINDIA.NS', 'SAIL.NS', 'SANOFI.NS', 'SBIN.NS', 'SHOPERSTOP.NS', 'SKFINDIA.NS', 'SUNDARMFIN.NS', 'SUNPHARMA.NS', 'TATACHEM.NS', 'TATAINVEST.NS', 'TECHM.NS', 'TORNTPHARM.NS', 'TRITURBINE.NS', 'TTKPRESTIG.NS', 'TTML.NS', 'UNIONBANK.NS', 'VMART.NS', 'VTL.NS', 'WELSPUNLIV.NS', 'ZYDUSWELL.NS'],
'2018-01-01': ['ABB.NS', 'ACC.NS', 'ADANIPORTS.NS', 'AIAENG.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BHEL.NS', 'BIRLACORPN.NS', 'BOSCHLTD.NS', 'CARBORUNIV.NS', 'CERA.NS', 'CIPLA.NS', 'COFORGE.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'FINPIPE.NS', 'GESHIP.NS', 'GLAXO.NS', 'GODREJCP.NS', 'GRASIM.NS', 'GUJALKALI.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDZINC.NS', 'ICICIBANK.NS', 'INDIACEM.NS', 'INDIGO.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KEI.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LUPIN.NS', 'MASTEK.NS', 'MPHASIS.NS', 'MRPL.NS', 'MUTHOOTFIN.NS', 'NATCOPHARM.NS', 'NH.NS', 'OBEROIRLTY.NS', 'PEL.NS', 'PETRONET.NS', 'PGHH.NS', 'RAJESHEXPO.NS', 'RELIANCE.NS', 'SAREGAMA.NS', 'SHOPERSTOP.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SUNDARMFIN.NS', 'SYNGENE.NS', 'TATACHEM.NS', 'TECHM.NS', 'TIMKEN.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'UPL.NS'],
'2018-02-01': ['ADANIPORTS.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'APOLLOHOSP.NS', 'BALKRISIND.NS', 'BHEL.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'DABUR.NS', 'DCMSHRIRAM.NS', 'DLF.NS', 'ECLERX.NS', 'EXIDEIND.NS', 'GAIL.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GODREJPROP.NS', 'GRAPHITE.NS', 'HEROMOTOCO.NS', 'HINDZINC.NS', 'ICICIPRULI.NS', 'INDHOTEL.NS', 'INDIGO.NS', 'INFIBEAM.NS', 'IPCALAB.NS', 'IRB.NS', 'ITC.NS', 'JINDALSAW.NS', 'JKCEMENT.NS', 'JMFINANCIL.NS', 'KEI.NS', 'KNRCON.NS', 'KSB.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'MAHLIFE.NS', 'MRPL.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'NETWORK18.NS', 'OLECTRA.NS', 'PCBL.NS', 'PETRONET.NS', 'PIDILITIND.NS', 'PRESTIGE.NS', 'RAJESHEXPO.NS', 'RCF.NS', 'RHIM.NS', 'SBIN.NS', 'SUPREMEIND.NS', 'SWANENERGY.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TITAN.NS', 'TORNTPOWER.NS', 'UCOBANK.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VAIBHAVGBL.NS', 'VGUARD.NS', 'WELCORP.NS', 'ZEEL.NS', 'ZFCVINDIA.NS'],
'2018-03-01': ['ABB.NS', 'ADANIENT.NS', 'APARINDS.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'ASAHIINDIA.NS', 'BAJAJFINSV.NS', 'BATAINDIA.NS', 'CCL.NS', 'CENTURYPLY.NS', 'CHOLAHLDNG.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'ELGIEQUIP.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'GILLETTE.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HCLTECH.NS', 'HEROMOTOCO.NS', 'HFCL.NS', 'ICICIPRULI.NS', 'IGL.NS', 'INDHOTEL.NS', 'INDUSINDBK.NS', 'INFIBEAM.NS', 'IOC.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JUBLPHARMA.NS', 'KEI.NS', 'KNRCON.NS', 'MARICO.NS', 'MGL.NS', 'NAUKRI.NS', 'NH.NS', 'OIL.NS', 'OLECTRA.NS', 'PATANJALI.NS', 'PCBL.NS', 'PETRONET.NS', 'PIDILITIND.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'QUESS.NS', 'RADICO.NS', 'RAIN.NS', 'RAMCOCEM.NS', 'SCHAEFFLER.NS', 'SHOPERSTOP.NS', 'SJVN.NS', 'SRF.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TANLA.NS', 'TATACOMM.NS', 'TORNTPHARM.NS', 'VBL.NS', 'VEDL.NS', 'VOLTAS.NS'],
'2018-04-01': ['AARTIIND.NS', 'ABFRL.NS', 'AEGISCHEM.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'APLLTD.NS', 'BAJAJFINSV.NS', 'BATAINDIA.NS', 'BIOCON.NS', 'BSOFT.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CHAMBLFERT.NS', 'COALINDIA.NS', 'COFORGE.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'EICHERMOT.NS', 'ENDURANCE.NS', 'FINPIPE.NS', 'GILLETTE.NS', 'GRAPHITE.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'INDIGO.NS', 'IPCALAB.NS', 'IRB.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JUBLPHARMA.NS', 'KANSAINER.NS', 'KEC.NS', 'LICHSGFIN.NS', 'LT.NS', 'LTIM.NS', 'LTTS.NS', 'LUXIND.NS', 'M&M.NS', 'MANAPPURAM.NS', 'MARUTI.NS', 'MASTEK.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'NHPC.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'PFIZER.NS', 'PGHL.NS', 'PIIND.NS', 'QUESS.NS', 'RADICO.NS', 'RALLIS.NS', 'RBLBANK.NS', 'SKFINDIA.NS', 'SONATSOFTW.NS', 'SYMPHONY.NS', 'UPL.NS', 'VBL.NS', 'VOLTAS.NS', 'WHIRLPOOL.NS', 'ZEEL.NS', 'ZENSARTECH.NS', 'ZYDUSWELL.NS'],
'2018-05-01': ['3MINDIA.NS', 'AARTIDRUGS.NS', 'ABB.NS', 'ACC.NS', 'AIAENG.NS', 'ALKEM.NS', 'APLLTD.NS', 'BAJAJ-AUTO.NS', 'BANKBARODA.NS', 'BHARTIARTL.NS', 'BOSCHLTD.NS', 'CEATLTD.NS', 'CGPOWER.NS', 'COALINDIA.NS', 'CONCOR.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'DEEPAKFERT.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'FINCABLES.NS', 'FORTIS.NS', 'GESHIP.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GODFRYPHLP.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'HFCL.NS', 'HINDALCO.NS', 'IBULHSGFIN.NS', 'IIFL.NS', 'INDIANB.NS', 'INDIGO.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JMFINANCIL.NS', 'KANSAINER.NS', 'KEC.NS', 'KSB.NS', 'LICHSGFIN.NS', 'LUPIN.NS', 'MASTEK.NS', 'MCX.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NBCC.NS', 'NMDC.NS', 'NTPC.NS', 'PAGEIND.NS', 'PEL.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'PIIND.NS', 'POLYMED.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'SCHAEFFLER.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SPARC.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TORNTPOWER.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'USHAMART.NS', 'VEDL.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'VOLTAS.NS', 'ZEEL.NS'],
'2018-06-01': ['ABFRL.NS', 'ADANIPORTS.NS', 'AEGISCHEM.NS', 'ALKYLAMINE.NS', 'ATUL.NS', 'AXISBANK.NS', 'BATAINDIA.NS', 'BHEL.NS', 'BPCL.NS', 'DLF.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'EIHOTEL.NS', 'ESCORTS.NS', 'FINCABLES.NS', 'GILLETTE.NS', 'GLENMARK.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HONAUT.NS', 'IBULHSGFIN.NS', 'ICICIPRULI.NS', 'INDHOTEL.NS', 'ITC.NS', 'JAMNAAUTO.NS', 'JMFINANCIL.NS', 'JUBLFOOD.NS', 'KSB.NS', 'LAXMIMACH.NS', 'LT.NS', 'LUPIN.NS', 'M&MFIN.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'MRF.NS', 'NATCOPHARM.NS', 'NLCINDIA.NS', 'PATANJALI.NS', 'PERSISTENT.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RBLBANK.NS', 'SAIL.NS', 'SANOFI.NS', 'SCHAEFFLER.NS', 'SFL.NS', 'SHREECEM.NS', 'SPARC.NS', 'STLTECH.NS', 'SUNTV.NS', 'SUPREMEIND.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'TEAMLEASE.NS', 'TIMKEN.NS', 'TRIVENI.NS', 'VTL.NS', 'WELSPUNLIV.NS'],
'2018-07-01': ['APLLTD.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'AUROPHARMA.NS', 'BLUEDART.NS', 'BSE.NS', 'BSOFT.NS', 'CIEINDIA.NS', 'COFORGE.NS', 'CRISIL.NS', 'CYIENT.NS', 'DRREDDY.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'EXIDEIND.NS', 'GAIL.NS', 'GLENMARK.NS', 'GRAPHITE.NS', 'HAVELLS.NS', 'HEG.NS', 'INDIANB.NS', 'INDUSINDBK.NS', 'IPCALAB.NS', 'JUSTDIAL.NS', 'LTIM.NS', 'LUXIND.NS', 'M&M.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MPHASIS.NS', 'NATCOPHARM.NS', 'NESTLEIND.NS', 'OFSS.NS', 'PEL.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'QUESS.NS', 'RADICO.NS', 'RELIANCE.NS', 'SAIL.NS', 'SUNDRMFAST.NS', 'SYNGENE.NS', 'TATACONSUM.NS', 'TEAMLEASE.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VIPIND.NS', 'VMART.NS', 'YESBANK.NS', 'ZYDUSWELL.NS'],
'2018-08-01': ['AARTIDRUGS.NS', 'ABB.NS', 'ALLCARGO.NS', 'BALAMINES.NS', 'BANKINDIA.NS', 'BCG.NS', 'BEL.NS', 'BHARATFORG.NS', 'BHEL.NS', 'BLS.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CIEINDIA.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CUB.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'DLF.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'ENGINERSIN.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FINPIPE.NS', 'FSL.NS', 'GAEL.NS', 'GESHIP.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GSFC.NS', 'GUJGASLTD.NS', 'HCLTECH.NS', 'HUDCO.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INTELLECT.NS', 'IOB.NS', 'IOC.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JINDALSAW.NS', 'JUBLFOOD.NS', 'JYOTHYLAB.NS', 'LUXIND.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MINDACORP.NS', 'MUTHOOTFIN.NS', 'NAVINFLUOR.NS', 'NLCINDIA.NS', 'OBEROIRLTY.NS', 'ONGC.NS', 'PERSISTENT.NS', 'PIIND.NS', 'PNB.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'PRSMJOHNSN.NS', 'RAMCOCEM.NS', 'RTNINDIA.NS', 'SAIL.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'SONATSOFTW.NS', 'TATASTEEL.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TTML.NS', 'UNIONBANK.NS', 'UPL.NS', 'USHAMART.NS', 'VINATIORGA.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZYDUSLIFE.NS'],
'2018-09-01': ['AARTIDRUGS.NS', 'ADANIPORTS.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'ASHOKLEY.NS', 'ASTRAL.NS', 'BAYERCROP.NS', 'CANBK.NS', 'COALINDIA.NS', 'COLPAL.NS', 'CONCOR.NS', 'CROMPTON.NS', 'CYIENT.NS', 'DEEPAKNTR.NS', 'DMART.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'ERIS.NS', 'EXIDEIND.NS', 'FACT.NS', 'FDC.NS', 'FORTIS.NS', 'GAEL.NS', 'GAIL.NS', 'GESHIP.NS', 'GILLETTE.NS', 'GRAPHITE.NS', 'GSPL.NS', 'HINDCOPPER.NS', 'IDBI.NS', 'IGL.NS', 'IIFL.NS', 'JKPAPER.NS', 'JSL.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KNRCON.NS', 'KRBL.NS', 'LTIM.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MOTHERSON.NS', 'MUTHOOTFIN.NS', 'NAVINFLUOR.NS', 'NCC.NS', 'NH.NS', 'NHPC.NS', 'NLCINDIA.NS', 'OIL.NS', 'PFC.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'REDINGTON.NS', 'SAIL.NS', 'SCHAEFFLER.NS', 'SIEMENS.NS', 'SJVN.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUPREMEIND.NS', 'SYNGENE.NS', 'TANLA.NS', 'TATAMOTORS.NS', 'TEJASNET.NS', 'TTML.NS', 'TVSMOTOR.NS', 'UNIONBANK.NS', 'VEDL.NS'],
'2018-10-01': ['ABFRL.NS', 'ACC.NS', 'AIAENG.NS', 'APLLTD.NS', 'ATUL.NS', 'AXISBANK.NS', 'BAJAJHLDNG.NS', 'BPCL.NS', 'CIPLA.NS', 'CYIENT.NS', 'DIVISLAB.NS', 'DRREDDY.NS', 'GAIL.NS', 'GUJALKALI.NS', 'JSWSTEEL.NS', 'LUPIN.NS', 'NMDC.NS', 'NTPC.NS', 'SONATSOFTW.NS', 'SUNPHARMA.NS', 'TECHM.NS', 'UBL.NS', 'USHAMART.NS', 'VEDL.NS'],
'2018-11-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'ABFRL.NS', 'AEGISCHEM.NS', 'ALKYLAMINE.NS', 'APLLTD.NS', 'ASTRAL.NS', 'BALKRISIND.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BCG.NS', 'BEL.NS', 'BIOCON.NS', 'CANFINHOME.NS', 'CASTROLIND.NS', 'CCL.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'COFORGE.NS', 'COLPAL.NS', 'CROMPTON.NS', 'DCMSHRIRAM.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'EXIDEIND.NS', 'FINPIPE.NS', 'FORTIS.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GSFC.NS', 'GSPL.NS', 'IDBI.NS', 'INDHOTEL.NS', 'INDIGO.NS', 'INDUSTOWER.NS', 'INFY.NS', 'JBCHEPHARM.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JUSTDIAL.NS', 'KAJARIACER.NS', 'KEC.NS', 'KRBL.NS', 'LUPIN.NS', 'M&MFIN.NS', 'MANAPPURAM.NS', 'MRPL.NS', 'MUTHOOTFIN.NS', 'NATIONALUM.NS', 'NHPC.NS', 'OBEROIRLTY.NS', 'PCBL.NS', 'PETRONET.NS', 'PNB.NS', 'PNCINFRA.NS', 'POLYMED.NS', 'RAIN.NS', 'RHIM.NS', 'SJVN.NS', 'SUPRAJIT.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TORNTPHARM.NS', 'TRIDENT.NS', 'TVSMOTOR.NS', 'UNIONBANK.NS', 'VGUARD.NS', 'VOLTAS.NS'],
'2018-12-01': ['ALLCARGO.NS', 'ALOKINDS.NS', 'BALRAMCHIN.NS', 'BANKINDIA.NS', 'BIOCON.NS', 'BPCL.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CHOLAFIN.NS', 'COROMANDEL.NS', 'DABUR.NS', 'DELTACORP.NS', 'DLF.NS', 'ELGIEQUIP.NS', 'ENGINERSIN.NS', 'GAEL.NS', 'GSFC.NS', 'GUJGASLTD.NS', 'HINDZINC.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'IGL.NS', 'INDIACEM.NS', 'INFY.NS', 'IOB.NS', 'IRB.NS', 'ITC.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'JSWENERGY.NS', 'JUSTDIAL.NS', 'KEI.NS', 'KNRCON.NS', 'MAHABANK.NS', 'NATIONALUM.NS', 'NLCINDIA.NS', 'PNCINFRA.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'REDINGTON.NS', 'RTNINDIA.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SOBHA.NS', 'STLTECH.NS', 'TATACHEM.NS', 'TATAPOWER.NS', 'TECHM.NS', 'TRENT.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'UNIONBANK.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VTL.NS', 'WELCORP.NS', 'WIPRO.NS', 'ZYDUSLIFE.NS'],
'2019-01-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'ADANIENT.NS', 'ADANIPOWER.NS', 'ALLCARGO.NS', 'AMBUJACEM.NS', 'APLLTD.NS', 'APOLLOTYRE.NS', 'AUBANK.NS', 'AVANTIFEED.NS', 'BALRAMCHIN.NS', 'BEL.NS', 'BIOCON.NS', 'CASTROLIND.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'DABUR.NS', 'DLF.NS', 'ELGIEQUIP.NS', 'FACT.NS', 'FINPIPE.NS', 'GAEL.NS', 'GAIL.NS', 'GESHIP.NS', 'GMRINFRA.NS', 'GODFRYPHLP.NS', 'GPPL.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HFCL.NS', 'HINDALCO.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IEX.NS', 'IGL.NS', 'IIFL.NS', 'INDIACEM.NS', 'INDIANB.NS', 'IOB.NS', 'IOC.NS', 'ITC.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JUBLFOOD.NS', 'JUSTDIAL.NS', 'KEC.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MFSL.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'MPHASIS.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NCC.NS', 'NETWORK18.NS', 'NHPC.NS', 'NTPC.NS', 'ONGC.NS', 'PERSISTENT.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RALLIS.NS', 'RCF.NS', 'REDINGTON.NS', 'RTNINDIA.NS', 'SAREGAMA.NS', 'SUNDRMFAST.NS', 'SUPRAJIT.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TECHM.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TV18BRDCST.NS', 'TVSMOTOR.NS', 'UPL.NS', 'VEDL.NS', 'VIPIND.NS', 'WIPRO.NS', 'ZEEL.NS'],
'2019-02-01': ['AARTIDRUGS.NS', 'ALOKINDS.NS', 'APLLTD.NS', 'ASTRAL.NS', 'ATUL.NS', 'BAJFINANCE.NS', 'BANKINDIA.NS', 'BATAINDIA.NS', 'BCG.NS', 'BIOCON.NS', 'BLUEDART.NS', 'BRIGADE.NS', 'CASTROLIND.NS', 'CESC.NS', 'CGCL.NS', 'CUB.NS', 'DIVISLAB.NS', 'ECLERX.NS', 'EPL.NS', 'GODFRYPHLP.NS', 'GRANULES.NS', 'HFCL.NS', 'HINDUNILVR.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'INGERRAND.NS', 'IOC.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JKLAKSHMI.NS', 'JUBLFOOD.NS', 'KEI.NS', 'KOTAKBANK.NS', 'KRBL.NS', 'LTIM.NS', 'MAHABANK.NS', 'NATCOPHARM.NS', 'NBCC.NS', 'NMDC.NS', 'PETRONET.NS', 'PFC.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'PIIND.NS', 'PNB.NS', 'PRAJIND.NS', 'RADICO.NS', 'RBLBANK.NS', 'RCF.NS', 'RECLTD.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'SUNDRMFAST.NS', 'SUNTECK.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TIMKEN.NS', 'TORNTPHARM.NS', 'TRENT.NS', 'TRIDENT.NS', 'TTKPRESTIG.NS', 'VEDL.NS', 'VINATIORGA.NS', 'VTL.NS'],
'2019-03-01': ['AARTIDRUGS.NS', 'ACC.NS', 'AEGISCHEM.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'ASIANPAINT.NS', 'BAJFINANCE.NS', 'BAYERCROP.NS', 'BEL.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'CANFINHOME.NS', 'CASTROLIND.NS', 'CERA.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'DABUR.NS', 'DIXON.NS', 'DRREDDY.NS', 'ECLERX.NS', 'EPL.NS', 'FDC.NS', 'GILLETTE.NS', 'GRASIM.NS', 'HAVELLS.NS', 'HONAUT.NS', 'ICICIPRULI.NS', 'IDFCFIRSTB.NS', 'INDIACEM.NS', 'INFY.NS', 'INGERRAND.NS', 'JINDALSAW.NS', 'KEC.NS', 'MGL.NS', 'MHRIL.NS', 'MUTHOOTFIN.NS', 'NCC.NS', 'NTPC.NS', 'PETRONET.NS', 'PGHL.NS', 'POONAWALLA.NS', 'PRSMJOHNSN.NS', 'RAJESHEXPO.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RELAXO.NS', 'RELIANCE.NS', 'RHIM.NS', 'SCHAEFFLER.NS', 'SKFINDIA.NS', 'SPARC.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SYNGENE.NS', 'TATAMOTORS.NS', 'TATASTEEL.NS', 'TCS.NS', 'TIMKEN.NS', 'TORNTPHARM.NS', 'VBL.NS', 'VMART.NS', 'WIPRO.NS'],
'2019-04-01': ['ABB.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'AJANTPHARM.NS', 'APOLLOHOSP.NS', 'ASTRAL.NS', 'AUROPHARMA.NS', 'BAJAJ-AUTO.NS', 'BAYERCROP.NS', 'BBTC.NS', 'BHARTIARTL.NS', 'BIRLACORPN.NS', 'BRITANNIA.NS', 'CCL.NS', 'CHOLAHLDNG.NS', 'CONCOR.NS', 'CROMPTON.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DMART.NS', 'DRREDDY.NS', 'ERIS.NS', 'HDFCLIFE.NS', 'HONAUT.NS', 'INDUSTOWER.NS', 'INFY.NS', 'JSWSTEEL.NS', 'KPRMILL.NS', 'LAXMIMACH.NS', 'LTTS.NS', 'M&MFIN.NS', 'MFSL.NS', 'NESTLEIND.NS', 'NH.NS', 'NIACL.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'PHOENIXLTD.NS', 'QUESS.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RELAXO.NS', 'SKFINDIA.NS', 'SUNDARMFIN.NS', 'SUNTV.NS', 'SUPREMEIND.NS', 'TATAELXSI.NS', 'TCS.NS', 'TEAMLEASE.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TRENT.NS', 'TTKPRESTIG.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'VINATIORGA.NS', 'VMART.NS', 'WHIRLPOOL.NS', 'ZEEL.NS', 'ZFCVINDIA.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2019-05-01': ['ABCAPITAL.NS', 'ALKYLAMINE.NS', 'APARINDS.NS', 'APOLLOHOSP.NS', 'BERGEPAINT.NS', 'BHEL.NS', 'BLS.NS', 'BLUEDART.NS', 'CANFINHOME.NS', 'CDSL.NS', 'CESC.NS', 'CGCL.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'DIXON.NS', 'ENDURANCE.NS', 'ERIS.NS', 'FEDERALBNK.NS', 'FORTIS.NS', 'GALAXYSURF.NS', 'GESHIP.NS', 'GLENMARK.NS', 'GMMPFAUDLR.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'IEX.NS', 'IIFL.NS', 'JBCHEPHARM.NS', 'JMFINANCIL.NS', 'JSWENERGY.NS', 'JUSTDIAL.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KEC.NS', 'KEI.NS', 'KNRCON.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LUXIND.NS', 'MANAPPURAM.NS', 'MCDOWELL-N.NS', 'MGL.NS', 'MHRIL.NS', 'MRPL.NS', 'NESTLEIND.NS', 'NMDC.NS', 'OFSS.NS', 'PERSISTENT.NS', 'PFC.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'PRSMJOHNSN.NS', 'RAIN.NS', 'RATNAMANI.NS', 'SAIL.NS', 'SFL.NS', 'SJVN.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATACONSUM.NS', 'TEAMLEASE.NS', 'TIINDIA.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'TVSMOTOR.NS', 'UBL.NS', 'VGUARD.NS', 'VIPIND.NS', 'VOLTAS.NS', 'WELCORP.NS', 'ZEEL.NS', 'ZYDUSWELL.NS'],
'2019-06-01': ['ABCAPITAL.NS', 'ABFRL.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'AVANTIFEED.NS', 'BANKINDIA.NS', 'BDL.NS', 'BHEL.NS', 'BLS.NS', 'BOSCHLTD.NS', 'BSOFT.NS', 'CANBK.NS', 'CDSL.NS', 'CIPLA.NS', 'CRISIL.NS', 'DABUR.NS', 'DEEPAKFERT.NS', 'EPL.NS', 'FINCABLES.NS', 'GESHIP.NS', 'GODREJIND.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HEROMOTOCO.NS', 'HUDCO.NS', 'IEX.NS', 'INDIACEM.NS', 'INDUSINDBK.NS', 'INFIBEAM.NS', 'IPCALAB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JSL.NS', 'JUBLFOOD.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'KSB.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'MAHABANK.NS', 'MASTEK.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MHRIL.NS', 'MMTC.NS', 'NTPC.NS', 'OIL.NS', 'PATANJALI.NS', 'PFIZER.NS', 'PNBHOUSING.NS', 'POWERGRID.NS', 'RAIN.NS', 'RALLIS.NS', 'RECLTD.NS', 'RELAXO.NS', 'RELIANCE.NS', 'SUNDRMFAST.NS', 'SUPREMEIND.NS', 'SWANENERGY.NS', 'TATAPOWER.NS', 'TEJASNET.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TTKPRESTIG.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'WIPRO.NS'],
'2019-07-01': ['ABFRL.NS', 'ADANIENT.NS', 'ADANIPORTS.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BLUESTARCO.NS', 'BPCL.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'COALINDIA.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DEEPAKNTR.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'FACT.NS', 'FORTIS.NS', 'GPPL.NS', 'GUJGASLTD.NS', 'HINDPETRO.NS', 'INDIACEM.NS', 'IOB.NS', 'IOC.NS', 'ISEC.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JINDALSAW.NS', 'JSL.NS', 'JSWSTEEL.NS', 'KPRMILL.NS', 'MAHABANK.NS', 'MASTEK.NS', 'MHRIL.NS', 'NBCC.NS', 'NHPC.NS', 'NLCINDIA.NS', 'ONGC.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'PRESTIGE.NS', 'RADICO.NS', 'RALLIS.NS', 'RCF.NS', 'SAIL.NS', 'SAREGAMA.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SUZLON.NS', 'TATAELXSI.NS', 'TATASTEEL.NS', 'TRIVENI.NS', 'TTML.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'USHAMART.NS', 'VEDL.NS', 'WELCORP.NS', 'WELSPUNLIV.NS'],
'2019-08-01': ['ADANIGREEN.NS', 'ADANIPOWER.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'AUBANK.NS', 'CROMPTON.NS', 'DIVISLAB.NS', 'EMAMILTD.NS', 'GALAXYSURF.NS', 'GILLETTE.NS', 'GODREJPROP.NS', 'GUJGASLTD.NS', 'ICICIBANK.NS', 'INDIGO.NS', 'IPCALAB.NS', 'ISEC.NS', 'JBCHEPHARM.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'LUPIN.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'MPHASIS.NS', 'MRPL.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'OFSS.NS', 'PGHH.NS', 'PIDILITIND.NS', 'RELAXO.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'SUNPHARMA.NS', 'TATACONSUM.NS', 'THERMAX.NS', 'TRITURBINE.NS', 'VBL.NS', 'WHIRLPOOL.NS', 'ZEEL.NS'],
'2019-09-01': ['ABCAPITAL.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'ADANIPOWER.NS', 'ALKYLAMINE.NS', 'APOLLOTYRE.NS', 'AUBANK.NS', 'BALRAMCHIN.NS', 'BEL.NS', 'BIOCON.NS', 'BLUESTARCO.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CESC.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FINPIPE.NS', 'FORTIS.NS', 'FSL.NS', 'GAEL.NS', 'GESHIP.NS', 'GMRINFRA.NS', 'GPPL.NS', 'GUJGASLTD.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'ISEC.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JUBLFOOD.NS', 'KPRMILL.NS', 'MHRIL.NS', 'MMTC.NS', 'NETWORK18.NS', 'NHPC.NS', 'NTPC.NS', 'ORIENTELEC.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'RADICO.NS', 'RALLIS.NS', 'RECLTD.NS', 'SJVN.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'USHAMART.NS', 'VGUARD.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'ZYDUSLIFE.NS'],
'2019-10-01': ['3MINDIA.NS', 'ACC.NS', 'ADANIENT.NS', 'ADANIPOWER.NS', 'AJANTPHARM.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'APOLLOTYRE.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BDL.NS', 'BEL.NS', 'CANFINHOME.NS', 'CDSL.NS', 'CENTURYTEX.NS', 'COFORGE.NS', 'CYIENT.NS', 'DABUR.NS', 'DEEPAKFERT.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'FACT.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'GAIL.NS', 'GODFRYPHLP.NS', 'GSPL.NS', 'GUJALKALI.NS', 'GUJGASLTD.NS', 'HAL.NS', 'HCLTECH.NS', 'HEROMOTOCO.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'IDBI.NS', 'IDFC.NS', 'IIFL.NS', 'INDUSTOWER.NS', 'INFY.NS', 'ITI.NS', 'JKCEMENT.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JUBLPHARMA.NS', 'KEC.NS', 'LINDEINDIA.NS', 'MFSL.NS', 'MINDACORP.NS', 'NAM-INDIA.NS', 'NAVINFLUOR.NS', 'OFSS.NS', 'OLECTRA.NS', 'PETRONET.NS', 'PHOENIXLTD.NS', 'PNCINFRA.NS', 'QUESS.NS', 'RADICO.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'RCF.NS', 'SFL.NS', 'SHARDACROP.NS', 'SHRIRAMFIN.NS', 'SOLARINDS.NS', 'STLTECH.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TATACHEM.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TATAPOWER.NS', 'TECHM.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'UBL.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VARROC.NS', 'VEDL.NS', 'VMART.NS', 'WELCORP.NS', 'WELSPUNLIV.NS'],
'2019-11-01': ['ABFRL.NS', 'ACC.NS', 'AIAENG.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'AUBANK.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BANKBARODA.NS', 'BBTC.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'BLUEDART.NS', 'BSE.NS', 'CANBK.NS', 'CENTURYPLY.NS', 'CESC.NS', 'CGCL.NS', 'CHOLAFIN.NS', 'CIPLA.NS', 'COALINDIA.NS', 'CONCOR.NS', 'CREDITACC.NS', 'DABUR.NS', 'DRREDDY.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'ERIS.NS', 'EXIDEIND.NS', 'FINCABLES.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'HAVELLS.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HONAUT.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'ITC.NS', 'JKCEMENT.NS', 'KAJARIACER.NS', 'LICHSGFIN.NS', 'LT.NS', 'LUPIN.NS', 'LUXIND.NS', 'M&MFIN.NS', 'NTPC.NS', 'OFSS.NS', 'OLECTRA.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'RALLIS.NS', 'RATNAMANI.NS', 'SCHAEFFLER.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SPARC.NS', 'SRF.NS', 'SUNDARMFIN.NS', 'SUPRAJIT.NS', 'SYMPHONY.NS', 'TATACOMM.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'THERMAX.NS', 'TORNTPHARM.NS', 'TTKPRESTIG.NS', 'UPL.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2019-12-01': ['3MINDIA.NS', 'AARTIDRUGS.NS', 'AARTIIND.NS', 'ACC.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'AMBUJACEM.NS', 'APOLLOHOSP.NS', 'ASHOKLEY.NS', 'ASTRAL.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BDL.NS', 'BEML.NS', 'BPCL.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CANFINHOME.NS', 'CDSL.NS', 'CERA.NS', 'CHOLAFIN.NS', 'COALINDIA.NS', 'COFORGE.NS', 'CONCOR.NS', 'EIDPARRY.NS', 'ESCORTS.NS', 'FEDERALBNK.NS', 'GAEL.NS', 'GICRE.NS', 'GLENMARK.NS', 'GODREJCP.NS', 'GRASIM.NS', 'HAL.NS', 'HCLTECH.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'HONAUT.NS', 'IBULHSGFIN.NS', 'ICICIPRULI.NS', 'INGERRAND.NS', 'IRCON.NS', 'JKCEMENT.NS', 'JSWENERGY.NS', 'KAJARIACER.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LTIM.NS', 'LTTS.NS', 'MAHABANK.NS', 'MARUTI.NS', 'MRF.NS', 'NAVINFLUOR.NS', 'NBCC.NS', 'NESTLEIND.NS', 'NIACL.NS', 'OBEROIRLTY.NS', 'PCBL.NS', 'PEL.NS', 'PETRONET.NS', 'PFC.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'PNB.NS', 'POONAWALLA.NS', 'PRESTIGE.NS', 'QUESS.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SHRIRAMFIN.NS', 'SKFINDIA.NS', 'SONATSOFTW.NS', 'SUNDARMFIN.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TECHM.NS', 'TRENT.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'VGUARD.NS', 'VOLTAS.NS', 'WELCORP.NS', 'WHIRLPOOL.NS', 'YESBANK.NS', 'ZFCVINDIA.NS'],
'2020-01-01': ['ADANIPOWER.NS', 'ALLCARGO.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BSOFT.NS', 'CANBK.NS', 'CCL.NS', 'CDSL.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'DEEPAKFERT.NS', 'ELGIEQUIP.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'FACT.NS', 'FEDERALBNK.NS', 'GESHIP.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'HINDZINC.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'IDEA.NS', 'IEX.NS', 'IIFL.NS', 'INDUSTOWER.NS', 'INFY.NS', 'IRB.NS', 'IRCON.NS', 'ITI.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'JSL.NS', 'KARURVYSYA.NS', 'KPRMILL.NS', 'LAURUSLABS.NS', 'MAHLIFE.NS', 'MHRIL.NS', 'MMTC.NS', 'NATIONALUM.NS', 'NCC.NS', 'NHPC.NS', 'OBEROIRLTY.NS', 'PCBL.NS', 'PNB.NS', 'PNCINFRA.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'RADICO.NS', 'RAIN.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'TATAPOWER.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'UBL.NS', 'UCOBANK.NS', 'UNOMINDA.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VEDL.NS', 'ZEEL.NS'],
'2020-02-01': ['ABFRL.NS', 'ACC.NS', 'ASIANPAINT.NS', 'ATGL.NS', 'AUROPHARMA.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BBTC.NS', 'BLUESTARCO.NS', 'BORORENEW.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'CONCOR.NS', 'CREDITACC.NS', 'DEEPAKNTR.NS', 'ECLERX.NS', 'ENDURANCE.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'GICRE.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GRASIM.NS', 'HAL.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HINDUNILVR.NS', 'HUDCO.NS', 'IEX.NS', 'INDIACEM.NS', 'INDUSTOWER.NS', 'JINDALSAW.NS', 'JUBLPHARMA.NS', 'KPRMILL.NS', 'KRBL.NS', 'MAHABANK.NS', 'MINDACORP.NS', 'MRPL.NS', 'NETWORK18.NS', 'NIACL.NS', 'NLCINDIA.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'PFC.NS', 'PFIZER.NS', 'POLYPLEX.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RECLTD.NS', 'SAIL.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SUNDARMFIN.NS', 'SUNTV.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TRITURBINE.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'VBL.NS', 'VGUARD.NS', 'VOLTAS.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2020-03-01': ['ABFRL.NS', 'AEGISCHEM.NS', 'AIAENG.NS', 'ALLCARGO.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'ASAHIINDIA.NS', 'AUROPHARMA.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BERGEPAINT.NS', 'BHARTIARTL.NS', 'BLUEDART.NS', 'BRIGADE.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'CGCL.NS', 'CREDITACC.NS', 'DABUR.NS', 'ESCORTS.NS', 'FDC.NS', 'FORTIS.NS', 'GAEL.NS', 'GALAXYSURF.NS', 'GMMPFAUDLR.NS', 'GRANULES.NS', 'GUJGASLTD.NS', 'HINDUNILVR.NS', 'IEX.NS', 'INFIBEAM.NS', 'IRCON.NS', 'JKCEMENT.NS', 'JMFINANCIL.NS', 'LALPATHLAB.NS', 'LTIM.NS', 'MCX.NS', 'MINDACORP.NS', 'NAM-INDIA.NS', 'NESTLEIND.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PIIND.NS', 'RALLIS.NS', 'SHRIRAMFIN.NS', 'SONATSOFTW.NS', 'SRF.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TATAINVEST.NS', 'TIINDIA.NS', 'TITAN.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'WELCORP.NS', 'ZYDUSWELL.NS'],
'2020-04-01': ['ADANIGREEN.NS', 'AUROPHARMA.NS', 'BEL.NS', 'BERGEPAINT.NS', 'CIPLA.NS', 'COALINDIA.NS', 'COLPAL.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'EPL.NS', 'FACT.NS', 'GMMPFAUDLR.NS', 'GRANULES.NS', 'HINDZINC.NS', 'IRCON.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'MARICO.NS', 'MCX.NS', 'NAVINFLUOR.NS', 'NHPC.NS', 'NIACL.NS', 'NLCINDIA.NS', 'NMDC.NS', 'PFC.NS', 'SJVN.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'ZYDUSLIFE.NS'],
'2020-05-01': ['3MINDIA.NS', 'ACC.NS', 'ADANIPORTS.NS', 'ALKEM.NS', 'APLAPOLLO.NS', 'ASIANPAINT.NS', 'BALKRISIND.NS', 'BANDHANBNK.NS', 'BATAINDIA.NS', 'BBTC.NS', 'BERGEPAINT.NS', 'BPCL.NS', 'BSE.NS', 'BSOFT.NS', 'CENTRALBK.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'CRISIL.NS', 'DABUR.NS', 'DCMSHRIRAM.NS', 'ECLERX.NS', 'EXIDEIND.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRINDWELL.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'HONAUT.NS', 'HUDCO.NS', 'IDEA.NS', 'INFIBEAM.NS', 'ISEC.NS', 'JBMA.NS', 'JKPAPER.NS', 'JSL.NS', 'JUBLFOOD.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KANSAINER.NS', 'KOTAKBANK.NS', 'KPRMILL.NS', 'LICHSGFIN.NS', 'LTIM.NS', 'MANAPPURAM.NS', 'MARUTI.NS', 'MGL.NS', 'MOTHERSON.NS', 'MRF.NS', 'MRPL.NS', 'NETWORK18.NS', 'NIACL.NS', 'NTPC.NS', 'OIL.NS', 'ONGC.NS', 'PFC.NS', 'PGHH.NS', 'POLYPLEX.NS', 'RAJESHEXPO.NS', 'RCF.NS', 'RELAXO.NS', 'SAIL.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'STLTECH.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'SUPREMEIND.NS', 'SUZLON.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TIMKEN.NS', 'TRITURBINE.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UNOMINDA.NS', 'VBL.NS', 'VEDL.NS', 'VGUARD.NS', 'WHIRLPOOL.NS', 'ZYDUSWELL.NS'],
'2020-06-01': ['ADANIENT.NS', 'ADANIPOWER.NS', 'AEGISCHEM.NS', 'APARINDS.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'ASIANPAINT.NS', 'AVANTIFEED.NS', 'BATAINDIA.NS', 'BDL.NS', 'BEL.NS', 'BERGEPAINT.NS', 'BHARTIARTL.NS', 'BPCL.NS', 'BSOFT.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'COLPAL.NS', 'CONCOR.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DLF.NS', 'FINPIPE.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GICRE.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GSPL.NS', 'HAL.NS', 'HDFCBANK.NS', 'HEG.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'ICICIPRULI.NS', 'INFY.NS', 'INGERRAND.NS', 'IOC.NS', 'IRCON.NS', 'ITI.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'KRBL.NS', 'LAXMIMACH.NS', 'MANAPPURAM.NS', 'MASTEK.NS', 'MMTC.NS', 'NAM-INDIA.NS', 'NETWORK18.NS', 'NIACL.NS', 'NMDC.NS', 'PEL.NS', 'PGHL.NS', 'PIDILITIND.NS', 'POLYPLEX.NS', 'RAIN.NS', 'RALLIS.NS', 'RCF.NS', 'REDINGTON.NS', 'RHIM.NS', 'SAIL.NS', 'SBILIFE.NS', 'SFL.NS', 'SPARC.NS', 'SRF.NS', 'STLTECH.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'SUPREMEIND.NS', 'SYMPHONY.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TATASTEEL.NS', 'TCS.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TRIVENI.NS', 'TTML.NS', 'TV18BRDCST.NS', 'TVSMOTOR.NS', 'UBL.NS', 'UNOMINDA.NS', 'VBL.NS', 'VEDL.NS', 'VGUARD.NS', 'WHIRLPOOL.NS'],
'2020-07-01': ['ADANIENT.NS', 'ALLCARGO.NS', 'APLAPOLLO.NS', 'APOLLOTYRE.NS', 'BANKBARODA.NS', 'BCG.NS', 'BPCL.NS', 'BRIGADE.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CASTROLIND.NS', 'CENTURYPLY.NS', 'CESC.NS', 'CHAMBLFERT.NS', 'ECLERX.NS', 'FEDERALBNK.NS', 'GICRE.NS', 'GMRINFRA.NS', 'GNFC.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'INDIACEM.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'IOC.NS', 'ITC.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JYOTHYLAB.NS', 'KPRMILL.NS', 'L&TFH.NS', 'LAURUSLABS.NS', 'MAHABANK.NS', 'MAHLIFE.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NCC.NS', 'NLCINDIA.NS', 'NTPC.NS', 'OLECTRA.NS', 'PCBL.NS', 'PNB.NS', 'POLYMED.NS', 'POWERGRID.NS', 'RAIN.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RITES.NS', 'RVNL.NS', 'SAIL.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'SOBHA.NS', 'STLTECH.NS', 'SUNTECK.NS', 'SUNTV.NS', 'TATAMOTORS.NS', 'TATASTEEL.NS', 'TEJASNET.NS', 'UNIONBANK.NS', 'UPL.NS', 'VBL.NS', 'VIPIND.NS', 'WELCORP.NS', 'ZENSARTECH.NS'],
'2020-08-01': ['ABB.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'ADANIGREEN.NS', 'AEGISCHEM.NS', 'AIAENG.NS', 'AMBER.NS', 'ASAHIINDIA.NS', 'ASIANPAINT.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BALRAMCHIN.NS', 'BANKINDIA.NS', 'BAYERCROP.NS', 'BEML.NS', 'BIOCON.NS', 'BLUEDART.NS', 'BPCL.NS', 'BRIGADE.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'ECLERX.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'EXIDEIND.NS', 'FACT.NS', 'FEDERALBNK.NS', 'GILLETTE.NS', 'GMMPFAUDLR.NS', 'GPPL.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HINDCOPPER.NS', 'HINDUNILVR.NS', 'ICICIGI.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'IOC.NS', 'IRCON.NS', 'ITC.NS', 'JMFINANCIL.NS', 'JSWENERGY.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'KEI.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'KPITTECH.NS', 'KSB.NS', 'LINDEINDIA.NS', 'LUXIND.NS', 'MAHLIFE.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MRPL.NS', 'NETWORK18.NS', 'NH.NS', 'NHPC.NS', 'NMDC.NS', 'OIL.NS', 'ORIENTELEC.NS', 'PGHH.NS', 'PGHL.NS', 'PNBHOUSING.NS', 'POLYCAB.NS', 'PRESTIGE.NS', 'RADICO.NS', 'RAIN.NS', 'RBLBANK.NS', 'REDINGTON.NS', 'RENUKA.NS', 'RHIM.NS', 'RVNL.NS', 'SAIL.NS', 'SANOFI.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'SRF.NS', 'SUNDARMFIN.NS', 'SUNTECK.NS', 'SWANENERGY.NS', 'TATACHEM.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'THERMAX.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'TV18BRDCST.NS', 'TVSMOTOR.NS', 'UCOBANK.NS', 'USHAMART.NS', 'VARROC.NS', 'VIPIND.NS', 'VMART.NS', 'VTL.NS'],
'2020-09-01': ['ABCAPITAL.NS', 'ADANIPOWER.NS', 'APOLLOTYRE.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BEL.NS', 'BHEL.NS', 'BLS.NS', 'BSE.NS', 'CANBK.NS', 'CENTRALBK.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'DCMSHRIRAM.NS', 'EIDPARRY.NS', 'EXIDEIND.NS', 'FEDERALBNK.NS', 'GESHIP.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GPPL.NS', 'GRAPHITE.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HEG.NS', 'HFCL.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'INDIANB.NS', 'IOB.NS', 'IRB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JSL.NS', 'JUBLPHARMA.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'M&M.NS', 'M&MFIN.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NCC.NS', 'NHPC.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NTPC.NS', 'OLECTRA.NS', 'ONGC.NS', 'PCBL.NS', 'PFC.NS', 'PNB.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RAIN.NS', 'REDINGTON.NS', 'RENUKA.NS', 'RVNL.NS', 'SAIL.NS', 'SJVN.NS', 'STLTECH.NS', 'SYNGENE.NS', 'TEJASNET.NS', 'TRIVENI.NS', 'TTML.NS', 'TVSMOTOR.NS', 'UCOBANK.NS', 'UNIONBANK.NS'],
'2020-10-01': ['ADANIPORTS.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'AVANTIFEED.NS', 'BALAMINES.NS', 'BALRAMCHIN.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'CENTURYPLY.NS', 'CIEINDIA.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DELTACORP.NS', 'ECLERX.NS', 'EIHOTEL.NS', 'EMAMILTD.NS', 'EXIDEIND.NS', 'FINPIPE.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODREJIND.NS', 'GPIL.NS', 'GPPL.NS', 'GRAPHITE.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HFCL.NS', 'HINDALCO.NS', 'IDEA.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'LEMONTREE.NS', 'MAHLIFE.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'OBEROIRLTY.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'REDINGTON.NS', 'RHIM.NS', 'SHOPERSTOP.NS', 'SONATSOFTW.NS', 'STLTECH.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'TATACOMM.NS', 'TATAMOTORS.NS', 'TEJASNET.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'UNOMINDA.NS', 'UPL.NS', 'USHAMART.NS', 'VGUARD.NS', 'ZEEL.NS'],
'2020-11-01': ['AAVAS.NS', 'ABB.NS', 'AJANTPHARM.NS', 'AMBER.NS', 'APLLTD.NS', 'ASAHIINDIA.NS', 'ATUL.NS', 'BAJFINANCE.NS', 'BIRLACORPN.NS', 'BLUESTARCO.NS', 'CENTURYPLY.NS', 'CHAMBLFERT.NS', 'COCHINSHIP.NS', 'CONCOR.NS', 'CYIENT.NS', 'DABUR.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DRREDDY.NS', 'ENDURANCE.NS', 'ESCORTS.NS', 'FDC.NS', 'FINEORG.NS', 'FSL.NS', 'GNFC.NS', 'GRINDWELL.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HINDZINC.NS', 'ICICIBANK.NS', 'IGL.NS', 'INDIAMART.NS', 'INDIGO.NS', 'INFY.NS', 'ISEC.NS', 'JBCHEPHARM.NS', 'JMFINANCIL.NS', 'KNRCON.NS', 'LT.NS', 'LTIM.NS', 'LTTS.NS', 'LUXIND.NS', 'MARUTI.NS', 'MCX.NS', 'MFSL.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NH.NS', 'OFSS.NS', 'PAGEIND.NS', 'PETRONET.NS', 'PFIZER.NS', 'PGHH.NS', 'PGHL.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'QUESS.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'RATNAMANI.NS', 'RELAXO.NS', 'SAFARI.NS', 'SCHAEFFLER.NS', 'SIEMENS.NS', 'SUNDRMFAST.NS', 'SUNTECK.NS', 'TATAINVEST.NS', 'TECHM.NS', 'THERMAX.NS', 'TIMKEN.NS', 'TRENT.NS', 'TVSMOTOR.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'VMART.NS', 'WESTLIFE.NS', 'WHIRLPOOL.NS', 'ZYDUSLIFE.NS'],
'2020-12-01': ['AARTIDRUGS.NS', 'AVANTIFEED.NS', 'CENTRALBK.NS', 'DEEPAKFERT.NS', 'ECLERX.NS', 'FACT.NS', 'GAEL.NS', 'GNFC.NS', 'GODREJIND.NS', 'GUJALKALI.NS', 'HINDPETRO.NS', 'IDBI.NS', 'IDEA.NS', 'IOC.NS', 'IRB.NS', 'ITI.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KPITTECH.NS', 'NLCINDIA.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'PRESTIGE.NS', 'REDINGTON.NS', 'RENUKA.NS', 'SHARDACROP.NS', 'SONATSOFTW.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'USHAMART.NS', 'WELSPUNLIV.NS', 'ZEEL.NS'],
'2021-01-01': ['ADANIPOWER.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'ASHOKLEY.NS', 'BALRAMCHIN.NS', 'BANKINDIA.NS', 'CENTRALBK.NS', 'CESC.NS', 'CGPOWER.NS', 'COALINDIA.NS', 'DCMSHRIRAM.NS', 'ENGINERSIN.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'GPPL.NS', 'GUJALKALI.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IDEA.NS', 'IDFCFIRSTB.NS', 'INDIANB.NS', 'IOB.NS', 'IOC.NS', 'IRB.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KPRMILL.NS', 'LEMONTREE.NS', 'MINDACORP.NS', 'NBCC.NS', 'NHPC.NS', 'NIACL.NS', 'NLCINDIA.NS', 'NTPC.NS', 'OIL.NS', 'ONGC.NS', 'PFC.NS', 'PNCINFRA.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'RAIN.NS', 'RBLBANK.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'SJVN.NS', 'SUNTV.NS', 'TATAMTRDVR.NS', 'TRITURBINE.NS', 'TTML.NS', 'UNIONBANK.NS', 'WELCORP.NS', 'YESBANK.NS'],
'2021-02-01': ['ADANIENT.NS', 'ADANIPOWER.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'BALAMINES.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BCG.NS', 'BEL.NS', 'BEML.NS', 'BHEL.NS', 'BLS.NS', 'CANBK.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CESC.NS', 'CIEINDIA.NS', 'DELTACORP.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'EXIDEIND.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'GAIL.NS', 'GODREJIND.NS', 'GPIL.NS', 'GRAPHITE.NS', 'GSFC.NS', 'HEG.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'HUDCO.NS', 'IDEA.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'IOB.NS', 'IOC.NS', 'JAMNAAUTO.NS', 'JSL.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'KEC.NS', 'KPRMILL.NS', 'MAHABANK.NS', 'MINDACORP.NS', 'MMTC.NS', 'MRPL.NS', 'NBCC.NS', 'NCC.NS', 'NETWORK18.NS', 'NHPC.NS', 'OIL.NS', 'PNCINFRA.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'RCF.NS', 'REDINGTON.NS', 'RTNINDIA.NS', 'SHARDACROP.NS', 'STLTECH.NS', 'SUPRAJIT.NS', 'SUZLON.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VEDL.NS', 'ZEEL.NS'],
'2021-03-01': ['BCG.NS', 'BEL.NS', 'CASTROLIND.NS', 'CESC.NS', 'EIHOTEL.NS', 'GMRINFRA.NS', 'GODREJIND.NS', 'HFCL.NS', 'IDBI.NS', 'IDEA.NS', 'INDHOTEL.NS', 'ITI.NS', 'JSWENERGY.NS', 'KPRMILL.NS', 'LEMONTREE.NS', 'MHRIL.NS', 'NAM-INDIA.NS', 'NETWORK18.NS', 'NLCINDIA.NS', 'PFC.NS', 'PRSMJOHNSN.NS', 'RENUKA.NS', 'RHIM.NS', 'SHOPERSTOP.NS', 'SUZLON.NS', 'TRIDENT.NS', 'TTML.NS', 'UCOBANK.NS', 'USHAMART.NS', 'WELCORP.NS', 'WELSPUNLIV.NS'],
'2021-04-01': ['AARTIDRUGS.NS', 'ABCAPITAL.NS', 'AEGISCHEM.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'APOLLOHOSP.NS', 'ASTRAL.NS', 'AUROPHARMA.NS', 'BAJAJFINSV.NS', 'BHEL.NS', 'BIOCON.NS', 'BPCL.NS', 'BRIGADE.NS', 'CANBK.NS', 'CEATLTD.NS', 'CERA.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'ERIS.NS', 'FINPIPE.NS', 'GAIL.NS', 'GESHIP.NS', 'GICRE.NS', 'GODFRYPHLP.NS', 'GUJALKALI.NS', 'HCLTECH.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'INDIACEM.NS', 'INFIBEAM.NS', 'IOB.NS', 'IRCON.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JKPAPER.NS', 'JUBLFOOD.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KEI.NS', 'LAURUSLABS.NS', 'LICHSGFIN.NS', 'LTIM.NS', 'LTTS.NS', 'LUXIND.NS', 'MAHABANK.NS', 'MASTEK.NS', 'MFSL.NS', 'MGL.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NAM-INDIA.NS', 'NATIONALUM.NS', 'NHPC.NS', 'NIACL.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'OIL.NS', 'PGHH.NS', 'PIIND.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'QUESS.NS', 'RADICO.NS', 'RAYMOND.NS', 'RCF.NS', 'SIEMENS.NS', 'SJVN.NS', 'SUMICHEM.NS', 'SUPRAJIT.NS', 'SWSOLAR.NS', 'TATAELXSI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TECHM.NS', 'TIMKEN.NS', 'TORNTPHARM.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS', 'UBL.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VBL.NS', 'VINATIORGA.NS', 'VOLTAS.NS', 'ZENSARTECH.NS'],
'2021-05-01': ['AARTIDRUGS.NS', 'ADANIPORTS.NS', 'APOLLOTYRE.NS', 'AVANTIFEED.NS', 'BEL.NS', 'BHARATFORG.NS', 'BHEL.NS', 'BPCL.NS', 'BSE.NS', 'CASTROLIND.NS', 'CESC.NS', 'CGPOWER.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'CUB.NS', 'EPL.NS', 'ERIS.NS', 'FACT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FSL.NS', 'GAIL.NS', 'GICRE.NS', 'GODREJIND.NS', 'GRANULES.NS', 'GUJGASLTD.NS', 'HFCL.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'ICICIBANK.NS', 'IDBI.NS', 'INDHOTEL.NS', 'INDUSTOWER.NS', 'IRCON.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JKPAPER.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KEI.NS', 'MAHABANK.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NAM-INDIA.NS', 'NETWORK18.NS', 'NHPC.NS', 'OIL.NS', 'ONGC.NS', 'PCBL.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'RCF.NS', 'REDINGTON.NS', 'SAFARI.NS', 'SHARDACROP.NS', 'SOBHA.NS', 'SUMICHEM.NS', 'TATAPOWER.NS', 'TRENT.NS', 'TRITURBINE.NS', 'TTKPRESTIG.NS', 'TTML.NS', 'UPL.NS', 'WELCORP.NS', 'WELSPUNLIV.NS'],
'2021-06-01': ['360ONE.NS', 'AAVAS.NS', 'ADANIPORTS.NS', 'ALOKINDS.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'AUROPHARMA.NS', 'BAJAJHLDNG.NS', 'BALRAMCHIN.NS', 'BCG.NS', 'BDL.NS', 'BEL.NS', 'BEML.NS', 'BORORENEW.NS', 'CANFINHOME.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CUB.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'DIXON.NS', 'FACT.NS', 'GAEL.NS', 'GILLETTE.NS', 'GLENMARK.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GUJGASLTD.NS', 'HAL.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'IGL.NS', 'INDIACEM.NS', 'IOB.NS', 'IRCON.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JSL.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'L&TFH.NS', 'LAXMIMACH.NS', 'LTIM.NS', 'LTTS.NS', 'MAHABANK.NS', 'MAHLIFE.NS', 'NAVINFLUOR.NS', 'NBCC.NS', 'NETWORK18.NS', 'NH.NS', 'NIACL.NS', 'NTPC.NS', 'OFSS.NS', 'ONGC.NS', 'PAGEIND.NS', 'PCBL.NS', 'PETRONET.NS', 'PHOENIXLTD.NS', 'PIIND.NS', 'POLYMED.NS', 'POWERGRID.NS', 'RAIN.NS', 'RAJESHEXPO.NS', 'RCF.NS', 'RHIM.NS', 'RVNL.NS', 'SAFARI.NS', 'SFL.NS', 'SHRIRAMFIN.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SUNDARMFIN.NS', 'SUNTECK.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'SYNGENE.NS', 'TANLA.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TATAPOWER.NS', 'TCS.NS', 'TEAMLEASE.NS', 'TIMKEN.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'USHAMART.NS', 'VBL.NS', 'VMART.NS', 'VOLTAS.NS', 'VTL.NS', 'WELSPUNLIV.NS', 'ZENSARTECH.NS', 'ZFCVINDIA.NS'],
'2021-07-01': ['AARTIIND.NS', 'ACC.NS', 'ADANIENT.NS', 'AMBUJACEM.NS', 'AXISBANK.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BANDHANBNK.NS', 'BATAINDIA.NS', 'BBTC.NS', 'BEML.NS', 'BERGEPAINT.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BPCL.NS', 'BRIGADE.NS', 'CASTROLIND.NS', 'CENTURYPLY.NS', 'CHALET.NS', 'CHOLAHLDNG.NS', 'COLPAL.NS', 'DABUR.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'ESCORTS.NS', 'FACT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'GAEL.NS', 'GALAXYSURF.NS', 'GNFC.NS', 'GODREJCP.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GRANULES.NS', 'GSFC.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IDEA.NS', 'IEX.NS', 'INDIACEM.NS', 'INDIANB.NS', 'INDUSINDBK.NS', 'INFIBEAM.NS', 'IRCON.NS', 'IRCTC.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KPRMILL.NS', 'KRBL.NS', 'LEMONTREE.NS', 'LT.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MRPL.NS', 'NAM-INDIA.NS', 'NBCC.NS', 'NCC.NS', 'NESTLEIND.NS', 'NETWORK18.NS', 'NIACL.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'ORIENTELEC.NS', 'PCBL.NS', 'PHOENIXLTD.NS', 'PNB.NS', 'PNBHOUSING.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'RAJESHEXPO.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'RCF.NS', 'RECLTD.NS', 'RHIM.NS', 'SAFARI.NS', 'SAIL.NS', 'SBIN.NS', 'SHOPERSTOP.NS', 'SPARC.NS', 'STLTECH.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SWANENERGY.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TEJASNET.NS', 'THERMAX.NS', 'TRENT.NS', 'TRIDENT.NS', 'TV18BRDCST.NS', 'ULTRACEMCO.NS', 'UNIONBANK.NS', 'UPL.NS', 'VGUARD.NS', 'VTL.NS', 'WESTLIFE.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'ZYDUSWELL.NS'],
'2021-08-01': ['ABB.NS', 'ADANIENT.NS', 'AMBER.NS', 'ATUL.NS', 'BAYERCROP.NS', 'BHARATFORG.NS', 'BLUESTARCO.NS', 'BOSCHLTD.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CENTURYPLY.NS', 'CERA.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'CRISIL.NS', 'CSBBANK.NS', 'CUMMINSIND.NS', 'DELTACORP.NS', 'EMAMILTD.NS', 'ESCORTS.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FINEORG.NS', 'FINPIPE.NS', 'FSL.NS', 'GPPL.NS', 'GRINDWELL.NS', 'HEG.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'HONAUT.NS', 'IBULHSGFIN.NS', 'INDHOTEL.NS', 'INGERRAND.NS', 'IPCALAB.NS', 'IRB.NS', 'KAJARIACER.NS', 'KEC.NS', 'KEI.NS', 'KRBL.NS', 'LAURUSLABS.NS', 'MCX.NS', 'METROPOLIS.NS', 'MGL.NS', 'MOTILALOFS.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'NH.NS', 'NMDC.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'ORIENTELEC.NS', 'PAGEIND.NS', 'PHOENIXLTD.NS', 'PIIND.NS', 'POLYCAB.NS', 'POLYMED.NS', 'PRAJIND.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'RCF.NS', 'RECLTD.NS', 'RELAXO.NS', 'RITES.NS', 'SBIN.NS', 'SHREECEM.NS', 'SUNDARMFIN.NS', 'SWANENERGY.NS', 'SWSOLAR.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'TITAN.NS', 'TRIVENI.NS', 'UBL.NS', 'UPL.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VIPIND.NS', 'WHIRLPOOL.NS', 'ZYDUSWELL.NS'],
'2021-09-01': ['3MINDIA.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'ASTRAL.NS', 'ATUL.NS', 'BALKRISIND.NS', 'BDL.NS', 'BEML.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BIRLACORPN.NS', 'CCL.NS', 'CHAMBLFERT.NS', 'CIEINDIA.NS', 'COLPAL.NS', 'CONCOR.NS', 'CRISIL.NS', 'DELTACORP.NS', 'DLF.NS', 'ENDURANCE.NS', 'GAEL.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GMRINFRA.NS', 'GODREJIND.NS', 'GRASIM.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HEG.NS', 'HFCL.NS', 'ICICIPRULI.NS', 'IGL.NS', 'IIFL.NS', 'IRB.NS', 'JKPAPER.NS', 'KANSAINER.NS', 'KOTAKBANK.NS', 'KPRMILL.NS', 'LAURUSLABS.NS', 'LAXMIMACH.NS', 'LUXIND.NS', 'MCX.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGL.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NIACL.NS', 'ORIENTELEC.NS', 'PAGEIND.NS', 'PCBL.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'PRINCEPIPE.NS', 'QUESS.NS', 'RADICO.NS', 'RAIN.NS', 'REDINGTON.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SHRIRAMFIN.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUNTECK.NS', 'SUPRAJIT.NS', 'SUVENPHAR.NS', 'TATACOMM.NS', 'THERMAX.NS', 'UNOMINDA.NS', 'VEDL.NS', 'VMART.NS', 'WELSPUNLIV.NS', 'WHIRLPOOL.NS'],
'2021-10-01': ['ABCAPITAL.NS', 'ADANIPOWER.NS', 'ALOKINDS.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'BANKBARODA.NS', 'BORORENEW.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CIEINDIA.NS', 'ELGIEQUIP.NS', 'FACT.NS', 'FEDERALBNK.NS', 'GPIL.NS', 'HFCL.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'JAMNAAUTO.NS', 'JSL.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'KPRMILL.NS', 'MAHABANK.NS', 'MAXHEALTH.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NAM-INDIA.NS', 'NCC.NS', 'NETWORK18.NS', 'PATANJALI.NS', 'PNB.NS', 'RECLTD.NS', 'RENUKA.NS', 'RVNL.NS', 'SAREGAMA.NS', 'SHARDACROP.NS', 'SUZLON.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VEDL.NS', 'VTL.NS', 'YESBANK.NS'],
'2021-11-01': ['360ONE.NS', '3MINDIA.NS', 'ADANIGREEN.NS', 'AFFLE.NS', 'ALLCARGO.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'ASTRAL.NS', 'AUBANK.NS', 'BAJAJFINSV.NS', 'BDL.NS', 'BEL.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BSE.NS', 'CDSL.NS', 'CERA.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CUB.NS', 'CYIENT.NS', 'DELTACORP.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DLF.NS', 'EIDPARRY.NS', 'FINEORG.NS', 'GLAXO.NS', 'GMMPFAUDLR.NS', 'GODREJIND.NS', 'GPIL.NS', 'GPPL.NS', 'GSFC.NS', 'HINDPETRO.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'INDUSINDBK.NS', 'IOC.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JSWENERGY.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KEC.NS', 'KEI.NS', 'KOTAKBANK.NS', 'KPRMILL.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MPHASIS.NS', 'MRPL.NS', 'NH.NS', 'NHPC.NS', 'NLCINDIA.NS', 'OBEROIRLTY.NS', 'OIL.NS', 'ONGC.NS', 'PNB.NS', 'POONAWALLA.NS', 'PRINCEPIPE.NS', 'RAYMOND.NS', 'RELIANCE.NS', 'RITES.NS', 'RVNL.NS', 'SAFARI.NS', 'SAREGAMA.NS', 'SCHAEFFLER.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SJVN.NS', 'SOBHA.NS', 'SUNTECK.NS', 'SUPRAJIT.NS', 'TECHM.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TORNTPOWER.NS', 'TRIVENI.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UJJIVANSFB.NS', 'UPL.NS', 'VGUARD.NS', 'VOLTAS.NS', 'VTL.NS', 'ZFCVINDIA.NS'],
'2021-12-01': ['AAVAS.NS', 'ABB.NS', 'ABCAPITAL.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'AEGISCHEM.NS', 'AFFLE.NS', 'ALLCARGO.NS', 'APLLTD.NS', 'BDL.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'CAMS.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CDSL.NS', 'CENTURYPLY.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'COFORGE.NS', 'CRISIL.NS', 'DMART.NS', 'EIDPARRY.NS', 'FINEORG.NS', 'FLUOROCHEM.NS', 'FORTIS.NS', 'GLENMARK.NS', 'GODFRYPHLP.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HINDZINC.NS', 'IDEA.NS', 'IEX.NS', 'INGERRAND.NS', 'KANSAINER.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'MINDACORP.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'NHPC.NS', 'OIL.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'PGHL.NS', 'PNBHOUSING.NS', 'POONAWALLA.NS', 'RATNAMANI.NS', 'REDINGTON.NS', 'SAREGAMA.NS', 'SCHAEFFLER.NS', 'SOBHA.NS', 'SUNDRMFAST.NS', 'SUPRAJIT.NS', 'SYNGENE.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TECHM.NS', 'TEJASNET.NS', 'TIINDIA.NS', 'TITAN.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TVSMOTOR.NS', 'UTIAMC.NS', 'VEDL.NS', 'VTL.NS', 'ZEEL.NS'],
'2022-01-01': ['3MINDIA.NS', 'AARTIDRUGS.NS', 'AAVAS.NS', 'ABFRL.NS', 'ADANIENT.NS', 'AIAENG.NS', 'AMBER.NS', 'ANGELONE.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'ATGL.NS', 'BBTC.NS', 'BEL.NS', 'BERGEPAINT.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'CDSL.NS', 'CENTURYPLY.NS', 'CESC.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'COLPAL.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DABUR.NS', 'ENDURANCE.NS', 'EPL.NS', 'EXIDEIND.NS', 'FDC.NS', 'FINEORG.NS', 'FINPIPE.NS', 'FSL.NS', 'GAEL.NS', 'GICRE.NS', 'GNFC.NS', 'GPIL.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HAPPSTMNDS.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'HINDUNILVR.NS', 'ICICIBANK.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'INDIACEM.NS', 'INDIGO.NS', 'IRB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JKCEMENT.NS', 'JUSTDIAL.NS', 'KANSAINER.NS', 'LAURUSLABS.NS', 'LINDEINDIA.NS', 'MARUTI.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MUTHOOTFIN.NS', 'NATIONALUM.NS', 'NETWORK18.NS', 'NLCINDIA.NS', 'NMDC.NS', 'OIL.NS', 'ONGC.NS', 'ORIENTELEC.NS', 'PEL.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RAMCOCEM.NS', 'RCF.NS', 'RENUKA.NS', 'RVNL.NS', 'SAFARI.NS', 'SANOFI.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'STLTECH.NS', 'SUMICHEM.NS', 'SYMPHONY.NS', 'TATAELXSI.NS', 'TATAMOTORS.NS', 'TATAPOWER.NS', 'TEAMLEASE.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TV18BRDCST.NS', 'UBL.NS', 'UPL.NS', 'USHAMART.NS', 'UTIAMC.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VEDL.NS', 'VOLTAS.NS', 'WELSPUNLIV.NS', 'YESBANK.NS', 'ZYDUSLIFE.NS'],
'2022-02-01': ['ABB.NS', 'ABFRL.NS', 'ACC.NS', 'ADANIPOWER.NS', 'AFFLE.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'ASHOKLEY.NS', 'ATUL.NS', 'BANKINDIA.NS', 'BBTC.NS', 'BEL.NS', 'BEML.NS', 'BHARATFORG.NS', 'BIOCON.NS', 'BLUEDART.NS', 'BPCL.NS', 'BRIGADE.NS', 'BSE.NS', 'CANFINHOME.NS', 'CENTRALBK.NS', 'CERA.NS', 'CHAMBLFERT.NS', 'COALINDIA.NS', 'CONCOR.NS', 'CSBBANK.NS', 'CUMMINSIND.NS', 'DELTACORP.NS', 'EIDPARRY.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'FINEORG.NS', 'GALAXYSURF.NS', 'GESHIP.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GRINDWELL.NS', 'GSFC.NS', 'GUJALKALI.NS', 'GUJGASLTD.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'HONAUT.NS', 'HUDCO.NS', 'ICICIBANK.NS', 'INDIACEM.NS', 'IRCTC.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'KEC.NS', 'KPRMILL.NS', 'LICHSGFIN.NS', 'M&MFIN.NS', 'MAZDOCK.NS', 'NATCOPHARM.NS', 'NCC.NS', 'NIACL.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'PAGEIND.NS', 'PCBL.NS', 'PERSISTENT.NS', 'PHOENIXLTD.NS', 'PNCINFRA.NS', 'POLYCAB.NS', 'POLYPLEX.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RAJESHEXPO.NS', 'RCF.NS', 'RECLTD.NS', 'RITES.NS', 'ROUTE.NS', 'RVNL.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SHOPERSTOP.NS', 'SIEMENS.NS', 'SRF.NS', 'SUMICHEM.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SWSOLAR.NS', 'TANLA.NS', 'TATAINVEST.NS', 'TEAMLEASE.NS', 'UBL.NS', 'UNOMINDA.NS', 'UPL.NS', 'VBL.NS', 'VTL.NS'],
'2022-03-01': ['ABBOTINDIA.NS', 'ADANIGREEN.NS', 'ADANIPOWER.NS', 'AMBER.NS', 'ANGELONE.NS', 'APOLLOHOSP.NS', 'BAJAJ-AUTO.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BDL.NS', 'BEL.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'CCL.NS', 'CHALET.NS', 'CIPLA.NS', 'COLPAL.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DMART.NS', 'ESCORTS.NS', 'GAEL.NS', 'GAIL.NS', 'GILLETTE.NS', 'GPIL.NS', 'HAL.NS', 'JINDALSTEL.NS', 'JKPAPER.NS', 'KNRCON.NS', 'LAURUSLABS.NS', 'LEMONTREE.NS', 'LINDEINDIA.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MASTEK.NS', 'MAXHEALTH.NS', 'MCDOWELL-N.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MPHASIS.NS', 'NMDC.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'OIL.NS', 'PAGEIND.NS', 'PETRONET.NS', 'PGHH.NS', 'RAYMOND.NS', 'SCHAEFFLER.NS', 'SFL.NS', 'SHARDACROP.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'TATASTEEL.NS', 'TIMKEN.NS', 'TITAN.NS', 'TRENT.NS', 'TV18BRDCST.NS', 'VBL.NS', 'VIPIND.NS', 'VOLTAS.NS', 'VTL.NS'],
'2022-04-01': ['ABB.NS', 'ACC.NS', 'ADANIGREEN.NS', 'AEGISCHEM.NS', 'AMBER.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'BEL.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BIRLACORPN.NS', 'BLS.NS', 'BPCL.NS', 'BSOFT.NS', 'CANBK.NS', 'CDSL.NS', 'CHAMBLFERT.NS', 'COROMANDEL.NS', 'CUB.NS', 'CYIENT.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'DRREDDY.NS', 'ECLERX.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FEDERALBNK.NS', 'FINEORG.NS', 'FLUOROCHEM.NS', 'GMMPFAUDLR.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'HDFCBANK.NS', 'HEG.NS', 'HINDALCO.NS', 'ICICIBANK.NS', 'ICICIPRULI.NS', 'IDFC.NS', 'IEX.NS', 'INDIACEM.NS', 'INDIANB.NS', 'INDUSINDBK.NS', 'IOC.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'KPITTECH.NS', 'LICHSGFIN.NS', 'LTIM.NS', 'M&M.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MGL.NS', 'NATIONALUM.NS', 'NETWORK18.NS', 'NLCINDIA.NS', 'OFSS.NS', 'PFC.NS', 'PIDILITIND.NS', 'PNCINFRA.NS', 'RENUKA.NS', 'RVNL.NS', 'SAIL.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SBIN.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SPARC.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'TANLA.NS', 'TATACOMM.NS', 'TATAPOWER.NS', 'TCS.NS', 'TECHM.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TVSMOTOR.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'VARROC.NS', 'VBL.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'VOLTAS.NS', 'WESTLIFE.NS', 'WIPRO.NS', 'ZFCVINDIA.NS'],
'2022-05-01': ['360ONE.NS', 'AEGISCHEM.NS', 'ALKYLAMINE.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'BAJAJ-AUTO.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BANKBARODA.NS', 'BATAINDIA.NS', 'BERGEPAINT.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'CASTROLIND.NS', 'CCL.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'COCHINSHIP.NS', 'CROMPTON.NS', 'CUB.NS', 'DABUR.NS', 'DIVISLAB.NS', 'DIXON.NS', 'ECLERX.NS', 'ENDURANCE.NS', 'GAIL.NS', 'GODREJCP.NS', 'GPIL.NS', 'GPPL.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'ICICIBANK.NS', 'ICICIPRULI.NS', 'IIFL.NS', 'INDIAMART.NS', 'INDIANB.NS', 'INDUSINDBK.NS', 'IOC.NS', 'JAMNAAUTO.NS', 'JSWSTEEL.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'KEI.NS', 'KOTAKBANK.NS', 'KRBL.NS', 'LAURUSLABS.NS', 'LICHSGFIN.NS', 'MARICO.NS', 'MCX.NS', 'MOTILALOFS.NS', 'NCC.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'PFC.NS', 'PGHL.NS', 'PIIND.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'RAYMOND.NS', 'RHIM.NS', 'RITES.NS', 'SAFARI.NS', 'SBICARD.NS', 'SHARDACROP.NS', 'SOLARINDS.NS', 'SUNTECK.NS', 'TEJASNET.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'TRIVENI.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS', 'VAIBHAVGBL.NS', 'VEDL.NS', 'VOLTAS.NS', 'ZFCVINDIA.NS'],
'2022-06-01': ['ABFRL.NS', 'ACC.NS', 'ALKEM.NS', 'ANGELONE.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'ATGL.NS', 'BAJAJHLDNG.NS', 'BANKINDIA.NS', 'BHEL.NS', 'CAMS.NS', 'CDSL.NS', 'CENTURYPLY.NS', 'CERA.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DIXON.NS', 'DLF.NS', 'ENGINERSIN.NS', 'EPL.NS', 'ESCORTS.NS', 'FACT.NS', 'GALAXYSURF.NS', 'GICRE.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GRANULES.NS', 'HINDCOPPER.NS', 'IDEA.NS', 'IGL.NS', 'IIFL.NS', 'INDHOTEL.NS', 'INDIAMART.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KNRCON.NS', 'KPITTECH.NS', 'LAURUSLABS.NS', 'LT.NS', 'MASTEK.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'NCC.NS', 'NLCINDIA.NS', 'OFSS.NS', 'PFC.NS', 'PFIZER.NS', 'PGHH.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'RAIN.NS', 'RCF.NS', 'RENUKA.NS', 'ROUTE.NS', 'RVNL.NS', 'SAFARI.NS', 'SANOFI.NS', 'SAREGAMA.NS', 'SBICARD.NS', 'SBIN.NS', 'SHOPERSTOP.NS', 'SUNDRMFAST.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SYNGENE.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAPOWER.NS', 'TEJASNET.NS', 'TRENT.NS', 'TRIVENI.NS', 'TTKPRESTIG.NS', 'UNIONBANK.NS', 'UNOMINDA.NS', 'UPL.NS', 'VBL.NS', 'VMART.NS', 'WESTLIFE.NS', 'ZEEL.NS'],
'2022-07-01': ['360ONE.NS', 'AFFLE.NS', 'AMBUJACEM.NS', 'AVANTIFEED.NS', 'BEL.NS', 'BHARTIARTL.NS', 'BLS.NS', 'CARBORUNIV.NS', 'CENTURYTEX.NS', 'CGCL.NS', 'COALINDIA.NS', 'CREDITACC.NS', 'CSBBANK.NS', 'CUB.NS', 'EIDPARRY.NS', 'ELGIEQUIP.NS', 'ERIS.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'FORTIS.NS', 'GAEL.NS', 'GESHIP.NS', 'GICRE.NS', 'GRANULES.NS', 'HUDCO.NS', 'IIFL.NS', 'INDHOTEL.NS', 'INDUSTOWER.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JKLAKSHMI.NS', 'KEC.NS', 'KPITTECH.NS', 'KRBL.NS', 'M&MFIN.NS', 'MAXHEALTH.NS', 'MCX.NS', 'MGL.NS', 'MINDACORP.NS', 'MRPL.NS', 'OIL.NS', 'ONGC.NS', 'PATANJALI.NS', 'PETRONET.NS', 'PNCINFRA.NS', 'POLYMED.NS', 'PRAJIND.NS', 'SAFARI.NS', 'SBICARD.NS', 'SBIN.NS', 'SONATSOFTW.NS', 'SUPRAJIT.NS', 'SYNGENE.NS', 'TEJASNET.NS', 'TTKPRESTIG.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VGUARD.NS', 'WELCORP.NS', 'ZYDUSLIFE.NS'],
'2022-08-01': ['ABFRL.NS', 'ALLCARGO.NS', 'BANKINDIA.NS', 'BPCL.NS', 'CANBK.NS', 'CESC.NS', 'DELTACORP.NS', 'EPL.NS', 'EQUITASBNK.NS', 'FSL.NS', 'GAIL.NS', 'GPPL.NS', 'GRAPHITE.NS', 'GSFC.NS', 'HFCL.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'IDFC.NS', 'IIFL.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JINDALSAW.NS', 'JMFINANCIL.NS', 'JSL.NS', 'KRBL.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MAZDOCK.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NBCC.NS', 'NHPC.NS', 'PNB.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'POONAWALLA.NS', 'RCF.NS', 'RENUKA.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'TATAMTRDVR.NS', 'TRITURBINE.NS', 'VEDL.NS', 'WELCORP.NS'],
'2022-09-01': ['AAVAS.NS', 'ALKYLAMINE.NS', 'ASTERDM.NS', 'AUBANK.NS', 'AVANTIFEED.NS', 'BALAMINES.NS', 'BDL.NS', 'BHARATFORG.NS', 'BIRLACORPN.NS', 'BPCL.NS', 'BRITANNIA.NS', 'CGCL.NS', 'CGPOWER.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CUMMINSIND.NS', 'DALBHARAT.NS', 'DEEPAKNTR.NS', 'EPL.NS', 'ERIS.NS', 'FDC.NS', 'FLUOROCHEM.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GSFC.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HDFCAMC.NS', 'HDFCLIFE.NS', 'HEROMOTOCO.NS', 'ICICIGI.NS', 'IDEA.NS', 'IIFL.NS', 'INDIAMART.NS', 'ISEC.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JINDALSAW.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'KNRCON.NS', 'KPITTECH.NS', 'LEMONTREE.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'LUPIN.NS', 'MARICO.NS', 'MAXHEALTH.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'MINDACORP.NS', 'NAM-INDIA.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NH.NS', 'OLECTRA.NS', 'ONGC.NS', 'PETRONET.NS', 'PFIZER.NS', 'PRESTIGE.NS', 'RAYMOND.NS', 'RELAXO.NS', 'SBICARD.NS', 'SHRIRAMFIN.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUPRAJIT.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATACONSUM.NS', 'TATAMOTORS.NS', 'TATAPOWER.NS', 'TECHM.NS', 'TV18BRDCST.NS', 'UBL.NS', 'USHAMART.NS', 'VARROC.NS', 'VINATIORGA.NS', 'VMART.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'ZYDUSLIFE.NS'],
'2022-10-01': ['AAVAS.NS', 'ABB.NS', 'ACC.NS', 'ADANIGREEN.NS', 'ADANIPOWER.NS', 'AEGISCHEM.NS', 'AFFLE.NS', 'AIAENG.NS', 'APLAPOLLO.NS', 'ASTRAL.NS', 'BAJAJFINSV.NS', 'BEML.NS', 'BORORENEW.NS', 'CGPOWER.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CONCOR.NS', 'CRISIL.NS', 'CUB.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'GLENMARK.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GRASIM.NS', 'GUJGASLTD.NS', 'HAL.NS', 'HCLTECH.NS', 'ICICIBANK.NS', 'IIFL.NS', 'INDIAMART.NS', 'IPCALAB.NS', 'KANSAINER.NS', 'KEI.NS', 'LTTS.NS', 'M&M.NS', 'MAHLIFE.NS', 'MAXHEALTH.NS', 'MCDOWELL-N.NS', 'MUTHOOTFIN.NS', 'NESTLEIND.NS', 'PNBHOUSING.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'RADICO.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'ROSSARI.NS', 'SBICARD.NS', 'SUPRAJIT.NS', 'SWANENERGY.NS', 'SWSOLAR.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TRIVENI.NS', 'TTKPRESTIG.NS', 'UNOMINDA.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VEDL.NS', 'VTL.NS', 'ZEEL.NS', 'ZYDUSWELL.NS'],
'2022-11-01': ['360ONE.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'AUROPHARMA.NS', 'BEL.NS', 'CENTRALBK.NS', 'CENTURYTEX.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CIEINDIA.NS', 'CUB.NS', 'DABUR.NS', 'FACT.NS', 'FORTIS.NS', 'GICRE.NS', 'GNFC.NS', 'GPPL.NS', 'GUJALKALI.NS', 'HDFCLIFE.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'INDIACEM.NS', 'IOC.NS', 'IRB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'LEMONTREE.NS', 'MARICO.NS', 'NBCC.NS', 'NIACL.NS', 'NMDC.NS', 'OIL.NS', 'ONGC.NS', 'PETRONET.NS', 'POONAWALLA.NS', 'RALLIS.NS', 'RTNINDIA.NS', 'SAIL.NS', 'SONATSOFTW.NS', 'SUNTV.NS', 'SUZLON.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VEDL.NS', 'WELSPUNLIV.NS', 'ZEEL.NS', 'ZENSARTECH.NS'],
'2022-12-01': ['360ONE.NS', '3MINDIA.NS', 'ADANIPORTS.NS', 'AFFLE.NS', 'AIAENG.NS', 'ALLCARGO.NS', 'ANGELONE.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'ASIANPAINT.NS', 'ATGL.NS', 'AUBANK.NS', 'BAJAJ-AUTO.NS', 'BDL.NS', 'BERGEPAINT.NS', 'BOSCHLTD.NS', 'CARBORUNIV.NS', 'CDSL.NS', 'CGCL.NS', 'CHALET.NS', 'CONCOR.NS', 'CUB.NS', 'DRREDDY.NS', 'FORTIS.NS', 'GMMPFAUDLR.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'GSFC.NS', 'HAVELLS.NS', 'HEG.NS', 'HONAUT.NS', 'IEX.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INGERRAND.NS', 'IRCTC.NS', 'ISEC.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'KOTAKBANK.NS', 'KSB.NS', 'LTIM.NS', 'M&M.NS', 'M&MFIN.NS', 'MASTEK.NS', 'MINDACORP.NS', 'MRPL.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'RADICO.NS', 'SANOFI.NS', 'SPARC.NS', 'SWSOLAR.NS', 'SYNGENE.NS', 'TANLA.NS', 'TATAINVEST.NS', 'TEJASNET.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TITAN.NS', 'TRENT.NS', 'TV18BRDCST.NS', 'UBL.NS', 'VIPIND.NS', 'VTL.NS', 'ZEEL.NS', 'ZENSARTECH.NS'],
'2023-01-01': ['AARTIDRUGS.NS', 'AEGISCHEM.NS', 'ATGL.NS', 'AUBANK.NS', 'BDL.NS', 'BHARATFORG.NS', 'BHEL.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'BRITANNIA.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'DALBHARAT.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'EPL.NS', 'FINCABLES.NS', 'FORTIS.NS', 'GAEL.NS', 'GESHIP.NS', 'GSFC.NS', 'GSPL.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HINDPETRO.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IIFL.NS', 'INDIANB.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'IRCON.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KNRCON.NS', 'KPITTECH.NS', 'L&TFH.NS', 'LICHSGFIN.NS', 'MANAPPURAM.NS', 'MAXHEALTH.NS', 'NBCC.NS', 'NCC.NS', 'NH.NS', 'NLCINDIA.NS', 'OIL.NS', 'PNCINFRA.NS', 'POONAWALLA.NS', 'PRINCEPIPE.NS', 'RAJESHEXPO.NS', 'RALLIS.NS', 'RAYMOND.NS', 'REDINGTON.NS', 'RENUKA.NS', 'SAIL.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SHOPERSTOP.NS', 'SHRIRAMFIN.NS', 'SONATSOFTW.NS', 'STLTECH.NS', 'SUMICHEM.NS', 'SUPREMEIND.NS', 'SYMPHONY.NS', 'TITAN.NS', 'TVSMOTOR.NS', 'UJJIVANSFB.NS', 'UNIONBANK.NS', 'VBL.NS', 'VEDL.NS', 'VGUARD.NS', 'WELCORP.NS', 'ZYDUSLIFE.NS'],
'2023-02-01': ['360ONE.NS', 'AJANTPHARM.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'ASTRAL.NS', 'BAJAJHLDNG.NS', 'BHARATFORG.NS', 'BLUESTARCO.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'CAMS.NS', 'COROMANDEL.NS', 'CUMMINSIND.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'FINCABLES.NS', 'GMMPFAUDLR.NS', 'GODFRYPHLP.NS', 'HAL.NS', 'HAVELLS.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'IGL.NS', 'INDIAMART.NS', 'INFY.NS', 'INTELLECT.NS', 'JKPAPER.NS', 'LICHSGFIN.NS', 'LINDEINDIA.NS', 'LT.NS', 'LTIM.NS', 'MAXHEALTH.NS', 'MAZDOCK.NS', 'MPHASIS.NS', 'MRF.NS', 'OFSS.NS', 'PGHH.NS', 'PGHL.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'ROUTE.NS', 'SAFARI.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SOBHA.NS', 'SUNTECK.NS', 'TATAELXSI.NS', 'TCS.NS', 'TIMKEN.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'VIPIND.NS', 'VOLTAS.NS', 'WESTLIFE.NS', 'ZFCVINDIA.NS', 'ZYDUSLIFE.NS'],
'2023-03-01': ['ABCAPITAL.NS', 'APLAPOLLO.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'CGPOWER.NS', 'COALINDIA.NS', 'COROMANDEL.NS', 'EPL.NS', 'ESCORTS.NS', 'FEDERALBNK.NS', 'GODREJCP.NS', 'HAVELLS.NS', 'IDFC.NS', 'INDHOTEL.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INTELLECT.NS', 'IRB.NS', 'JSWENERGY.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'LEMONTREE.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NCC.NS', 'NHPC.NS', 'NLCINDIA.NS', 'ORIENTELEC.NS', 'PCBL.NS', 'PRSMJOHNSN.NS', 'RAMCOCEM.NS', 'RECLTD.NS', 'RITES.NS', 'SHARDACROP.NS', 'SUNDRMFAST.NS', 'SYNGENE.NS', 'TATAMTRDVR.NS', 'USHAMART.NS', 'VGUARD.NS', 'VTL.NS', 'YESBANK.NS'],
'2023-04-01': ['ABCAPITAL.NS', 'AEGISCHEM.NS', 'AJANTPHARM.NS', 'ANGELONE.NS', 'APOLLOTYRE.NS', 'AXISBANK.NS', 'BANKBARODA.NS', 'BERGEPAINT.NS', 'BLS.NS', 'BPCL.NS', 'BRIGADE.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHALET.NS', 'CHOLAFIN.NS', 'COCHINSHIP.NS', 'CSBBANK.NS', 'DABUR.NS', 'DEEPAKNTR.NS', 'EIHOTEL.NS', 'EPL.NS', 'EQUITASBNK.NS', 'FEDERALBNK.NS', 'FINPIPE.NS', 'GMRINFRA.NS', 'GRANULES.NS', 'GRINDWELL.NS', 'HDFCBANK.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'IDFC.NS', 'IGL.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'IRCON.NS', 'JBCHEPHARM.NS', 'JINDALSAW.NS', 'JSL.NS', 'KARURVYSYA.NS', 'KPRMILL.NS', 'LEMONTREE.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MUTHOOTFIN.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NH.NS', 'NHPC.NS', 'NTPC.NS', 'OIL.NS', 'ONGC.NS', 'ORIENTELEC.NS', 'PCBL.NS', 'PETRONET.NS', 'PFC.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RITES.NS', 'RVNL.NS', 'SAREGAMA.NS', 'SBICARD.NS', 'SHOPERSTOP.NS', 'SUNDARMFIN.NS', 'SUNPHARMA.NS', 'TECHM.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TVSMOTOR.NS', 'VGUARD.NS', 'WELCORP.NS', 'ZEEL.NS', 'ZENSARTECH.NS'],
'2023-05-01': ['ADANIENT.NS', 'ADANIGREEN.NS', 'AEGISCHEM.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'ANGELONE.NS', 'ASAHIINDIA.NS', 'ASTERDM.NS', 'BAJAJFINSV.NS', 'BALKRISIND.NS', 'BHARATFORG.NS', 'BIRLACORPN.NS', 'BSOFT.NS', 'CDSL.NS', 'CENTURYTEX.NS', 'CHAMBLFERT.NS', 'CONCOR.NS', 'CREDITACC.NS', 'DMART.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'EQUITASBNK.NS', 'ESCORTS.NS', 'GLAND.NS', 'GPPL.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRINDWELL.NS', 'HAPPSTMNDS.NS', 'HDFCLIFE.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'IBULHSGFIN.NS', 'ICICIPRULI.NS', 'IRB.NS', 'ITI.NS', 'JKLAKSHMI.NS', 'JSL.NS', 'JSWENERGY.NS', 'JUBLFOOD.NS', 'JUBLPHARMA.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KPRMILL.NS', 'LICHSGFIN.NS', 'LINDEINDIA.NS', 'M&M.NS', 'MAHLIFE.NS', 'MARUTI.NS', 'MAXHEALTH.NS', 'MCDOWELL-N.NS', 'MOTILALOFS.NS', 'NETWORK18.NS', 'NIACL.NS', 'OIL.NS', 'PEL.NS', 'PFIZER.NS', 'PGHH.NS', 'PNBHOUSING.NS', 'POWERINDIA.NS', 'PRINCEPIPE.NS', 'RATNAMANI.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'SANOFI.NS', 'SAREGAMA.NS', 'SBILIFE.NS', 'SHRIRAMFIN.NS', 'SPARC.NS', 'STLTECH.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SUZLON.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'THERMAX.NS', 'TIMKEN.NS', 'TRENT.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'TTKPRESTIG.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'USHAMART.NS', 'VEDL.NS', 'VGUARD.NS', 'ZENSARTECH.NS', 'ZFCVINDIA.NS'],
'2023-06-01': ['360ONE.NS', 'ABBOTINDIA.NS', 'ADANIGREEN.NS', 'AFFLE.NS', 'ALOKINDS.NS', 'APARINDS.NS', 'AXISBANK.NS', 'BALKRISIND.NS', 'BBTC.NS', 'BHARATFORG.NS', 'BHEL.NS', 'BLS.NS', 'BPCL.NS', 'CANBK.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'EMAMILTD.NS', 'FINEORG.NS', 'GLAXO.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'HEG.NS', 'IBULHSGFIN.NS', 'IGL.NS', 'INDIAMART.NS', 'INDUSTOWER.NS', 'INFY.NS', 'IRB.NS', 'JBCHEPHARM.NS', 'JSL.NS', 'KEC.NS', 'KNRCON.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'MCX.NS', 'METROPOLIS.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NAVINFLUOR.NS', 'NCC.NS', 'OBEROIRLTY.NS', 'ORIENTELEC.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'PNCINFRA.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RADICO.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'REDINGTON.NS', 'RELIANCE.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SUNTV.NS', 'SUPREMEIND.NS', 'SUVENPHAR.NS', 'SWANENERGY.NS', 'TCS.NS', 'THERMAX.NS', 'TORNTPOWER.NS', 'UBL.NS', 'USHAMART.NS', 'VTL.NS', 'WELSPUNLIV.NS', 'WESTLIFE.NS', 'YESBANK.NS', 'ZFCVINDIA.NS'],
'2023-07-01': ['3MINDIA.NS', 'AARTIDRUGS.NS', 'ACC.NS', 'ADANIENT.NS', 'ADANIPORTS.NS', 'AIAENG.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'ASTERDM.NS', 'ATUL.NS', 'AUBANK.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BBTC.NS', 'BDL.NS', 'BLUESTARCO.NS', 'BOSCHLTD.NS', 'BRIGADE.NS', 'CAMS.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CERA.NS', 'CHALET.NS', 'COCHINSHIP.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CRISIL.NS', 'DALBHARAT.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'ELGIEQUIP.NS', 'FINCABLES.NS', 'FINEORG.NS', 'GALAXYSURF.NS', 'GNFC.NS', 'GRANULES.NS', 'GRASIM.NS', 'GUJALKALI.NS', 'HINDUNILVR.NS', 'ICICIBANK.NS', 'INGERRAND.NS', 'IPCALAB.NS', 'JUSTDIAL.NS', 'KAJARIACER.NS', 'KEC.NS', 'KSB.NS', 'LINDEINDIA.NS', 'LTTS.NS', 'LUXIND.NS', 'MASTEK.NS', 'MGL.NS', 'MHRIL.NS', 'MPHASIS.NS', 'OBEROIRLTY.NS', 'PERSISTENT.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PNCINFRA.NS', 'POLYCAB.NS', 'RADICO.NS', 'REDINGTON.NS', 'RELAXO.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SIEMENS.NS', 'SOBHA.NS', 'TATACHEM.NS', 'TATAELXSI.NS', 'TCS.NS', 'TIMKEN.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'TVSMOTOR.NS', 'VBL.NS'],
'2023-08-01': ['AAVAS.NS', 'AFFLE.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'ATUL.NS', 'BAJAJFINSV.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BLUESTARCO.NS', 'BOSCHLTD.NS', 'CARBORUNIV.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'COFORGE.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CUB.NS', 'CYIENT.NS', 'DABUR.NS', 'DIVISLAB.NS', 'DMART.NS', 'ECLERX.NS', 'EIHOTEL.NS', 'GALAXYSURF.NS', 'GLAXO.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HDFCLIFE.NS', 'INDHOTEL.NS', 'INDIGO.NS', 'INDUSTOWER.NS', 'INFY.NS', 'IOB.NS', 'IOC.NS', 'IRCTC.NS', 'ITC.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JUSTDIAL.NS', 'KARURVYSYA.NS', 'KEI.NS', 'KNRCON.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LTTS.NS', 'M&M.NS', 'MARUTI.NS', 'MAXHEALTH.NS', 'MRPL.NS', 'NH.NS', 'OFSS.NS', 'OLECTRA.NS', 'PAGEIND.NS', 'PCBL.NS', 'PRINCEPIPE.NS', 'RCF.NS', 'RENUKA.NS', 'RHIM.NS', 'RTNINDIA.NS', 'RVNL.NS', 'SAREGAMA.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SHOPERSTOP.NS', 'SOLARINDS.NS', 'SUPRAJIT.NS', 'TATACONSUM.NS', 'TECHM.NS', 'TITAN.NS', 'TRIVENI.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UBL.NS', 'UCOBANK.NS', 'ULTRACEMCO.NS', 'VOLTAS.NS', 'VTL.NS', 'WHIRLPOOL.NS', 'WIPRO.NS'],
'2023-09-01': ['AARTIDRUGS.NS', 'ABB.NS', 'ABFRL.NS', 'ADANIPORTS.NS', 'AEGISCHEM.NS', 'ASTRAL.NS', 'AXISBANK.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BANKINDIA.NS', 'BIOCON.NS', 'BOSCHLTD.NS', 'BRIGADE.NS', 'CAMS.NS', 'CANFINHOME.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'COALINDIA.NS', 'COLPAL.NS', 'CREDITACC.NS', 'CRISIL.NS', 'CROMPTON.NS', 'DMART.NS', 'DRREDDY.NS', 'EIDPARRY.NS', 'ENDURANCE.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'FACT.NS', 'FORTIS.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GESHIP.NS', 'GILLETTE.NS', 'GLENMARK.NS', 'GRINDWELL.NS', 'HAL.NS', 'HAPPSTMNDS.NS', 'HCLTECH.NS', 'HDFCLIFE.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'ICICIPRULI.NS', 'IGL.NS', 'INDIACEM.NS', 'INDIAMART.NS', 'IPCALAB.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'KARURVYSYA.NS', 'L&TFH.NS', 'M&MFIN.NS', 'MARICO.NS', 'MAXHEALTH.NS', 'MCDOWELL-N.NS', 'MOTHERSON.NS', 'NAVINFLUOR.NS', 'OIL.NS', 'ONGC.NS', 'ORIENTELEC.NS', 'PEL.NS', 'PGHH.NS', 'PNBHOUSING.NS', 'POONAWALLA.NS', 'POWERINDIA.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RAIN.NS', 'RELAXO.NS', 'RENUKA.NS', 'SAIL.NS', 'SANOFI.NS', 'SAREGAMA.NS', 'SBILIFE.NS', 'SKFINDIA.NS', 'SONATSOFTW.NS', 'SUNDARMFIN.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUPRAJIT.NS', 'TATAINVEST.NS', 'TORNTPOWER.NS', 'TTKPRESTIG.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'VMART.NS', 'WIPRO.NS', 'ZYDUSLIFE.NS'],
'2023-10-01': ['3MINDIA.NS', 'ACC.NS', 'ADANIPORTS.NS', 'AFFLE.NS', 'ANGELONE.NS', 'APLAPOLLO.NS', 'APOLLOHOSP.NS', 'ASTERDM.NS', 'BAJAJFINSV.NS', 'BEML.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'BSOFT.NS', 'CAMS.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CGCL.NS', 'COLPAL.NS', 'CONCOR.NS', 'CRISIL.NS', 'CYIENT.NS', 'DIVISLAB.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'ELGIEQUIP.NS', 'FDC.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'FLUOROCHEM.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'IIFL.NS', 'INDHOTEL.NS', 'INDUSINDBK.NS', 'INTELLECT.NS', 'IRCTC.NS', 'ISEC.NS', 'JINDALSAW.NS', 'JUBLFOOD.NS', 'KEC.NS', 'KEI.NS', 'KPITTECH.NS', 'LAURUSLABS.NS', 'LAXMIMACH.NS', 'LINDEINDIA.NS', 'LTTS.NS', 'M&MFIN.NS', 'MAHLIFE.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MOTILALOFS.NS', 'NATCOPHARM.NS', 'NCC.NS', 'NESTLEIND.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'RAMCOCEM.NS', 'RCF.NS', 'RITES.NS', 'SANOFI.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SFL.NS', 'SHRIRAMFIN.NS', 'SUNDRMFAST.NS', 'SWANENERGY.NS', 'SYNGENE.NS', 'TATACONSUM.NS', 'TATAMOTORS.NS', 'TCS.NS', 'TORNTPHARM.NS', 'USHAMART.NS', 'UTIAMC.NS', 'VGUARD.NS', 'VOLTAS.NS', 'WELSPUNLIV.NS', 'WHIRLPOOL.NS', 'ZEEL.NS', 'ZENSARTECH.NS'],
'2023-11-01': ['360ONE.NS', 'ABB.NS', 'AIAENG.NS', 'AMBER.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ASTERDM.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BALRAMCHIN.NS', 'BHARTIARTL.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CGCL.NS', 'DIXON.NS', 'EIHOTEL.NS', 'EMAMILTD.NS', 'ENDURANCE.NS', 'EQUITASBNK.NS', 'ESCORTS.NS', 'GAEL.NS', 'GILLETTE.NS', 'GMMPFAUDLR.NS', 'GODREJCP.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'HEROMOTOCO.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INTELLECT.NS', 'IRCON.NS', 'JBCHEPHARM.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JUSTDIAL.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'LT.NS', 'LUPIN.NS', 'MARUTI.NS', 'MAXHEALTH.NS', 'MAZDOCK.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'MRF.NS', 'OIL.NS', 'OLECTRA.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PNB.NS', 'QUESS.NS', 'RADICO.NS', 'RALLIS.NS', 'RCF.NS', 'RELAXO.NS', 'ROUTE.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SPARC.NS', 'SUNDRMFAST.NS', 'SUNTECK.NS', 'SUPREMEIND.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TEJASNET.NS', 'THERMAX.NS', 'TITAN.NS', 'VAIBHAVGBL.NS', 'VARROC.NS', 'VBL.NS', 'VGUARD.NS', 'VOLTAS.NS', 'VTL.NS', 'WHIRLPOOL.NS', 'ZEEL.NS'],
'2023-12-01': ['3MINDIA.NS', 'ABBOTINDIA.NS', 'ADANIENT.NS', 'ADANIPORTS.NS', 'AIAENG.NS', 'ALOKINDS.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'BALKRISIND.NS', 'BANDHANBNK.NS', 'BANKINDIA.NS', 'BATAINDIA.NS', 'BLS.NS', 'CANFINHOME.NS', 'CENTURYPLY.NS', 'CERA.NS', 'CHALET.NS', 'DALBHARAT.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'EIHOTEL.NS', 'EPL.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'FLUOROCHEM.NS', 'GALAXYSURF.NS', 'GLENMARK.NS', 'GNFC.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'IDEA.NS', 'INGERRAND.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JSL.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'KANSAINER.NS', 'LAURUSLABS.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MASTEK.NS', 'MAZDOCK.NS', 'MCDOWELL-N.NS', 'MPHASIS.NS', 'OIL.NS', 'PATANJALI.NS', 'PGHL.NS', 'PNB.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'POLYCAB.NS', 'PRINCEPIPE.NS', 'RAMCOCEM.NS', 'RCF.NS', 'RELAXO.NS', 'RELIANCE.NS', 'RITES.NS', 'RVNL.NS', 'SAREGAMA.NS', 'SFL.NS', 'SHOPERSTOP.NS', 'SUMICHEM.NS', 'SUPREMEIND.NS', 'SYNGENE.NS', 'TCS.NS', 'TIINDIA.NS', 'UJJIVANSFB.NS', 'UNIONBANK.NS', 'USHAMART.NS', 'VAIBHAVGBL.NS', 'VGUARD.NS', 'WESTLIFE.NS', 'ZFCVINDIA.NS'],
'2024-01-01': ['ABB.NS', 'AIAENG.NS', 'ALOKINDS.NS', 'ASAHIINDIA.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BANDHANBNK.NS', 'BANKINDIA.NS', 'BATAINDIA.NS', 'BCG.NS', 'BIOCON.NS', 'BORORENEW.NS', 'CDSL.NS', 'CGPOWER.NS', 'CIPLA.NS', 'CRISIL.NS', 'CUMMINSIND.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DELTACORP.NS', 'ELGIEQUIP.NS', 'EPL.NS', 'ERIS.NS', 'FINCABLES.NS', 'HAPPSTMNDS.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INFIBEAM.NS', 'IOB.NS', 'IRCON.NS', 'ISEC.NS', 'JAMNAAUTO.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'LAXMIMACH.NS', 'LEMONTREE.NS', 'MARICO.NS', 'METROPOLIS.NS', 'MMTC.NS', 'NATCOPHARM.NS', 'NAVINFLUOR.NS', 'NETWORK18.NS', 'NIACL.NS', 'OFSS.NS', 'ORIENTELEC.NS', 'PCBL.NS', 'PHOENIXLTD.NS', 'PNCINFRA.NS', 'POLYCAB.NS', 'RAIN.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'RITES.NS', 'ROSSARI.NS', 'RTNINDIA.NS', 'SAREGAMA.NS', 'SBILIFE.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'SUNDARMFIN.NS', 'SUPREMEIND.NS', 'SUZLON.NS', 'TATACOMM.NS', 'TIINDIA.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'ZEEL.NS'],
'2024-02-01': ['3MINDIA.NS', 'AARTIDRUGS.NS', 'ABB.NS', 'AEGISCHEM.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'ASTRAL.NS', 'BAYERCROP.NS', 'BHARATFORG.NS', 'BRITANNIA.NS', 'CAMS.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CGPOWER.NS', 'CIPLA.NS', 'COFORGE.NS', 'CONCOR.NS', 'DALBHARAT.NS', 'ECLERX.NS', 'ERIS.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'FDC.NS', 'GALAXYSURF.NS', 'GLAND.NS', 'GMRINFRA.NS', 'GPIL.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GUJALKALI.NS', 'HINDALCO.NS', 'IBULHSGFIN.NS', 'IGL.NS', 'INDIACEM.NS', 'INDIGO.NS', 'IPCALAB.NS', 'JSL.NS', 'KANSAINER.NS', 'KEI.NS', 'KOTAKBANK.NS', 'M&MFIN.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MAZDOCK.NS', 'MHRIL.NS', 'MPHASIS.NS', 'PATANJALI.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'POWERINDIA.NS', 'PRESTIGE.NS', 'RADICO.NS', 'SBIN.NS', 'SHREECEM.NS', 'SKFINDIA.NS', 'SONATSOFTW.NS', 'SUNDARMFIN.NS', 'SUNTECK.NS', 'SYNGENE.NS', 'TATASTEEL.NS', 'TCS.NS', 'TECHM.NS', 'THERMAX.NS', 'TITAN.NS', 'TRENT.NS', 'TVSMOTOR.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'VARROC.NS', 'VTL.NS', 'WELSPUNLIV.NS', 'ZFCVINDIA.NS'],

    
 }

# Initialize lists to store results
ticker_list = []
percentage_returns = []
first_day_closes = []
last_day_closes = []
start_dates = []  # List to store the start dates
end_dates = []    # List to store the end dates

# Loop through the dictionary and download data for each date-ticker pair
for start_date, tickers in date_ticker_dict.items():
    end_date = pd.to_datetime(start_date) + pd.DateOffset(months=1) - pd.DateOffset(days=1)  # Last day of the month

    # Loop through tickers in this iteration
    for ticker in tickers:
        # Download historical stock data using yfinance for the specified ticker and dates
        try:
            stocks = yf.download(ticker, start=start_date, end=end_date)

            # Extracting the closing prices on the first and last day
            first_day_close = stocks['Close'].iloc[0]
            last_day_close = stocks['Close'].iloc[-1]

            # Calculating percentage return for this ticker
            percentage_return = ((last_day_close - first_day_close) / first_day_close) * 100

            # Appending the results to the lists
            ticker_list.append(ticker)
            percentage_returns.append(percentage_return)
            first_day_closes.append(first_day_close)
            last_day_closes.append(last_day_close)
            start_dates.append(pd.to_datetime(start_date))
            end_dates.append(end_date)  # Append end date for each ticker
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

# Creating a DataFrame with ticker symbols, percentage returns, and capital information
returns_df = pd.DataFrame({
    'Start_Date': start_dates,
    'End_Date': end_dates,
    'Ticker': ticker_list,
    'Percentage_Return': percentage_returns,
    'First_Day_Close': first_day_closes,
    'Last_Day_Close': last_day_closes,
})

# Assuming an initial investment of $10,000 for each stock
initial_investment = 10000

# Calculating the capital at the last day
returns_df['Capital_At_Last_Day'] = initial_investment * (1 + returns_df['Percentage_Return'] / 100)

# Calculating the difference between capital at the last day and capital required
returns_df['Capital_Difference'] = returns_df['Capital_At_Last_Day'] - initial_investment

# Total amount invested
total_invested = initial_investment * len(returns_df)

# Total amount returned
total_returned = returns_df['Capital_At_Last_Day'].sum()

# Calculate percentage return
percentage_return = ((total_returned - total_invested) / total_invested) * 100

# Displaying the DataFrame with ticker names, percentage returns, and capital information
print(returns_df[['Start_Date', 'End_Date', 'Ticker', 'Percentage_Return', 'First_Day_Close', 'Last_Day_Close']])

# Display total amount invested and total amount returned in percentage
print("\nTotal Amount Invested: $", total_invested)
print("Total Amount Returned: $", total_returned)
print("Percentage Return: ", percentage_return, "%")

returns_df.to_csv('stock_Cluster4.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %% [markdown]
# # CLUSTER 5

# %%
import yfinance as yf
import pandas as pd

# Input dictionary
date_ticker_dict =  {  
'2017-04-01': ['3MINDIA.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'ADANIPOWER.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APLLTD.NS', 'ASIANPAINT.NS', 'BALKRISIND.NS', 'BANKBARODA.NS', 'BHEL.NS', 'BIOCON.NS', 'BOSCHLTD.NS', 'CANBK.NS', 'CASTROLIND.NS', 'CCL.NS', 'CESC.NS', 'CGCL.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'COFORGE.NS', 'CONCOR.NS', 'CUB.NS', 'DLF.NS', 'GILLETTE.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GRAPHITE.NS', 'GUJALKALI.NS', 'HCLTECH.NS', 'HEG.NS', 'HINDPETRO.NS', 'ITC.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JUBLPHARMA.NS', 'KAJARIACER.NS', 'LINDEINDIA.NS', 'LUXIND.NS', 'M&MFIN.NS', 'MCX.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'PEL.NS', 'PETRONET.NS', 'PGHL.NS', 'PIDILITIND.NS', 'PNB.NS', 'POONAWALLA.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'REDINGTON.NS', 'SAREGAMA.NS', 'SHARDACROP.NS', 'SIEMENS.NS', 'SJVN.NS', 'SOBHA.NS', 'SUZLON.NS', 'TATAINVEST.NS', 'TEAMLEASE.NS', 'TIMKEN.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS', 'UNIONBANK.NS', 'VEDL.NS', 'VINATIORGA.NS', 'ZFCVINDIA.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2017-05-01': ['ABFRL.NS', 'AMBUJACEM.NS', 'APOLLOHOSP.NS', 'ASTRAL.NS', 'BALAMINES.NS', 'BALRAMCHIN.NS', 'BHEL.NS', 'BPCL.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHOLAHLDNG.NS', 'DEEPAKNTR.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'FINCABLES.NS', 'GAEL.NS', 'GESHIP.NS', 'GMRINFRA.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GRAPHITE.NS', 'GSFC.NS', 'GSPL.NS', 'HEROMOTOCO.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDUNILVR.NS', 'IDBI.NS', 'IGL.NS', 'INDHOTEL.NS', 'INDUSTOWER.NS', 'INTELLECT.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'JYOTHYLAB.NS', 'KNRCON.NS', 'M&M.NS', 'M&MFIN.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MUTHOOTFIN.NS', 'NCC.NS', 'NLCINDIA.NS', 'OLECTRA.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'RELAXO.NS', 'RELIANCE.NS', 'RTNINDIA.NS', 'SBIN.NS', 'SIEMENS.NS', 'SJVN.NS', 'STLTECH.NS', 'SUNDRMFAST.NS', 'SUPREMEIND.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TTML.NS', 'USHAMART.NS', 'VIPIND.NS', 'VOLTAS.NS', 'WHIRLPOOL.NS'],
'2017-06-01': ['AARTIIND.NS', 'ABFRL.NS', 'ACC.NS', 'APLAPOLLO.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'ATUL.NS', 'BAJFINANCE.NS', 'BAYERCROP.NS', 'BHARTIARTL.NS', 'BPCL.NS', 'BRIGADE.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CEATLTD.NS', 'CENTURYPLY.NS', 'CERA.NS', 'CHOLAHLDNG.NS', 'CUB.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'FEDERALBNK.NS', 'GAIL.NS', 'GRASIM.NS', 'HCLTECH.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'HONAUT.NS', 'INDHOTEL.NS', 'INDIGO.NS', 'KAJARIACER.NS', 'KEI.NS', 'LAXMIMACH.NS', 'LT.NS', 'MARICO.NS', 'MRF.NS', 'NATCOPHARM.NS', 'PGHH.NS', 'POONAWALLA.NS', 'RAMCOCEM.NS', 'SUNDARMFIN.NS', 'SUNTECK.NS', 'TATACOMM.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TTKPRESTIG.NS', 'VAIBHAVGBL.NS'],
'2017-07-01': ['AARTIIND.NS', 'ADANIENT.NS', 'ADANIPORTS.NS', 'AMBUJACEM.NS', 'APLAPOLLO.NS', 'ASHOKLEY.NS', 'AXISBANK.NS', 'BAJFINANCE.NS', 'BAYERCROP.NS', 'BIRLACORPN.NS', 'CEATLTD.NS', 'CENTURYPLY.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'COROMANDEL.NS', 'DEEPAKFERT.NS', 'DIVISLAB.NS', 'DRREDDY.NS', 'EIHOTEL.NS', 'GLAXO.NS', 'GMRINFRA.NS', 'GODFRYPHLP.NS', 'GRINDWELL.NS', 'GSPL.NS', 'HEROMOTOCO.NS', 'HONAUT.NS', 'ICICIBANK.NS', 'IDEA.NS', 'INDHOTEL.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JSWSTEEL.NS', 'KPRMILL.NS', 'LICHSGFIN.NS', 'MANAPPURAM.NS', 'MFSL.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'NATCOPHARM.NS', 'NBCC.NS', 'NESTLEIND.NS', 'NETWORK18.NS', 'PEL.NS', 'PIDILITIND.NS', 'PIIND.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'SOLARINDS.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'TATAELXSI.NS', 'TITAN.NS', 'TRITURBINE.NS', 'UPL.NS', 'VAIBHAVGBL.NS', 'VEDL.NS', 'VINATIORGA.NS'],
'2017-08-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'ASIANPAINT.NS', 'AUROPHARMA.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BIOCON.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'BRIGADE.NS', 'CANBK.NS', 'CEATLTD.NS', 'CHAMBLFERT.NS', 'CUMMINSIND.NS', 'DCMSHRIRAM.NS', 'EMAMILTD.NS', 'GODREJIND.NS', 'GRINDWELL.NS', 'HCLTECH.NS', 'HINDPETRO.NS', 'IBULHSGFIN.NS', 'ICICIBANK.NS', 'IIFL.NS', 'INDIGO.NS', 'JKCEMENT.NS', 'LT.NS', 'LUXIND.NS', 'M&M.NS', 'MHRIL.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'PEL.NS', 'PGHH.NS', 'PNB.NS', 'POLYPLEX.NS', 'PRESTIGE.NS', 'SANOFI.NS', 'SHREECEM.NS', 'SUNDARMFIN.NS', 'SYMPHONY.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'UBL.NS', 'UPL.NS', 'VOLTAS.NS', 'ZEEL.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2017-09-01': ['ACC.NS', 'ADANIENT.NS', 'ADANIPOWER.NS', 'ALKYLAMINE.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'AVANTIFEED.NS', 'BALRAMCHIN.NS', 'BEL.NS', 'BEML.NS', 'BHARTIARTL.NS', 'CARBORUNIV.NS', 'CENTURYTEX.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'CYIENT.NS', 'DABUR.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'EPL.NS', 'GAEL.NS', 'GNFC.NS', 'GPIL.NS', 'GSPL.NS', 'HDFCBANK.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'IBULHSGFIN.NS', 'ITI.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KRBL.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MGL.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'NATIONALUM.NS', 'NMDC.NS', 'PETRONET.NS', 'PFIZER.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'PRESTIGE.NS', 'RAIN.NS', 'RCF.NS', 'REDINGTON.NS', 'RELAXO.NS', 'RELIANCE.NS', 'RHIM.NS', 'SHOPERSTOP.NS', 'SOLARINDS.NS', 'SPARC.NS', 'STLTECH.NS', 'SUNTECK.NS', 'SWANENERGY.NS', 'TATAINVEST.NS', 'TORNTPOWER.NS', 'TRIVENI.NS', 'TVSMOTOR.NS', 'VAIBHAVGBL.NS', 'VTL.NS', 'YESBANK.NS'],
'2017-10-01': ['ASAHIINDIA.NS', 'ATUL.NS', 'AVANTIFEED.NS', 'BAJAJHLDNG.NS', 'BALKRISIND.NS', 'BLS.NS', 'BLUESTARCO.NS', 'CCL.NS', 'CIPLA.NS', 'CONCOR.NS', 'DIVISLAB.NS', 'FINCABLES.NS', 'GLAXO.NS', 'GRINDWELL.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'INDUSTOWER.NS', 'JINDALSAW.NS', 'JSL.NS', 'JYOTHYLAB.NS', 'KRBL.NS', 'MARUTI.NS', 'MGL.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'OLECTRA.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'PFIZER.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'RADICO.NS', 'RELAXO.NS', 'SANOFI.NS', 'SCHAEFFLER.NS', 'SHREECEM.NS', 'SYNGENE.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TIMKEN.NS', 'USHAMART.NS', 'VMART.NS', 'WHIRLPOOL.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2017-11-01': ['ADANIENT.NS', 'ADANIPOWER.NS', 'AEGISCHEM.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'AXISBANK.NS', 'BALRAMCHIN.NS', 'BLUESTARCO.NS', 'CCL.NS', 'CENTURYPLY.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'CONCOR.NS', 'FDC.NS', 'FEDERALBNK.NS', 'GRANULES.NS', 'HFCL.NS', 'HINDALCO.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IDEA.NS', 'INDIACEM.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'IOB.NS', 'IPCALAB.NS', 'ITI.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JSL.NS', 'KEI.NS', 'MAHABANK.NS', 'MGL.NS', 'MINDACORP.NS', 'MMTC.NS', 'NAUKRI.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NTPC.NS', 'PETRONET.NS', 'PFC.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RALLIS.NS', 'RECLTD.NS', 'RHIM.NS', 'SHOPERSTOP.NS', 'SJVN.NS', 'SPARC.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'SYNGENE.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'THERMAX.NS', 'TITAN.NS', 'TRIDENT.NS', 'TTKPRESTIG.NS', 'VINATIORGA.NS', 'WELCORP.NS', 'ZEEL.NS', 'ZENSARTECH.NS'],
'2017-12-01': ['ABFRL.NS', 'ADANIPOWER.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'ATUL.NS', 'BAJAJ-AUTO.NS', 'BANKINDIA.NS', 'BAYERCROP.NS', 'BEL.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BIRLACORPN.NS', 'CHOLAFIN.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'CUB.NS', 'CYIENT.NS', 'DABUR.NS', 'DELTACORP.NS', 'ESCORTS.NS', 'GAIL.NS', 'GESHIP.NS', 'GUJALKALI.NS', 'HDFCBANK.NS', 'HEG.NS', 'HINDCOPPER.NS', 'HINDUNILVR.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'INFY.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'KAJARIACER.NS', 'KEC.NS', 'KSB.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MOTHERSON.NS', 'MRF.NS', 'NESTLEIND.NS', 'NLCINDIA.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'PAGEIND.NS', 'PEL.NS', 'PIDILITIND.NS', 'RALLIS.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RELAXO.NS', 'RHIM.NS', 'SCHAEFFLER.NS', 'SPARC.NS', 'SRF.NS', 'STLTECH.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'TANLA.NS', 'TATAELXSI.NS', 'TVSMOTOR.NS', 'UBL.NS', 'VGUARD.NS', 'ZEEL.NS', 'ZENSARTECH.NS'],
'2018-01-01': ['ABFRL.NS', 'ALOKINDS.NS', 'APLLTD.NS', 'AXISBANK.NS', 'BALAMINES.NS', 'BHARTIARTL.NS', 'BLS.NS', 'BLUEDART.NS', 'CESC.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'CONCOR.NS', 'CRISIL.NS', 'CYIENT.NS', 'DEEPAKFERT.NS', 'DRREDDY.NS', 'EPL.NS', 'GAEL.NS', 'GAIL.NS', 'GLENMARK.NS', 'GODREJIND.NS', 'GRANULES.NS', 'IDFC.NS', 'IGL.NS', 'INGERRAND.NS', 'IRB.NS', 'JBMA.NS', 'JKPAPER.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'KARURVYSYA.NS', 'KSB.NS', 'LT.NS', 'M&MFIN.NS', 'MARICO.NS', 'MFSL.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NESTLEIND.NS', 'NLCINDIA.NS', 'NMDC.NS', 'OIL.NS', 'PCBL.NS', 'PIDILITIND.NS', 'PIIND.NS', 'PNCINFRA.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'RCF.NS', 'RHIM.NS', 'STLTECH.NS', 'SUZLON.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TCS.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'USHAMART.NS', 'VAIBHAVGBL.NS', 'VEDL.NS', 'VIPIND.NS', 'ZEEL.NS'],
'2018-02-01': ['3MINDIA.NS', 'ASHOKLEY.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAYERCROP.NS', 'BLUEDART.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'COALINDIA.NS', 'CYIENT.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'ESCORTS.NS', 'FINCABLES.NS', 'GAEL.NS', 'GODREJCP.NS', 'HEG.NS', 'HINDUNILVR.NS', 'INTELLECT.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'LTTS.NS', 'M&M.NS', 'MARUTI.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'ONGC.NS', 'PGHL.NS', 'PRSMJOHNSN.NS', 'RELIANCE.NS', 'SIEMENS.NS', 'STLTECH.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SYNGENE.NS', 'TV18BRDCST.NS', 'UBL.NS', 'VEDL.NS'],
'2018-03-01': ['AARTIIND.NS', 'ALKEM.NS', 'APOLLOTYRE.NS', 'BIOCON.NS', 'BSOFT.NS', 'CASTROLIND.NS', 'CHAMBLFERT.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'COFORGE.NS', 'COROMANDEL.NS', 'CUB.NS', 'CYIENT.NS', 'ESCORTS.NS', 'FORTIS.NS', 'GODREJCP.NS', 'GPIL.NS', 'HEG.NS', 'HINDZINC.NS', 'IDBI.NS', 'IIFL.NS', 'INTELLECT.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LTTS.NS', 'MPHASIS.NS', 'NAVINFLUOR.NS', 'NCC.NS', 'NESTLEIND.NS', 'OBEROIRLTY.NS', 'PFIZER.NS', 'PRESTIGE.NS', 'RAJESHEXPO.NS', 'RELIANCE.NS', 'SONATSOFTW.NS', 'STLTECH.NS', 'SUNDRMFAST.NS', 'TATAELXSI.NS', 'TCS.NS', 'TECHM.NS', 'TV18BRDCST.NS', 'VGUARD.NS', 'VMART.NS', 'WELCORP.NS'],
'2018-04-01': ['APOLLOTYRE.NS', 'ASHOKLEY.NS', 'BAJFINANCE.NS', 'BERGEPAINT.NS', 'CASTROLIND.NS', 'CHOLAFIN.NS', 'DIVISLAB.NS', 'EXIDEIND.NS', 'FSL.NS', 'GODREJCP.NS', 'GPPL.NS', 'HCLTECH.NS', 'KEI.NS', 'M&MFIN.NS', 'MARICO.NS', 'NETWORK18.NS', 'PIDILITIND.NS', 'PNCINFRA.NS', 'RELAXO.NS', 'SHRIRAMFIN.NS', 'SOLARINDS.NS', 'SRF.NS', 'SUNTECK.NS', 'SYNGENE.NS', 'TECHM.NS', 'TRENT.NS', 'TV18BRDCST.NS'],
'2018-05-01': ['ADANIPORTS.NS', 'AMBUJACEM.NS', 'APLAPOLLO.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'AVANTIFEED.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'BSE.NS', 'CARBORUNIV.NS', 'CENTURYTEX.NS', 'CESC.NS', 'CUB.NS', 'DEEPAKNTR.NS', 'DLF.NS', 'ECLERX.NS', 'EPL.NS', 'FEDERALBNK.NS', 'GAEL.NS', 'GMRINFRA.NS', 'GODREJCP.NS', 'GPIL.NS', 'GPPL.NS', 'GSFC.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HINDZINC.NS', 'ICICIPRULI.NS', 'INDHOTEL.NS', 'INFIBEAM.NS', 'INFY.NS', 'JBCHEPHARM.NS', 'JSWENERGY.NS', 'JUBLPHARMA.NS', 'KARURVYSYA.NS', 'KEI.NS', 'KNRCON.NS', 'KPRMILL.NS', 'L&TFH.NS', 'MAHLIFE.NS', 'MANAPPURAM.NS', 'MHRIL.NS', 'MMTC.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NCC.NS', 'NHPC.NS', 'OBEROIRLTY.NS', 'OIL.NS', 'PCBL.NS', 'POONAWALLA.NS', 'PRSMJOHNSN.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'RELIANCE.NS', 'SKFINDIA.NS', 'STLTECH.NS', 'SUNTECK.NS', 'TANLA.NS', 'TATAPOWER.NS', 'TECHM.NS', 'TRENT.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VMART.NS', 'WHIRLPOOL.NS', 'ZYDUSLIFE.NS'],
'2018-06-01': ['AIAENG.NS', 'BAJAJHLDNG.NS', 'BAYERCROP.NS', 'BIOCON.NS', 'BLS.NS', 'BSE.NS', 'CENTRALBK.NS', 'CIEINDIA.NS', 'CONCOR.NS', 'ENDURANCE.NS', 'EXIDEIND.NS', 'GAIL.NS', 'GNFC.NS', 'GODREJIND.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'INTELLECT.NS', 'IOC.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'LTTS.NS', 'NAUKRI.NS', 'PHOENIXLTD.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'QUESS.NS', 'RELAXO.NS', 'RENUKA.NS', 'RHIM.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SHARDACROP.NS', 'SHOPERSTOP.NS', 'TORNTPHARM.NS', 'TRITURBINE.NS', 'UBL.NS', 'VIPIND.NS', 'YESBANK.NS'],
'2018-07-01': ['ABBOTINDIA.NS', 'BAJFINANCE.NS', 'DABUR.NS', 'GODREJIND.NS', 'HDFCBANK.NS', 'JUBLFOOD.NS', 'PFIZER.NS', 'PGHH.NS', 'RBLBANK.NS', 'SANOFI.NS', 'SCHAEFFLER.NS', 'SUNPHARMA.NS', 'TATAELXSI.NS', 'TRITURBINE.NS', 'ZENSARTECH.NS'],
'2018-08-01': ['AIAENG.NS', 'ASAHIINDIA.NS', 'ATUL.NS', 'AXISBANK.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BBTC.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'BSOFT.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'CIPLA.NS', 'CROMPTON.NS', 'DELTACORP.NS', 'DIVISLAB.NS', 'ESCORTS.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GRASIM.NS', 'HDFCBANK.NS', 'IBULHSGFIN.NS', 'INDIANB.NS', 'INDUSINDBK.NS', 'INFY.NS', 'JKPAPER.NS', 'JSWSTEEL.NS', 'KEI.NS', 'KPRMILL.NS', 'L&TFH.NS', 'LALPATHLAB.NS', 'LICHSGFIN.NS', 'M&M.NS', 'MARUTI.NS', 'MASTEK.NS', 'MFSL.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'MRF.NS', 'NAUKRI.NS', 'PAGEIND.NS', 'PETRONET.NS', 'PFIZER.NS', 'PGHH.NS', 'PIDILITIND.NS', 'PNBHOUSING.NS', 'RALLIS.NS', 'RBLBANK.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SOLARINDS.NS', 'STLTECH.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'TATACHEM.NS', 'TATAELXSI.NS', 'TATAPOWER.NS', 'TCS.NS', 'TECHM.NS', 'TITAN.NS', 'TRENT.NS', 'UCOBANK.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VGUARD.NS', 'VOLTAS.NS', 'ZENSARTECH.NS', 'ZYDUSWELL.NS'],
'2018-09-01': ['AARTIIND.NS', 'AIAENG.NS', 'ALKEM.NS', 'AMBUJACEM.NS', 'APLLTD.NS', 'ASAHIINDIA.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BERGEPAINT.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIOCON.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'CESC.NS', 'CHAMBLFERT.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'EPL.NS', 'FSL.NS', 'GRASIM.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HEG.NS', 'HINDALCO.NS', 'HINDUNILVR.NS', 'HINDZINC.NS', 'IDFC.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'IOB.NS', 'IPCALAB.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JSWENERGY.NS', 'KANSAINER.NS', 'KPRMILL.NS', 'L&TFH.NS', 'M&M.NS', 'NATIONALUM.NS', 'NETWORK18.NS', 'NMDC.NS', 'PNB.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'PRSMJOHNSN.NS', 'RALLIS.NS', 'RECLTD.NS', 'RELIANCE.NS', 'RTNINDIA.NS', 'SBIN.NS', 'SHARDACROP.NS', 'SKFINDIA.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'STLTECH.NS', 'TATAELXSI.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TRENT.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'UCOBANK.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VOLTAS.NS', 'ZFCVINDIA.NS', 'ZYDUSLIFE.NS'],
'2018-10-01': ['ABB.NS', 'AUROPHARMA.NS', 'BIOCON.NS', 'CARBORUNIV.NS', 'DCMSHRIRAM.NS', 'HCLTECH.NS', 'INDHOTEL.NS', 'INFY.NS', 'LTIM.NS', 'OIL.NS', 'ONGC.NS', 'RELIANCE.NS', 'SFL.NS'],
'2018-11-01': ['AIAENG.NS', 'APOLLOHOSP.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'BATAINDIA.NS', 'BOSCHLTD.NS', 'CONCOR.NS', 'DRREDDY.NS', 'EIDPARRY.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HEG.NS', 'HINDUNILVR.NS', 'IGL.NS', 'KSB.NS', 'LINDEINDIA.NS', 'LT.NS', 'LTTS.NS', 'MCDOWELL-N.NS', 'MGL.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'PGHL.NS', 'PIIND.NS', 'RADICO.NS', 'RAYMOND.NS', 'SBIN.NS', 'SHRIRAMFIN.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SUNDARMFIN.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'THERMAX.NS', 'TITAN.NS', 'TTKPRESTIG.NS', 'UPL.NS', 'VMART.NS'],
'2018-12-01': ['AARTIIND.NS', 'ADANIENT.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ASTRAL.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BEML.NS', 'BERGEPAINT.NS', 'BLUEDART.NS', 'BRIGADE.NS', 'CCL.NS', 'CEATLTD.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'CONCOR.NS', 'CROMPTON.NS', 'CUB.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'FINPIPE.NS', 'GLENMARK.NS', 'GODREJPROP.NS', 'GSPL.NS', 'HEROMOTOCO.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ITI.NS', 'JUBLFOOD.NS', 'KAJARIACER.NS', 'KEC.NS', 'L&TFH.NS', 'LICHSGFIN.NS', 'LUPIN.NS', 'M&MFIN.NS', 'MANAPPURAM.NS', 'MFSL.NS', 'MINDACORP.NS', 'MUTHOOTFIN.NS', 'NAVINFLUOR.NS', 'NCC.NS', 'NHPC.NS', 'OBEROIRLTY.NS', 'PHOENIXLTD.NS', 'PIIND.NS', 'RADICO.NS', 'RATNAMANI.NS', 'RELIANCE.NS', 'RHIM.NS', 'TATACOMM.NS', 'THERMAX.NS', 'TRITURBINE.NS', 'USHAMART.NS'],
'2019-01-01': ['AJANTPHARM.NS', 'ALKEM.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'BAJFINANCE.NS', 'BERGEPAINT.NS', 'BRITANNIA.NS', 'CANFINHOME.NS', 'CEATLTD.NS', 'CENTURYTEX.NS', 'CHOLAHLDNG.NS', 'CRISIL.NS', 'DELTACORP.NS', 'DMART.NS', 'ERIS.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'GLENMARK.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'HINDZINC.NS', 'IBULHSGFIN.NS', 'IPCALAB.NS', 'KOTAKBANK.NS', 'LICHSGFIN.NS', 'LT.NS', 'LTIM.NS', 'LTTS.NS', 'M&M.NS', 'MARICO.NS', 'MOTILALOFS.NS', 'NESTLEIND.NS', 'OFSS.NS', 'OLECTRA.NS', 'PEL.NS', 'PETRONET.NS', 'PGHH.NS', 'PGHL.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'SANOFI.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SYMPHONY.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TIMKEN.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TTKPRESTIG.NS', 'VINATIORGA.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2019-02-01': ['ABBOTINDIA.NS', 'ABFRL.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'AUROPHARMA.NS', 'BAYERCROP.NS', 'BRITANNIA.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'DABUR.NS', 'DIXON.NS', 'DRREDDY.NS', 'GODREJPROP.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'IGL.NS', 'INDIGO.NS', 'INDUSTOWER.NS', 'LALPATHLAB.NS', 'LUPIN.NS', 'MGL.NS', 'MPHASIS.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'OFSS.NS', 'PERSISTENT.NS', 'PGHL.NS', 'RELIANCE.NS', 'SANOFI.NS', 'SHARDACROP.NS', 'TCS.NS', 'TECHM.NS', 'TIINDIA.NS', 'UBL.NS', 'UPL.NS', 'VBL.NS', 'VMART.NS', 'WHIRLPOOL.NS'],
'2019-03-01': ['3MINDIA.NS', 'ABCAPITAL.NS', 'ADANIPOWER.NS', 'AIAENG.NS', 'APLAPOLLO.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BALKRISIND.NS', 'BHARATFORG.NS', 'BLUESTARCO.NS', 'CCL.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'ENDURANCE.NS', 'GAIL.NS', 'GMRINFRA.NS', 'GRINDWELL.NS', 'HCLTECH.NS', 'HINDZINC.NS', 'ICICIGI.NS', 'IGL.NS', 'IPCALAB.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JUSTDIAL.NS', 'KAJARIACER.NS', 'KRBL.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'MPHASIS.NS', 'NAM-INDIA.NS', 'NAUKRI.NS', 'NH.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'PEL.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PRAJIND.NS', 'SFL.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SONATSOFTW.NS', 'SUNTV.NS', 'TIINDIA.NS', 'TITAN.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'VGUARD.NS', 'ZEEL.NS'],
'2019-04-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'AMBER.NS', 'APARINDS.NS', 'AVANTIFEED.NS', 'BALAMINES.NS', 'BALRAMCHIN.NS', 'BEL.NS', 'BHEL.NS', 'BPCL.NS', 'BSE.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CESC.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'COALINDIA.NS', 'COFORGE.NS', 'DELTACORP.NS', 'DLF.NS', 'EIHOTEL.NS', 'ESCORTS.NS', 'FEDERALBNK.NS', 'GAIL.NS', 'GLENMARK.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'HUDCO.NS', 'ICICIPRULI.NS', 'IIFL.NS', 'INDIACEM.NS', 'INTELLECT.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JUSTDIAL.NS', 'KAJARIACER.NS', 'LALPATHLAB.NS', 'LT.NS', 'MASTEK.NS', 'MRPL.NS', 'NAUKRI.NS', 'NBCC.NS', 'NLCINDIA.NS', 'NMDC.NS', 'OIL.NS', 'OLECTRA.NS', 'ONGC.NS', 'PFC.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'REDINGTON.NS', 'RHIM.NS', 'SBILIFE.NS', 'SHARDACROP.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SPARC.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SYNGENE.NS', 'TANLA.NS', 'TRIVENI.NS', 'VGUARD.NS', 'VIPIND.NS', 'VTL.NS', 'WELCORP.NS', 'ZENSARTECH.NS'],
'2019-05-01': ['AARTIIND.NS', 'ACC.NS', 'AIAENG.NS', 'APLLTD.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BHARTIARTL.NS', 'BLUESTARCO.NS', 'BPCL.NS', 'BSE.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CROMPTON.NS', 'CUB.NS', 'DIVISLAB.NS', 'ELGIEQUIP.NS', 'FDC.NS', 'FSL.NS', 'GAIL.NS', 'GRANULES.NS', 'HAVELLS.NS', 'IGL.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INFY.NS', 'INGERRAND.NS', 'IOC.NS', 'IPCALAB.NS', 'ITC.NS', 'JINDALSTEL.NS', 'KPRMILL.NS', 'LTIM.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NAUKRI.NS', 'NTPC.NS', 'OIL.NS', 'PATANJALI.NS', 'PETRONET.NS', 'PGHL.NS', 'PIDILITIND.NS', 'PRESTIGE.NS', 'RAJESHEXPO.NS', 'RECLTD.NS', 'RHIM.NS', 'SBIN.NS', 'SOLARINDS.NS', 'SUNTECK.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'SYMPHONY.NS', 'TANLA.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATASTEEL.NS', 'TEJASNET.NS', 'UNOMINDA.NS', 'VTL.NS', 'ZENSARTECH.NS'],
'2019-06-01': ['ABBOTINDIA.NS', 'ACC.NS', 'ADANIPOWER.NS', 'AIAENG.NS', 'ALLCARGO.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APOLLOHOSP.NS', 'ASTERDM.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'BSE.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CESC.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'DCMSHRIRAM.NS', 'DLF.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'FINPIPE.NS', 'FSL.NS', 'GAIL.NS', 'GMMPFAUDLR.NS', 'GODREJCP.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GSPL.NS', 'GUJALKALI.NS', 'IBULHSGFIN.NS', 'INFY.NS', 'ISEC.NS', 'JINDALSAW.NS', 'JSWENERGY.NS', 'KPRMILL.NS', 'KRBL.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'LTTS.NS', 'M&MFIN.NS', 'MFSL.NS', 'MPHASIS.NS', 'NAUKRI.NS', 'NBCC.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'ONGC.NS', 'PETRONET.NS', 'PHOENIXLTD.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'REDINGTON.NS', 'SHRIRAMFIN.NS', 'TATACHEM.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TIINDIA.NS', 'WHIRLPOOL.NS', 'ZYDUSWELL.NS'],
'2019-07-01': ['AARTIIND.NS', 'ADANIPOWER.NS', 'AIAENG.NS', 'AMBER.NS', 'APOLLOHOSP.NS', 'ASTRAL.NS', 'ATUL.NS', 'AUBANK.NS', 'AXISBANK.NS', 'BAJAJHLDNG.NS', 'BEL.NS', 'BRIGADE.NS', 'CANFINHOME.NS', 'CERA.NS', 'CRISIL.NS', 'DCMSHRIRAM.NS', 'DLF.NS', 'DMART.NS', 'ENGINERSIN.NS', 'EPL.NS', 'FDC.NS', 'FINPIPE.NS', 'GILLETTE.NS', 'GMMPFAUDLR.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GSPL.NS', 'HAL.NS', 'HAVELLS.NS', 'HDFCBANK.NS', 'HINDALCO.NS', 'HINDUNILVR.NS', 'ICICIPRULI.NS', 'INGERRAND.NS', 'JKCEMENT.NS', 'JUSTDIAL.NS', 'KEC.NS', 'KEI.NS', 'KNRCON.NS', 'KSB.NS', 'LICHSGFIN.NS', 'LTTS.NS', 'M&M.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MPHASIS.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NAUKRI.NS', 'PETRONET.NS', 'PIIND.NS', 'RELAXO.NS', 'SANOFI.NS', 'SFL.NS', 'SHOPERSTOP.NS', 'SOBHA.NS', 'SYNGENE.NS', 'TATAINVEST.NS', 'TATAPOWER.NS', 'TCS.NS', 'THERMAX.NS', 'VBL.NS', 'ZENSARTECH.NS'],
'2019-08-01': ['BERGEPAINT.NS', 'CANFINHOME.NS', 'COLPAL.NS', 'DABUR.NS', 'DMART.NS', 'FINPIPE.NS', 'GLAXO.NS', 'GSPL.NS', 'HDFCLIFE.NS', 'ICICIPRULI.NS', 'PGHL.NS', 'POWERGRID.NS', 'RALLIS.NS', 'REDINGTON.NS', 'SPARC.NS', 'TCS.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'UBL.NS'],
'2019-09-01': ['AMBER.NS', 'AUROPHARMA.NS', 'AVANTIFEED.NS', 'BAJAJ-AUTO.NS', 'BBTC.NS', 'BPCL.NS', 'BRITANNIA.NS', 'BSE.NS', 'CEATLTD.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'CUB.NS', 'DIVISLAB.NS', 'ESCORTS.NS', 'FINEORG.NS', 'GILLETTE.NS', 'GLAXO.NS', 'IPCALAB.NS', 'JKCEMENT.NS', 'KANSAINER.NS', 'KEI.NS', 'LTIM.NS', 'LTTS.NS', 'MARUTI.NS', 'MGL.NS', 'MINDACORP.NS', 'MPHASIS.NS', 'NATCOPHARM.NS', 'NH.NS', 'OBEROIRLTY.NS', 'PIIND.NS', 'RAJESHEXPO.NS', 'REDINGTON.NS', 'RHIM.NS', 'SANOFI.NS', 'SFL.NS', 'SIEMENS.NS', 'SOBHA.NS', 'SPARC.NS', 'SUNTECK.NS', 'SUPREMEIND.NS', 'SYMPHONY.NS', 'TATACHEM.NS', 'TCS.NS', 'TECHM.NS', 'UBL.NS', 'VAIBHAVGBL.NS', 'VARROC.NS', 'VBL.NS', 'VINATIORGA.NS', 'VMART.NS', 'WHIRLPOOL.NS', 'ZEEL.NS'],
'2019-10-01': ['ABB.NS', 'ABFRL.NS', 'ALKEM.NS', 'ALLCARGO.NS', 'ASTRAL.NS', 'AVANTIFEED.NS', 'BAJAJ-AUTO.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BAYERCROP.NS', 'BBTC.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BRITANNIA.NS', 'BSE.NS', 'CASTROLIND.NS', 'CEATLTD.NS', 'CERA.NS', 'CHOLAHLDNG.NS', 'CROMPTON.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'EPL.NS', 'ERIS.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'FDC.NS', 'FORTIS.NS', 'GAEL.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GPPL.NS', 'GRANULES.NS', 'GRINDWELL.NS', 'HAVELLS.NS', 'IGL.NS', 'ITC.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JUBLFOOD.NS', 'KAJARIACER.NS', 'LT.NS', 'LUXIND.NS', 'MARICO.NS', 'MARUTI.NS', 'MCX.NS', 'MHRIL.NS', 'MOTILALOFS.NS', 'MUTHOOTFIN.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'ORIENTELEC.NS', 'PGHL.NS', 'PIDILITIND.NS', 'REDINGTON.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SHOPERSTOP.NS', 'SONATSOFTW.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'TATACONSUM.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TRENT.NS', 'TTKPRESTIG.NS', 'TV18BRDCST.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'VAIBHAVGBL.NS', 'VTL.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2019-11-01': ['ADANIPOWER.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'APLAPOLLO.NS', 'ASHOKLEY.NS', 'BALRAMCHIN.NS', 'BANKINDIA.NS', 'BEL.NS', 'BHEL.NS', 'BORORENEW.NS', 'BRIGADE.NS', 'CARBORUNIV.NS', 'DLF.NS', 'EIDPARRY.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FINPIPE.NS', 'GAIL.NS', 'GESHIP.NS', 'GNFC.NS', 'GPPL.NS', 'GSFC.NS', 'GUJALKALI.NS', 'HINDCOPPER.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'IOB.NS', 'IOC.NS', 'IPCALAB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JMFINANCIL.NS', 'JSWENERGY.NS', 'L&TFH.NS', 'LAURUSLABS.NS', 'LEMONTREE.NS', 'MAHABANK.NS', 'MMTC.NS', 'MRPL.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NETWORK18.NS', 'NLCINDIA.NS', 'ONGC.NS', 'PCBL.NS', 'PFC.NS', 'PNB.NS', 'RAIN.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RHIM.NS', 'RITES.NS', 'SAIL.NS', 'TATACHEM.NS', 'TATASTEEL.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'USHAMART.NS', 'WELSPUNLIV.NS', 'YESBANK.NS', 'ZYDUSLIFE.NS'],
'2019-12-01': ['ABFRL.NS', 'AEGISCHEM.NS', 'ASAHIINDIA.NS', 'AVANTIFEED.NS', 'BALAMINES.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BAYERCROP.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BIRLACORPN.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CHOLAHLDNG.NS', 'COCHINSHIP.NS', 'DIVISLAB.NS', 'DRREDDY.NS', 'ECLERX.NS', 'ENDURANCE.NS', 'ERIS.NS', 'EXIDEIND.NS', 'FDC.NS', 'GMMPFAUDLR.NS', 'GODREJIND.NS', 'GPIL.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'HDFCBANK.NS', 'HEG.NS', 'HUDCO.NS', 'ICICIGI.NS', 'IDEA.NS', 'IGL.NS', 'INDUSTOWER.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'JYOTHYLAB.NS', 'KEC.NS', 'KPRMILL.NS', 'LEMONTREE.NS', 'M&MFIN.NS', 'MCX.NS', 'MOTHERSON.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NETWORK18.NS', 'NH.NS', 'RAIN.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RHIM.NS', 'RTNINDIA.NS', 'SAIL.NS', 'SAREGAMA.NS', 'SFL.NS', 'SPARC.NS', 'SUNPHARMA.NS', 'TATAELXSI.NS', 'TATASTEEL.NS', 'TEJASNET.NS', 'TIMKEN.NS', 'TRIDENT.NS', 'TV18BRDCST.NS', 'TVSMOTOR.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VBL.NS', 'ZYDUSLIFE.NS'],
'2020-01-01': ['AARTIIND.NS', 'ABBOTINDIA.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ADANIENT.NS', 'AEGISCHEM.NS', 'ALOKINDS.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'AUBANK.NS', 'AXISBANK.NS', 'BAJFINANCE.NS', 'BATAINDIA.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'CEATLTD.NS', 'CERA.NS', 'CGCL.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'CUB.NS', 'DIVISLAB.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'ENDURANCE.NS', 'ERIS.NS', 'FINCABLES.NS', 'FINEORG.NS', 'GODFRYPHLP.NS', 'GPPL.NS', 'GRINDWELL.NS', 'GSPL.NS', 'GUJALKALI.NS', 'HCLTECH.NS', 'ICICIGI.NS', 'IDFCFIRSTB.NS', 'IGL.NS', 'INDUSINDBK.NS', 'INGERRAND.NS', 'IOB.NS', 'IPCALAB.NS', 'JAMNAAUTO.NS', 'JKCEMENT.NS', 'JSWSTEEL.NS', 'JUBLPHARMA.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'LEMONTREE.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'MAHABANK.NS', 'MARUTI.NS', 'MCX.NS', 'MGL.NS', 'MINDACORP.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NESTLEIND.NS', 'NH.NS', 'NLCINDIA.NS', 'NTPC.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'PFC.NS', 'PFIZER.NS', 'PGHL.NS', 'PIDILITIND.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RITES.NS', 'SANOFI.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SHOPERSTOP.NS', 'SHRIRAMFIN.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SUNTECK.NS', 'SUPREMEIND.NS', 'SYNGENE.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAMTRDVR.NS', 'TEJASNET.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TRENT.NS', 'TVSMOTOR.NS', 'UPL.NS', 'WELCORP.NS', 'WHIRLPOOL.NS'],
'2020-02-01': ['AARTIDRUGS.NS', 'AAVAS.NS', 'ADANIGREEN.NS', 'AEGISCHEM.NS', 'AJANTPHARM.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'ASTERDM.NS', 'AVANTIFEED.NS', 'BAJAJ-AUTO.NS', 'BATAINDIA.NS', 'BIOCON.NS', 'BSE.NS', 'CDSL.NS', 'CENTURYPLY.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'DABUR.NS', 'DEEPAKFERT.NS', 'EPL.NS', 'EXIDEIND.NS', 'FACT.NS', 'FSL.NS', 'GAEL.NS', 'GLAXO.NS', 'GRANULES.NS', 'GSFC.NS', 'HEROMOTOCO.NS', 'HONAUT.NS', 'ICICIPRULI.NS', 'IIFL.NS', 'INFIBEAM.NS', 'INFY.NS', 'JINDALSTEL.NS', 'JMFINANCIL.NS', 'KOTAKBANK.NS', 'LT.NS', 'LUXIND.NS', 'M&M.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MCDOWELL-N.NS', 'MHRIL.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NESTLEIND.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'PNCINFRA.NS', 'PRESTIGE.NS', 'RCF.NS', 'RITES.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'SUPRAJIT.NS', 'TECHM.NS', 'TIINDIA.NS', 'TORNTPOWER.NS', 'TV18BRDCST.NS', 'UNOMINDA.NS', 'VARROC.NS', 'VIPIND.NS', 'WELCORP.NS'],
'2020-03-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'ALKYLAMINE.NS', 'APOLLOHOSP.NS', 'BAYERCROP.NS', 'BSOFT.NS', 'CCL.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'DEEPAKNTR.NS', 'DMART.NS', 'HONAUT.NS', 'IPCALAB.NS', 'ISEC.NS', 'JBCHEPHARM.NS', 'MCDOWELL-N.NS', 'POLYMED.NS', 'RADICO.NS', 'SUZLON.NS', 'TORNTPHARM.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VMART.NS', 'VTL.NS', 'ZFCVINDIA.NS'],
'2020-04-01': ['ABBOTINDIA.NS', 'AJANTPHARM.NS', 'DMART.NS', 'DRREDDY.NS', 'HINDUNILVR.NS', 'INDIACEM.NS', 'IPCALAB.NS', 'NESTLEIND.NS'],
'2020-05-01': ['AIAENG.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'ATUL.NS', 'AVANTIFEED.NS', 'BAJAJ-AUTO.NS', 'BALAMINES.NS', 'BAYERCROP.NS', 'BCG.NS', 'BHARTIARTL.NS', 'CASTROLIND.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'DMART.NS', 'EPL.NS', 'FACT.NS', 'FDC.NS', 'GESHIP.NS', 'GLAXO.NS', 'HCLTECH.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'IGL.NS', 'INDIACEM.NS', 'INFY.NS', 'IPCALAB.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'LALPATHLAB.NS', 'MFSL.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'OFSS.NS', 'PETRONET.NS', 'PGHL.NS', 'PIDILITIND.NS', 'RALLIS.NS', 'SFL.NS', 'SRF.NS', 'SUNPHARMA.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TCS.NS', 'TORNTPHARM.NS', 'UPL.NS', 'VAIBHAVGBL.NS', 'ZYDUSLIFE.NS'],
'2020-06-01': ['ACC.NS', 'ADANIPORTS.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'APLAPOLLO.NS', 'ATGL.NS', 'BAJAJ-AUTO.NS', 'BALAMINES.NS', 'BBTC.NS', 'BHARATFORG.NS', 'BHEL.NS', 'BIOCON.NS', 'CDSL.NS', 'CEATLTD.NS', 'CERA.NS', 'COFORGE.NS', 'COROMANDEL.NS', 'DCMSHRIRAM.NS', 'DELTACORP.NS', 'DIVISLAB.NS', 'ENDURANCE.NS', 'ERIS.NS', 'EXIDEIND.NS', 'FACT.NS', 'FDC.NS', 'GMRINFRA.NS', 'GRANULES.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'HCLTECH.NS', 'HDFCLIFE.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'ICICIGI.NS', 'IEX.NS', 'IGL.NS', 'INFIBEAM.NS', 'ISEC.NS', 'JKCEMENT.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'LAURUSLABS.NS', 'LT.NS', 'LUPIN.NS', 'M&M.NS', 'MARUTI.NS', 'MCDOWELL-N.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGL.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'MPHASIS.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'NTPC.NS', 'ONGC.NS', 'PAGEIND.NS', 'PIIND.NS', 'RADICO.NS', 'RAMCOCEM.NS', 'RELIANCE.NS', 'SANOFI.NS', 'SHARDACROP.NS', 'SHREECEM.NS', 'SUNPHARMA.NS', 'SUZLON.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAPOWER.NS', 'TORNTPOWER.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'WELSPUNLIV.NS', 'ZEEL.NS', 'ZYDUSLIFE.NS'],
'2020-07-01': ['3MINDIA.NS', 'AAVAS.NS', 'ACC.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ALKYLAMINE.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'APLLTD.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BANDHANBNK.NS', 'BBTC.NS', 'BEML.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BOSCHLTD.NS', 'CDSL.NS', 'CEATLTD.NS', 'CHOLAFIN.NS', 'CIPLA.NS', 'COLPAL.NS', 'CONCOR.NS', 'CREDITACC.NS', 'CROMPTON.NS', 'DABUR.NS', 'EMAMILTD.NS', 'GLAXO.NS', 'GMMPFAUDLR.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GRANULES.NS', 'GRASIM.NS', 'GSPL.NS', 'HAVELLS.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'ICICIPRULI.NS', 'INFY.NS', 'INGERRAND.NS', 'IPCALAB.NS', 'JBCHEPHARM.NS', 'JKLAKSHMI.NS', 'JUBLFOOD.NS', 'JUSTDIAL.NS', 'KAJARIACER.NS', 'KOTAKBANK.NS', 'LAXMIMACH.NS', 'LT.NS', 'LUPIN.NS', 'MARUTI.NS', 'MCX.NS', 'MGL.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'PAGEIND.NS', 'PETRONET.NS', 'PGHH.NS', 'POLYCAB.NS', 'PRESTIGE.NS', 'RADICO.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'RBLBANK.NS', 'SANOFI.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SFL.NS', 'SHREECEM.NS', 'SPARC.NS', 'SUPREMEIND.NS', 'TCS.NS', 'THERMAX.NS', 'TIMKEN.NS', 'TRENT.NS', 'TTKPRESTIG.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'VARROC.NS', 'VOLTAS.NS', 'WHIRLPOOL.NS', 'WIPRO.NS'],
'2020-08-01': ['AARTIIND.NS', 'AAVAS.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ATGL.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BALAMINES.NS', 'BANDHANBNK.NS', 'BDL.NS', 'BEL.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BIRLACORPN.NS', 'BOSCHLTD.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'COCHINSHIP.NS', 'COLPAL.NS', 'CONCOR.NS', 'DCMSHRIRAM.NS', 'EMAMILTD.NS', 'ENDURANCE.NS', 'ESCORTS.NS', 'FINEORG.NS', 'GESHIP.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODREJCP.NS', 'GPIL.NS', 'GRASIM.NS', 'GSFC.NS', 'HAL.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS', 'HUDCO.NS', 'ICICIPRULI.NS', 'ITI.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KEC.NS', 'KRBL.NS', 'LUPIN.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MOTILALOFS.NS', 'NAVINFLUOR.NS', 'NLCINDIA.NS', 'OFSS.NS', 'PAGEIND.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'RALLIS.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'SAREGAMA.NS', 'SIEMENS.NS', 'SOLARINDS.NS', 'SUPRAJIT.NS', 'TATAPOWER.NS', 'TEAMLEASE.NS', 'TEJASNET.NS', 'TIMKEN.NS', 'TITAN.NS', 'VBL.NS', 'VEDL.NS'],
'2020-09-01': ['ABB.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'AMBER.NS', 'APOLLOHOSP.NS', 'ASAHIINDIA.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'ATGL.NS', 'BAJFINANCE.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'CENTURYTEX.NS', 'CHALET.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'CUB.NS', 'DALBHARAT.NS', 'DIXON.NS', 'DLF.NS', 'EPL.NS', 'FINEORG.NS', 'GALAXYSURF.NS', 'GMMPFAUDLR.NS', 'GODREJPROP.NS', 'HCLTECH.NS', 'HONAUT.NS', 'IIFL.NS', 'INFY.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JMFINANCIL.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KOTAKBANK.NS', 'LAXMIMACH.NS', 'LINDEINDIA.NS', 'LTTS.NS', 'LUXIND.NS', 'MARICO.NS', 'MFSL.NS', 'MOTILALOFS.NS', 'NAUKRI.NS', 'NH.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'POLYCAB.NS', 'QUESS.NS', 'RADICO.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RELAXO.NS', 'RELIANCE.NS', 'SBIN.NS', 'SHOPERSTOP.NS', 'SPARC.NS', 'SUNDRMFAST.NS', 'TATAINVEST.NS', 'TCS.NS', 'TITAN.NS', 'TTKPRESTIG.NS', 'VIPIND.NS', 'VMART.NS', 'VOLTAS.NS', 'WIPRO.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2020-10-01': ['AAVAS.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'AEGISCHEM.NS', 'AFFLE.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'ASIANPAINT.NS', 'ATGL.NS', 'ATUL.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'BSE.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CHAMBLFERT.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'COLPAL.NS', 'CRISIL.NS', 'CUB.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DIXON.NS', 'DMART.NS', 'EICHERMOT.NS', 'ERIS.NS', 'FDC.NS', 'FINEORG.NS', 'FORTIS.NS', 'GALAXYSURF.NS', 'GRINDWELL.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HDFCBANK.NS', 'HONAUT.NS', 'ICICIGI.NS', 'INDIGO.NS', 'IPCALAB.NS', 'JKCEMENT.NS', 'KANSAINER.NS', 'KNRCON.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'LTTS.NS', 'LUPIN.NS', 'MCX.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MRF.NS', 'OFSS.NS', 'PFIZER.NS', 'PGHL.NS', 'PIIND.NS', 'POLYMED.NS', 'QUESS.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'RELAXO.NS', 'RELIANCE.NS', 'RITES.NS', 'SANOFI.NS', 'SUNTECK.NS', 'SUPREMEIND.NS', 'TATAINVEST.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TORNTPHARM.NS', 'TRENT.NS', 'TTKPRESTIG.NS', 'ULTRACEMCO.NS', 'VARROC.NS', 'VMART.NS', 'VOLTAS.NS', 'VTL.NS', 'WESTLIFE.NS', 'WHIRLPOOL.NS', 'ZYDUSLIFE.NS'],
'2020-11-01': ['ADANIPORTS.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'BALAMINES.NS', 'BALRAMCHIN.NS', 'BORORENEW.NS', 'BRIGADE.NS', 'CASTROLIND.NS', 'CIEINDIA.NS', 'CUB.NS', 'DELTACORP.NS', 'EMAMILTD.NS', 'FINPIPE.NS', 'GAEL.NS', 'GPIL.NS', 'GPPL.NS', 'GSFC.NS', 'HFCL.NS', 'HINDPETRO.NS', 'IDFC.NS', 'INFIBEAM.NS', 'IOC.NS', 'JBMA.NS', 'JSWENERGY.NS', 'KANSAINER.NS', 'L&TFH.NS', 'MRPL.NS', 'NCC.NS', 'NTPC.NS', 'PCBL.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'RAIN.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'SHARDACROP.NS', 'SHRIRAMFIN.NS', 'SUZLON.NS', 'TATACOMM.NS', 'TATASTEEL.NS', 'WELSPUNLIV.NS'],
'2020-12-01': ['360ONE.NS', '3MINDIA.NS', 'AARTIIND.NS', 'AAVAS.NS', 'ABB.NS', 'ABFRL.NS', 'ACC.NS', 'AIAENG.NS', 'ALKEM.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'ASTERDM.NS', 'AUROPHARMA.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BDL.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'BSE.NS', 'CANFINHOME.NS', 'CCL.NS', 'CEATLTD.NS', 'CENTURYTEX.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'CUB.NS', 'DIVISLAB.NS', 'DLF.NS', 'EICHERMOT.NS', 'ENDURANCE.NS', 'ESCORTS.NS', 'GALAXYSURF.NS', 'GESHIP.NS', 'GLAXO.NS', 'GRANULES.NS', 'HAL.NS', 'HAVELLS.NS', 'HDFCAMC.NS', 'HDFCLIFE.NS', 'HONAUT.NS', 'ICICIBANK.NS', 'INGERRAND.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'KEC.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'MASTEK.NS', 'NAM-INDIA.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'NH.NS', 'OBEROIRLTY.NS', 'PAGEIND.NS', 'PETRONET.NS', 'POLYCAB.NS', 'RALLIS.NS', 'RELAXO.NS', 'SCHAEFFLER.NS', 'SHREECEM.NS', 'SKFINDIA.NS', 'SPARC.NS', 'SRF.NS', 'SUPREMEIND.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'TIMKEN.NS', 'TITAN.NS', 'ULTRACEMCO.NS', 'ZYDUSLIFE.NS'],
'2021-01-01': ['AARTIIND.NS', 'AAVAS.NS', 'ABFRL.NS', 'ADANIGREEN.NS', 'AEGISCHEM.NS', 'AFFLE.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'AMBER.NS', 'APOLLOHOSP.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'AXISBANK.NS', 'BAJAJHLDNG.NS', 'BALKRISIND.NS', 'BANDHANBNK.NS', 'BATAINDIA.NS', 'BDL.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'CANFINHOME.NS', 'CDSL.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CHALET.NS', 'CHOLAHLDNG.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'COROMANDEL.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DALBHARAT.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'FORTIS.NS', 'GALAXYSURF.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'HAL.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'IGL.NS', 'IIFL.NS', 'INDIAMART.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INGERRAND.NS', 'ITC.NS', 'JINDALSTEL.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'LUPIN.NS', 'M&M.NS', 'M&MFIN.NS', 'MARICO.NS', 'MARUTI.NS', 'MASTEK.NS', 'MCX.NS', 'MFSL.NS', 'MGL.NS', 'MRF.NS', 'NATCOPHARM.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'OFSS.NS', 'PGHH.NS', 'PGHL.NS', 'POLYCAB.NS', 'RAJESHEXPO.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RITES.NS', 'SANOFI.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SOLARINDS.NS', 'SPARC.NS', 'SUNDARMFIN.NS', 'SWSOLAR.NS', 'TANLA.NS', 'TATAINVEST.NS', 'TCS.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TORNTPHARM.NS', 'VARROC.NS', 'VBL.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'VOLTAS.NS', 'WESTLIFE.NS', 'ZENSARTECH.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2021-02-01': ['AAVAS.NS', 'ADANIPORTS.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'AMBER.NS', 'APLAPOLLO.NS', 'APOLLOHOSP.NS', 'AXISBANK.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CIPLA.NS', 'COLPAL.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'DALBHARAT.NS', 'DEEPAKNTR.NS', 'DIXON.NS', 'DLF.NS', 'EICHERMOT.NS', 'ERIS.NS', 'FORTIS.NS', 'GUJGASLTD.NS', 'HAL.NS', 'HEROMOTOCO.NS', 'HINDZINC.NS', 'HONAUT.NS', 'ICICIBANK.NS', 'INGERRAND.NS', 'INTELLECT.NS', 'IRCTC.NS', 'JKCEMENT.NS', 'LEMONTREE.NS', 'LICHSGFIN.NS', 'LTIM.NS', 'LTTS.NS', 'LUXIND.NS', 'MARICO.NS', 'MRF.NS', 'NAM-INDIA.NS', 'NH.NS', 'PERSISTENT.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'RADICO.NS', 'RELAXO.NS', 'SAFARI.NS', 'SBIN.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SYMPHONY.NS', 'TATAINVEST.NS', 'TCS.NS', 'ULTRACEMCO.NS', 'VAIBHAVGBL.NS', 'VMART.NS', 'VOLTAS.NS', 'VTL.NS', 'WESTLIFE.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'ZENSARTECH.NS'],
'2021-03-01': ['AARTIIND.NS', 'ADANIPOWER.NS', 'ALKYLAMINE.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BDL.NS', 'BLS.NS', 'BORORENEW.NS', 'CANBK.NS', 'CENTRALBK.NS', 'CHAMBLFERT.NS', 'CIEINDIA.NS', 'COCHINSHIP.NS', 'DCMSHRIRAM.NS', 'DLF.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'FSL.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GMMPFAUDLR.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'IOC.NS', 'IRCON.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JINDALSAW.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'JUBLFOOD.NS', 'JUSTDIAL.NS', 'KEI.NS', 'KNRCON.NS', 'KPITTECH.NS', 'M&MFIN.NS', 'MANAPPURAM.NS', 'MGL.NS', 'MRPL.NS', 'MUTHOOTFIN.NS', 'NHPC.NS', 'NIACL.NS', 'ORIENTELEC.NS', 'PCBL.NS', 'PETRONET.NS', 'PHOENIXLTD.NS', 'PNB.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'RELIANCE.NS', 'RVNL.NS', 'SFL.NS', 'SHARDACROP.NS', 'SIEMENS.NS', 'SJVN.NS', 'SWANENERGY.NS', 'TATACOMM.NS', 'TATAELXSI.NS', 'TATASTEEL.NS', 'TRITURBINE.NS', 'TVSMOTOR.NS', 'UPL.NS', 'VINATIORGA.NS', 'VOLTAS.NS'],
'2021-04-01': ['AARTIIND.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'AFFLE.NS', 'AMBER.NS', 'APARINDS.NS', 'APLLTD.NS', 'ASAHIINDIA.NS', 'ASIANPAINT.NS', 'AUBANK.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BAYERCROP.NS', 'BEML.NS', 'BERGEPAINT.NS', 'BLUESTARCO.NS', 'BRITANNIA.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'CHOLAHLDNG.NS', 'DABUR.NS', 'DIVISLAB.NS', 'ELGIEQUIP.NS', 'ENDURANCE.NS', 'EPL.NS', 'FACT.NS', 'GMMPFAUDLR.NS', 'GNFC.NS', 'GODREJCP.NS', 'HINDALCO.NS', 'HONAUT.NS', 'IDBI.NS', 'IEX.NS', 'IIFL.NS', 'INFY.NS', 'ITC.NS', 'JUSTDIAL.NS', 'KANSAINER.NS', 'KNRCON.NS', 'KPRMILL.NS', 'LAXMIMACH.NS', 'MARICO.NS', 'NAVINFLUOR.NS', 'NBCC.NS', 'NESTLEIND.NS', 'PAGEIND.NS', 'PIDILITIND.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'PRESTIGE.NS', 'PRINCEPIPE.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'REDINGTON.NS', 'RELAXO.NS', 'SHRIRAMFIN.NS', 'SKFINDIA.NS', 'SUNDARMFIN.NS', 'SUPREMEIND.NS', 'SYMPHONY.NS', 'TATACONSUM.NS', 'TATAPOWER.NS', 'TCS.NS', 'THERMAX.NS', 'TITAN.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'VAIBHAVGBL.NS', 'VMART.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'ZYDUSWELL.NS'],
'2021-05-01': ['ABBOTINDIA.NS', 'ACC.NS', 'AEGISCHEM.NS', 'AFFLE.NS', 'AJANTPHARM.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BAYERCROP.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'CANFINHOME.NS', 'CCL.NS', 'CENTURYTEX.NS', 'CHOLAFIN.NS', 'CONCOR.NS', 'CSBBANK.NS', 'EIDPARRY.NS', 'ELGIEQUIP.NS', 'FORTIS.NS', 'GESHIP.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GSFC.NS', 'GSPL.NS', 'GUJALKALI.NS', 'HINDALCO.NS', 'INGERRAND.NS', 'INTELLECT.NS', 'IPCALAB.NS', 'IRCTC.NS', 'JUBLPHARMA.NS', 'KSB.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'LTTS.NS', 'LUPIN.NS', 'LUXIND.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'OFSS.NS', 'PETRONET.NS', 'PGHH.NS', 'PIIND.NS', 'POLYCAB.NS', 'PRSMJOHNSN.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'RALLIS.NS', 'RATNAMANI.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SPARC.NS', 'STLTECH.NS', 'SUNDARMFIN.NS', 'SUPREMEIND.NS', 'SWSOLAR.NS', 'TATACONSUM.NS', 'TEJASNET.NS', 'UBL.NS', 'VAIBHAVGBL.NS', 'ZYDUSWELL.NS'],
'2021-06-01': ['AARTIIND.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'ACC.NS', 'ADANIGREEN.NS', 'AEGISCHEM.NS', 'ALKEM.NS', 'ALLCARGO.NS', 'AMBUJACEM.NS', 'AXISBANK.NS', 'BAJFINANCE.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BHARATFORG.NS', 'BLS.NS', 'BOSCHLTD.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CESC.NS', 'COALINDIA.NS', 'CSBBANK.NS', 'DALBHARAT.NS', 'DEEPAKFERT.NS', 'DLF.NS', 'DMART.NS', 'DRREDDY.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EXIDEIND.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FLUOROCHEM.NS', 'FORTIS.NS', 'GALAXYSURF.NS', 'GLAXO.NS', 'GRAPHITE.NS', 'GSFC.NS', 'HDFCAMC.NS', 'HINDCOPPER.NS', 'HUDCO.NS', 'ICICIPRULI.NS', 'IDFC.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INFY.NS', 'INTELLECT.NS', 'IRB.NS', 'IRCTC.NS', 'ITC.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JMFINANCIL.NS', 'JUBLFOOD.NS', 'JUBLPHARMA.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KSB.NS', 'LALPATHLAB.NS', 'LT.NS', 'MANAPPURAM.NS', 'MARUTI.NS', 'MFSL.NS', 'MGL.NS', 'MOTHERSON.NS', 'MRF.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NESTLEIND.NS', 'NHPC.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'OIL.NS', 'ORIENTELEC.NS', 'PEL.NS', 'PFC.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'QUESS.NS', 'RADICO.NS', 'RALLIS.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'SAIL.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SHARDACROP.NS', 'SPARC.NS', 'SRF.NS', 'SUMICHEM.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'TATAMTRDVR.NS', 'TATASTEEL.NS', 'TECHM.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'VARROC.NS', 'VEDL.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'WELCORP.NS', 'WESTLIFE.NS', 'ZEEL.NS'],
'2021-07-01': ['ABFRL.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'ALOKINDS.NS', 'ASAHIINDIA.NS', 'ASIANPAINT.NS', 'ATUL.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BLS.NS', 'BRITANNIA.NS', 'BSE.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CERA.NS', 'CHAMBLFERT.NS', 'CIPLA.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'DALBHARAT.NS', 'DEEPAKFERT.NS', 'DIXON.NS', 'DMART.NS', 'DRREDDY.NS', 'EMAMILTD.NS', 'ERIS.NS', 'FORTIS.NS', 'GICRE.NS', 'GLENMARK.NS', 'GODFRYPHLP.NS', 'GODREJIND.NS', 'GPIL.NS', 'GRASIM.NS', 'HINDUNILVR.NS', 'ICICIGI.NS', 'INDHOTEL.NS', 'INGERRAND.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'KEI.NS', 'KSB.NS', 'LTTS.NS', 'MAHLIFE.NS', 'MANAPPURAM.NS', 'MARUTI.NS', 'METROPOLIS.NS', 'MUTHOOTFIN.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NH.NS', 'OFSS.NS', 'PATANJALI.NS', 'PFC.NS', 'POWERINDIA.NS', 'PRAJIND.NS', 'QUESS.NS', 'RAIN.NS', 'RATNAMANI.NS', 'SBILIFE.NS', 'SFL.NS', 'SOLARINDS.NS', 'SUMICHEM.NS', 'SUNDARMFIN.NS', 'SWSOLAR.NS', 'TATAINVEST.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TCS.NS', 'TEAMLEASE.NS', 'TIMKEN.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VINATIORGA.NS', 'VIPIND.NS', 'WELSPUNLIV.NS', 'ZENSARTECH.NS', 'ZYDUSLIFE.NS'],
'2021-08-01': ['ABFRL.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'AUBANK.NS', 'AVANTIFEED.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BATAINDIA.NS', 'BEL.NS', 'BERGEPAINT.NS', 'BHARTIARTL.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CGCL.NS', 'COROMANDEL.NS', 'CYIENT.NS', 'DALBHARAT.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'EIDPARRY.NS', 'ELGIEQUIP.NS', 'FACT.NS', 'FINCABLES.NS', 'FORTIS.NS', 'GALAXYSURF.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GSFC.NS', 'GSPL.NS', 'HAL.NS', 'HCLTECH.NS', 'HFCL.NS', 'ICICIBANK.NS', 'ICICIPRULI.NS', 'IDFC.NS', 'IEX.NS', 'IGL.NS', 'ISEC.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JINDALSTEL.NS', 'JMFINANCIL.NS', 'JSWSTEEL.NS', 'JYOTHYLAB.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'PEL.NS', 'PFC.NS', 'PFIZER.NS', 'POWERINDIA.NS', 'SAFARI.NS', 'SBICARD.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'STLTECH.NS', 'SUMICHEM.NS', 'SUVENPHAR.NS', 'SYNGENE.NS', 'TANLA.NS', 'TATAELXSI.NS', 'TATAPOWER.NS', 'TIMKEN.NS', 'TORNTPHARM.NS', 'TRENT.NS', 'VINATIORGA.NS', 'VOLTAS.NS', 'ZFCVINDIA.NS'],
'2021-09-01': ['AARTIIND.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'APARINDS.NS', 'BALRAMCHIN.NS', 'BEL.NS', 'BLUEDART.NS', 'BPCL.NS', 'BRIGADE.NS', 'BSE.NS', 'BSOFT.NS', 'CANBK.NS', 'CENTURYTEX.NS', 'CESC.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIPLA.NS', 'COALINDIA.NS', 'CREDITACC.NS', 'CROMPTON.NS', 'CYIENT.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'EMAMILTD.NS', 'GESHIP.NS', 'GRINDWELL.NS', 'HINDPETRO.NS', 'IDBI.NS', 'INFIBEAM.NS', 'IOC.NS', 'ISEC.NS', 'ITC.NS', 'JAMNAAUTO.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JSL.NS', 'KEC.NS', 'KEI.NS', 'KSB.NS', 'M&M.NS', 'M&MFIN.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MASTEK.NS', 'MHRIL.NS', 'NATIONALUM.NS', 'NH.NS', 'NHPC.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'ONGC.NS', 'PEL.NS', 'PETRONET.NS', 'PFC.NS', 'PIDILITIND.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'PRESTIGE.NS', 'RATNAMANI.NS', 'RECLTD.NS', 'RELAXO.NS', 'RHIM.NS', 'RITES.NS', 'SFL.NS', 'SHREECEM.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SONATSOFTW.NS', 'SUMICHEM.NS', 'SUPREMEIND.NS', 'SWSOLAR.NS', 'SYNGENE.NS', 'TATACHEM.NS', 'TATAINVEST.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TEAMLEASE.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'UBL.NS', 'USHAMART.NS', 'VIPIND.NS', 'VTL.NS', 'WESTLIFE.NS'],
'2021-10-01': ['AARTIIND.NS', 'AAVAS.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ADANIGREEN.NS', 'AJANTPHARM.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ATUL.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BATAINDIA.NS', 'BRITANNIA.NS', 'BSE.NS', 'CDSL.NS', 'CHOLAHLDNG.NS', 'COFORGE.NS', 'CROMPTON.NS', 'CSBBANK.NS', 'CUB.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'ERIS.NS', 'GALAXYSURF.NS', 'GESHIP.NS', 'GODREJIND.NS', 'GRINDWELL.NS', 'HAVELLS.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'ICICIGI.NS', 'INDIAMART.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INGERRAND.NS', 'INTELLECT.NS', 'ISEC.NS', 'JUBLFOOD.NS', 'JUSTDIAL.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KEC.NS', 'KPITTECH.NS', 'KSB.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'LINDEINDIA.NS', 'LT.NS', 'MAHLIFE.NS', 'MCX.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'PGHH.NS', 'PIDILITIND.NS', 'PRAJIND.NS', 'PRINCEPIPE.NS', 'QUESS.NS', 'RAIN.NS', 'RITES.NS', 'ROSSARI.NS', 'SBIN.NS', 'SHOPERSTOP.NS', 'SKFINDIA.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'STLTECH.NS', 'TCS.NS', 'TEAMLEASE.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'UBL.NS', 'UNOMINDA.NS', 'VBL.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'VMART.NS', 'WESTLIFE.NS', 'ZENSARTECH.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2021-11-01': ['AAVAS.NS', 'ACC.NS', 'ATGL.NS', 'BAJAJHLDNG.NS', 'BATAINDIA.NS', 'BEML.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'BRIGADE.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'DMART.NS', 'ENDURANCE.NS', 'ERIS.NS', 'ESCORTS.NS', 'FINPIPE.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'GUJALKALI.NS', 'IEX.NS', 'INDIACEM.NS', 'INGERRAND.NS', 'KSB.NS', 'LAXMIMACH.NS', 'LT.NS', 'LTTS.NS', 'M&M.NS', 'MARUTI.NS', 'METROPOLIS.NS', 'MOTILALOFS.NS', 'ORIENTELEC.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'RAMCOCEM.NS', 'RELAXO.NS', 'SANOFI.NS', 'SFL.NS', 'SHRIRAMFIN.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SWSOLAR.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TIMKEN.NS', 'TITAN.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'VIPIND.NS', 'VMART.NS', 'WESTLIFE.NS', 'ZEEL.NS'],
'2021-12-01': ['APLAPOLLO.NS', 'ASAHIINDIA.NS', 'ATGL.NS', 'BAJAJHLDNG.NS', 'BRIGADE.NS', 'BSE.NS', 'BSOFT.NS', 'CIPLA.NS', 'FINCABLES.NS', 'GLAXO.NS', 'KEI.NS', 'KPRMILL.NS', 'LTTS.NS', 'MAXHEALTH.NS', 'METROPOLIS.NS', 'MOTILALOFS.NS', 'NH.NS', 'ORIENTELEC.NS', 'PGHH.NS', 'POWERINDIA.NS', 'RADICO.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SONATSOFTW.NS', 'TIMKEN.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'UNOMINDA.NS', 'ZFCVINDIA.NS'],
'2022-01-01': ['AARTIIND.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'AFFLE.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'ASTRAL.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'AVANTIFEED.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BAYERCROP.NS', 'BORORENEW.NS', 'BOSCHLTD.NS', 'BSE.NS', 'CCL.NS', 'CEATLTD.NS', 'CENTURYTEX.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'DEEPAKNTR.NS', 'DIXON.NS', 'EICHERMOT.NS', 'ERIS.NS', 'FLUOROCHEM.NS', 'GLAND.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GRANULES.NS', 'HAVELLS.NS', 'HINDALCO.NS', 'HONAUT.NS', 'INTELLECT.NS', 'IPCALAB.NS', 'ISEC.NS', 'KEC.NS', 'KEI.NS', 'KNRCON.NS', 'LT.NS', 'LTTS.NS', 'LUPIN.NS', 'MASTEK.NS', 'MAZDOCK.NS', 'METROPOLIS.NS', 'MPHASIS.NS', 'NATCOPHARM.NS', 'NBCC.NS', 'NESTLEIND.NS', 'OLECTRA.NS', 'PAGEIND.NS', 'PCBL.NS', 'PGHH.NS', 'PGHL.NS', 'PIDILITIND.NS', 'PIIND.NS', 'POLYCAB.NS', 'RAJESHEXPO.NS', 'RALLIS.NS', 'RAYMOND.NS', 'RELAXO.NS', 'RHIM.NS', 'SBILIFE.NS', 'SFL.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'SUNDRMFAST.NS', 'SUNTECK.NS', 'SUPRAJIT.NS', 'SYNGENE.NS', 'THERMAX.NS', 'TIMKEN.NS', 'TRIDENT.NS', 'ULTRACEMCO.NS', 'VARROC.NS', 'VINATIORGA.NS', 'WELCORP.NS'],
'2022-02-01': ['360ONE.NS', 'AAVAS.NS', 'ALOKINDS.NS', 'AMBER.NS', 'ASAHIINDIA.NS', 'ATGL.NS', 'AVANTIFEED.NS', 'BALRAMCHIN.NS', 'BATAINDIA.NS', 'BCG.NS', 'BHARTIARTL.NS', 'BORORENEW.NS', 'CGCL.NS', 'CHOLAFIN.NS', 'CIPLA.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'FACT.NS', 'GAIL.NS', 'GICRE.NS', 'GPIL.NS', 'IDFC.NS', 'IIFL.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'INTELLECT.NS', 'IOB.NS', 'IOC.NS', 'IRB.NS', 'JSL.NS', 'JUSTDIAL.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'KPITTECH.NS', 'LEMONTREE.NS', 'M&M.NS', 'MAHABANK.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NH.NS', 'NLCINDIA.NS', 'OLECTRA.NS', 'PNB.NS', 'POWERGRID.NS', 'REDINGTON.NS', 'RENUKA.NS', 'SJVN.NS', 'SPARC.NS', 'SUVENPHAR.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VARROC.NS', 'VIPIND.NS', 'WELCORP.NS'],
'2022-03-01': ['CGCL.NS', 'CHOLAFIN.NS', 'COALINDIA.NS', 'CREDITACC.NS', 'GESHIP.NS', 'GNFC.NS', 'JSWENERGY.NS', 'NATIONALUM.NS', 'POWERGRID.NS', 'VEDL.NS'],
'2022-04-01': ['AARTIIND.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'AFFLE.NS', 'ANGELONE.NS', 'ATUL.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BATAINDIA.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'CANFINHOME.NS', 'CENTURYTEX.NS', 'CGCL.NS', 'CHOLAFIN.NS', 'CIPLA.NS', 'COALINDIA.NS', 'DCMSHRIRAM.NS', 'DLF.NS', 'EIDPARRY.NS', 'GESHIP.NS', 'GLAXO.NS', 'GODREJPROP.NS', 'HFCL.NS', 'ICICIGI.NS', 'INDIGO.NS', 'INGERRAND.NS', 'IPCALAB.NS', 'IRB.NS', 'JSL.NS', 'JYOTHYLAB.NS', 'L&TFH.NS', 'LAURUSLABS.NS', 'LTTS.NS', 'M&MFIN.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MPHASIS.NS', 'NAM-INDIA.NS', 'NAVINFLUOR.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'OIL.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'PIIND.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'PRAJIND.NS', 'PRESTIGE.NS', 'QUESS.NS', 'RITES.NS', 'SANOFI.NS', 'SAREGAMA.NS', 'SFL.NS', 'STLTECH.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATACHEM.NS', 'TATASTEEL.NS', 'TEAMLEASE.NS', 'TEJASNET.NS', 'TIMKEN.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TTML.NS', 'UTIAMC.NS', 'WELCORP.NS', 'ZEEL.NS'],
'2022-05-01': ['ADANIPORTS.NS', 'AMBER.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'ATGL.NS', 'AUBANK.NS', 'BANDHANBNK.NS', 'BBTC.NS', 'BEL.NS', 'BLUEDART.NS', 'BLUESTARCO.NS', 'BORORENEW.NS', 'BSE.NS', 'CEATLTD.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'EICHERMOT.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'FINEORG.NS', 'GILLETTE.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GSFC.NS', 'HAL.NS', 'HDFCLIFE.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'INGERRAND.NS', 'ITC.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JYOTHYLAB.NS', 'LINDEINDIA.NS', 'MAZDOCK.NS', 'METROPOLIS.NS', 'MHRIL.NS', 'NESTLEIND.NS', 'PAGEIND.NS', 'PHOENIXLTD.NS', 'POONAWALLA.NS', 'RCF.NS', 'ROUTE.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SUMICHEM.NS', 'SUNPHARMA.NS', 'SUVENPHAR.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'THERMAX.NS', 'UBL.NS', 'UPL.NS', 'VINATIORGA.NS'],
'2022-06-01': ['3MINDIA.NS', 'ABBOTINDIA.NS', 'ADANIENT.NS', 'AEGISCHEM.NS', 'AMBUJACEM.NS', 'BALAMINES.NS', 'BANDHANBNK.NS', 'BATAINDIA.NS', 'BBTC.NS', 'BEL.NS', 'BHARATFORG.NS', 'BORORENEW.NS', 'BOSCHLTD.NS', 'BRIGADE.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CENTURYTEX.NS', 'CGCL.NS', 'CHALET.NS', 'CIPLA.NS', 'COALINDIA.NS', 'CONCOR.NS', 'DEEPAKFERT.NS', 'DMART.NS', 'ELGIEQUIP.NS', 'ENDURANCE.NS', 'FINPIPE.NS', 'FLUOROCHEM.NS', 'GAEL.NS', 'GESHIP.NS', 'GMRINFRA.NS', 'GSFC.NS', 'GUJGASLTD.NS', 'HDFCBANK.NS', 'ICICIBANK.NS', 'ICICIPRULI.NS', 'INDIGO.NS', 'INGERRAND.NS', 'IOB.NS', 'JUBLFOOD.NS', 'KEC.NS', 'KEI.NS', 'KOTAKBANK.NS', 'KPRMILL.NS', 'KSB.NS', 'LAXMIMACH.NS', 'LEMONTREE.NS', 'LICHSGFIN.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MAHLIFE.NS', 'MARICO.NS', 'MARUTI.NS', 'MAXHEALTH.NS', 'MCX.NS', 'MFSL.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'NHPC.NS', 'NTPC.NS', 'OIL.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'PIIND.NS', 'POWERGRID.NS', 'RELIANCE.NS', 'SHARDACROP.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SRF.NS', 'SWANENERGY.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TORNTPHARM.NS', 'UBL.NS', 'VINATIORGA.NS', 'WHIRLPOOL.NS'],
'2022-07-01': ['AJANTPHARM.NS', 'BAJAJ-AUTO.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'CCL.NS', 'CHALET.NS', 'COROMANDEL.NS', 'CUMMINSIND.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'FLUOROCHEM.NS', 'GILLETTE.NS', 'GMMPFAUDLR.NS', 'HEROMOTOCO.NS', 'ITC.NS', 'LINDEINDIA.NS', 'MAHLIFE.NS', 'NESTLEIND.NS', 'PHOENIXLTD.NS', 'RADICO.NS', 'RECLTD.NS', 'SCHAEFFLER.NS', 'SHOPERSTOP.NS', 'SIEMENS.NS', 'SOBHA.NS', 'SUNTECK.NS', 'THERMAX.NS', 'TIMKEN.NS', 'TORNTPHARM.NS', 'VIPIND.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2022-08-01': ['3MINDIA.NS', 'AARTIIND.NS', 'ACC.NS', 'ADANIGREEN.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'APLAPOLLO.NS', 'ASTRAL.NS', 'BAJAJ-AUTO.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BAYERCROP.NS', 'BERGEPAINT.NS', 'BIRLACORPN.NS', 'CAMS.NS', 'CENTURYTEX.NS', 'CIPLA.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'ENDURANCE.NS', 'ERIS.NS', 'GALAXYSURF.NS', 'GILLETTE.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GRANULES.NS', 'GRINDWELL.NS', 'HAVELLS.NS', 'HDFCAMC.NS', 'INDIAMART.NS', 'INFY.NS', 'IRCTC.NS', 'ISEC.NS', 'JINDALSTEL.NS', 'KEI.NS', 'KOTAKBANK.NS', 'KPRMILL.NS', 'KSB.NS', 'LTTS.NS', 'MARICO.NS', 'MCX.NS', 'METROPOLIS.NS', 'MFSL.NS', 'NATCOPHARM.NS', 'OLECTRA.NS', 'PERSISTENT.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'POLYCAB.NS', 'POLYPLEX.NS', 'RADICO.NS', 'ROUTE.NS', 'SAREGAMA.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SRF.NS', 'SUNTECK.NS', 'SUPREMEIND.NS', 'TATACOMM.NS', 'TATAMOTORS.NS', 'TCS.NS', 'TTKPRESTIG.NS', 'UBL.NS', 'UNOMINDA.NS', 'UTIAMC.NS', 'VARROC.NS'],
'2022-09-01': ['360ONE.NS', 'ASHOKLEY.NS', 'BANKINDIA.NS', 'BLS.NS', 'CANBK.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CESC.NS', 'CHAMBLFERT.NS', 'CIEINDIA.NS', 'CROMPTON.NS', 'CSBBANK.NS', 'DELTACORP.NS', 'DLF.NS', 'EIHOTEL.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'EQUITASBNK.NS', 'EXIDEIND.NS', 'FACT.NS', 'GICRE.NS', 'GODREJIND.NS', 'HFCL.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'IGL.NS', 'INFIBEAM.NS', 'IOB.NS', 'IRCON.NS', 'JSL.NS', 'L&TFH.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MHRIL.NS', 'NBCC.NS', 'NIACL.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NTPC.NS', 'PFC.NS', 'PNB.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'RALLIS.NS', 'RCF.NS', 'RTNINDIA.NS', 'SAIL.NS', 'SUVENPHAR.NS', 'SUZLON.NS', 'TATAMTRDVR.NS', 'TATASTEEL.NS', 'UCOBANK.NS', 'UJJIVANSFB.NS', 'VEDL.NS', 'VTL.NS', 'YESBANK.NS', 'ZEEL.NS'],
'2022-10-01': ['AARTIDRUGS.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'ASTERDM.NS', 'BANKBARODA.NS', 'BDL.NS', 'BHEL.NS', 'BLS.NS', 'BLUESTARCO.NS', 'CCL.NS', 'CENTRALBK.NS', 'CGCL.NS', 'CHALET.NS', 'CROMPTON.NS', 'CSBBANK.NS', 'EIHOTEL.NS', 'EMAMILTD.NS', 'EPL.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'GESHIP.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDIANB.NS', 'IRCTC.NS', 'ISEC.NS', 'ITC.NS', 'JINDALSTEL.NS', 'JUBLFOOD.NS', 'JYOTHYLAB.NS', 'KEC.NS', 'LICHSGFIN.NS', 'LUPIN.NS', 'MARICO.NS', 'MHRIL.NS', 'NCC.NS', 'NMDC.NS', 'ORIENTELEC.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RVNL.NS', 'SJVN.NS', 'SUMICHEM.NS', 'SUNTV.NS', 'UNIONBANK.NS', 'VGUARD.NS', 'WELCORP.NS'],
'2022-11-01': ['AARTIDRUGS.NS', 'ACC.NS', 'ADANIENT.NS', 'AJANTPHARM.NS', 'ANGELONE.NS', 'APOLLOHOSP.NS', 'BEML.NS', 'BOSCHLTD.NS', 'CAMS.NS', 'CCL.NS', 'CEATLTD.NS', 'CERA.NS', 'CGCL.NS', 'COFORGE.NS', 'DALBHARAT.NS', 'DEEPAKFERT.NS', 'DLF.NS', 'DRREDDY.NS', 'EIDPARRY.NS', 'ELGIEQUIP.NS', 'ERIS.NS', 'ESCORTS.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'ICICIBANK.NS', 'INDIAMART.NS', 'ISEC.NS', 'JBCHEPHARM.NS', 'JKCEMENT.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'JYOTHYLAB.NS', 'KEC.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'LTIM.NS', 'LUPIN.NS', 'MGL.NS', 'MHRIL.NS', 'NAVINFLUOR.NS', 'PATANJALI.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'RELIANCE.NS', 'SBILIFE.NS', 'SHOPERSTOP.NS', 'SIEMENS.NS', 'SOLARINDS.NS', 'TATAINVEST.NS', 'TCS.NS', 'TECHM.NS', 'TEJASNET.NS', 'TIINDIA.NS', 'UPL.NS', 'ZFCVINDIA.NS'],
'2022-12-01': ['AEGISCHEM.NS', 'AMBUJACEM.NS', 'BALKRISIND.NS', 'BBTC.NS', 'BHARATFORG.NS', 'BLUESTARCO.NS', 'BSOFT.NS', 'CANFINHOME.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CIPLA.NS', 'COLPAL.NS', 'DELTACORP.NS', 'DLF.NS', 'ECLERX.NS', 'EMAMILTD.NS', 'EPL.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'FSL.NS', 'GLENMARK.NS', 'GODREJCP.NS', 'GPPL.NS', 'GRAPHITE.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'IDFC.NS', 'IGL.NS', 'IOB.NS', 'ITI.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'JUBLPHARMA.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KPITTECH.NS', 'KRBL.NS', 'LAXMIMACH.NS', 'LTTS.NS', 'MAXHEALTH.NS', 'MGL.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NETWORK18.NS', 'OFSS.NS', 'ORIENTELEC.NS', 'PCBL.NS', 'PIDILITIND.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'RAIN.NS', 'RAJESHEXPO.NS', 'SAIL.NS', 'SBILIFE.NS', 'SBIN.NS', 'SHRIRAMFIN.NS', 'STLTECH.NS', 'SUPRAJIT.NS', 'SUVENPHAR.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TATACOMM.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATASTEEL.NS', 'TECHM.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'UJJIVANSFB.NS', 'VINATIORGA.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'WIPRO.NS', 'YESBANK.NS'],
'2023-01-01': ['ABCAPITAL.NS', 'APOLLOTYRE.NS', 'BANKINDIA.NS', 'CENTRALBK.NS', 'EQUITASBNK.NS', 'FEDERALBNK.NS', 'FINPIPE.NS', 'GAIL.NS', 'GICRE.NS', 'HINDALCO.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'IOB.NS', 'IOC.NS', 'IRB.NS', 'JINDALSAW.NS', 'KARURVYSYA.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NIACL.NS', 'NMDC.NS', 'PETRONET.NS', 'PFC.NS', 'PNB.NS', 'RCF.NS', 'RVNL.NS', 'SUZLON.NS', 'TATASTEEL.NS', 'YESBANK.NS'],
'2023-02-01': ['AFFLE.NS', 'ALLCARGO.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'BANDHANBNK.NS', 'BDL.NS', 'BEML.NS', 'BLS.NS', 'BPCL.NS', 'BSOFT.NS', 'CANFINHOME.NS', 'CCL.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'COALINDIA.NS', 'CSBBANK.NS', 'EMAMILTD.NS', 'FACT.NS', 'FSL.NS', 'GAEL.NS', 'GICRE.NS', 'GODREJCP.NS', 'GPIL.NS', 'GSPL.NS', 'HINDCOPPER.NS', 'HINDZINC.NS', 'IDFC.NS', 'IRCON.NS', 'JINDALSTEL.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KPRMILL.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MGL.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NCC.NS', 'NMDC.NS', 'NTPC.NS', 'PEL.NS', 'PNBHOUSING.NS', 'RAYMOND.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RITES.NS', 'RVNL.NS', 'SAIL.NS', 'SHARDACROP.NS', 'STLTECH.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUVENPHAR.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'UCOBANK.NS', 'UPL.NS', 'USHAMART.NS', 'WIPRO.NS'],
'2023-03-01': ['3MINDIA.NS', 'AEGISCHEM.NS', 'ALKEM.NS', 'AUROPHARMA.NS', 'BDL.NS', 'BERGEPAINT.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CHALET.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'CREDITACC.NS', 'FSL.NS', 'GLENMARK.NS', 'GMMPFAUDLR.NS', 'HAL.NS', 'IEX.NS', 'IGL.NS', 'KEI.NS', 'KPRMILL.NS', 'KSB.NS', 'LTIM.NS', 'LTTS.NS', 'M&MFIN.NS', 'MGL.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'NH.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'OLECTRA.NS', 'PETRONET.NS', 'PFC.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'RATNAMANI.NS', 'SWSOLAR.NS', 'TANLA.NS', 'TEAMLEASE.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'ZYDUSLIFE.NS'],
'2023-04-01': ['ABB.NS', 'BAJAJ-AUTO.NS', 'BALRAMCHIN.NS', 'BEL.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CERA.NS', 'COLPAL.NS', 'CRISIL.NS', 'CUMMINSIND.NS', 'GESHIP.NS', 'GLAXO.NS', 'GRASIM.NS', 'HAL.NS', 'HINDUNILVR.NS', 'ICICIBANK.NS', 'ICICIPRULI.NS', 'INDIAMART.NS', 'ITC.NS', 'JKCEMENT.NS', 'KEI.NS', 'LTIM.NS', 'MCX.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'OFSS.NS', 'OLECTRA.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'RADICO.NS', 'ROUTE.NS', 'SAFARI.NS', 'SANOFI.NS', 'SCHAEFFLER.NS', 'SHARDACROP.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SJVN.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TITAN.NS', 'TRENT.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2023-05-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ADANIPORTS.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'AUBANK.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BANKINDIA.NS', 'BATAINDIA.NS', 'BIOCON.NS', 'BLS.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'CENTURYPLY.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'COROMANDEL.NS', 'CSBBANK.NS', 'CUB.NS', 'DALBHARAT.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'ENDURANCE.NS', 'ERIS.NS', 'FEDERALBNK.NS', 'FSL.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GICRE.NS', 'GSPL.NS', 'GUJALKALI.NS', 'HAVELLS.NS', 'HDFCBANK.NS', 'HINDALCO.NS', 'HINDZINC.NS', 'IDEA.NS', 'IIFL.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INTELLECT.NS', 'IOB.NS', 'IRCTC.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JSWSTEEL.NS', 'KPITTECH.NS', 'LALPATHLAB.NS', 'LUPIN.NS', 'LUXIND.NS', 'M&MFIN.NS', 'MARICO.NS', 'MASTEK.NS', 'MAZDOCK.NS', 'MGL.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NLCINDIA.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'ONGC.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PIDILITIND.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PRAJIND.NS', 'RAIN.NS', 'RCF.NS', 'RELAXO.NS', 'RELIANCE.NS', 'ROSSARI.NS', 'SBICARD.NS', 'SHOPERSTOP.NS', 'SONATSOFTW.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUPREMEIND.NS', 'TANLA.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'TORNTPOWER.NS', 'TVSMOTOR.NS', 'UBL.NS', 'UJJIVANSFB.NS', 'UNOMINDA.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VINATIORGA.NS', 'VTL.NS', 'WIPRO.NS', 'ZYDUSWELL.NS'],
'2023-06-01': ['ABCAPITAL.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'AJANTPHARM.NS', 'AMBUJACEM.NS', 'ANGELONE.NS', 'APOLLOHOSP.NS', 'ASTERDM.NS', 'BANKBARODA.NS', 'BAYERCROP.NS', 'BCG.NS', 'BIOCON.NS', 'BLUEDART.NS', 'CAMS.NS', 'CARBORUNIV.NS', 'CEATLTD.NS', 'CENTURYPLY.NS', 'CGCL.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'COALINDIA.NS', 'CYIENT.NS', 'DABUR.NS', 'DCMSHRIRAM.NS', 'ELGIEQUIP.NS', 'ERIS.NS', 'FDC.NS', 'GESHIP.NS', 'GODREJIND.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HINDPETRO.NS', 'HUDCO.NS', 'ICICIPRULI.NS', 'IDBI.NS', 'IDEA.NS', 'INDIACEM.NS', 'INFIBEAM.NS', 'INGERRAND.NS', 'IRCON.NS', 'ISEC.NS', 'ITI.NS', 'JBMA.NS', 'JUBLFOOD.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'KEI.NS', 'LTTS.NS', 'LUXIND.NS', 'M&MFIN.NS', 'MAZDOCK.NS', 'MFSL.NS', 'MGL.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'MRPL.NS', 'NAUKRI.NS', 'NBCC.NS', 'NETWORK18.NS', 'NIACL.NS', 'PEL.NS', 'PNB.NS', 'PNBHOUSING.NS', 'POWERINDIA.NS', 'PRINCEPIPE.NS', 'QUESS.NS', 'RBLBANK.NS', 'ROSSARI.NS', 'RVNL.NS', 'SBIN.NS', 'SHRIRAMFIN.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'TATAPOWER.NS', 'TECHM.NS', 'TRITURBINE.NS', 'UNOMINDA.NS', 'UTIAMC.NS', 'VARROC.NS', 'VEDL.NS'],
'2023-07-01': ['ALOKINDS.NS', 'AMBER.NS', 'APOLLOTYRE.NS', 'AVANTIFEED.NS', 'BANKBARODA.NS', 'BHARATFORG.NS', 'BHEL.NS', 'CASTROLIND.NS', 'CENTRALBK.NS', 'CGCL.NS', 'CGPOWER.NS', 'CROMPTON.NS', 'CSBBANK.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'DLF.NS', 'DMART.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'EPL.NS', 'EQUITASBNK.NS', 'FDC.NS', 'GESHIP.NS', 'GRAPHITE.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'IDBI.NS', 'IDFC.NS', 'IIFL.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INFY.NS', 'IOC.NS', 'JINDALSTEL.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JSWENERGY.NS', 'JUBLFOOD.NS', 'JYOTHYLAB.NS', 'KANSAINER.NS', 'KPITTECH.NS', 'LAURUSLABS.NS', 'LICHSGFIN.NS', 'MOTHERSON.NS', 'NH.NS', 'NHPC.NS', 'PNBHOUSING.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'RALLIS.NS', 'RAYMOND.NS', 'RELIANCE.NS', 'RTNINDIA.NS', 'SHARDACROP.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'SUMICHEM.NS', 'SUPRAJIT.NS', 'SUVENPHAR.NS', 'SWANENERGY.NS', 'TATAINVEST.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TECHM.NS', 'TEJASNET.NS', 'TTKPRESTIG.NS', 'UBL.NS', 'UJJIVANSFB.NS', 'UNOMINDA.NS', 'USHAMART.NS', 'VTL.NS', 'WELCORP.NS', 'WESTLIFE.NS', 'ZENSARTECH.NS'],
'2023-08-01': ['ABFRL.NS', 'ADANIENT.NS', 'ADANIPOWER.NS', 'AEGISCHEM.NS', 'AIAENG.NS', 'ALLCARGO.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'AVANTIFEED.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BBTC.NS', 'BDL.NS', 'BERGEPAINT.NS', 'BHARTIARTL.NS', 'BRIGADE.NS', 'CGPOWER.NS', 'CONCOR.NS', 'CSBBANK.NS', 'EIDPARRY.NS', 'ENDURANCE.NS', 'EQUITASBNK.NS', 'FACT.NS', 'FEDERALBNK.NS', 'GAEL.NS', 'GESHIP.NS', 'GRASIM.NS', 'HINDZINC.NS', 'HONAUT.NS', 'ICICIPRULI.NS', 'IDBI.NS', 'IDEA.NS', 'INDIACEM.NS', 'INDIAMART.NS', 'INDUSINDBK.NS', 'INGERRAND.NS', 'INTELLECT.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JSWSTEEL.NS', 'KRBL.NS', 'L&TFH.NS', 'LUXIND.NS', 'MAHABANK.NS', 'MARICO.NS', 'MCX.NS', 'MGL.NS', 'MHRIL.NS', 'MINDACORP.NS', 'NAUKRI.NS', 'NIACL.NS', 'PEL.NS', 'PETRONET.NS', 'PNB.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'PRESTIGE.NS', 'RAIN.NS', 'RELAXO.NS', 'RELIANCE.NS', 'SANOFI.NS', 'SFL.NS', 'SONATSOFTW.NS', 'SUNDARMFIN.NS', 'SUPREMEIND.NS', 'SYNGENE.NS', 'TCS.NS', 'TEJASNET.NS', 'TIMKEN.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS', 'UNOMINDA.NS', 'UTIAMC.NS', 'VARROC.NS', 'VGUARD.NS', 'VMART.NS'],
'2023-09-01': ['AARTIIND.NS', 'ACC.NS', 'ADANIPOWER.NS', 'ALKYLAMINE.NS', 'APLLTD.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'AUROPHARMA.NS', 'BEL.NS', 'CASTROLIND.NS', 'CENTURYTEX.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'DALBHARAT.NS', 'DLF.NS', 'ENGINERSIN.NS', 'EXIDEIND.NS', 'FDC.NS', 'FINEORG.NS', 'FLUOROCHEM.NS', 'GAEL.NS', 'GLAXO.NS', 'GNFC.NS', 'GODREJPROP.NS', 'HDFCAMC.NS', 'HEG.NS', 'IDFC.NS', 'IIFL.NS', 'INDIANB.NS', 'INDUSTOWER.NS', 'INFY.NS', 'INGERRAND.NS', 'IOB.NS', 'IRB.NS', 'IRCTC.NS', 'ISEC.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JUBLFOOD.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KEC.NS', 'KPITTECH.NS', 'KRBL.NS', 'LAURUSLABS.NS', 'LICHSGFIN.NS', 'LT.NS', 'LTIM.NS', 'M&M.NS', 'MAZDOCK.NS', 'MINDACORP.NS', 'NAM-INDIA.NS', 'NATIONALUM.NS', 'NH.NS', 'NHPC.NS', 'NIACL.NS', 'NLCINDIA.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'PAGEIND.NS', 'PFC.NS', 'PNB.NS', 'RATNAMANI.NS', 'RCF.NS', 'RHIM.NS', 'ROSSARI.NS', 'ROUTE.NS', 'RVNL.NS', 'SOBHA.NS', 'SRF.NS', 'SUNDRMFAST.NS', 'SUVENPHAR.NS', 'SWSOLAR.NS', 'TATAPOWER.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'TRIVENI.NS', 'UCOBANK.NS', 'UJJIVANSFB.NS', 'WELCORP.NS', 'WESTLIFE.NS', 'ZEEL.NS'],
'2023-10-01': ['ALOKINDS.NS', 'APLLTD.NS', 'AVANTIFEED.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BEL.NS', 'BHARATFORG.NS', 'BHEL.NS', 'BIOCON.NS', 'CENTURYTEX.NS', 'CESC.NS', 'CGPOWER.NS', 'CHALET.NS', 'CROMPTON.NS', 'CSBBANK.NS', 'DEEPAKFERT.NS', 'DLF.NS', 'EMAMILTD.NS', 'EQUITASBNK.NS', 'FACT.NS', 'FEDERALBNK.NS', 'FORTIS.NS', 'FSL.NS', 'GAIL.NS', 'GICRE.NS', 'GLAND.NS', 'GMRINFRA.NS', 'GNFC.NS', 'GODREJIND.NS', 'GRAPHITE.NS', 'GSFC.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'IBULHSGFIN.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'IRB.NS', 'JINDALSTEL.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'KPRMILL.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'MANAPPURAM.NS', 'MASTEK.NS', 'MMTC.NS', 'MRPL.NS', 'NAM-INDIA.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NHPC.NS', 'NIACL.NS', 'NLCINDIA.NS', 'PCBL.NS', 'PETRONET.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'POWERGRID.NS', 'RENUKA.NS', 'RHIM.NS', 'ROUTE.NS', 'RVNL.NS', 'SJVN.NS', 'SUNPHARMA.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TEAMLEASE.NS', 'TEJASNET.NS', 'TTML.NS', 'VAIBHAVGBL.NS'],
'2023-11-01': ['ADANIPOWER.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'BALKRISIND.NS', 'BIRLACORPN.NS', 'BLS.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'CANFINHOME.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'CIPLA.NS', 'CRISIL.NS', 'CUB.NS', 'DEEPAKFERT.NS', 'ECLERX.NS', 'ELGIEQUIP.NS', 'ERIS.NS', 'GALAXYSURF.NS', 'GICRE.NS', 'GODFRYPHLP.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GPIL.NS', 'HDFCAMC.NS', 'ICICIGI.NS', 'IIFL.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'IRB.NS', 'JKLAKSHMI.NS', 'JYOTHYLAB.NS', 'KPITTECH.NS', 'KSB.NS', 'L&TFH.NS', 'LICHSGFIN.NS', 'MRPL.NS', 'MUTHOOTFIN.NS', 'NIACL.NS', 'NLCINDIA.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'ONGC.NS', 'PFC.NS', 'PGHH.NS', 'PNBHOUSING.NS', 'POLYMED.NS', 'POWERGRID.NS', 'SAFARI.NS', 'SJVN.NS', 'SOBHA.NS', 'SUNTV.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'TIINDIA.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TTKPRESTIG.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'UNIONBANK.NS', 'ZFCVINDIA.NS'],
'2023-12-01': ['ABB.NS', 'AFFLE.NS', 'AMBUJACEM.NS', 'ASTRAL.NS', 'AUBANK.NS', 'BAJAJHLDNG.NS', 'BAYERCROP.NS', 'BEL.NS', 'BHARATFORG.NS', 'BORORENEW.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CESC.NS', 'CGPOWER.NS', 'CREDITACC.NS', 'CRISIL.NS', 'CUB.NS', 'DEEPAKNTR.NS', 'DIXON.NS', 'ELGIEQUIP.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'ERIS.NS', 'FACT.NS', 'GILLETTE.NS', 'GMRINFRA.NS', 'GPPL.NS', 'GRAPHITE.NS', 'GSFC.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'HUDCO.NS', 'ICICIPRULI.NS', 'INDHOTEL.NS', 'INFY.NS', 'IRB.NS', 'IRCTC.NS', 'ISEC.NS', 'JINDALSAW.NS', 'JSWSTEEL.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'KEI.NS', 'KNRCON.NS', 'L&TFH.NS', 'LALPATHLAB.NS', 'LT.NS', 'LTIM.NS', 'MARUTI.NS', 'MINDACORP.NS', 'MRF.NS', 'NAUKRI.NS', 'NCC.NS', 'NESTLEIND.NS', 'NHPC.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PIDILITIND.NS', 'POLYMED.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'RALLIS.NS', 'REDINGTON.NS', 'SAFARI.NS', 'SAIL.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SOLARINDS.NS', 'SRF.NS', 'SWSOLAR.NS', 'TATAELXSI.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TECHM.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TTML.NS', 'UBL.NS', 'VARROC.NS', 'VTL.NS', 'WELSPUNLIV.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZENSARTECH.NS', 'ZYDUSLIFE.NS'],
'2024-01-01': ['ADANIENT.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'AVANTIFEED.NS', 'BAYERCROP.NS', 'BERGEPAINT.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'CANBK.NS', 'CENTRALBK.NS', 'DABUR.NS', 'DRREDDY.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'EQUITASBNK.NS', 'FACT.NS', 'FEDERALBNK.NS', 'FSL.NS', 'GICRE.NS', 'GILLETTE.NS', 'GLENMARK.NS', 'GNFC.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GRANULES.NS', 'GSPL.NS', 'GUJALKALI.NS', 'HAVELLS.NS', 'HINDZINC.NS', 'IBULHSGFIN.NS', 'IDFC.NS', 'IGL.NS', 'INDUSTOWER.NS', 'INFY.NS', 'INGERRAND.NS', 'IPCALAB.NS', 'IRB.NS', 'ITC.NS', 'ITI.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'KPITTECH.NS', 'KRBL.NS', 'KSB.NS', 'MAHLIFE.NS', 'MANAPPURAM.NS', 'MAXHEALTH.NS', 'MINDACORP.NS', 'MOTILALOFS.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NBCC.NS', 'NH.NS', 'OBEROIRLTY.NS', 'ONGC.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'POONAWALLA.NS', 'PRINCEPIPE.NS', 'RBLBANK.NS', 'ROUTE.NS', 'RVNL.NS', 'SANOFI.NS', 'SFL.NS', 'SHARDACROP.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'SRF.NS', 'SUNTV.NS', 'TATAELXSI.NS', 'TECHM.NS', 'TEJASNET.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'UTIAMC.NS', 'VARROC.NS', 'VMART.NS', 'WELCORP.NS', 'YESBANK.NS'],
'2024-02-01': ['AARTIIND.NS', 'ABBOTINDIA.NS', 'ABFRL.NS', 'ADANIGREEN.NS', 'AIAENG.NS', 'ALOKINDS.NS', 'APARINDS.NS', 'APLLTD.NS', 'ATGL.NS', 'AVANTIFEED.NS', 'BAJAJHLDNG.NS', 'CEATLTD.NS', 'CENTURYPLY.NS', 'COLPAL.NS', 'DRREDDY.NS', 'FACT.NS', 'FINCABLES.NS', 'FLUOROCHEM.NS', 'FORTIS.NS', 'FSL.NS', 'GAEL.NS', 'GESHIP.NS', 'GILLETTE.NS', 'GLENMARK.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'HINDZINC.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'INGERRAND.NS', 'ISEC.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'KEC.NS', 'KNRCON.NS', 'KSB.NS', 'L&TFH.NS', 'LTTS.NS', 'MANAPPURAM.NS', 'MAXHEALTH.NS', 'MCX.NS', 'NETWORK18.NS', 'NH.NS', 'NTPC.NS', 'PFIZER.NS', 'POONAWALLA.NS', 'RALLIS.NS', 'REDINGTON.NS', 'SANOFI.NS', 'SIEMENS.NS', 'SYMPHONY.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TTKPRESTIG.NS', 'UTIAMC.NS', 'VBL.NS', 'VEDL.NS', 'VMART.NS', 'VOLTAS.NS', 'WELCORP.NS', 'WIPRO.NS', 'YESBANK.NS'],
}


# Initialize lists to store results
ticker_list = []
percentage_returns = []
first_day_closes = []
last_day_closes = []
start_dates = []  # List to store the start dates
end_dates = []    # List to store the end dates

# Loop through the dictionary and download data for each date-ticker pair
for start_date, tickers in date_ticker_dict.items():
    end_date = pd.to_datetime(start_date) + pd.DateOffset(months=1) - pd.DateOffset(days=1)  # Last day of the month

    # Loop through tickers in this iteration
    for ticker in tickers:
        # Download historical stock data using yfinance for the specified ticker and dates
        try:
            stocks = yf.download(ticker, start=start_date, end=end_date)

            # Extracting the closing prices on the first and last day
            first_day_close = stocks['Close'].iloc[0]
            last_day_close = stocks['Close'].iloc[-1]

            # Calculating percentage return for this ticker
            percentage_return = ((last_day_close - first_day_close) / first_day_close) * 100

            # Appending the results to the lists
            ticker_list.append(ticker)
            percentage_returns.append(percentage_return)
            first_day_closes.append(first_day_close)
            last_day_closes.append(last_day_close)
            start_dates.append(pd.to_datetime(start_date))
            end_dates.append(end_date)  # Append end date for each ticker
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

# Creating a DataFrame with ticker symbols, percentage returns, and capital information
returns_df = pd.DataFrame({
    'Start_Date': start_dates,
    'End_Date': end_dates,
    'Ticker': ticker_list,
    'Percentage_Return': percentage_returns,
    'First_Day_Close': first_day_closes,
    'Last_Day_Close': last_day_closes,
})

# Assuming an initial investment of $10,000 for each stock
initial_investment = 10000

# Calculating the capital at the last day
returns_df['Capital_At_Last_Day'] = initial_investment * (1 + returns_df['Percentage_Return'] / 100)

# Calculating the difference between capital at the last day and capital required
returns_df['Capital_Difference'] = returns_df['Capital_At_Last_Day'] - initial_investment

# Total amount invested
total_invested = initial_investment * len(returns_df)

# Total amount returned
total_returned = returns_df['Capital_At_Last_Day'].sum()

# Calculate percentage return
percentage_return = ((total_returned - total_invested) / total_invested) * 100

# Displaying the DataFrame with ticker names, percentage returns, and capital information
print(returns_df[['Start_Date', 'End_Date', 'Ticker', 'Percentage_Return', 'First_Day_Close', 'Last_Day_Close']])

# Display total amount invested and total amount returned in percentage
print("\nTotal Amount Invested: $", total_invested)
print("Total Amount Returned: $", total_returned)
print("Percentage Return: ", percentage_return, "%")

returns_df.to_csv('stock_Cluster5.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %% [markdown]
# # Cluster 6

# %%
import yfinance as yf
import pandas as pd

# Input dictionary
date_ticker_dict =  {  

    '2017-04-01': ['ABB.NS', 'ADANIENT.NS', 'APLAPOLLO.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'ATUL.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BALAMINES.NS', 'BANKINDIA.NS', 'BEML.NS', 'BERGEPAINT.NS', 'BIRLACORPN.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'CANFINHOME.NS', 'CEATLTD.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'DCMSHRIRAM.NS', 'EICHERMOT.NS', 'EXIDEIND.NS', 'FEDERALBNK.NS', 'GAEL.NS', 'GNFC.NS', 'GRANULES.NS', 'GRINDWELL.NS', 'GSFC.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'INDHOTEL.NS', 'INDUSTOWER.NS', 'IOC.NS', 'JINDALSAW.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'KEI.NS', 'KNRCON.NS', 'KPRMILL.NS', 'KRBL.NS', 'L&TFH.NS', 'LT.NS', 'MARICO.NS', 'MUTHOOTFIN.NS', 'NHPC.NS', 'NLCINDIA.NS', 'PFC.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'RADICO.NS', 'RALLIS.NS', 'RATNAMANI.NS', 'RELAXO.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SUNDRMFAST.NS', 'SUPREMEIND.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TITAN.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'TRIDENT.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'VGUARD.NS', 'VMART.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZEEL.NS'],
'2017-05-01': ['ABB.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'APARINDS.NS', 'ASIANPAINT.NS', 'BAJFINANCE.NS', 'BANKBARODA.NS', 'BATAINDIA.NS', 'BEML.NS', 'BHARATFORG.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'CENTRALBK.NS', 'CENTURYTEX.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'CUMMINSIND.NS', 'ENGINERSIN.NS', 'EPL.NS', 'ESCORTS.NS', 'FINPIPE.NS', 'FORTIS.NS', 'GNFC.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'HAVELLS.NS', 'HONAUT.NS', 'IBULHSGFIN.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'IOB.NS', 'IRB.NS', 'JAMNAAUTO.NS', 'JKCEMENT.NS', 'KANSAINER.NS', 'KARURVYSYA.NS', 'KEC.NS', 'KOTAKBANK.NS', 'L&TFH.NS', 'LINDEINDIA.NS', 'MAHABANK.NS', 'MARICO.NS', 'MARUTI.NS', 'MFSL.NS', 'NATCOPHARM.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'OBEROIRLTY.NS', 'PFC.NS', 'PRAJIND.NS', 'RAIN.NS', 'RATNAMANI.NS', 'RCF.NS', 'SRF.NS', 'SUZLON.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TRIVENI.NS', 'UNIONBANK.NS', 'UPL.NS', 'VMART.NS', 'WELSPUNLIV.NS', 'YESBANK.NS'],
'2017-06-01': ['3MINDIA.NS', 'AEGISCHEM.NS', 'ASHOKLEY.NS', 'BHARATFORG.NS', 'CHAMBLFERT.NS', 'COFORGE.NS', 'COROMANDEL.NS', 'FINPIPE.NS', 'GRINDWELL.NS', 'IGL.NS', 'IIFL.NS', 'INDUSINDBK.NS', 'JAMNAAUTO.NS', 'JMFINANCIL.NS', 'KOTAKBANK.NS', 'M&M.NS', 'M&MFIN.NS', 'MCDOWELL-N.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'NH.NS', 'PCBL.NS', 'PEL.NS', 'PERSISTENT.NS', 'PIDILITIND.NS', 'REDINGTON.NS', 'SOLARINDS.NS', 'TATASTEEL.NS', 'TCS.NS', 'TEAMLEASE.NS', 'WIPRO.NS'],
'2017-07-01': ['ASTRAL.NS', 'BALKRISIND.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BLUEDART.NS', 'BRITANNIA.NS', 'CARBORUNIV.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'COLPAL.NS', 'CRISIL.NS', 'DABUR.NS', 'DEEPAKNTR.NS', 'ELGIEQUIP.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'HINDZINC.NS', 'IIFL.NS', 'KEC.NS', 'KEI.NS', 'L&TFH.NS', 'LAXMIMACH.NS', 'LUXIND.NS', 'MARUTI.NS', 'MCDOWELL-N.NS', 'MUTHOOTFIN.NS', 'PAGEIND.NS', 'PFIZER.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'RATNAMANI.NS', 'SAREGAMA.NS', 'SUNTECK.NS', 'SUPREMEIND.NS', 'TATAINVEST.NS', 'TVSMOTOR.NS', 'VMART.NS', 'ZYDUSLIFE.NS'],
'2017-08-01': ['ADANIPOWER.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'APOLLOTYRE.NS', 'BALRAMCHIN.NS', 'BANKINDIA.NS', 'BEL.NS', 'BHARTIARTL.NS', 'CENTURYTEX.NS', 'CESC.NS', 'CGCL.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'COROMANDEL.NS', 'CUB.NS', 'EIDPARRY.NS', 'GODREJCP.NS', 'GPIL.NS', 'GSFC.NS', 'HINDCOPPER.NS', 'HINDZINC.NS', 'INFY.NS', 'JBMA.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'KANSAINER.NS', 'KRBL.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'MOTHERSON.NS', 'NMDC.NS', 'PGHL.NS', 'POONAWALLA.NS', 'RADICO.NS', 'RAIN.NS', 'RCF.NS', 'REDINGTON.NS', 'RENUKA.NS', 'SAIL.NS', 'SJVN.NS', 'TATASTEEL.NS', 'TRENT.NS', 'USHAMART.NS', 'VEDL.NS', 'VINATIORGA.NS'],
'2017-09-01': ['3MINDIA.NS', 'AMBUJACEM.NS', 'ASTRAL.NS', 'BAJFINANCE.NS', 'BIRLACORPN.NS', 'BRITANNIA.NS', 'COLPAL.NS', 'DEEPAKFERT.NS', 'EICHERMOT.NS', 'FINCABLES.NS', 'GILLETTE.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'IIFL.NS', 'INDUSINDBK.NS', 'KAJARIACER.NS', 'KEC.NS', 'LAXMIMACH.NS', 'LUXIND.NS', 'M&MFIN.NS', 'MARUTI.NS', 'MOTILALOFS.NS', 'PAGEIND.NS', 'PGHH.NS', 'PIDILITIND.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'RATNAMANI.NS', 'SUPREMEIND.NS', 'TEAMLEASE.NS', 'TECHM.NS', 'TITAN.NS', 'VMART.NS'],
'2017-10-01': ['ASHOKLEY.NS', 'ASTRAL.NS', 'BAJAJ-AUTO.NS', 'BRITANNIA.NS', 'CGCL.NS', 'CHOLAHLDNG.NS', 'COALINDIA.NS', 'COFORGE.NS', 'DEEPAKNTR.NS', 'FDC.NS', 'GAIL.NS', 'GODREJPROP.NS', 'HONAUT.NS', 'IGL.NS', 'ITI.NS', 'JBMA.NS', 'KEI.NS', 'LTIM.NS', 'ONGC.NS', 'PCBL.NS', 'PERSISTENT.NS', 'PGHH.NS', 'RAIN.NS', 'RTNINDIA.NS', 'SHOPERSTOP.NS', 'SUNTECK.NS', 'TECHM.NS', 'TVSMOTOR.NS', 'VIPIND.NS', 'VTL.NS'],
'2017-11-01': ['AARTIIND.NS', 'ADANIPORTS.NS', 'ASTRAL.NS', 'BAJAJ-AUTO.NS', 'BANKBARODA.NS', 'BATAINDIA.NS', 'BPCL.NS', 'BRITANNIA.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CENTURYTEX.NS', 'CIPLA.NS', 'COROMANDEL.NS', 'DABUR.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'EIDPARRY.NS', 'ELGIEQUIP.NS', 'ESCORTS.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'GAEL.NS', 'GLAXO.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'GUJGASLTD.NS', 'IGL.NS', 'INDIGO.NS', 'INTELLECT.NS', 'JINDALSAW.NS', 'JSWENERGY.NS', 'JUBLFOOD.NS', 'KANSAINER.NS', 'KSB.NS', 'LINDEINDIA.NS', 'LT.NS', 'LTIM.NS', 'MARUTI.NS', 'MASTEK.NS', 'MPHASIS.NS', 'NATCOPHARM.NS', 'NAVINFLUOR.NS', 'OBEROIRLTY.NS', 'PIIND.NS', 'RELAXO.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SHRIRAMFIN.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SYMPHONY.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TCS.NS', 'TECHM.NS', 'TV18BRDCST.NS', 'ULTRACEMCO.NS', 'VOLTAS.NS'],
'2017-12-01': ['AARTIDRUGS.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'APLAPOLLO.NS', 'BIOCON.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'DCMSHRIRAM.NS', 'DIVISLAB.NS', 'ECLERX.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'FDC.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GRAPHITE.NS', 'HONAUT.NS', 'IGL.NS', 'INDHOTEL.NS', 'JUBLFOOD.NS', 'JUSTDIAL.NS', 'KNRCON.NS', 'LUXIND.NS', 'MCDOWELL-N.NS', 'MPHASIS.NS', 'NETWORK18.NS', 'PFIZER.NS', 'PNCINFRA.NS', 'PRESTIGE.NS', 'QUESS.NS', 'RAIN.NS', 'REDINGTON.NS', 'RENUKA.NS', 'SAREGAMA.NS', 'SHARDACROP.NS', 'SHRIRAMFIN.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'VAIBHAVGBL.NS', 'VOLTAS.NS'],
'2018-01-01': ['ABBOTINDIA.NS', 'ADANIENT.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'ASTRAL.NS', 'BALKRISIND.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CEATLTD.NS', 'CENTURYTEX.NS', 'CGPOWER.NS', 'COLPAL.NS', 'CROMPTON.NS', 'CUB.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'DIVISLAB.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FINCABLES.NS', 'FORTIS.NS', 'GILLETTE.NS', 'GNFC.NS', 'GSFC.NS', 'HAVELLS.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'HONAUT.NS', 'INFY.NS', 'INTELLECT.NS', 'IPCALAB.NS', 'JSWENERGY.NS', 'LINDEINDIA.NS', 'LTTS.NS', 'LUXIND.NS', 'M&M.NS', 'MOTILALOFS.NS', 'MRF.NS', 'RADICO.NS', 'RAIN.NS', 'RAMCOCEM.NS', 'RELAXO.NS', 'SANOFI.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TATAELXSI.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS', 'VGUARD.NS', 'VMART.NS', 'VOLTAS.NS', 'VTL.NS', 'WHIRLPOOL.NS', 'ZENSARTECH.NS', 'ZFCVINDIA.NS'],
'2018-02-01': ['ABBOTINDIA.NS', 'APLLTD.NS', 'BIOCON.NS', 'BSOFT.NS', 'DEEPAKNTR.NS', 'FACT.NS', 'GPIL.NS', 'HCLTECH.NS', 'ICICIBANK.NS', 'IIFL.NS', 'INDUSINDBK.NS', 'INFY.NS', 'IOC.NS', 'JINDALSTEL.NS', 'JUBLPHARMA.NS', 'MASTEK.NS', 'PERSISTENT.NS', 'PHOENIXLTD.NS', 'RADICO.NS', 'SANOFI.NS', 'SONATSOFTW.NS', 'TATAELXSI.NS', 'VBL.NS', 'YESBANK.NS'],
'2018-03-01': ['ASHOKLEY.NS', 'BHARATFORG.NS', 'BRITANNIA.NS', 'CANFINHOME.NS', 'ENDURANCE.NS', 'FDC.NS', 'FSL.NS', 'GAEL.NS', 'INDIGO.NS', 'INFY.NS', 'KEC.NS', 'LTIM.NS', 'MASTEK.NS', 'PERSISTENT.NS', 'PGHL.NS', 'SANOFI.NS', 'SUNDARMFIN.NS', 'ZYDUSWELL.NS'],
'2018-04-01': ['ASTRAL.NS', 'BRITANNIA.NS', 'HEG.NS', 'INDUSINDBK.NS', 'JKLAKSHMI.NS', 'LAXMIMACH.NS', 'PNBHOUSING.NS', 'SANOFI.NS', 'VINATIORGA.NS', 'VMART.NS'],
'2018-05-01': ['ABBOTINDIA.NS', 'AEGISCHEM.NS', 'APARINDS.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BATAINDIA.NS', 'BHARATFORG.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'CIPLA.NS', 'COLPAL.NS', 'DIVISLAB.NS', 'DMART.NS', 'EICHERMOT.NS', 'GNFC.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'HONAUT.NS', 'INDUSINDBK.NS', 'IPCALAB.NS', 'JSWSTEEL.NS', 'LT.NS', 'LTIM.NS', 'LTTS.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'OFSS.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'RADICO.NS', 'RAYMOND.NS', 'RELAXO.NS', 'SHRIRAMFIN.NS', 'SONATSOFTW.NS', 'SUNDARMFIN.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'ZFCVINDIA.NS'],
'2018-06-01': ['ABBOTINDIA.NS', 'ASIANPAINT.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BBTC.NS', 'BERGEPAINT.NS', 'COALINDIA.NS', 'COFORGE.NS', 'DMART.NS', 'GODREJCP.NS', 'HEG.NS', 'INDUSINDBK.NS', 'INFY.NS', 'KRBL.NS', 'MCX.NS', 'MHRIL.NS', 'MPHASIS.NS', 'NESTLEIND.NS', 'PAGEIND.NS', 'PFIZER.NS', 'PIDILITIND.NS', 'RADICO.NS', 'SONATSOFTW.NS', 'TATAELXSI.NS', 'TCS.NS', 'TECHM.NS', 'TORNTPOWER.NS', 'VINATIORGA.NS', 'VMART.NS', 'ZENSARTECH.NS'],
'2018-07-01': ['BATAINDIA.NS', 'CIPLA.NS', 'GLAXO.NS', 'HINDUNILVR.NS', 'INFY.NS', 'JYOTHYLAB.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'LUPIN.NS', 'PAGEIND.NS', 'TCS.NS'],
'2018-08-01': ['ABBOTINDIA.NS', 'ACC.NS', 'ADANIPORTS.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'ALOKINDS.NS', 'AMBUJACEM.NS', 'APLLTD.NS', 'ASTRAL.NS', 'BATAINDIA.NS', 'BERGEPAINT.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'COFORGE.NS', 'DMART.NS', 'ENDURANCE.NS', 'GAIL.NS', 'GILLETTE.NS', 'GODREJIND.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GSPL.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'ICICIBANK.NS', 'ICICIPRULI.NS', 'IPCALAB.NS', 'LTIM.NS', 'LTTS.NS', 'M&MFIN.NS', 'MARICO.NS', 'MCX.NS', 'MGL.NS', 'NESTLEIND.NS', 'NH.NS', 'PCBL.NS', 'PFC.NS', 'POLYMED.NS', 'RADICO.NS', 'RECLTD.NS', 'SBIN.NS', 'TANLA.NS', 'TORNTPHARM.NS', 'TTKPRESTIG.NS', 'ULTRACEMCO.NS', 'VIPIND.NS'],
'2018-09-01': ['ABB.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'APOLLOHOSP.NS', 'ATUL.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BBTC.NS', 'BHARATFORG.NS', 'BRITANNIA.NS', 'CCL.NS', 'CENTURYTEX.NS', 'DLF.NS', 'DRREDDY.NS', 'ENDURANCE.NS', 'GODFRYPHLP.NS', 'GODREJIND.NS', 'GPIL.NS', 'GRINDWELL.NS', 'HCLTECH.NS', 'HONAUT.NS', 'INFY.NS', 'INGERRAND.NS', 'JUBLFOOD.NS', 'LALPATHLAB.NS', 'LT.NS', 'LUPIN.NS', 'MPHASIS.NS', 'NAUKRI.NS', 'OLECTRA.NS', 'PAGEIND.NS', 'PIDILITIND.NS', 'POWERGRID.NS', 'RAJESHEXPO.NS', 'SANOFI.NS', 'SFL.NS', 'SHOPERSTOP.NS', 'SRF.NS', 'TORNTPOWER.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'VBL.NS', 'VGUARD.NS', 'VMART.NS', 'WHIRLPOOL.NS'],
'2018-10-01': ['DEEPAKNTR.NS', 'LTTS.NS', 'TCS.NS', 'WIPRO.NS'],
'2018-11-01': ['CANBK.NS', 'CGCL.NS', 'COROMANDEL.NS', 'CUMMINSIND.NS', 'FEDERALBNK.NS', 'GAEL.NS', 'GAIL.NS', 'GESHIP.NS', 'INTELLECT.NS', 'IOB.NS', 'JINDALSAW.NS', 'MAHABANK.NS', 'NLCINDIA.NS', 'PRAJIND.NS', 'RECLTD.NS', 'RELAXO.NS', 'SRF.NS', 'TATAPOWER.NS', 'TORNTPOWER.NS', 'TRIVENI.NS', 'UCOBANK.NS', 'USHAMART.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'WIPRO.NS'],
'2018-12-01': ['ABB.NS', 'ADANIPORTS.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'BAJFINANCE.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'CENTURYTEX.NS', 'CGCL.NS', 'CUMMINSIND.NS', 'DMART.NS', 'DRREDDY.NS', 'FEDERALBNK.NS', 'FORTIS.NS', 'GODREJIND.NS', 'HAVELLS.NS', 'HINDUNILVR.NS', 'INDIGO.NS', 'JUBLPHARMA.NS', 'KANSAINER.NS', 'KOTAKBANK.NS', 'MARICO.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'PIDILITIND.NS', 'PRESTIGE.NS', 'RAYMOND.NS', 'SHREECEM.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TTKPRESTIG.NS', 'UPL.NS', 'VIPIND.NS', 'VMART.NS', 'ZEEL.NS'],
'2019-01-01': ['ABFRL.NS', 'ADANIPORTS.NS', 'ALOKINDS.NS', 'ASTRAL.NS', 'BAJAJFINSV.NS', 'BANKBARODA.NS', 'BHEL.NS', 'BPCL.NS', 'BRIGADE.NS', 'CANBK.NS', 'CENTRALBK.NS', 'CGPOWER.NS', 'CONCOR.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'FEDERALBNK.NS', 'GSFC.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'IDFC.NS', 'INDHOTEL.NS', 'IRB.NS', 'JKLAKSHMI.NS', 'JMFINANCIL.NS', 'L&TFH.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MGL.NS', 'MINDACORP.NS', 'MMTC.NS', 'PFC.NS', 'PIIND.NS', 'PNB.NS', 'PNCINFRA.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'RECLTD.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'VBL.NS', 'VTL.NS'],
'2019-02-01': ['AARTIIND.NS', 'CHAMBLFERT.NS', 'COFORGE.NS', 'EIHOTEL.NS', 'INFY.NS', 'JINDALSAW.NS', 'PFIZER.NS', 'RAJESHEXPO.NS', 'TITAN.NS'],
'2019-03-01': ['ABFRL.NS', 'BAJAJ-AUTO.NS', 'CARBORUNIV.NS', 'CIPLA.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'DIVISLAB.NS', 'ELGIEQUIP.NS', 'GRANULES.NS', 'IOC.NS', 'JSL.NS', 'JUBLPHARMA.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'NMDC.NS', 'OIL.NS', 'ONGC.NS', 'PERSISTENT.NS', 'PFC.NS', 'PIIND.NS', 'QUESS.NS', 'RECLTD.NS', 'REDINGTON.NS', 'SRF.NS', 'SUPREMEIND.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'TANLA.NS', 'TRIVENI.NS', 'VOLTAS.NS', 'YESBANK.NS', 'ZFCVINDIA.NS'],
'2019-04-01': ['3MINDIA.NS', 'ADANIPORTS.NS', 'AIAENG.NS', 'AMBUJACEM.NS', 'ASIANPAINT.NS', 'ATUL.NS', 'BERGEPAINT.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'CARBORUNIV.NS', 'CDSL.NS', 'CENTURYTEX.NS', 'COCHINSHIP.NS', 'DEEPAKNTR.NS', 'ECLERX.NS', 'FINCABLES.NS', 'GILLETTE.NS', 'GODREJIND.NS', 'GSPL.NS', 'HCLTECH.NS', 'IBULHSGFIN.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'IDFC.NS', 'IGL.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'INGERRAND.NS', 'IOC.NS', 'ITC.NS', 'JKCEMENT.NS', 'JUBLFOOD.NS', 'KEC.NS', 'KEI.NS', 'KOTAKBANK.NS', 'L&TFH.NS', 'LUXIND.NS', 'MCX.NS', 'MHRIL.NS', 'NAM-INDIA.NS', 'NTPC.NS', 'PETRONET.NS', 'PFIZER.NS', 'PGHH.NS', 'PGHL.NS', 'PIDILITIND.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'RAMCOCEM.NS', 'RELIANCE.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SYMPHONY.NS', 'TATACOMM.NS', 'USHAMART.NS'],
'2019-05-01': ['ADANIPORTS.NS', 'AUROPHARMA.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BALRAMCHIN.NS', 'BATAINDIA.NS', 'CHOLAHLDNG.NS', 'CIPLA.NS', 'COALINDIA.NS', 'DCMSHRIRAM.NS', 'ECLERX.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GUJGASLTD.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HINDPETRO.NS', 'HINDUNILVR.NS', 'ICICIBANK.NS', 'ICICIPRULI.NS', 'INDIGO.NS', 'INTELLECT.NS', 'JKLAKSHMI.NS', 'JSWSTEEL.NS', 'KOTAKBANK.NS', 'MASTEK.NS', 'MOTILALOFS.NS', 'PIIND.NS', 'POONAWALLA.NS', 'RAMCOCEM.NS', 'RBLBANK.NS', 'REDINGTON.NS', 'RELIANCE.NS', 'SBILIFE.NS', 'SIEMENS.NS', 'SYNGENE.NS', 'TRIVENI.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'VINATIORGA.NS', 'VMART.NS'],
'2019-06-01': ['ADANIENT.NS', 'ADANIPORTS.NS', 'ALKEM.NS', 'APLAPOLLO.NS', 'ASTRAL.NS', 'BALRAMCHIN.NS', 'BERGEPAINT.NS', 'BPCL.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'CONCOR.NS', 'CUB.NS', 'DIXON.NS', 'ELGIEQUIP.NS', 'FDC.NS', 'GILLETTE.NS', 'GSFC.NS', 'HAL.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'ICICIBANK.NS', 'ICICIPRULI.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'IOC.NS', 'JBCHEPHARM.NS', 'JKLAKSHMI.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KEC.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'NAM-INDIA.NS', 'NAVINFLUOR.NS', 'NHPC.NS', 'PFC.NS', 'PGHH.NS', 'PIDILITIND.NS', 'PIIND.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'PRESTIGE.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'RCF.NS', 'SHOPERSTOP.NS', 'SIEMENS.NS', 'SJVN.NS', 'SOLARINDS.NS', 'SONATSOFTW.NS', 'SRF.NS', 'SUNTECK.NS', 'TCS.NS', 'TRENT.NS', 'TRIVENI.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'VBL.NS', 'ZENSARTECH.NS'],
'2019-07-01': ['ABB.NS', 'BATAINDIA.NS', 'BDL.NS', 'CANBK.NS', 'CESC.NS', 'COFORGE.NS', 'CUB.NS', 'FEDERALBNK.NS', 'GODREJPROP.NS', 'ICICIBANK.NS', 'INDHOTEL.NS', 'INTELLECT.NS', 'LT.NS', 'LTIM.NS', 'NH.NS', 'OBEROIRLTY.NS', 'PFC.NS', 'PFIZER.NS', 'PGHL.NS', 'PNCINFRA.NS', 'POWERGRID.NS', 'RATNAMANI.NS', 'REDINGTON.NS', 'SBILIFE.NS', 'SBIN.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SRF.NS', 'SUNDARMFIN.NS', 'SUPREMEIND.NS', 'TATACHEM.NS', 'VGUARD.NS', 'VINATIORGA.NS', 'VOLTAS.NS', 'WHIRLPOOL.NS'],
'2019-08-01': ['EPL.NS', 'ICICIGI.NS', 'INFY.NS', 'NAM-INDIA.NS', 'SANOFI.NS', 'SBILIFE.NS', 'VAIBHAVGBL.NS'],
'2019-09-01': ['AJANTPHARM.NS', 'ALKEM.NS', 'APOLLOHOSP.NS', 'ASTRAL.NS', 'CANFINHOME.NS', 'DABUR.NS', 'DELTACORP.NS', 'DMART.NS', 'GALAXYSURF.NS', 'GMMPFAUDLR.NS', 'GODFRYPHLP.NS', 'GSPL.NS', 'HCLTECH.NS', 'HDFCLIFE.NS', 'HINDUNILVR.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'IGL.NS', 'INDIGO.NS', 'INFY.NS', 'JBCHEPHARM.NS', 'LALPATHLAB.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'NAVINFLUOR.NS', 'PEL.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'RELAXO.NS', 'SBILIFE.NS', 'SUNPHARMA.NS', 'SWANENERGY.NS', 'TATACONSUM.NS', 'TORNTPHARM.NS', 'TRENT.NS', 'UNOMINDA.NS', 'VIPIND.NS', 'VOLTAS.NS'],
'2019-10-01': ['ABBOTINDIA.NS', 'AIAENG.NS', 'AMBER.NS', 'ATUL.NS', 'BEML.NS', 'BLUEDART.NS', 'BLUESTARCO.NS', 'BORORENEW.NS', 'CENTURYPLY.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'CUB.NS', 'GLAXO.NS', 'GODREJCP.NS', 'GODREJPROP.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HINDPETRO.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'IOC.NS', 'JYOTHYLAB.NS', 'KSB.NS', 'LALPATHLAB.NS', 'MAHLIFE.NS', 'MGL.NS', 'MRF.NS', 'PAGEIND.NS', 'PFIZER.NS', 'PIIND.NS', 'RELIANCE.NS', 'RHIM.NS', 'TEAMLEASE.NS', 'TIMKEN.NS', 'TITAN.NS', 'VIPIND.NS', 'VOLTAS.NS'],
'2019-11-01': ['3MINDIA.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'ASIANPAINT.NS', 'ATUL.NS', 'AXISBANK.NS', 'BAJFINANCE.NS', 'BANDHANBNK.NS', 'BLUESTARCO.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'CEATLTD.NS', 'CERA.NS', 'COLPAL.NS', 'DIVISLAB.NS', 'DIXON.NS', 'ENDURANCE.NS', 'ESCORTS.NS', 'FINEORG.NS', 'GALAXYSURF.NS', 'GODFRYPHLP.NS', 'HAL.NS', 'HDFCAMC.NS', 'HDFCLIFE.NS', 'HINDPETRO.NS', 'ICICIGI.NS', 'JUBLPHARMA.NS', 'JYOTHYLAB.NS', 'KSB.NS', 'LALPATHLAB.NS', 'M&M.NS', 'MARUTI.NS', 'MINDACORP.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'OIL.NS', 'PERSISTENT.NS', 'PGHH.NS', 'PIIND.NS', 'POLYPLEX.NS', 'RAMCOCEM.NS', 'SBIN.NS', 'SKFINDIA.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUNTV.NS', 'SYNGENE.NS', 'TATAINVEST.NS', 'TIINDIA.NS', 'TITAN.NS', 'UNOMINDA.NS', 'VARROC.NS', 'VOLTAS.NS', 'WIPRO.NS'],
'2019-12-01': ['AAVAS.NS', 'ABBOTINDIA.NS', 'AMBER.NS', 'AUBANK.NS', 'BAJAJFINSV.NS', 'BALKRISIND.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'BOSCHLTD.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CUB.NS', 'DELTACORP.NS', 'DIXON.NS', 'EICHERMOT.NS', 'GLAXO.NS', 'GODFRYPHLP.NS', 'GPPL.NS', 'HDFCAMC.NS', 'ICICIBANK.NS', 'INDUSINDBK.NS', 'IPCALAB.NS', 'LICHSGFIN.NS', 'LINDEINDIA.NS', 'LUPIN.NS', 'LUXIND.NS', 'MASTEK.NS', 'MFSL.NS', 'MGL.NS', 'MOTILALOFS.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PIIND.NS', 'PNCINFRA.NS', 'RATNAMANI.NS', 'RELIANCE.NS', 'SANOFI.NS', 'SBIN.NS', 'SHREECEM.NS', 'SRF.NS', 'TATACONSUM.NS', 'TORNTPHARM.NS'],
'2020-01-01': ['AARTIDRUGS.NS', 'AAVAS.NS', 'ALKYLAMINE.NS', 'ASTERDM.NS', 'ATGL.NS', 'AVANTIFEED.NS', 'BAJAJFINSV.NS', 'BALAMINES.NS', 'BERGEPAINT.NS', 'BIOCON.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'DCMSHRIRAM.NS', 'DEEPAKNTR.NS', 'DIXON.NS', 'DLF.NS', 'ECLERX.NS', 'FDC.NS', 'GODREJPROP.NS', 'HDFCLIFE.NS', 'HINDALCO.NS', 'ICICIBANK.NS', 'JBCHEPHARM.NS', 'JUBLFOOD.NS', 'KEC.NS', 'L&TFH.NS', 'MANAPPURAM.NS', 'MASTEK.NS', 'MFSL.NS', 'MOTHERSON.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NAVINFLUOR.NS', 'PHOENIXLTD.NS', 'POLYPLEX.NS', 'RELAXO.NS', 'RHIM.NS', 'SAIL.NS', 'SCHAEFFLER.NS', 'SUNDRMFAST.NS', 'SUPRAJIT.NS', 'SWANENERGY.NS', 'TANLA.NS', 'TATAMOTORS.NS', 'TRIVENI.NS', 'ZFCVINDIA.NS'],
'2020-02-01': ['3MINDIA.NS', 'ADANIENT.NS', 'AIAENG.NS', 'ALLCARGO.NS', 'ALOKINDS.NS', 'ASTRAL.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BAYERCROP.NS', 'BERGEPAINT.NS', 'BHARTIARTL.NS', 'BLUEDART.NS', 'BRITANNIA.NS', 'CERA.NS', 'DALBHARAT.NS', 'DRREDDY.NS', 'EIDPARRY.NS', 'ERIS.NS', 'GRINDWELL.NS', 'INGERRAND.NS', 'INTELLECT.NS', 'KAJARIACER.NS', 'KEC.NS', 'KEI.NS', 'KSB.NS', 'LALPATHLAB.NS', 'LTTS.NS', 'M&MFIN.NS', 'MANAPPURAM.NS', 'MGL.NS', 'MRF.NS', 'NAVINFLUOR.NS', 'PIIND.NS', 'POLYMED.NS', 'RAJESHEXPO.NS', 'RHIM.NS', 'SHOPERSTOP.NS', 'SHREECEM.NS', 'SOBHA.NS', 'SUNDRMFAST.NS', 'TANLA.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TIMKEN.NS', 'TRENT.NS', 'TRIVENI.NS', 'VINATIORGA.NS', 'VTL.NS', 'WHIRLPOOL.NS'],
'2020-03-01': ['AJANTPHARM.NS', 'ALKEM.NS', 'ATUL.NS', 'CANFINHOME.NS', 'DIVISLAB.NS', 'INDIACEM.NS', 'MFSL.NS', 'MUTHOOTFIN.NS', 'NAVINFLUOR.NS', 'NLCINDIA.NS', 'ORIENTELEC.NS', 'SANOFI.NS', 'SFL.NS', 'TRENT.NS'],
'2020-04-01': ['PATANJALI.NS'],
'2020-05-01': ['AARTIDRUGS.NS', 'ABBOTINDIA.NS', 'APLLTD.NS', 'AUROPHARMA.NS', 'BIOCON.NS', 'BRITANNIA.NS', 'CIPLA.NS', 'DIXON.NS', 'DRREDDY.NS', 'ERIS.NS', 'GLENMARK.NS', 'GMMPFAUDLR.NS', 'GUJALKALI.NS', 'HEROMOTOCO.NS', 'LUPIN.NS', 'MUTHOOTFIN.NS', 'NAVINFLUOR.NS', 'PFIZER.NS', 'PIIND.NS', 'RELIANCE.NS', 'SANOFI.NS', 'SYNGENE.NS', 'VINATIORGA.NS'],
'2020-06-01': ['APLLTD.NS', 'AUROPHARMA.NS', 'BALKRISIND.NS', 'BRITANNIA.NS', 'CIPLA.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'GLENMARK.NS', 'GODREJCP.NS', 'HEROMOTOCO.NS', 'LTIM.NS', 'MUTHOOTFIN.NS', 'NESTLEIND.NS', 'OFSS.NS', 'PATANJALI.NS', 'PETRONET.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'VINATIORGA.NS'],
'2020-07-01': ['ABCAPITAL.NS', 'ATGL.NS', 'AVANTIFEED.NS', 'BALRAMCHIN.NS', 'BANKINDIA.NS', 'BHEL.NS', 'BSE.NS', 'BSOFT.NS', 'CCL.NS', 'CENTRALBK.NS', 'CIEINDIA.NS', 'COCHINSHIP.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FDC.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'GAIL.NS', 'GLENMARK.NS', 'GPIL.NS', 'GPPL.NS', 'GSFC.NS', 'HINDCOPPER.NS', 'IBULHSGFIN.NS', 'IDEA.NS', 'INDIANB.NS', 'INTELLECT.NS', 'IRB.NS', 'ITI.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'KARURVYSYA.NS', 'KEI.NS', 'KPITTECH.NS', 'KRBL.NS', 'MANAPPURAM.NS', 'MINDACORP.NS', 'MMTC.NS', 'MRPL.NS', 'NETWORK18.NS', 'POLYPLEX.NS', 'PRSMJOHNSN.NS', 'RCF.NS', 'RHIM.NS', 'SONATSOFTW.NS', 'SUNDRMFAST.NS', 'SUPRAJIT.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAPOWER.NS', 'TRIDENT.NS', 'TRIVENI.NS', 'TTML.NS', 'TV18BRDCST.NS', 'TVSMOTOR.NS', 'UCOBANK.NS', 'USHAMART.NS', 'VEDL.NS', 'WELSPUNLIV.NS'],
'2020-08-01': ['3MINDIA.NS', 'ACC.NS', 'ADANIENT.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'AMBUJACEM.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'ATUL.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'BALKRISIND.NS', 'BBTC.NS', 'BLS.NS', 'BRITANNIA.NS', 'BSE.NS', 'CIPLA.NS', 'COROMANDEL.NS', 'DABUR.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'ERIS.NS', 'FDC.NS', 'FORTIS.NS', 'GAEL.NS', 'GALAXYSURF.NS', 'GLENMARK.NS', 'GODREJPROP.NS', 'GRANULES.NS', 'HDFCLIFE.NS', 'HINDZINC.NS', 'IPCALAB.NS', 'JBCHEPHARM.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JSWSTEEL.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LTTS.NS', 'M&M.NS', 'MARICO.NS', 'MARUTI.NS', 'MUTHOOTFIN.NS', 'NAUKRI.NS', 'PEL.NS', 'PIIND.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'QUESS.NS', 'RELIANCE.NS', 'SBILIFE.NS', 'SHARDACROP.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TATASTEEL.NS', 'TCS.NS', 'TORNTPHARM.NS', 'TTKPRESTIG.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'VAIBHAVGBL.NS', 'VOLTAS.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2020-09-01': ['AARTIDRUGS.NS', 'ADANIPORTS.NS', 'AEGISCHEM.NS', 'AIAENG.NS', 'ALKYLAMINE.NS', 'ATUL.NS', 'AVANTIFEED.NS', 'BALAMINES.NS', 'BCG.NS', 'CARBORUNIV.NS', 'CENTURYPLY.NS', 'CERA.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'ENDURANCE.NS', 'GAEL.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GRANULES.NS', 'GRASIM.NS', 'GUJGASLTD.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS', 'ICICIBANK.NS', 'IDEA.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'INFIBEAM.NS', 'JSWENERGY.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'KEI.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'LTIM.NS', 'MAHABANK.NS', 'MARUTI.NS', 'MASTEK.NS', 'ORIENTELEC.NS', 'PGHL.NS', 'POLYPLEX.NS', 'PRESTIGE.NS', 'RHIM.NS', 'SAREGAMA.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'TATACOMM.NS', 'TATAELXSI.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TRENT.NS', 'TRITURBINE.NS', 'UNOMINDA.NS', 'UPL.NS', 'VAIBHAVGBL.NS', 'VARROC.NS', 'WELCORP.NS', 'ZEEL.NS', 'ZENSARTECH.NS'],
'2020-10-01': ['AARTIDRUGS.NS', 'ADANIENT.NS', 'ALLCARGO.NS', 'ASTRAL.NS', 'BALKRISIND.NS', 'BERGEPAINT.NS', 'BSOFT.NS', 'CDSL.NS', 'CEATLTD.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'CREDITACC.NS', 'CROMPTON.NS', 'DEEPAKNTR.NS', 'ELGIEQUIP.NS', 'ENDURANCE.NS', 'ESCORTS.NS', 'FSL.NS', 'GAEL.NS', 'GODREJCP.NS', 'GRANULES.NS', 'GRASIM.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HEROMOTOCO.NS', 'IDFC.NS', 'IEX.NS', 'INDIAMART.NS', 'INFY.NS', 'JBCHEPHARM.NS', 'JUBLFOOD.NS', 'KEC.NS', 'KPRMILL.NS', 'KRBL.NS', 'LUXIND.NS', 'MASTEK.NS', 'MPHASIS.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'NCC.NS', 'NH.NS', 'PAGEIND.NS', 'PCBL.NS', 'PNBHOUSING.NS', 'RATNAMANI.NS', 'SAREGAMA.NS', 'SIEMENS.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATAELXSI.NS', 'TATAMTRDVR.NS', 'TCS.NS', 'TECHM.NS', 'TITAN.NS', 'TVSMOTOR.NS', 'VAIBHAVGBL.NS', 'VEDL.NS', 'WELCORP.NS', 'ZENSARTECH.NS', 'ZYDUSWELL.NS'],
'2020-11-01': ['ABFRL.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'AUBANK.NS', 'AXISBANK.NS', 'BERGEPAINT.NS', 'CANFINHOME.NS', 'CDSL.NS', 'CEATLTD.NS', 'CERA.NS', 'COLPAL.NS', 'CROMPTON.NS', 'DALBHARAT.NS', 'DMART.NS', 'GODREJPROP.NS', 'GRANULES.NS', 'GRASIM.NS', 'HCLTECH.NS', 'INTELLECT.NS', 'IPCALAB.NS', 'JKLAKSHMI.NS', 'JSWSTEEL.NS', 'LALPATHLAB.NS', 'LAURUSLABS.NS', 'LAXMIMACH.NS', 'LINDEINDIA.NS', 'MASTEK.NS', 'METROPOLIS.NS', 'MPHASIS.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'OBEROIRLTY.NS', 'ORIENTELEC.NS', 'PIDILITIND.NS', 'PIIND.NS', 'POLYCAB.NS', 'RAMCOCEM.NS', 'SHREECEM.NS', 'SOBHA.NS', 'SRF.NS', 'SUNDARMFIN.NS', 'SUPREMEIND.NS', 'TATACHEM.NS', 'TATAELXSI.NS', 'TCS.NS', 'TIINDIA.NS', 'ULTRACEMCO.NS', 'VAIBHAVGBL.NS', 'VOLTAS.NS', 'WIPRO.NS', 'ZYDUSWELL.NS'],
'2020-12-01': ['ADANIPOWER.NS', 'ALLCARGO.NS', 'ASHOKLEY.NS', 'BALAMINES.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BHEL.NS', 'BSOFT.NS', 'CIEINDIA.NS', 'DCMSHRIRAM.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'FEDERALBNK.NS', 'FSL.NS', 'GMRINFRA.NS', 'GPPL.NS', 'GSFC.NS', 'HEG.NS', 'HFCL.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IBULHSGFIN.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'IRCON.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JSL.NS', 'KARURVYSYA.NS', 'KPRMILL.NS', 'LEMONTREE.NS', 'MAHABANK.NS', 'MAHLIFE.NS', 'MMTC.NS', 'MRPL.NS', 'NBCC.NS', 'NHPC.NS', 'NMDC.NS', 'NTPC.NS', 'OIL.NS', 'OLECTRA.NS', 'ONGC.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'RAIN.NS', 'RCF.NS', 'RHIM.NS', 'SHOPERSTOP.NS', 'SOBHA.NS', 'STLTECH.NS', 'TEJASNET.NS', 'TTML.NS', 'WELCORP.NS', 'YESBANK.NS'],
'2021-01-01': ['ADANIENT.NS', 'ASAHIINDIA.NS', 'BANKBARODA.NS', 'BEL.NS', 'BHEL.NS', 'BLUESTARCO.NS', 'BSE.NS', 'CANBK.NS', 'CENTURYPLY.NS', 'CIEINDIA.NS', 'DELTACORP.NS', 'ELGIEQUIP.NS', 'EXIDEIND.NS', 'FACT.NS', 'FINPIPE.NS', 'GAIL.NS', 'GPIL.NS', 'GRAPHITE.NS', 'HEG.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'IBULHSGFIN.NS', 'IEX.NS', 'INFIBEAM.NS', 'INTELLECT.NS', 'JAMNAAUTO.NS', 'JSL.NS', 'JUBLFOOD.NS', 'JUBLPHARMA.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'L&TFH.NS', 'MHRIL.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NCC.NS', 'NMDC.NS', 'PCBL.NS', 'RCF.NS', 'RECLTD.NS', 'RHIM.NS', 'RVNL.NS', 'SONATSOFTW.NS', 'STLTECH.NS', 'SUNTECK.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAMOTORS.NS', 'TATAPOWER.NS', 'TEJASNET.NS', 'TRIDENT.NS', 'TTKPRESTIG.NS', 'UNOMINDA.NS', 'ZEEL.NS'],
'2021-02-01': ['ALKYLAMINE.NS', 'ASTRAL.NS', 'ATGL.NS', 'BAJAJHLDNG.NS', 'BORORENEW.NS', 'CENTURYPLY.NS', 'CHAMBLFERT.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'ENDURANCE.NS', 'FACT.NS', 'GAEL.NS', 'HAVELLS.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'INDIAMART.NS', 'JKPAPER.NS', 'JYOTHYLAB.NS', 'KPITTECH.NS', 'LT.NS', 'MHRIL.NS', 'NATIONALUM.NS', 'OLECTRA.NS', 'ORIENTELEC.NS', 'PCBL.NS', 'PGHL.NS', 'POLYCAB.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RVNL.NS', 'SFL.NS', 'SHRIRAMFIN.NS', 'SOBHA.NS', 'SUPREMEIND.NS', 'TEAMLEASE.NS', 'TEJASNET.NS', 'THERMAX.NS', 'TRIDENT.NS', 'UNOMINDA.NS', 'UPL.NS', 'VARROC.NS'],
'2021-03-01': ['360ONE.NS', '3MINDIA.NS', 'AAVAS.NS', 'ABB.NS', 'ADANIGREEN.NS', 'AEGISCHEM.NS', 'APOLLOHOSP.NS', 'AUBANK.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'CARBORUNIV.NS', 'CEATLTD.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CGCL.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'COALINDIA.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'ELGIEQUIP.NS', 'FACT.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GSPL.NS', 'HAL.NS', 'HONAUT.NS', 'HUDCO.NS', 'IEX.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'INTELLECT.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'KARURVYSYA.NS', 'KEC.NS', 'L&TFH.NS', 'MINDACORP.NS', 'NCC.NS', 'NMDC.NS', 'ONGC.NS', 'PEL.NS', 'PGHH.NS', 'PNBHOUSING.NS', 'POLYCAB.NS', 'POLYPLEX.NS', 'RAJESHEXPO.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'SANOFI.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SKFINDIA.NS', 'STLTECH.NS', 'SUPREMEIND.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TEAMLEASE.NS', 'TEJASNET.NS', 'TTKPRESTIG.NS', 'UNOMINDA.NS', 'VBL.NS', 'WESTLIFE.NS'],
'2021-04-01': ['360ONE.NS', 'AAVAS.NS', 'ACC.NS', 'AIAENG.NS', 'ALKYLAMINE.NS', 'AMBUJACEM.NS', 'ATUL.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'CANFINHOME.NS', 'CDSL.NS', 'CENTURYPLY.NS', 'CGCL.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'CONCOR.NS', 'CUMMINSIND.NS', 'DEEPAKFERT.NS', 'FORTIS.NS', 'FSL.NS', 'GILLETTE.NS', 'GRAPHITE.NS', 'GRINDWELL.NS', 'GSPL.NS', 'HINDUNILVR.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JSWENERGY.NS', 'LALPATHLAB.NS', 'MPHASIS.NS', 'ORIENTELEC.NS', 'PERSISTENT.NS', 'POLYCAB.NS', 'POLYMED.NS', 'SAIL.NS', 'SHREECEM.NS', 'SONATSOFTW.NS', 'TATACHEM.NS', 'TATASTEEL.NS', 'TORNTPOWER.NS', 'VGUARD.NS', 'ZFCVINDIA.NS'],
'2021-05-01': ['ADANIENT.NS', 'ADANIPOWER.NS', 'ATGL.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'BAJAJFINSV.NS', 'BALKRISIND.NS', 'CARBORUNIV.NS', 'CENTURYPLY.NS', 'CIPLA.NS', 'CYIENT.NS', 'DEEPAKFERT.NS', 'DIXON.NS', 'DRREDDY.NS', 'GAEL.NS', 'HINDCOPPER.NS', 'ICICIPRULI.NS', 'IDFC.NS', 'IEX.NS', 'ISEC.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'LAURUSLABS.NS', 'MRPL.NS', 'NATIONALUM.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PRAJIND.NS', 'PRINCEPIPE.NS', 'RAIN.NS', 'SONATSOFTW.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SUNTV.NS', 'SUVENPHAR.NS', 'TATACHEM.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TV18BRDCST.NS', 'TVSMOTOR.NS', 'WIPRO.NS', 'ZFCVINDIA.NS'],
'2021-06-01': ['ADANIENT.NS', 'ALKYLAMINE.NS', 'ASTRAL.NS', 'ATGL.NS', 'ATUL.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BALAMINES.NS', 'BBTC.NS', 'BERGEPAINT.NS', 'BHEL.NS', 'BLUEDART.NS', 'BPCL.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'COFORGE.NS', 'EIHOTEL.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'GAIL.NS', 'GODREJCP.NS', 'GPPL.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'HFCL.NS', 'HINDPETRO.NS', 'ICICIBANK.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'IOC.NS', 'JSWENERGY.NS', 'JSWSTEEL.NS', 'JUSTDIAL.NS', 'LEMONTREE.NS', 'LICHSGFIN.NS', 'LUPIN.NS', 'MARICO.NS', 'METROPOLIS.NS', 'MMTC.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NLCINDIA.NS', 'PNB.NS', 'POLYCAB.NS', 'PRAJIND.NS', 'RECLTD.NS', 'RENUKA.NS', 'SHOPERSTOP.NS', 'SIEMENS.NS', 'SJVN.NS', 'STLTECH.NS', 'SUPREMEIND.NS', 'TATAELXSI.NS', 'TRENT.NS', 'TRIVENI.NS', 'TTML.NS', 'TV18BRDCST.NS', 'UNOMINDA.NS', 'ZYDUSLIFE.NS'],
'2021-07-01': ['ABBOTINDIA.NS', 'AJANTPHARM.NS', 'ASTRAL.NS', 'BHARATFORG.NS', 'CDSL.NS', 'CESC.NS', 'CSBBANK.NS', 'CYIENT.NS', 'DIVISLAB.NS', 'EPL.NS', 'FINCABLES.NS', 'FLUOROCHEM.NS', 'GMRINFRA.NS', 'GRINDWELL.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'ICICIPRULI.NS', 'IGL.NS', 'IRB.NS', 'ISEC.NS', 'JINDALSAW.NS', 'JKLAKSHMI.NS', 'JSL.NS', 'KEC.NS', 'KNRCON.NS', 'LALPATHLAB.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'MPHASIS.NS', 'NATCOPHARM.NS', 'OLECTRA.NS', 'PFIZER.NS', 'PIDILITIND.NS', 'PIIND.NS', 'PNCINFRA.NS', 'PRINCEPIPE.NS', 'RADICO.NS', 'REDINGTON.NS', 'RELAXO.NS', 'RITES.NS', 'RVNL.NS', 'SONATSOFTW.NS', 'SUZLON.NS', 'TATACOMM.NS', 'TECHM.NS', 'TRIVENI.NS', 'UBL.NS', 'UCOBANK.NS'],
'2021-08-01': ['AARTIIND.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'BALAMINES.NS', 'BALRAMCHIN.NS', 'BLS.NS', 'BORORENEW.NS', 'BSE.NS', 'CARBORUNIV.NS', 'CCL.NS', 'CDSL.NS', 'CESC.NS', 'CROMPTON.NS', 'DABUR.NS', 'DLF.NS', 'ERIS.NS', 'GAEL.NS', 'GODREJCP.NS', 'GRANULES.NS', 'GUJALKALI.NS', 'GUJGASLTD.NS', 'HINDALCO.NS', 'IIFL.NS', 'IRCTC.NS', 'JAMNAAUTO.NS', 'JINDALSAW.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'KANSAINER.NS', 'KNRCON.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'LT.NS', 'MARICO.NS', 'MFSL.NS', 'NATIONALUM.NS', 'OIL.NS', 'PCBL.NS', 'PIDILITIND.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'POONAWALLA.NS', 'PRESTIGE.NS', 'QUESS.NS', 'REDINGTON.NS', 'RHIM.NS', 'SAIL.NS', 'SAREGAMA.NS', 'SBILIFE.NS', 'SFL.NS', 'SHOPERSTOP.NS', 'SOLARINDS.NS', 'SPARC.NS', 'SUNTECK.NS', 'SUNTV.NS', 'USHAMART.NS', 'VEDL.NS', 'WELSPUNLIV.NS', 'WESTLIFE.NS', 'WIPRO.NS'],
'2021-09-01': ['360ONE.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'AFFLE.NS', 'AMBUJACEM.NS', 'ASIANPAINT.NS', 'AXISBANK.NS', 'BATAINDIA.NS', 'BCG.NS', 'CANFINHOME.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DALBHARAT.NS', 'ESCORTS.NS', 'FLUOROCHEM.NS', 'HAVELLS.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HINDALCO.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'INDIAMART.NS', 'INFY.NS', 'JSWENERGY.NS', 'JUBLFOOD.NS', 'KPITTECH.NS', 'LT.NS', 'MCDOWELL-N.NS', 'NAM-INDIA.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'OFSS.NS', 'OIL.NS', 'PIIND.NS', 'POWERINDIA.NS', 'RELIANCE.NS', 'ROSSARI.NS', 'SAFARI.NS', 'SANOFI.NS', 'SPARC.NS', 'SUNPHARMA.NS', 'TIMKEN.NS', 'TRENT.NS', 'ULTRACEMCO.NS', 'VBL.NS', 'ZENSARTECH.NS', 'ZYDUSWELL.NS'],
'2021-10-01': ['AMBER.NS', 'ASHOKLEY.NS', 'ATGL.NS', 'BALAMINES.NS', 'BEL.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIRLACORPN.NS', 'BLS.NS', 'BLUEDART.NS', 'BOSCHLTD.NS', 'BRIGADE.NS', 'CANBK.NS', 'CESC.NS', 'CHAMBLFERT.NS', 'CIPLA.NS', 'DEEPAKNTR.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'ESCORTS.NS', 'GAIL.NS', 'GPPL.NS', 'HAL.NS', 'HCLTECH.NS', 'HINDALCO.NS', 'INDIACEM.NS', 'INDIANB.NS', 'IOB.NS', 'IRCON.NS', 'ITI.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'LTIM.NS', 'M&M.NS', 'MARUTI.NS', 'MRPL.NS', 'NBCC.NS', 'PCBL.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PFC.NS', 'PHOENIXLTD.NS', 'PNCINFRA.NS', 'POLYCAB.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RCF.NS', 'SAFARI.NS', 'SBILIFE.NS', 'SJVN.NS', 'SOBHA.NS', 'SUNDRMFAST.NS', 'SYMPHONY.NS', 'TATACHEM.NS', 'TATAMOTORS.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'TRIVENI.NS', 'VIPIND.NS', 'WHIRLPOOL.NS'],
'2021-11-01': ['ABFRL.NS', 'ASHOKLEY.NS', 'BANKBARODA.NS', 'BCG.NS', 'BORORENEW.NS', 'CGCL.NS', 'EIHOTEL.NS', 'FEDERALBNK.NS', 'GMRINFRA.NS', 'GRINDWELL.NS', 'IIFL.NS', 'INDIANB.NS', 'INDIGO.NS', 'JAMNAAUTO.NS', 'JBMA.NS', 'JSL.NS', 'LEMONTREE.NS', 'NETWORK18.NS', 'RAJESHEXPO.NS', 'SBIN.NS', 'SUNTV.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TRIDENT.NS', 'TTML.NS', 'UNIONBANK.NS', 'USHAMART.NS'],
'2021-12-01': ['POLYMED.NS', 'POLYPLEX.NS', 'POWERGRID.NS', 'TANLA.NS', 'THERMAX.NS', 'WELCORP.NS'],
'2022-01-01': ['ABCAPITAL.NS', 'ALLCARGO.NS', 'ASIANPAINT.NS', 'BALRAMCHIN.NS', 'BCG.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'COFORGE.NS', 'DRREDDY.NS', 'ELGIEQUIP.NS', 'FACT.NS', 'FORTIS.NS', 'GALAXYSURF.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GRAPHITE.NS', 'GRINDWELL.NS', 'IDEA.NS', 'IDFC.NS', 'INFY.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JSL.NS', 'KAJARIACER.NS', 'LALPATHLAB.NS', 'LTIM.NS', 'NAVINFLUOR.NS', 'NH.NS', 'POONAWALLA.NS', 'RADICO.NS', 'RAIN.NS', 'SAREGAMA.NS', 'SHARDACROP.NS', 'SJVN.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SWANENERGY.NS', 'TANLA.NS', 'TATACOMM.NS', 'TCS.NS', 'TIINDIA.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'VTL.NS', 'ZENSARTECH.NS', 'ZFCVINDIA.NS'],
'2022-02-01': ['ANGELONE.NS', 'AUBANK.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BANDHANBNK.NS', 'BAYERCROP.NS', 'BLS.NS', 'CCL.NS', 'CHALET.NS', 'CHOLAHLDNG.NS', 'DCMSHRIRAM.NS', 'FEDERALBNK.NS', 'FLUOROCHEM.NS', 'HAL.NS', 'HEROMOTOCO.NS', 'INDHOTEL.NS', 'INGERRAND.NS', 'JBMA.NS', 'LAXMIMACH.NS', 'LINDEINDIA.NS', 'MARUTI.NS', 'MOTHERSON.NS', 'POONAWALLA.NS', 'POWERINDIA.NS', 'PRAJIND.NS', 'RAYMOND.NS', 'RHIM.NS', 'SBIN.NS', 'THERMAX.NS', 'TRIVENI.NS'],
'2022-03-01': ['FINEORG.NS', 'NH.NS', 'POWERINDIA.NS', 'RATNAMANI.NS', 'RHIM.NS'],
'2022-04-01': ['360ONE.NS', 'ADANIPORTS.NS', 'ALKEM.NS', 'ALLCARGO.NS', 'ASTERDM.NS', 'BCG.NS', 'BDL.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BSE.NS', 'CGPOWER.NS', 'CHALET.NS', 'COLPAL.NS', 'CONCOR.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'EPL.NS', 'FORTIS.NS', 'GAEL.NS', 'GAIL.NS', 'GPIL.NS', 'HAL.NS', 'INFY.NS', 'ITC.NS', 'JSWSTEEL.NS', 'LEMONTREE.NS', 'NMDC.NS', 'PCBL.NS', 'PERSISTENT.NS', 'RAYMOND.NS', 'RCF.NS', 'RELIANCE.NS', 'SAFARI.NS', 'SCHAEFFLER.NS', 'SHARDACROP.NS', 'SRF.NS', 'SUNPHARMA.NS', 'TATACONSUM.NS', 'TRENT.NS', 'TV18BRDCST.NS', 'VEDL.NS', 'VMART.NS'],
'2022-05-01': ['ABCAPITAL.NS', 'ACC.NS', 'AMBUJACEM.NS', 'BDL.NS', 'CESC.NS', 'CIEINDIA.NS', 'DEEPAKFERT.NS', 'EIDPARRY.NS', 'GAEL.NS', 'GESHIP.NS', 'GICRE.NS', 'GUJALKALI.NS', 'HAVELLS.NS', 'INDHOTEL.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'KSB.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'M&MFIN.NS', 'MAHLIFE.NS', 'MAXHEALTH.NS', 'MINDACORP.NS', 'NHPC.NS', 'NLCINDIA.NS', 'NTPC.NS', 'PATANJALI.NS', 'QUESS.NS', 'RELIANCE.NS', 'RENUKA.NS', 'SHOPERSTOP.NS', 'TIINDIA.NS', 'USHAMART.NS', 'VBL.NS', 'WELCORP.NS', 'ZYDUSWELL.NS'],
'2022-06-01': ['ABB.NS', 'ADANIPOWER.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'BAJAJ-AUTO.NS', 'BDL.NS', 'BLS.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CUB.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'FINEORG.NS', 'HDFCLIFE.NS', 'HINDUNILVR.NS', 'HUDCO.NS', 'INDIANB.NS', 'ITC.NS', 'MRPL.NS', 'PETRONET.NS', 'PHOENIXLTD.NS', 'POWERINDIA.NS', 'QUESS.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RTNINDIA.NS', 'SBILIFE.NS', 'SUMICHEM.NS', 'WELCORP.NS', 'ZYDUSLIFE.NS'],
'2022-07-01': ['3MINDIA.NS', 'ABBOTINDIA.NS', 'AIAENG.NS', 'APARINDS.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'BLUEDART.NS', 'CGPOWER.NS', 'CIEINDIA.NS', 'ENDURANCE.NS', 'JAMNAAUTO.NS', 'KSB.NS', 'M&M.NS', 'MARUTI.NS', 'RAJESHEXPO.NS', 'SHRIRAMFIN.NS', 'SKFINDIA.NS', 'TIINDIA.NS', 'VBL.NS', 'WESTLIFE.NS'],
'2022-08-01': ['360ONE.NS', 'ABCAPITAL.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'AMBUJACEM.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'AXISBANK.NS', 'BANKBARODA.NS', 'BDL.NS', 'BHEL.NS', 'BLS.NS', 'BRIGADE.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CENTURYPLY.NS', 'CHOLAFIN.NS', 'COCHINSHIP.NS', 'CROMPTON.NS', 'DEEPAKFERT.NS', 'EIHOTEL.NS', 'ENGINERSIN.NS', 'FACT.NS', 'FINCABLES.NS', 'FORTIS.NS', 'GMRINFRA.NS', 'HAPPSTMNDS.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'HUDCO.NS', 'ICICIPRULI.NS', 'IDFCFIRSTB.NS', 'INDIANB.NS', 'IPCALAB.NS', 'JKPAPER.NS', 'JYOTHYLAB.NS', 'KEC.NS', 'KNRCON.NS', 'KPITTECH.NS', 'NTPC.NS', 'PATANJALI.NS', 'PCBL.NS', 'PFC.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RAIN.NS', 'RALLIS.NS', 'RITES.NS', 'ROSSARI.NS', 'SAIL.NS', 'SUNTV.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TORNTPOWER.NS', 'UNIONBANK.NS', 'UPL.NS', 'USHAMART.NS', 'VBL.NS', 'YESBANK.NS', 'ZEEL.NS'],
'2022-09-01': ['ABCAPITAL.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'AFFLE.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'ASTRAL.NS', 'BAJAJHLDNG.NS', 'BLUESTARCO.NS', 'CANFINHOME.NS', 'CENTURYPLY.NS', 'CERA.NS', 'CHOLAFIN.NS', 'COLPAL.NS', 'CUB.NS', 'DEEPAKFERT.NS', 'DMART.NS', 'FINCABLES.NS', 'FORTIS.NS', 'GODREJCP.NS', 'GRASIM.NS', 'HAVELLS.NS', 'HONAUT.NS', 'INDUSINDBK.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JYOTHYLAB.NS', 'KANSAINER.NS', 'LALPATHLAB.NS', 'LICHSGFIN.NS', 'LT.NS', 'M&M.NS', 'NESTLEIND.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'PIIND.NS', 'POONAWALLA.NS', 'RATNAMANI.NS', 'REDINGTON.NS', 'RHIM.NS', 'ROSSARI.NS', 'SBILIFE.NS', 'SHOPERSTOP.NS', 'SOLARINDS.NS', 'STLTECH.NS', 'SUNTV.NS', 'THERMAX.NS', 'TVSMOTOR.NS', 'UNOMINDA.NS', 'UTIAMC.NS', 'VAIBHAVGBL.NS', 'VBL.NS', 'ZFCVINDIA.NS'],
'2022-10-01': ['360ONE.NS', '3MINDIA.NS', 'ALKEM.NS', 'ALLCARGO.NS', 'AMBUJACEM.NS', 'CARBORUNIV.NS', 'CEATLTD.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'ESCORTS.NS', 'FINEORG.NS', 'GMMPFAUDLR.NS', 'HINDUNILVR.NS', 'INDIACEM.NS', 'INDUSINDBK.NS', 'JBCHEPHARM.NS', 'JKLAKSHMI.NS', 'KARURVYSYA.NS', 'KSB.NS', 'METROPOLIS.NS', 'NH.NS', 'PATANJALI.NS', 'QUESS.NS', 'RENUKA.NS', 'RHIM.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUPREMEIND.NS', 'TATAINVEST.NS', 'TIINDIA.NS', 'UBL.NS', 'VIPIND.NS', 'WESTLIFE.NS', 'ZYDUSLIFE.NS'],
'2022-11-01': ['ABCAPITAL.NS', 'AEGISCHEM.NS', 'ALLCARGO.NS', 'APOLLOTYRE.NS', 'BANKBARODA.NS', 'BLS.NS', 'CASTROLIND.NS', 'CGPOWER.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'EQUITASBNK.NS', 'EXIDEIND.NS', 'FEDERALBNK.NS', 'GAIL.NS', 'GESHIP.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GUJGASLTD.NS', 'HFCL.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IGL.NS', 'INDHOTEL.NS', 'IOB.NS', 'IRCON.NS', 'ITC.NS', 'JINDALSTEL.NS', 'JKPAPER.NS', 'JSL.NS', 'JUBLPHARMA.NS', 'KRBL.NS', 'L&TFH.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'NCC.NS', 'NHPC.NS', 'NLCINDIA.NS', 'NTPC.NS', 'PNBHOUSING.NS', 'POWERGRID.NS', 'RBLBANK.NS', 'RCF.NS', 'RECLTD.NS', 'RVNL.NS', 'SJVN.NS', 'SWANENERGY.NS', 'TRITURBINE.NS', 'UJJIVANSFB.NS', 'USHAMART.NS', 'VGUARD.NS'],
'2022-12-01': ['ABBOTINDIA.NS', 'ACC.NS', 'ADANIENT.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'AXISBANK.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BHARTIARTL.NS', 'CANBK.NS', 'CCL.NS', 'CGPOWER.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DALBHARAT.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'FACT.NS', 'GAIL.NS', 'GODFRYPHLP.NS', 'GPIL.NS', 'GSPL.NS', 'HAL.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'IBULHSGFIN.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'IDFCFIRSTB.NS', 'INDIANB.NS', 'INDIGO.NS', 'INFY.NS', 'IRCON.NS', 'JSL.NS', 'JSWSTEEL.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'LT.NS', 'LUPIN.NS', 'MANAPPURAM.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MRF.NS', 'NLCINDIA.NS', 'NMDC.NS', 'PETRONET.NS', 'PFIZER.NS', 'PIIND.NS', 'RALLIS.NS', 'RAYMOND.NS', 'RELIANCE.NS', 'RHIM.NS', 'SHREECEM.NS', 'SUNPHARMA.NS', 'SUPREMEIND.NS', 'TATACONSUM.NS', 'TCS.NS', 'ULTRACEMCO.NS', 'UPL.NS', 'UTIAMC.NS', 'VBL.NS', 'VEDL.NS'],
'2023-01-01': ['ABBOTINDIA.NS', 'AXISBANK.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BANKBARODA.NS', 'BAYERCROP.NS', 'CANBK.NS', 'CRISIL.NS', 'GODFRYPHLP.NS', 'GPIL.NS', 'HINDZINC.NS', 'ICICIGI.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JSWSTEEL.NS', 'KAJARIACER.NS', 'KEC.NS', 'LINDEINDIA.NS', 'ONGC.NS', 'PGHH.NS', 'PNBHOUSING.NS', 'POWERINDIA.NS', 'RHIM.NS', 'SANOFI.NS', 'SHARDACROP.NS', 'SOLARINDS.NS', 'SUNDRMFAST.NS', 'SUVENPHAR.NS', 'UTIAMC.NS', 'WESTLIFE.NS'],
'2023-02-01': ['3MINDIA.NS', 'AIAENG.NS', 'BAJAJ-AUTO.NS', 'BALKRISIND.NS', 'CGPOWER.NS', 'CYIENT.NS', 'ECLERX.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'GRINDWELL.NS', 'HCLTECH.NS', 'IIFL.NS', 'INDIANB.NS', 'INDIGO.NS', 'IOC.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'KEI.NS', 'MARUTI.NS', 'OIL.NS', 'PNCINFRA.NS', 'PRINCEPIPE.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'SONATSOFTW.NS', 'SUPREMEIND.NS', 'SWSOLAR.NS', 'TATAMTRDVR.NS', 'VEDL.NS', 'ZENSARTECH.NS'],
'2023-03-01': ['ABB.NS', 'APARINDS.NS', 'BAJAJHLDNG.NS', 'BOSCHLTD.NS', 'CERA.NS', 'CIEINDIA.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'ELGIEQUIP.NS', 'FLUOROCHEM.NS', 'GAIL.NS', 'GLAXO.NS', 'GPPL.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'INDIAMART.NS', 'INGERRAND.NS', 'ITC.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JSL.NS', 'KPITTECH.NS', 'LINDEINDIA.NS', 'OIL.NS', 'ONGC.NS', 'PERSISTENT.NS', 'PNBHOUSING.NS', 'POLYCAB.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'RADICO.NS', 'ROUTE.NS', 'SAFARI.NS', 'SCHAEFFLER.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SUPRAJIT.NS', 'SUPREMEIND.NS', 'TECHM.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'VOLTAS.NS'],
'2023-04-01': ['ABBOTINDIA.NS', 'AIAENG.NS', 'APARINDS.NS', 'ASTERDM.NS', 'BDL.NS', 'CYIENT.NS', 'DALBHARAT.NS', 'DRREDDY.NS', 'FINCABLES.NS', 'GAIL.NS', 'GLENMARK.NS', 'GODREJCP.NS', 'GPPL.NS', 'IIFL.NS', 'JBMA.NS', 'JKLAKSHMI.NS', 'KPITTECH.NS', 'KSB.NS', 'LINDEINDIA.NS', 'MANAPPURAM.NS', 'MGL.NS', 'NCC.NS', 'NESTLEIND.NS', 'RAMCOCEM.NS', 'RELAXO.NS', 'SONATSOFTW.NS', 'SRF.NS', 'THERMAX.NS', 'TRITURBINE.NS', 'ULTRACEMCO.NS', 'USHAMART.NS', 'VBL.NS', 'ZYDUSLIFE.NS'],
'2023-05-01': ['ABCAPITAL.NS', 'ADANIPOWER.NS', 'AJANTPHARM.NS', 'APARINDS.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'BAJFINANCE.NS', 'BDL.NS', 'BEL.NS', 'BERGEPAINT.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BORORENEW.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CCL.NS', 'CEATLTD.NS', 'COALINDIA.NS', 'CRISIL.NS', 'DIVISLAB.NS', 'EICHERMOT.NS', 'ENGINERSIN.NS', 'EPL.NS', 'FLUOROCHEM.NS', 'GESHIP.NS', 'GNFC.NS', 'GODREJIND.NS', 'GRASIM.NS', 'HAL.NS', 'HEROMOTOCO.NS', 'HINDPETRO.NS', 'HUDCO.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IEX.NS', 'INDHOTEL.NS', 'INDIAMART.NS', 'INDIANB.NS', 'INDIGO.NS', 'INGERRAND.NS', 'IOC.NS', 'JUSTDIAL.NS', 'KRBL.NS', 'KSB.NS', 'L&TFH.NS', 'LEMONTREE.NS', 'LTTS.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MRF.NS', 'NBCC.NS', 'NHPC.NS', 'PFC.NS', 'PHOENIXLTD.NS', 'PNB.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PRSMJOHNSN.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RITES.NS', 'SBIN.NS', 'SIEMENS.NS', 'TATAELXSI.NS', 'TEJASNET.NS', 'TITAN.NS', 'UCOBANK.NS', 'UNIONBANK.NS', 'WELCORP.NS', 'WESTLIFE.NS'],
'2023-06-01': ['3MINDIA.NS', 'ADANIENT.NS', 'AIAENG.NS', 'AMBER.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BDL.NS', 'BEML.NS', 'BRITANNIA.NS', 'CDSL.NS', 'CENTURYTEX.NS', 'CERA.NS', 'COFORGE.NS', 'CRISIL.NS', 'CUMMINSIND.NS', 'DALBHARAT.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'ENDURANCE.NS', 'ESCORTS.NS', 'FLUOROCHEM.NS', 'GODREJPROP.NS', 'GRINDWELL.NS', 'HAL.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'IRCTC.NS', 'JKCEMENT.NS', 'LTIM.NS', 'M&M.NS', 'MARUTI.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NESTLEIND.NS', 'PATANJALI.NS', 'PERSISTENT.NS', 'PIDILITIND.NS', 'POLYCAB.NS', 'RELAXO.NS', 'ROUTE.NS', 'SCHAEFFLER.NS', 'TEJASNET.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TITAN.NS', 'ULTRACEMCO.NS', 'WHIRLPOOL.NS'],
'2023-07-01': ['360ONE.NS', 'AAVAS.NS', 'ABBOTINDIA.NS', 'AFFLE.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BAYERCROP.NS', 'BEML.NS', 'BERGEPAINT.NS', 'BRITANNIA.NS', 'CCL.NS', 'CDSL.NS', 'CEATLTD.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'COFORGE.NS', 'COLPAL.NS', 'CYIENT.NS', 'DABUR.NS', 'DELTACORP.NS', 'DIXON.NS', 'EMAMILTD.NS', 'ENDURANCE.NS', 'ESCORTS.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GPPL.NS', 'GRINDWELL.NS', 'HAL.NS', 'HAPPSTMNDS.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HONAUT.NS', 'IBULHSGFIN.NS', 'ITC.NS', 'JBCHEPHARM.NS', 'JKCEMENT.NS', 'JUBLPHARMA.NS', 'KEI.NS', 'KPRMILL.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LTIM.NS', 'MAHLIFE.NS', 'MANAPPURAM.NS', 'MARUTI.NS', 'MAXHEALTH.NS', 'METROPOLIS.NS', 'MOTILALOFS.NS', 'MRF.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'NTPC.NS', 'OFSS.NS', 'PGHH.NS', 'PGHL.NS', 'PIIND.NS', 'POWERINDIA.NS', 'PRESTIGE.NS', 'PRINCEPIPE.NS', 'RAMCOCEM.NS', 'RBLBANK.NS', 'ROUTE.NS', 'SAFARI.NS', 'SANOFI.NS', 'SFL.NS', 'SUNDARMFIN.NS', 'TATACONSUM.NS', 'TATAMTRDVR.NS', 'TEAMLEASE.NS', 'ULTRACEMCO.NS', 'VARROC.NS', 'VMART.NS', 'WHIRLPOOL.NS', 'ZFCVINDIA.NS'],
'2023-08-01': ['3MINDIA.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ABCAPITAL.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ASAHIINDIA.NS', 'BAJAJ-AUTO.NS', 'BAJAJHLDNG.NS', 'BANKINDIA.NS', 'BATAINDIA.NS', 'BEL.NS', 'CAMS.NS', 'CANBK.NS', 'CDSL.NS', 'CEATLTD.NS', 'CHALET.NS', 'CHOLAHLDNG.NS', 'COCHINSHIP.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CUMMINSIND.NS', 'DLF.NS', 'EPL.NS', 'EXIDEIND.NS', 'FDC.NS', 'GILLETTE.NS', 'GPPL.NS', 'GRANULES.NS', 'GRINDWELL.NS', 'HAL.NS', 'HINDALCO.NS', 'HUDCO.NS', 'ICICIGI.NS', 'IDFCFIRSTB.NS', 'IRCON.NS', 'JMFINANCIL.NS', 'KAJARIACER.NS', 'KEC.NS', 'KSB.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'MANAPPURAM.NS', 'MCDOWELL-N.NS', 'MFSL.NS', 'MRF.NS', 'NLCINDIA.NS', 'PFIZER.NS', 'PGHH.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'POWERGRID.NS', 'PRAJIND.NS', 'RADICO.NS', 'RALLIS.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'RITES.NS', 'SBIN.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SPARC.NS', 'SUNDRMFAST.NS', 'SUNTECK.NS', 'SUVENPHAR.NS', 'SUZLON.NS', 'TANLA.NS', 'TATACHEM.NS', 'THERMAX.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'VAIBHAVGBL.NS', 'WESTLIFE.NS', 'ZFCVINDIA.NS'],
'2023-09-01': ['3MINDIA.NS', 'AAVAS.NS', 'AIAENG.NS', 'AJANTPHARM.NS', 'ANGELONE.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'ATUL.NS', 'BAYERCROP.NS', 'BERGEPAINT.NS', 'CENTURYPLY.NS', 'CHOLAHLDNG.NS', 'COFORGE.NS', 'COROMANDEL.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DIXON.NS', 'FINCABLES.NS', 'GMMPFAUDLR.NS', 'GODFRYPHLP.NS', 'GODREJIND.NS', 'GUJALKALI.NS', 'HAVELLS.NS', 'INTELLECT.NS', 'KEI.NS', 'LTTS.NS', 'LUPIN.NS', 'MARUTI.NS', 'MCX.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'MRF.NS', 'OFSS.NS', 'PERSISTENT.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'PRAJIND.NS', 'PRINCEPIPE.NS', 'RAYMOND.NS', 'RITES.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATAMTRDVR.NS', 'TEJASNET.NS', 'THERMAX.NS', 'TITAN.NS', 'TVSMOTOR.NS', 'VBL.NS', 'VGUARD.NS', 'VOLTAS.NS', 'VTL.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2023-10-01': ['AAVAS.NS', 'ADANIPOWER.NS', 'AJANTPHARM.NS', 'AMBER.NS', 'APARINDS.NS', 'ASAHIINDIA.NS', 'AUROPHARMA.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BAYERCROP.NS', 'BBTC.NS', 'BHARTIARTL.NS', 'BLUESTARCO.NS', 'CANBK.NS', 'CDSL.NS', 'CHOLAFIN.NS', 'COCHINSHIP.NS', 'COROMANDEL.NS', 'DALBHARAT.NS', 'DIXON.NS', 'ESCORTS.NS', 'GESHIP.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GODFRYPHLP.NS', 'GPIL.NS', 'GRASIM.NS', 'GUJALKALI.NS', 'INDIANB.NS', 'IPCALAB.NS', 'JBCHEPHARM.NS', 'JSWENERGY.NS', 'KSB.NS', 'LALPATHLAB.NS', 'LICHSGFIN.NS', 'MARUTI.NS', 'MAZDOCK.NS', 'NH.NS', 'PERSISTENT.NS', 'PGHH.NS', 'POLYCAB.NS', 'SAFARI.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SUNTV.NS', 'TATACOMM.NS', 'THERMAX.NS', 'TRENT.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TVSMOTOR.NS', 'VBL.NS', 'WELCORP.NS', 'ZFCVINDIA.NS'],
'2023-11-01': ['BAJAJ-AUTO.NS', 'BBTC.NS', 'BSOFT.NS', 'CANBK.NS', 'COLPAL.NS', 'DLF.NS', 'GSFC.NS', 'HCLTECH.NS', 'IDEA.NS', 'IPCALAB.NS', 'ISEC.NS', 'ITI.NS', 'KARURVYSYA.NS', 'KPRMILL.NS', 'MOTILALOFS.NS', 'NBCC.NS', 'NESTLEIND.NS', 'NMDC.NS', 'PATANJALI.NS', 'PCBL.NS', 'PRSMJOHNSN.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'RECLTD.NS', 'SANOFI.NS', 'SBILIFE.NS', 'SONATSOFTW.NS', 'SUNDARMFIN.NS', 'SUVENPHAR.NS', 'SUZLON.NS', 'TATAELXSI.NS', 'TRENT.NS', 'TVSMOTOR.NS', 'WELCORP.NS', 'WELSPUNLIV.NS'],
'2023-12-01': ['360ONE.NS', 'ABFRL.NS', 'ADANIGREEN.NS', 'ADANIPOWER.NS', 'AJANTPHARM.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'ASTERDM.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BALRAMCHIN.NS', 'BDL.NS', 'BEML.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'BLUESTARCO.NS', 'CAMS.NS', 'CENTURYTEX.NS', 'CHAMBLFERT.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'CSBBANK.NS', 'DIVISLAB.NS', 'DLF.NS', 'DMART.NS', 'DRREDDY.NS', 'EIDPARRY.NS', 'EXIDEIND.NS', 'FSL.NS', 'GAEL.NS', 'GAIL.NS', 'GESHIP.NS', 'GLAND.NS', 'GLAXO.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GRASIM.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'ICICIGI.NS', 'IEX.NS', 'INDIGO.NS', 'INTELLECT.NS', 'IRCON.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'JUBLFOOD.NS', 'JYOTHYLAB.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KSB.NS', 'LICHSGFIN.NS', 'M&M.NS', 'MANAPPURAM.NS', 'MAXHEALTH.NS', 'MOTILALOFS.NS', 'MRPL.NS', 'NAM-INDIA.NS', 'NETWORK18.NS', 'NH.NS', 'ONGC.NS', 'PIIND.NS', 'POONAWALLA.NS', 'RHIM.NS', 'SBILIFE.NS', 'SONATSOFTW.NS', 'SPARC.NS', 'SUNDARMFIN.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATACONSUM.NS', 'ULTRACEMCO.NS', 'UTIAMC.NS'],
'2024-01-01': ['ACC.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ALKYLAMINE.NS', 'AMBUJACEM.NS', 'ATGL.NS', 'ATUL.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'BBTC.NS', 'BEML.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BLS.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'CEATLTD.NS', 'CENTURYPLY.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'CYIENT.NS', 'DIVISLAB.NS', 'DMART.NS', 'EICHERMOT.NS', 'ENGINERSIN.NS', 'GESHIP.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'HCLTECH.NS', 'HEG.NS', 'HFCL.NS', 'HINDPETRO.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'JSL.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'L&TFH.NS', 'LICHSGFIN.NS', 'LUPIN.NS', 'M&M.NS', 'MAZDOCK.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MGL.NS', 'MOTHERSON.NS', 'MRPL.NS', 'NAUKRI.NS', 'NHPC.NS', 'OLECTRA.NS', 'PETRONET.NS', 'PFC.NS', 'POWERGRID.NS', 'PRESTIGE.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RADICO.NS', 'RCF.NS', 'RECLTD.NS', 'RHIM.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SUNPHARMA.NS', 'SUPRAJIT.NS', 'SWSOLAR.NS', 'TANLA.NS', 'TATAINVEST.NS', 'TCS.NS', 'THERMAX.NS', 'TITAN.NS', 'UNOMINDA.NS', 'ZENSARTECH.NS', 'ZYDUSLIFE.NS'],
'2024-02-01': ['ADANIENT.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ASTERDM.NS', 'AUROPHARMA.NS', 'BANKBARODA.NS', 'BBTC.NS', 'BDL.NS', 'BEL.NS', 'BIRLACORPN.NS', 'BOSCHLTD.NS', 'BRIGADE.NS', 'CANBK.NS', 'CASTROLIND.NS', 'CCL.NS', 'CENTRALBK.NS', 'CESC.NS', 'CGCL.NS', 'COALINDIA.NS', 'DLF.NS', 'ENDURANCE.NS', 'GAIL.NS', 'GODREJPROP.NS', 'HAL.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HINDPETRO.NS', 'HONAUT.NS', 'INDHOTEL.NS', 'INDUSTOWER.NS', 'INFY.NS', 'INTELLECT.NS', 'IRCTC.NS', 'JINDALSAW.NS', 'JKPAPER.NS', 'JMFINANCIL.NS', 'JSWENERGY.NS', 'LT.NS', 'MINDACORP.NS', 'MOTHERSON.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NIACL.NS', 'NMDC.NS', 'RCF.NS', 'RELIANCE.NS', 'RTNINDIA.NS', 'SAIL.NS', 'SHOPERSTOP.NS', 'SPARC.NS', 'SUNPHARMA.NS', 'SUZLON.NS', 'TATACONSUM.NS', 'TORNTPOWER.NS', 'TRIDENT.NS', 'TV18BRDCST.NS', 'UCOBANK.NS', 'USHAMART.NS'],



}



# Initialize lists to store results
ticker_list = []
percentage_returns = []
first_day_closes = []
last_day_closes = []
start_dates = []  # List to store the start dates
end_dates = []    # List to store the end dates

# Loop through the dictionary and download data for each date-ticker pair
for start_date, tickers in date_ticker_dict.items():
    end_date = pd.to_datetime(start_date) + pd.DateOffset(months=1) - pd.DateOffset(days=1)  # Last day of the month

    # Loop through tickers in this iteration
    for ticker in tickers:
        # Download historical stock data using yfinance for the specified ticker and dates
        try:
            stocks = yf.download(ticker, start=start_date, end=end_date)

            # Extracting the closing prices on the first and last day
            first_day_close = stocks['Close'].iloc[0]
            last_day_close = stocks['Close'].iloc[-1]

            # Calculating percentage return for this ticker
            percentage_return = ((last_day_close - first_day_close) / first_day_close) * 100

            # Appending the results to the lists
            ticker_list.append(ticker)
            percentage_returns.append(percentage_return)
            first_day_closes.append(first_day_close)
            last_day_closes.append(last_day_close)
            start_dates.append(pd.to_datetime(start_date))
            end_dates.append(end_date)  # Append end date for each ticker
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

# Creating a DataFrame with ticker symbols, percentage returns, and capital information
returns_df = pd.DataFrame({
    'Start_Date': start_dates,
    'End_Date': end_dates,
    'Ticker': ticker_list,
    'Percentage_Return': percentage_returns,
    'First_Day_Close': first_day_closes,
    'Last_Day_Close': last_day_closes,
})

# Assuming an initial investment of $10,000 for each stock
initial_investment = 10000

# Calculating the capital at the last day
returns_df['Capital_At_Last_Day'] = initial_investment * (1 + returns_df['Percentage_Return'] / 100)

# Calculating the difference between capital at the last day and capital required
returns_df['Capital_Difference'] = returns_df['Capital_At_Last_Day'] - initial_investment

# Total amount invested
total_invested = initial_investment * len(returns_df)

# Total amount returned
total_returned = returns_df['Capital_At_Last_Day'].sum()

# Calculate percentage return
percentage_return = ((total_returned - total_invested) / total_invested) * 100

# Displaying the DataFrame with ticker names, percentage returns, and capital information
print(returns_df[['Start_Date', 'End_Date', 'Ticker', 'Percentage_Return', 'First_Day_Close', 'Last_Day_Close']])

# Display total amount invested and total amount returned in percentage
print("\nTotal Amount Invested: $", total_invested)
print("Total Amount Returned: $", total_returned)
print("Percentage Return: ", percentage_return, "%")

returns_df.to_csv('stock_Cluster6.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %% [markdown]
# # Cluster 7

# %%
import yfinance as yf
import pandas as pd

# Input dictionary
date_ticker_dict =  {  

  '2017-04-01': ['ADANIPORTS.NS', 'AIAENG.NS', 'ALKEM.NS', 'ASTRAL.NS', 'AVANTIFEED.NS', 'BATAINDIA.NS', 'CARBORUNIV.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'COLPAL.NS', 'CUMMINSIND.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'EIHOTEL.NS', 'FACT.NS', 'GESHIP.NS', 'GPIL.NS', 'HAVELLS.NS', 'HONAUT.NS', 'IIFL.NS', 'INDUSINDBK.NS', 'IPCALAB.NS', 'JKCEMENT.NS', 'KEC.NS', 'KOTAKBANK.NS', 'LICHSGFIN.NS', 'MAHLIFE.NS', 'MOTILALOFS.NS', 'MRF.NS', 'NATCOPHARM.NS', 'NESTLEIND.NS', 'OLECTRA.NS', 'PFIZER.NS', 'RELIANCE.NS', 'SANOFI.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SHOPERSTOP.NS', 'SUNDARMFIN.NS', 'SUPRAJIT.NS', 'SYMPHONY.NS', 'TATAPOWER.NS', 'TRIVENI.NS', 'WHIRLPOOL.NS'],
'2017-05-01': ['APOLLOTYRE.NS', 'AVANTIFEED.NS', 'BAJAJFINSV.NS', 'BALKRISIND.NS', 'BEL.NS', 'BERGEPAINT.NS', 'CEATLTD.NS', 'CERA.NS', 'CIEINDIA.NS', 'COLPAL.NS', 'CUB.NS', 'DLF.NS', 'EIHOTEL.NS', 'GAIL.NS', 'GILLETTE.NS', 'GRANULES.NS', 'GUJALKALI.NS', 'GUJGASLTD.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IIFL.NS', 'INDIANB.NS', 'INGERRAND.NS', 'IOC.NS', 'KAJARIACER.NS', 'KPRMILL.NS', 'KRBL.NS', 'LAXMIMACH.NS', 'MAHLIFE.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MRPL.NS', 'NBCC.NS', 'NETWORK18.NS', 'PNB.NS', 'RAYMOND.NS', 'RECLTD.NS', 'REDINGTON.NS', 'SCHAEFFLER.NS', 'TIMKEN.NS', 'TVSMOTOR.NS', 'UCOBANK.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'VAIBHAVGBL.NS', 'VGUARD.NS', 'VINATIORGA.NS'],
'2017-06-01': ['APARINDS.NS', 'ASAHIINDIA.NS', 'GILLETTE.NS', 'GODREJIND.NS', 'IBULHSGFIN.NS', 'ICICIBANK.NS', 'ITC.NS', 'KEC.NS', 'KPRMILL.NS', 'LICHSGFIN.NS', 'MHRIL.NS', 'MOTHERSON.NS', 'NAUKRI.NS', 'TVSMOTOR.NS', 'UPL.NS', 'VINATIORGA.NS', 'VOLTAS.NS'],
'2017-07-01': ['AUROPHARMA.NS', 'AVANTIFEED.NS', 'CANFINHOME.NS', 'GRASIM.NS', 'HEG.NS', 'INFIBEAM.NS', 'ITC.NS', 'KANSAINER.NS', 'KARURVYSYA.NS', 'KSB.NS', 'MHRIL.NS', 'NAUKRI.NS', 'PCBL.NS', 'PERSISTENT.NS', 'POONAWALLA.NS', 'RAIN.NS', 'RAJESHEXPO.NS', 'RTNINDIA.NS', 'SUPRAJIT.NS', 'TATASTEEL.NS', 'UNOMINDA.NS', 'WELCORP.NS'],
'2017-08-01': ['ASHOKLEY.NS', 'AVANTIFEED.NS', 'BIRLACORPN.NS', 'BLUESTARCO.NS', 'DABUR.NS', 'EICHERMOT.NS', 'GILLETTE.NS', 'GSPL.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'IGL.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'KEC.NS', 'KOTAKBANK.NS', 'M&MFIN.NS', 'NAVINFLUOR.NS', 'POWERGRID.NS', 'RAJESHEXPO.NS', 'SIEMENS.NS', 'STLTECH.NS', 'TATAELXSI.NS', 'TVSMOTOR.NS', 'WIPRO.NS'],
'2017-09-01': ['BAJAJFINSV.NS', 'BATAINDIA.NS', 'BLS.NS', 'BLUESTARCO.NS', 'BPCL.NS', 'CESC.NS', 'CONCOR.NS', 'DELTACORP.NS', 'GRAPHITE.NS', 'GSFC.NS', 'IGL.NS', 'INFIBEAM.NS', 'IOC.NS', 'JBMA.NS', 'JMFINANCIL.NS', 'JSL.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'KEI.NS', 'MRPL.NS', 'NESTLEIND.NS', 'PCBL.NS', 'RTNINDIA.NS', 'SAREGAMA.NS', 'SCHAEFFLER.NS', 'TATACONSUM.NS', 'TATASTEEL.NS', 'TRENT.NS', 'TRIDENT.NS', 'VEDL.NS', 'VIPIND.NS', 'WELCORP.NS', 'WIPRO.NS'],
'2017-10-01': ['AEGISCHEM.NS', 'CERA.NS', 'GILLETTE.NS', 'GRAPHITE.NS', 'HEG.NS'],
'2017-11-01': ['ASHOKLEY.NS', 'BANKINDIA.NS', 'BEL.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BSOFT.NS', 'CANBK.NS', 'DLF.NS', 'EIHOTEL.NS', 'EPL.NS', 'GAIL.NS', 'GMRINFRA.NS', 'GPIL.NS', 'GSFC.NS', 'HINDCOPPER.NS', 'IRB.NS', 'JAMNAAUTO.NS', 'JUSTDIAL.NS', 'MOTHERSON.NS', 'MRPL.NS', 'NATIONALUM.NS', 'NBCC.NS', 'OIL.NS', 'PCBL.NS', 'PNB.NS', 'PRAJIND.NS', 'RADICO.NS', 'RELIANCE.NS', 'TTML.NS', 'UNIONBANK.NS', 'VGUARD.NS', 'VIPIND.NS'],
'2017-12-01': ['BALAMINES.NS', 'BALKRISIND.NS', 'CENTURYPLY.NS', 'CERA.NS', 'CROMPTON.NS', 'DLF.NS', 'ENDURANCE.NS', 'FINCABLES.NS', 'GRINDWELL.NS', 'KEI.NS', 'LALPATHLAB.NS', 'MARUTI.NS', 'NAUKRI.NS', 'RADICO.NS', 'SOLARINDS.NS', 'SUNTECK.NS', 'SWANENERGY.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATAPOWER.NS', 'TIMKEN.NS', 'TITAN.NS', 'VIPIND.NS', 'WHIRLPOOL.NS', 'ZFCVINDIA.NS'],
'2018-01-01': ['ALKYLAMINE.NS', 'ATUL.NS', 'BBTC.NS', 'BIOCON.NS', 'CENTURYPLY.NS', 'COROMANDEL.NS', 'DLF.NS', 'ELGIEQUIP.NS', 'ENDURANCE.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'GRAPHITE.NS', 'GRINDWELL.NS', 'GSPL.NS', 'HEG.NS', 'HINDUNILVR.NS', 'IDEA.NS', 'IIFL.NS', 'JAMNAAUTO.NS', 'JKCEMENT.NS', 'JUBLPHARMA.NS', 'KEC.NS', 'KNRCON.NS', 'KPRMILL.NS', 'MANAPPURAM.NS', 'MINDACORP.NS', 'NAVINFLUOR.NS', 'NCC.NS', 'NETWORK18.NS', 'OFSS.NS', 'ONGC.NS', 'PAGEIND.NS', 'PFIZER.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'RALLIS.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'SAIL.NS', 'SHRIRAMFIN.NS', 'SPARC.NS', 'SRF.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'TANLA.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TV18BRDCST.NS', 'UNOMINDA.NS', 'WIPRO.NS'],
'2018-02-01': ['ABB.NS', 'ADANIENT.NS', 'COFORGE.NS', 'HDFCBANK.NS', 'IBULHSGFIN.NS', 'KOTAKBANK.NS', 'LT.NS', 'LTIM.NS', 'TCS.NS', 'ZENSARTECH.NS'],
'2018-03-01': ['ASTRAL.NS', 'CHOLAFIN.NS', 'IPCALAB.NS', 'LAXMIMACH.NS', 'LUXIND.NS'],
'2018-04-01': ['CYIENT.NS', 'JUBLFOOD.NS', 'JYOTHYLAB.NS', 'NESTLEIND.NS'],
'2018-05-01': ['AARTIIND.NS', 'ALKYLAMINE.NS', 'BALAMINES.NS', 'BBTC.NS', 'BERGEPAINT.NS', 'BIOCON.NS', 'CCL.NS', 'CIEINDIA.NS', 'CYIENT.NS', 'DABUR.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'FSL.NS', 'IDFC.NS', 'INTELLECT.NS', 'IRB.NS', 'ITC.NS', 'JAMNAAUTO.NS', 'JUBLFOOD.NS', 'LUXIND.NS', 'M&MFIN.NS', 'PNBHOUSING.NS', 'POWERGRID.NS', 'QUESS.NS', 'RBLBANK.NS', 'SUPREMEIND.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'TATAINVEST.NS', 'VIPIND.NS', 'YESBANK.NS', 'ZYDUSWELL.NS'],
'2018-06-01': ['ASTRAL.NS', 'BSOFT.NS', 'CUB.NS', 'DABUR.NS', 'FSL.NS', 'GLAXO.NS', 'GRAPHITE.NS', 'HINDUNILVR.NS', 'JUSTDIAL.NS', 'KEI.NS', 'LTIM.NS', 'M&M.NS', 'PGHL.NS', 'SOLARINDS.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'UNOMINDA.NS', 'VBL.NS'],
'2018-07-01': ['BRITANNIA.NS', 'GODREJCP.NS'],
'2018-08-01': ['3MINDIA.NS', 'APOLLOTYRE.NS', 'ASIANPAINT.NS', 'BAJAJFINSV.NS', 'BANKBARODA.NS', 'BRITANNIA.NS', 'EMAMILTD.NS', 'EXIDEIND.NS', 'HAVELLS.NS', 'HEG.NS', 'IGL.NS', 'INFIBEAM.NS', 'ITC.NS', 'PEL.NS', 'THERMAX.NS'],
'2018-09-01': ['ABFRL.NS', 'ADANIPOWER.NS', 'AJANTPHARM.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'AXISBANK.NS', 'COFORGE.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DCMSHRIRAM.NS', 'DIVISLAB.NS', 'FINPIPE.NS', 'GLENMARK.NS', 'GMRINFRA.NS', 'GODREJCP.NS', 'GRANULES.NS', 'ICICIBANK.NS', 'IDFCFIRSTB.NS', 'INTELLECT.NS', 'ITI.NS', 'NESTLEIND.NS', 'NTPC.NS', 'OFSS.NS', 'ONGC.NS', 'PETRONET.NS', 'RADICO.NS', 'RBLBANK.NS', 'RELAXO.NS', 'SUNPHARMA.NS', 'TECHM.NS', 'TTKPRESTIG.NS', 'UPL.NS', 'VIPIND.NS', 'ZYDUSWELL.NS'],
'2018-10-01': ['AUBANK.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BBTC.NS', 'BEML.NS', 'CANFINHOME.NS', 'CEATLTD.NS', 'DMART.NS', 'EICHERMOT.NS', 'GODREJIND.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'IBULHSGFIN.NS', 'INDUSINDBK.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'MARUTI.NS', 'MCDOWELL-N.NS', 'MOTILALOFS.NS', 'MRF.NS', 'PEL.NS', 'RAYMOND.NS', 'SUNTV.NS', 'SYMPHONY.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TIMKEN.NS', 'VIPIND.NS', 'ZEEL.NS'],
'2018-11-01': ['ADANIENT.NS', 'BALRAMCHIN.NS', 'DIVISLAB.NS', 'ICICIBANK.NS', 'PFC.NS', 'STLTECH.NS', 'VINATIORGA.NS'],
'2018-12-01': ['BLUESTARCO.NS', 'BRITANNIA.NS', 'COLPAL.NS', 'GODFRYPHLP.NS', 'HDFCBANK.NS', 'HONAUT.NS', 'INDHOTEL.NS', 'IPCALAB.NS', 'LT.NS', 'MCDOWELL-N.NS', 'SKFINDIA.NS', 'SRF.NS', 'TATAINVEST.NS', 'TEAMLEASE.NS', 'VGUARD.NS'],
'2019-01-01': ['ALKYLAMINE.NS', 'APARINDS.NS', 'BANKINDIA.NS', 'BATAINDIA.NS', 'BEML.NS', 'BLUEDART.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'CUB.NS', 'ENDURANCE.NS', 'EPL.NS', 'GLAXO.NS', 'GRINDWELL.NS', 'IDFCFIRSTB.NS', 'INDIGO.NS', 'INGERRAND.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KARURVYSYA.NS', 'KNRCON.NS', 'LINDEINDIA.NS', 'MUTHOOTFIN.NS', 'RATNAMANI.NS', 'SHOPERSTOP.NS', 'SIEMENS.NS', 'SUPREMEIND.NS', 'TATAINVEST.NS', 'TIINDIA.NS', 'TRENT.NS', 'UBL.NS', 'VGUARD.NS'],
'2019-02-01': ['AXISBANK.NS', 'KAJARIACER.NS', 'TANLA.NS', 'WIPRO.NS'],
'2019-03-01': ['BALRAMCHIN.NS', 'BATAINDIA.NS', 'JKLAKSHMI.NS', 'MANAPPURAM.NS', 'PFIZER.NS', 'RAMCOCEM.NS', 'SHARDACROP.NS', 'TECHM.NS'],
'2019-04-01': ['ACC.NS', 'APLAPOLLO.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BATAINDIA.NS', 'BEML.NS', 'BLUEDART.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CENTURYPLY.NS', 'CERA.NS', 'CHOLAFIN.NS', 'COROMANDEL.NS', 'CUB.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GPPL.NS', 'GRANULES.NS', 'HDFCBANK.NS', 'IDFCFIRSTB.NS', 'INDIGO.NS', 'IPCALAB.NS', 'JBCHEPHARM.NS', 'KNRCON.NS', 'LAURUSLABS.NS', 'LICHSGFIN.NS', 'MANAPPURAM.NS', 'MUTHOOTFIN.NS', 'NAVINFLUOR.NS', 'NCC.NS', 'OBEROIRLTY.NS', 'PEL.NS', 'PIIND.NS', 'PNB.NS', 'RECLTD.NS', 'SBIN.NS', 'SRF.NS', 'SUNTECK.NS', 'SUPRAJIT.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'UNIONBANK.NS', 'UPL.NS', 'VOLTAS.NS'],
'2019-05-01': ['APLAPOLLO.NS', 'AUBANK.NS', 'DRREDDY.NS', 'EPL.NS', 'HCLTECH.NS', 'HONAUT.NS', 'ICICIGI.NS', 'JKCEMENT.NS', 'LTTS.NS', 'LUPIN.NS', 'MAHABANK.NS', 'MCX.NS', 'ONGC.NS', 'RELAXO.NS', 'SHREECEM.NS', 'SRF.NS', 'TCS.NS', 'TECHM.NS', 'TITAN.NS', 'UPL.NS', 'WIPRO.NS'],
'2019-06-01': ['AARTIIND.NS', 'ABB.NS', 'AEGISCHEM.NS', 'AUBANK.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BIRLACORPN.NS', 'BLUESTARCO.NS', 'CGCL.NS', 'CHAMBLFERT.NS', 'DEEPAKNTR.NS', 'FACT.NS', 'FEDERALBNK.NS', 'GALAXYSURF.NS', 'HDFCLIFE.NS', 'HINDPETRO.NS', 'HONAUT.NS', 'ICICIGI.NS', 'IGL.NS', 'INDIGO.NS', 'INGERRAND.NS', 'JKCEMENT.NS', 'JMFINANCIL.NS', 'JUSTDIAL.NS', 'KNRCON.NS', 'KOTAKBANK.NS', 'LICHSGFIN.NS', 'LT.NS', 'MOTILALOFS.NS', 'MUTHOOTFIN.NS', 'NESTLEIND.NS', 'PGHL.NS', 'SBILIFE.NS', 'SBIN.NS', 'SHREECEM.NS', 'SOBHA.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATAINVEST.NS', 'TIMKEN.NS', 'TITAN.NS', 'VAIBHAVGBL.NS'],
'2019-07-01': ['ABBOTINDIA.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BSE.NS', 'CONCOR.NS', 'GALAXYSURF.NS', 'HDFCLIFE.NS', 'NESTLEIND.NS', 'NMDC.NS', 'NTPC.NS', 'RAJESHEXPO.NS', 'RECLTD.NS', 'SOLARINDS.NS', 'TATACONSUM.NS', 'TIMKEN.NS', 'TITAN.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'VAIBHAVGBL.NS'],
'2019-08-01': ['ASIANPAINT.NS', 'ZYDUSWELL.NS'],
'2019-09-01': ['ASIANPAINT.NS', 'BATAINDIA.NS', 'BERGEPAINT.NS', 'BRIGADE.NS', 'COFORGE.NS', 'COLPAL.NS', 'DIXON.NS', 'MCX.NS', 'NAM-INDIA.NS', 'NESTLEIND.NS', 'PETRONET.NS', 'PIDILITIND.NS', 'ZYDUSWELL.NS'],
'2019-10-01': ['ADANIGREEN.NS', 'ADANIPORTS.NS', 'ALKYLAMINE.NS', 'ASIANPAINT.NS', 'BAJAJFINSV.NS', 'BRIGADE.NS', 'CHOLAFIN.NS', 'CONCOR.NS', 'DIXON.NS', 'EIHOTEL.NS', 'FINEORG.NS', 'FINPIPE.NS', 'GALAXYSURF.NS', 'GESHIP.NS', 'GICRE.NS', 'HDFCLIFE.NS', 'ICICIPRULI.NS', 'INDHOTEL.NS', 'INDIGO.NS', 'INGERRAND.NS', 'ISEC.NS', 'KANSAINER.NS', 'KEI.NS', 'KOTAKBANK.NS', 'LAURUSLABS.NS', 'MANAPPURAM.NS', 'MCDOWELL-N.NS', 'NESTLEIND.NS', 'RALLIS.NS', 'RELAXO.NS', 'RITES.NS', 'SUPREMEIND.NS'],
'2019-11-01': ['AARTIDRUGS.NS', 'AARTIIND.NS', 'ASTERDM.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BDL.NS', 'BEML.NS', 'BPCL.NS', 'CASTROLIND.NS', 'CDSL.NS', 'CHAMBLFERT.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'CRISIL.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DELTACORP.NS', 'FDC.NS', 'FORTIS.NS', 'GODREJCP.NS', 'GRANULES.NS', 'GUJGASLTD.NS', 'HCLTECH.NS', 'HUDCO.NS', 'IGL.NS', 'INFIBEAM.NS', 'INGERRAND.NS', 'KANSAINER.NS', 'KPRMILL.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'MCX.NS', 'MOTHERSON.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'NH.NS', 'NMDC.NS', 'QUESS.NS', 'RELAXO.NS', 'RELIANCE.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TCS.NS', 'TRENT.NS', 'TVSMOTOR.NS', 'VGUARD.NS', 'WELCORP.NS'],
'2019-12-01': ['APLAPOLLO.NS', 'BCG.NS', 'EPL.NS', 'GESHIP.NS', 'GMRINFRA.NS', 'GUJGASLTD.NS', 'IDBI.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IIFL.NS', 'INFIBEAM.NS', 'JINDALSTEL.NS', 'KARURVYSYA.NS'],
'2020-01-01': ['AMBER.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BCG.NS', 'CRISIL.NS', 'EPL.NS', 'GMMPFAUDLR.NS', 'GUJGASLTD.NS', 'INFIBEAM.NS', 'ISEC.NS', 'JBMA.NS', 'JINDALSTEL.NS', 'SRF.NS', 'TATASTEEL.NS'],
'2020-02-01': ['AARTIIND.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'BIRLACORPN.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CANFINHOME.NS', 'CCL.NS', 'CHAMBLFERT.NS', 'COFORGE.NS', 'CYIENT.NS', 'DIVISLAB.NS', 'DLF.NS', 'DMART.NS', 'FDC.NS', 'FINEORG.NS', 'FORTIS.NS', 'GALAXYSURF.NS', 'GMMPFAUDLR.NS', 'GODREJPROP.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'IPCALAB.NS', 'IRB.NS', 'IRCON.NS', 'ISEC.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'KNRCON.NS', 'LAURUSLABS.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'NAUKRI.NS', 'PIDILITIND.NS', 'QUESS.NS', 'RADICO.NS', 'RATNAMANI.NS', 'RTNINDIA.NS', 'SFL.NS', 'TATACHEM.NS', 'TATACONSUM.NS', 'VMART.NS', 'ZFCVINDIA.NS'],
'2020-03-01': ['ABBOTINDIA.NS', 'ALOKINDS.NS', 'AUBANK.NS', 'RATNAMANI.NS'],
'2020-04-01': ['AAVAS.NS', 'ACC.NS', 'APOLLOHOSP.NS', 'AVANTIFEED.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BANDHANBNK.NS', 'BATAINDIA.NS', 'BBTC.NS', 'BOSCHLTD.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CHALET.NS', 'CONCOR.NS', 'DALBHARAT.NS', 'DCMSHRIRAM.NS', 'EICHERMOT.NS', 'ERIS.NS', 'EXIDEIND.NS', 'GALAXYSURF.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'ICICIBANK.NS', 'ISEC.NS', 'JKCEMENT.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KAJARIACER.NS', 'KRBL.NS', 'KSB.NS', 'LAXMIMACH.NS', 'LICHSGFIN.NS', 'LT.NS', 'LTTS.NS', 'MANAPPURAM.NS', 'MARUTI.NS', 'MCDOWELL-N.NS', 'MOTILALOFS.NS', 'PAGEIND.NS', 'PHOENIXLTD.NS', 'PRESTIGE.NS', 'RAJESHEXPO.NS', 'RATNAMANI.NS', 'SANOFI.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SHREECEM.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SRF.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUNTV.NS', 'SYNGENE.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TITAN.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'UPL.NS', 'VGUARD.NS', 'VMART.NS', 'VOLTAS.NS', 'ZEEL.NS'],
'2020-05-01': ['AARTIIND.NS', 'ADANIGREEN.NS', 'CESC.NS', 'LAURUSLABS.NS', 'TATACOMM.NS', 'TORNTPOWER.NS'],
'2020-06-01': ['ALKYLAMINE.NS', 'BCG.NS', 'BIRLACORPN.NS', 'CCL.NS', 'DIXON.NS', 'EIDPARRY.NS', 'ESCORTS.NS', 'GMMPFAUDLR.NS', 'GODREJIND.NS', 'IDEA.NS', 'INDIACEM.NS', 'INDUSTOWER.NS', 'ITC.NS', 'JBCHEPHARM.NS', 'JINDALSTEL.NS', 'JKLAKSHMI.NS', 'MARICO.NS', 'MCX.NS', 'POLYMED.NS', 'RELAXO.NS', 'TANLA.NS', 'VAIBHAVGBL.NS', 'WIPRO.NS', 'ZFCVINDIA.NS'],
'2020-07-01': ['ABB.NS', 'ASTERDM.NS', 'BALAMINES.NS', 'BALKRISIND.NS', 'BAYERCROP.NS', 'BRITANNIA.NS', 'CGCL.NS', 'COROMANDEL.NS', 'CRISIL.NS', 'DALBHARAT.NS', 'DIXON.NS', 'EICHERMOT.NS', 'ESCORTS.NS', 'GAEL.NS', 'GALAXYSURF.NS', 'GODREJCP.NS', 'HEROMOTOCO.NS', 'ISEC.NS', 'JKCEMENT.NS', 'JUBLPHARMA.NS', 'KANSAINER.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'LUXIND.NS', 'M&M.NS', 'MARICO.NS', 'MFSL.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'OFSS.NS', 'ORIENTELEC.NS', 'PEL.NS', 'PERSISTENT.NS', 'PNCINFRA.NS', 'RALLIS.NS', 'RELIANCE.NS', 'SAREGAMA.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SUNDARMFIN.NS', 'SWANENERGY.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TIINDIA.NS', 'ZFCVINDIA.NS'],
'2020-08-01': ['APOLLOHOSP.NS', 'BSOFT.NS', 'CDSL.NS', 'CGCL.NS', 'CYIENT.NS', 'DALBHARAT.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DRREDDY.NS', 'EPL.NS', 'FSL.NS', 'HCLTECH.NS', 'INFIBEAM.NS', 'INFY.NS', 'IRB.NS', 'JINDALSTEL.NS', 'NATCOPHARM.NS', 'SUPREMEIND.NS', 'TANLA.NS', 'TATACOMM.NS', 'TECHM.NS', 'TIINDIA.NS', 'WIPRO.NS', 'ZENSARTECH.NS', 'ZFCVINDIA.NS'],
'2020-09-01': ['ALLCARGO.NS', 'ASHOKLEY.NS', 'AXISBANK.NS', 'BANKINDIA.NS', 'BHARATFORG.NS', 'BLUESTARCO.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CGCL.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DIVISLAB.NS', 'ECLERX.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'FINPIPE.NS', 'FSL.NS', 'GNFC.NS', 'GPIL.NS', 'IDFC.NS', 'INDHOTEL.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INTELLECT.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'KEC.NS', 'KNRCON.NS', 'LICHSGFIN.NS', 'MAHLIFE.NS', 'METROPOLIS.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'POONAWALLA.NS', 'RATNAMANI.NS', 'RTNINDIA.NS', 'SCHAEFFLER.NS', 'SOLARINDS.NS', 'SUNTECK.NS', 'TATASTEEL.NS', 'TECHM.NS', 'TIMKEN.NS', 'USHAMART.NS', 'VEDL.NS'],
'2020-10-01': ['APLAPOLLO.NS', 'BLUEDART.NS', 'DRREDDY.NS', 'INTELLECT.NS', 'KAJARIACER.NS', 'LAURUSLABS.NS', 'NATCOPHARM.NS', 'TANLA.NS', 'VINATIORGA.NS', 'WELSPUNLIV.NS', 'WIPRO.NS'],
'2020-11-01': ['ACC.NS', 'ADANIENT.NS', 'AMBUJACEM.NS', 'APLAPOLLO.NS', 'ATGL.NS', 'CARBORUNIV.NS', 'CGCL.NS', 'CHOLAFIN.NS', 'HAVELLS.NS', 'JKCEMENT.NS', 'JSL.NS', 'KAJARIACER.NS', 'KOTAKBANK.NS', 'KPRMILL.NS', 'MAHLIFE.NS', 'PRSMJOHNSN.NS', 'SAREGAMA.NS', 'SWANENERGY.NS', 'TEJASNET.NS'],
'2020-12-01': ['ADANIPORTS.NS', 'AEGISCHEM.NS', 'AFFLE.NS', 'APLAPOLLO.NS', 'ASAHIINDIA.NS', 'ASTRAL.NS', 'BAJAJHLDNG.NS', 'BALKRISIND.NS', 'BANDHANBNK.NS', 'BEL.NS', 'BORORENEW.NS', 'BRIGADE.NS', 'CANBK.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CENTURYPLY.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'CREDITACC.NS', 'CYIENT.NS', 'DEEPAKNTR.NS', 'ELGIEQUIP.NS', 'ENGINERSIN.NS', 'EXIDEIND.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'FLUOROCHEM.NS', 'FORTIS.NS', 'GAIL.NS', 'GICRE.NS', 'GILLETTE.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GSPL.NS', 'HDFCBANK.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'INDUSTOWER.NS', 'INTELLECT.NS', 'IOB.NS', 'ITC.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JSWSTEEL.NS', 'KNRCON.NS', 'KSB.NS', 'LT.NS', 'LUXIND.NS', 'M&M.NS', 'MANAPPURAM.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MHRIL.NS', 'MINDACORP.NS', 'MRF.NS', 'NIACL.NS', 'ORIENTELEC.NS', 'PCBL.NS', 'PHOENIXLTD.NS', 'PNB.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'RBLBANK.NS', 'SAFARI.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SJVN.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUNTECK.NS', 'TATAINVEST.NS', 'TATAPOWER.NS', 'TVSMOTOR.NS', 'UNIONBANK.NS', 'VAIBHAVGBL.NS', 'VEDL.NS', 'VGUARD.NS', 'VOLTAS.NS', 'ZENSARTECH.NS'],
'2021-01-01': ['ABB.NS', 'ADANIPORTS.NS', 'ATGL.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BLUEDART.NS', 'BRIGADE.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'CHAMBLFERT.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'CROMPTON.NS', 'DABUR.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DLF.NS', 'DMART.NS', 'ECLERX.NS', 'ERIS.NS', 'FSL.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GUJGASLTD.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'INDIACEM.NS', 'INFY.NS', 'JSWSTEEL.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KEI.NS', 'KOTAKBANK.NS', 'KPITTECH.NS', 'KSB.NS', 'LAURUSLABS.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'LUXIND.NS', 'MPHASIS.NS', 'NAUKRI.NS', 'OBEROIRLTY.NS', 'PAGEIND.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PRAJIND.NS', 'QUESS.NS', 'RELAXO.NS', 'SAREGAMA.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SYNGENE.NS', 'TATACHEM.NS', 'TATAELXSI.NS', 'TECHM.NS', 'TIMKEN.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'VMART.NS', 'WIPRO.NS'],
'2021-02-01': ['ABB.NS', 'AEGISCHEM.NS', 'BAJAJ-AUTO.NS', 'BOSCHLTD.NS', 'CEATLTD.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'ECLERX.NS', 'EMAMILTD.NS', 'GRASIM.NS', 'KNRCON.NS', 'LAXMIMACH.NS', 'MAHLIFE.NS', 'SAREGAMA.NS', 'SOLARINDS.NS', 'TATAELXSI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TVSMOTOR.NS', 'UBL.NS', 'VGUARD.NS'],
'2021-03-01': ['ABFRL.NS', 'ADANIPORTS.NS', 'AFFLE.NS', 'AMBER.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'ASTRAL.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BANKINDIA.NS', 'BEML.NS', 'BHEL.NS', 'BPCL.NS', 'CENTURYPLY.NS', 'CGPOWER.NS', 'CONCOR.NS', 'DALBHARAT.NS', 'DEEPAKFERT.NS', 'DIXON.NS', 'GICRE.NS', 'GPIL.NS', 'GSFC.NS', 'HEG.NS', 'IDFC.NS', 'IOB.NS', 'IRCTC.NS', 'JBMA.NS', 'JKPAPER.NS', 'KAJARIACER.NS', 'KSB.NS', 'LAXMIMACH.NS', 'MAHABANK.NS', 'MFSL.NS', 'MOTHERSON.NS', 'NTPC.NS', 'OIL.NS', 'OLECTRA.NS', 'PNCINFRA.NS', 'PRINCEPIPE.NS', 'QUESS.NS', 'RADICO.NS', 'RAIN.NS', 'RATNAMANI.NS', 'REDINGTON.NS', 'SAFARI.NS', 'SAIL.NS', 'SONATSOFTW.NS', 'SYMPHONY.NS', 'TANLA.NS', 'TATAPOWER.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'UNIONBANK.NS', 'VEDL.NS', 'VIPIND.NS', 'VTL.NS'],
'2021-04-01': ['APLAPOLLO.NS', 'CGPOWER.NS', 'DALBHARAT.NS', 'ECLERX.NS', 'GPIL.NS', 'GUJGASLTD.NS', 'JSWSTEEL.NS', 'KPITTECH.NS', 'LINDEINDIA.NS', 'METROPOLIS.NS', 'NMDC.NS', 'OLECTRA.NS', 'PRAJIND.NS', 'SAREGAMA.NS', 'SCHAEFFLER.NS', 'TEAMLEASE.NS', 'TIINDIA.NS', 'VEDL.NS', 'VTL.NS'],
'2021-05-01': ['BALRAMCHIN.NS', 'DCMSHRIRAM.NS', 'ECLERX.NS', 'FINPIPE.NS', 'GLENMARK.NS', 'GNFC.NS', 'GRAPHITE.NS', 'HEG.NS', 'JSL.NS', 'JSWENERGY.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'NAVINFLUOR.NS', 'NMDC.NS', 'RENUKA.NS', 'RHIM.NS', 'SAREGAMA.NS', 'USHAMART.NS', 'VEDL.NS', 'VINATIORGA.NS'],
'2021-06-01': ['ASIANPAINT.NS', 'AVANTIFEED.NS', 'BATAINDIA.NS', 'BIRLACORPN.NS', 'BSOFT.NS', 'CCL.NS', 'CGCL.NS', 'CHALET.NS', 'COLPAL.NS', 'CONCOR.NS', 'CYIENT.NS', 'DIVISLAB.NS', 'ERIS.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'FSL.NS', 'GESHIP.NS', 'IBULHSGFIN.NS', 'INDHOTEL.NS', 'JAMNAAUTO.NS', 'JINDALSAW.NS', 'KEI.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'LAURUSLABS.NS', 'MASTEK.NS', 'MHRIL.NS', 'MOTILALOFS.NS', 'PERSISTENT.NS', 'PIDILITIND.NS', 'POWERINDIA.NS', 'RELIANCE.NS', 'SBIN.NS', 'SONATSOFTW.NS', 'TTKPRESTIG.NS', 'UCOBANK.NS', 'WIPRO.NS'],
'2021-07-01': ['AAVAS.NS', 'ABB.NS', 'AIAENG.NS', 'ALLCARGO.NS', 'APLAPOLLO.NS', 'APOLLOHOSP.NS', 'BAYERCROP.NS', 'BSOFT.NS', 'CENTRALBK.NS', 'CENTURYTEX.NS', 'CGCL.NS', 'CIEINDIA.NS', 'COFORGE.NS', 'DCMSHRIRAM.NS', 'ENDURANCE.NS', 'FINPIPE.NS', 'JBCHEPHARM.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'KPITTECH.NS', 'LUXIND.NS', 'MARICO.NS', 'MASTEK.NS', 'NAVINFLUOR.NS', 'OIL.NS', 'PEL.NS', 'POLYCAB.NS', 'POLYPLEX.NS', 'SCHAEFFLER.NS', 'SKFINDIA.NS', 'SRF.NS', 'TATACONSUM.NS', 'TTKPRESTIG.NS'],
'2021-08-01': ['360ONE.NS', 'ALKYLAMINE.NS', 'APOLLOHOSP.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BDL.NS', 'BIRLACORPN.NS', 'CENTURYTEX.NS', 'CIEINDIA.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'DMART.NS', 'ECLERX.NS', 'ENDURANCE.NS', 'GODREJPROP.NS', 'GPIL.NS', 'HAVELLS.NS', 'INFY.NS', 'KSB.NS', 'LTIM.NS', 'LUXIND.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MPHASIS.NS', 'OFSS.NS', 'PERSISTENT.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'RATNAMANI.NS', 'SANOFI.NS', 'SKFINDIA.NS', 'SUPRAJIT.NS', 'TATACOMM.NS', 'TEAMLEASE.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS'],
'2021-09-01': ['BHARTIARTL.NS', 'BLS.NS', 'COFORGE.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'FORTIS.NS', 'HDFCLIFE.NS', 'INDIGO.NS', 'IPCALAB.NS', 'IRCTC.NS', 'KAJARIACER.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'LTTS.NS', 'MPHASIS.NS', 'PERSISTENT.NS', 'PGHH.NS', 'POLYCAB.NS', 'SBILIFE.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TEJASNET.NS', 'TIINDIA.NS', 'TITAN.NS', 'WIPRO.NS'],
'2021-10-01': ['ABFRL.NS', 'AFFLE.NS', 'ALKEM.NS', 'ALLCARGO.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BLUESTARCO.NS', 'CANFINHOME.NS', 'CARBORUNIV.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CERA.NS', 'DIXON.NS', 'DMART.NS', 'FLUOROCHEM.NS', 'GNFC.NS', 'GRASIM.NS', 'HINDPETRO.NS', 'HONAUT.NS', 'INDHOTEL.NS', 'IRB.NS', 'IRCTC.NS', 'ITC.NS', 'KEI.NS', 'KOTAKBANK.NS', 'LTTS.NS', 'M&MFIN.NS', 'MASTEK.NS', 'MHRIL.NS', 'OBEROIRLTY.NS', 'PRESTIGE.NS', 'RELIANCE.NS', 'SCHAEFFLER.NS', 'SRF.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUPREMEIND.NS', 'SWSOLAR.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TEJASNET.NS', 'TRITURBINE.NS', 'VOLTAS.NS', 'WELCORP.NS'],
'2021-11-01': ['ASAHIINDIA.NS', 'BIRLACORPN.NS', 'BLUESTARCO.NS', 'CANBK.NS', 'CENTURYPLY.NS', 'CGPOWER.NS', 'ICICIBANK.NS', 'LTIM.NS', 'MANAPPURAM.NS', 'MINDACORP.NS', 'OLECTRA.NS', 'RADICO.NS', 'SHOPERSTOP.NS', 'TATAMOTORS.NS', 'TRITURBINE.NS'],
'2021-12-01': ['APOLLOHOSP.NS', 'BEML.NS', 'BORORENEW.NS', 'ESCORTS.NS', 'JBMA.NS', 'KPITTECH.NS', 'OLECTRA.NS', 'SFL.NS', 'TRIDENT.NS'],
'2022-01-01': ['CGPOWER.NS', 'ECLERX.NS', 'ESCORTS.NS', 'HCLTECH.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'MAXHEALTH.NS', 'PERSISTENT.NS', 'SCHAEFFLER.NS', 'TECHM.NS', 'UNOMINDA.NS', 'WIPRO.NS'],
'2022-02-01': ['ADANIGREEN.NS', 'BANKBARODA.NS', 'BDL.NS', 'CANBK.NS', 'DEEPAKFERT.NS', 'GAEL.NS', 'NTPC.NS', 'OIL.NS', 'ONGC.NS', 'TATAELXSI.NS', 'TV18BRDCST.NS'],
'2022-03-01': ['HINDALCO.NS'],
'2022-04-01': ['ADANIENT.NS', 'ATGL.NS', 'BAYERCROP.NS', 'BLUEDART.NS', 'CENTURYPLY.NS', 'CERA.NS', 'CREDITACC.NS', 'CRISIL.NS', 'CUMMINSIND.NS', 'GSFC.NS', 'GUJALKALI.NS', 'INDHOTEL.NS', 'JINDALSTEL.NS', 'JKPAPER.NS', 'KEI.NS', 'KSB.NS', 'MASTEK.NS', 'NH.NS', 'PHOENIXLTD.NS', 'POLYMED.NS', 'RATNAMANI.NS', 'RHIM.NS', 'SHOPERSTOP.NS', 'SOLARINDS.NS', 'SUMICHEM.NS', 'SUVENPHAR.NS', 'SWANENERGY.NS', 'TATAELXSI.NS', 'VIPIND.NS'],
'2022-05-01': ['ADANIENT.NS', 'ADANIGREEN.NS', 'AIAENG.NS', 'ANGELONE.NS', 'COLPAL.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'CRISIL.NS', 'M&M.NS', 'MRF.NS', 'POLYPLEX.NS', 'VARROC.NS'],
'2022-06-01': ['BALKRISIND.NS', 'BAYERCROP.NS', 'BLUEDART.NS', 'BRITANNIA.NS', 'HAL.NS', 'HEROMOTOCO.NS', 'M&M.NS', 'SCHAEFFLER.NS', 'SKFINDIA.NS', 'TIMKEN.NS', 'TVSMOTOR.NS', 'VGUARD.NS'],
'2022-07-01': ['ABB.NS', 'ACC.NS', 'ADANIENT.NS', 'APLLTD.NS', 'ATGL.NS', 'BALKRISIND.NS', 'BAYERCROP.NS', 'CERA.NS', 'CRISIL.NS', 'DIXON.NS', 'FINEORG.NS', 'GALAXYSURF.NS', 'GODREJCP.NS', 'GRINDWELL.NS', 'HAL.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'ICICIBANK.NS', 'JUBLFOOD.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LT.NS', 'MFSL.NS', 'MRF.NS', 'NAUKRI.NS', 'NAVINFLUOR.NS', 'PGHL.NS', 'POWERINDIA.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'RELIANCE.NS', 'ROSSARI.NS', 'SOLARINDS.NS', 'SUPREMEIND.NS', 'TATAELXSI.NS', 'TEAMLEASE.NS', 'TRENT.NS', 'VINATIORGA.NS', 'WHIRLPOOL.NS'],
'2022-08-01': ['AAVAS.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ALKYLAMINE.NS', 'APOLLOHOSP.NS', 'ATUL.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BHARATFORG.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'CERA.NS', 'COFORGE.NS', 'DALBHARAT.NS', 'DMART.NS', 'EICHERMOT.NS', 'ESCORTS.NS', 'FINEORG.NS', 'FLUOROCHEM.NS', 'GMMPFAUDLR.NS', 'GNFC.NS', 'HDFCBANK.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'INDIGO.NS', 'INGERRAND.NS', 'JKCEMENT.NS', 'JSWSTEEL.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'LTIM.NS', 'M&M.NS', 'MARUTI.NS', 'NAUKRI.NS', 'NESTLEIND.NS', 'PGHH.NS', 'PIIND.NS', 'RAMCOCEM.NS', 'SIEMENS.NS', 'SOBHA.NS', 'SUNDRMFAST.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TIINDIA.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TRENT.NS', 'VINATIORGA.NS', 'ZFCVINDIA.NS'],
'2022-09-01': ['ABFRL.NS', 'AEGISCHEM.NS', 'ALLCARGO.NS', 'AMBUJACEM.NS', 'BANKBARODA.NS', 'BEL.NS', 'BHEL.NS', 'CCL.NS', 'FEDERALBNK.NS', 'FINPIPE.NS', 'GPPL.NS', 'HINDCOPPER.NS', 'IBULHSGFIN.NS', 'ICICIBANK.NS', 'IDBI.NS', 'IDFC.NS', 'INDHOTEL.NS', 'INDIANB.NS', 'ITC.NS', 'JSWENERGY.NS', 'KARURVYSYA.NS', 'KRBL.NS', 'MMTC.NS', 'NCC.NS', 'NHPC.NS', 'OBEROIRLTY.NS', 'PCBL.NS', 'PNCINFRA.NS', 'POLYMED.NS', 'PRAJIND.NS', 'RAIN.NS', 'RBLBANK.NS', 'RECLTD.NS', 'RVNL.NS', 'SJVN.NS', 'TORNTPOWER.NS', 'TRITURBINE.NS', 'TTKPRESTIG.NS', 'UNIONBANK.NS'],
'2022-10-01': ['ABFRL.NS', 'BHARTIARTL.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'FLUOROCHEM.NS', 'GRANULES.NS', 'INDHOTEL.NS', 'INGERRAND.NS', 'JMFINANCIL.NS', 'KPITTECH.NS', 'KRBL.NS', 'LEMONTREE.NS', 'MAZDOCK.NS', 'RITES.NS', 'SAFARI.NS', 'SHOPERSTOP.NS', 'SOLARINDS.NS', 'TEJASNET.NS', 'TRITURBINE.NS'],
'2022-11-01': ['ABFRL.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BLUESTARCO.NS', 'CIPLA.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'CONCOR.NS', 'CUMMINSIND.NS', 'DEEPAKNTR.NS', 'EICHERMOT.NS', 'ENGINERSIN.NS', 'FDC.NS', 'FINCABLES.NS', 'GRANULES.NS', 'HCLTECH.NS', 'KEI.NS', 'M&M.NS', 'MARUTI.NS', 'MAXHEALTH.NS', 'MAZDOCK.NS', 'METROPOLIS.NS', 'NH.NS', 'PFC.NS', 'PNB.NS', 'RAJESHEXPO.NS', 'RITES.NS', 'SAFARI.NS', 'SPARC.NS', 'SUNPHARMA.NS', 'SYNGENE.NS', 'TATAMTRDVR.NS', 'TORNTPHARM.NS', 'TRENT.NS', 'VIPIND.NS', 'ZYDUSLIFE.NS'],
'2022-12-01': ['BLS.NS', 'BPCL.NS', 'CEATLTD.NS', 'DABUR.NS', 'EQUITASBNK.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'GESHIP.NS', 'GICRE.NS', 'GODREJIND.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HDFCLIFE.NS', 'HINDPETRO.NS', 'HINDZINC.NS', 'IDBI.NS', 'IIFL.NS', 'IRB.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JKCEMENT.NS', 'JKLAKSHMI.NS', 'KNRCON.NS', 'MAHABANK.NS', 'MAZDOCK.NS', 'MMTC.NS', 'NCC.NS', 'NIACL.NS', 'OIL.NS', 'ONGC.NS', 'PERSISTENT.NS', 'PNB.NS', 'RBLBANK.NS', 'RCF.NS', 'REDINGTON.NS', 'SJVN.NS', 'SONATSOFTW.NS', 'SUZLON.NS'],
'2023-01-01': ['APARINDS.NS', 'CIEINDIA.NS', 'GPPL.NS', 'JBMA.NS', 'RBLBANK.NS', 'RECLTD.NS', 'SWANENERGY.NS', 'UCOBANK.NS', 'USHAMART.NS'],
'2023-02-01': ['AEGISCHEM.NS', 'CARBORUNIV.NS', 'CIEINDIA.NS', 'COFORGE.NS', 'CRISIL.NS', 'ITC.NS', 'JINDALSAW.NS', 'JSL.NS', 'KPITTECH.NS', 'M&M.NS', 'MFSL.NS', 'NHPC.NS', 'POLYCAB.NS', 'TATAMOTORS.NS'],
'2023-03-01': ['BLUESTARCO.NS', 'CRISIL.NS', 'FINCABLES.NS', 'PGHL.NS', 'SANOFI.NS', 'SONATSOFTW.NS', 'ZENSARTECH.NS'],
'2023-04-01': ['ALKEM.NS', 'AUROPHARMA.NS', 'BOSCHLTD.NS', 'INGERRAND.NS'],
'2023-05-01': ['ALKEM.NS', 'APOLLOTYRE.NS', 'BAJAJHLDNG.NS', 'BANKBARODA.NS', 'BBTC.NS', 'BRITANNIA.NS', 'BSE.NS', 'CANFINHOME.NS', 'CENTRALBK.NS', 'CHALET.NS', 'CHOLAFIN.NS', 'COLPAL.NS', 'CYIENT.NS', 'DLF.NS', 'DRREDDY.NS', 'EIHOTEL.NS', 'EXIDEIND.NS', 'FACT.NS', 'FDC.NS', 'FINCABLES.NS', 'GAEL.NS', 'GMRINFRA.NS', 'GODREJPROP.NS', 'HEG.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IGL.NS', 'JBMA.NS', 'KEI.NS', 'LT.NS', 'MINDACORP.NS', 'MRPL.NS', 'NCC.NS', 'PCBL.NS', 'PIIND.NS', 'POLYCAB.NS', 'PRESTIGE.NS', 'RECLTD.NS', 'SAFARI.NS', 'SJVN.NS', 'SRF.NS', 'TATACONSUM.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TORNTPHARM.NS', 'TRITURBINE.NS', 'VARROC.NS', 'ZYDUSLIFE.NS'],
'2023-06-01': ['AVANTIFEED.NS', 'BEL.NS', 'BERGEPAINT.NS', 'BORORENEW.NS', 'BRIGADE.NS', 'BSE.NS', 'CCL.NS', 'CHALET.NS', 'CHOLAHLDNG.NS', 'CONCOR.NS', 'DLF.NS', 'ENGINERSIN.NS', 'EQUITASBNK.NS', 'EXIDEIND.NS', 'FSL.NS', 'GICRE.NS', 'GLENMARK.NS', 'HDFCLIFE.NS', 'HINDCOPPER.NS', 'JMFINANCIL.NS', 'LEMONTREE.NS', 'MAHABANK.NS', 'MARICO.NS', 'MAXHEALTH.NS', 'NAM-INDIA.NS', 'NLCINDIA.NS', 'OLECTRA.NS', 'PCBL.NS', 'PFC.NS', 'POONAWALLA.NS', 'RECLTD.NS', 'SONATSOFTW.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TV18BRDCST.NS', 'VBL.NS', 'WELCORP.NS', 'WIPRO.NS', 'ZENSARTECH.NS'],
'2023-07-01': ['ABB.NS', 'ABCAPITAL.NS', 'APARINDS.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'AUROPHARMA.NS', 'BAJAJ-AUTO.NS', 'BCG.NS', 'BEL.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'BIRLACORPN.NS', 'BLS.NS', 'BSE.NS', 'BSOFT.NS', 'CANFINHOME.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CHOLAFIN.NS', 'CUMMINSIND.NS', 'ERIS.NS', 'FACT.NS', 'FORTIS.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GODREJPROP.NS', 'HDFCLIFE.NS', 'HEG.NS', 'ICICIPRULI.NS', 'IDFCFIRSTB.NS', 'INDUSINDBK.NS', 'INTELLECT.NS', 'ISEC.NS', 'JINDALSAW.NS', 'JSWSTEEL.NS', 'KARURVYSYA.NS', 'LT.NS', 'M&M.NS', 'M&MFIN.NS', 'MAZDOCK.NS', 'MCDOWELL-N.NS', 'MRPL.NS', 'NATCOPHARM.NS', 'NLCINDIA.NS', 'PCBL.NS', 'QUESS.NS', 'RECLTD.NS', 'SAREGAMA.NS', 'SBILIFE.NS', 'SHOPERSTOP.NS', 'SKFINDIA.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUPREMEIND.NS', 'SUZLON.NS', 'SYNGENE.NS', 'TATACOMM.NS', 'TATAMOTORS.NS', 'TIINDIA.NS', 'TORNTPHARM.NS', 'UTIAMC.NS'],
'2023-08-01': ['360ONE.NS', 'AUROPHARMA.NS', 'BHEL.NS', 'CASTROLIND.NS', 'CESC.NS', 'EMAMILTD.NS', 'FINCABLES.NS', 'FORTIS.NS', 'FSL.NS', 'GAIL.NS', 'GICRE.NS', 'GLAND.NS', 'GLENMARK.NS', 'GPIL.NS', 'GRAPHITE.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'IBULHSGFIN.NS', 'ICICIBANK.NS', 'IDFC.NS', 'IIFL.NS', 'ISEC.NS', 'JINDALSTEL.NS', 'JSL.NS', 'KANSAINER.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'NATIONALUM.NS', 'NBCC.NS', 'NHPC.NS', 'NMDC.NS', 'OBEROIRLTY.NS', 'OIL.NS', 'ONGC.NS', 'PATANJALI.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'RATNAMANI.NS', 'SAIL.NS', 'SJVN.NS', 'SUNTV.NS', 'TATAMOTORS.NS', 'TATAPOWER.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'ZEEL.NS'],
'2023-09-01': ['ALOKINDS.NS', 'AVANTIFEED.NS', 'CENTRALBK.NS', 'CESC.NS', 'CSBBANK.NS', 'EMAMILTD.NS', 'FEDERALBNK.NS', 'FSL.NS', 'GICRE.NS', 'GPIL.NS', 'GPPL.NS', 'GRAPHITE.NS', 'GSFC.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'HUDCO.NS', 'IDEA.NS', 'IDFCFIRSTB.NS', 'INDHOTEL.NS', 'IRCON.NS', 'JAMNAAUTO.NS', 'JUBLPHARMA.NS', 'KNRCON.NS', 'LEMONTREE.NS', 'MAHABANK.NS', 'MANAPPURAM.NS', 'MMTC.NS', 'MRPL.NS', 'NBCC.NS', 'NETWORK18.NS', 'NMDC.NS', 'NTPC.NS', 'PCBL.NS', 'RALLIS.NS', 'RBLBANK.NS', 'SJVN.NS', 'SPARC.NS', 'SUMICHEM.NS', 'SUZLON.NS', 'SWANENERGY.NS', 'TATASTEEL.NS', 'TRIDENT.NS', 'TTML.NS', 'TV18BRDCST.NS', 'USHAMART.NS', 'WELSPUNLIV.NS', 'ZENSARTECH.NS'],
'2023-10-01': ['BANKINDIA.NS', 'BSE.NS', 'CHOLAHLDNG.NS', 'DCMSHRIRAM.NS', 'ERIS.NS', 'GRANULES.NS', 'IDEA.NS', 'IRCON.NS', 'KNRCON.NS', 'LUPIN.NS', 'MAHABANK.NS', 'NMDC.NS', 'NTPC.NS', 'OIL.NS', 'ONGC.NS', 'PFC.NS', 'PNB.NS', 'PRAJIND.NS', 'RBLBANK.NS', 'SUNDARMFIN.NS', 'SUVENPHAR.NS', 'SUZLON.NS', 'TATAMTRDVR.NS', 'TORNTPOWER.NS', 'UCOBANK.NS', 'UJJIVANSFB.NS', 'UNIONBANK.NS', 'VARROC.NS'],
'2023-11-01': ['CDSL.NS', 'COALINDIA.NS', 'CREDITACC.NS', 'FACT.NS', 'GNFC.NS', 'JINDALSAW.NS', 'MCX.NS', 'NAM-INDIA.NS', 'PERSISTENT.NS', 'PRESTIGE.NS', 'SOLARINDS.NS'],
'2023-12-01': ['AARTIIND.NS', 'AEGISCHEM.NS', 'ANGELONE.NS', 'ATGL.NS', 'AUROPHARMA.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'BSOFT.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'CONCOR.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'FORTIS.NS', 'GRANULES.NS', 'HDFCLIFE.NS', 'IBULHSGFIN.NS', 'INDIACEM.NS', 'LTTS.NS', 'LUPIN.NS', 'METROPOLIS.NS', 'MFSL.NS', 'NBCC.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NTPC.NS', 'OBEROIRLTY.NS', 'PHOENIXLTD.NS', 'PRAJIND.NS', 'PRSMJOHNSN.NS', 'QUESS.NS', 'RADICO.NS', 'RECLTD.NS', 'SJVN.NS', 'SOBHA.NS', 'SUNPHARMA.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'UNOMINDA.NS', 'WELCORP.NS'],
'2024-01-01': ['360ONE.NS', '3MINDIA.NS', 'ADANIGREEN.NS', 'AFFLE.NS', 'AJANTPHARM.NS', 'ALLCARGO.NS', 'ANGELONE.NS', 'APARINDS.NS', 'ASIANPAINT.NS', 'ASTERDM.NS', 'BALAMINES.NS', 'BANKBARODA.NS', 'CHALET.NS', 'COALINDIA.NS', 'CSBBANK.NS', 'DEEPAKNTR.NS', 'DIXON.NS', 'EMAMILTD.NS', 'ENDURANCE.NS', 'EXIDEIND.NS', 'FINEORG.NS', 'GLAND.NS', 'GPIL.NS', 'GSFC.NS', 'GUJGASLTD.NS', 'HDFCAMC.NS', 'HINDUNILVR.NS', 'IDEA.NS', 'IEX.NS', 'IOC.NS', 'IRCTC.NS', 'JSWSTEEL.NS', 'JUBLPHARMA.NS', 'KEI.NS', 'KOTAKBANK.NS', 'LAURUSLABS.NS', 'LT.NS', 'LTIM.NS', 'LTTS.NS', 'MASTEK.NS', 'MPHASIS.NS', 'NESTLEIND.NS', 'OIL.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PIDILITIND.NS', 'PNB.NS', 'POWERINDIA.NS', 'REDINGTON.NS', 'RELIANCE.NS', 'SUVENPHAR.NS', 'SWANENERGY.NS', 'TATACHEM.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TIMKEN.NS', 'TORNTPHARM.NS', 'TVSMOTOR.NS', 'UBL.NS', 'VBL.NS', 'VEDL.NS', 'ZYDUSWELL.NS'],
'2024-02-01': ['ACC.NS', 'AMBUJACEM.NS', 'BANKINDIA.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BLUESTARCO.NS', 'BORORENEW.NS', 'BPCL.NS', 'CHALET.NS', 'CHOLAHLDNG.NS', 'COCHINSHIP.NS', 'CUMMINSIND.NS', 'EIDPARRY.NS', 'ENGINERSIN.NS', 'GICRE.NS', 'GLAXO.NS', 'GODREJIND.NS', 'GPPL.NS', 'GSFC.NS', 'GSPL.NS', 'HFCL.NS', 'HINDCOPPER.NS', 'INDIANB.NS', 'IOB.NS', 'IOC.NS', 'IRCON.NS', 'JBMA.NS', 'JKCEMENT.NS', 'JYOTHYLAB.NS', 'KARURVYSYA.NS', 'LEMONTREE.NS', 'LICHSGFIN.NS', 'LUPIN.NS', 'MAHABANK.NS', 'MRF.NS', 'NATIONALUM.NS', 'NCC.NS', 'NLCINDIA.NS', 'OIL.NS', 'OLECTRA.NS', 'ONGC.NS', 'PFC.NS', 'POWERGRID.NS', 'RAIN.NS', 'RECLTD.NS', 'SOBHA.NS', 'TATAMTRDVR.NS', 'TORNTPHARM.NS', 'UNIONBANK.NS', 'VAIBHAVGBL.NS', 'ZYDUSLIFE.NS'],


}



# Initialize lists to store results
ticker_list = []
percentage_returns = []
first_day_closes = []
last_day_closes = []
start_dates = []  # List to store the start dates
end_dates = []    # List to store the end dates

# Loop through the dictionary and download data for each date-ticker pair
for start_date, tickers in date_ticker_dict.items():
    end_date = pd.to_datetime(start_date) + pd.DateOffset(months=1) - pd.DateOffset(days=1)  # Last day of the month

    # Loop through tickers in this iteration
    for ticker in tickers:
        # Download historical stock data using yfinance for the specified ticker and dates
        try:
            stocks = yf.download(ticker, start=start_date, end=end_date)

            # Extracting the closing prices on the first and last day
            first_day_close = stocks['Close'].iloc[0]
            last_day_close = stocks['Close'].iloc[-1]

            # Calculating percentage return for this ticker
            percentage_return = ((last_day_close - first_day_close) / first_day_close) * 100

            # Appending the results to the lists
            ticker_list.append(ticker)
            percentage_returns.append(percentage_return)
            first_day_closes.append(first_day_close)
            last_day_closes.append(last_day_close)
            start_dates.append(pd.to_datetime(start_date))
            end_dates.append(end_date)  # Append end date for each ticker
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

# Creating a DataFrame with ticker symbols, percentage returns, and capital information
returns_df = pd.DataFrame({
    'Start_Date': start_dates,
    'End_Date': end_dates,
    'Ticker': ticker_list,
    'Percentage_Return': percentage_returns,
    'First_Day_Close': first_day_closes,
    'Last_Day_Close': last_day_closes,
})

# Assuming an initial investment of $10,000 for each stock
initial_investment = 10000

# Calculating the capital at the last day
returns_df['Capital_At_Last_Day'] = initial_investment * (1 + returns_df['Percentage_Return'] / 100)

# Calculating the difference between capital at the last day and capital required
returns_df['Capital_Difference'] = returns_df['Capital_At_Last_Day'] - initial_investment

# Total amount invested
total_invested = initial_investment * len(returns_df)

# Total amount returned
total_returned = returns_df['Capital_At_Last_Day'].sum()

# Calculate percentage return
percentage_return = ((total_returned - total_invested) / total_invested) * 100

# Displaying the DataFrame with ticker names, percentage returns, and capital information
print(returns_df[['Start_Date', 'End_Date', 'Ticker', 'Percentage_Return', 'First_Day_Close', 'Last_Day_Close']])

# Display total amount invested and total amount returned in percentage
print("\nTotal Amount Invested: $", total_invested)
print("Total Amount Returned: $", total_returned)
print("Percentage Return: ", percentage_return, "%")

returns_df.to_csv('stock_Cluster7.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %% [markdown]
# # Cluster 8

# %%
import yfinance as yf
import pandas as pd

# Input dictionary
date_ticker_dict =  {  

'2017-04-01': ['ALKYLAMINE.NS', 'BBTC.NS', 'BLUEDART.NS', 'BLUESTARCO.NS', 'CERA.NS', 'ESCORTS.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'GUJGASLTD.NS', 'IBULHSGFIN.NS', 'INDIGO.NS', 'INGERRAND.NS', 'ITI.NS', 'JKLAKSHMI.NS', 'KARURVYSYA.NS', 'KSB.NS', 'LAXMIMACH.NS', 'NAVINFLUOR.NS', 'PCBL.NS', 'PGHH.NS', 'PRESTIGE.NS', 'RAIN.NS', 'RECLTD.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SUNTV.NS', 'THERMAX.NS', 'TORNTPHARM.NS', 'TRITURBINE.NS', 'VIPIND.NS', 'VOLTAS.NS'],
'2017-05-01': ['AARTIIND.NS', 'ACC.NS', 'BAYERCROP.NS', 'BBTC.NS', 'BIRLACORPN.NS', 'BRITANNIA.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CESC.NS', 'CHAMBLFERT.NS', 'CONCOR.NS', 'CYIENT.NS', 'DCMSHRIRAM.NS', 'FACT.NS', 'HDFCBANK.NS', 'HEG.NS', 'KEI.NS', 'LICHSGFIN.NS', 'LT.NS', 'LUXIND.NS', 'MASTEK.NS', 'MRF.NS', 'PNCINFRA.NS', 'POLYPLEX.NS', 'PRSMJOHNSN.NS', 'RAJESHEXPO.NS', 'SHREECEM.NS', 'SKFINDIA.NS', 'TATACHEM.NS'],
'2017-06-01': ['AVANTIFEED.NS', 'BIRLACORPN.NS', 'ESCORTS.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'JKCEMENT.NS', 'MARUTI.NS', 'RAJESHEXPO.NS', 'SUPRAJIT.NS'],
'2017-07-01': ['GILLETTE.NS', 'TEAMLEASE.NS'],
'2017-08-01': ['ADANIPORTS.NS', 'ASAHIINDIA.NS', 'BAJAJHLDNG.NS', 'BEML.NS', 'BRITANNIA.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'HEG.NS', 'INDUSINDBK.NS', 'INFIBEAM.NS', 'JUBLFOOD.NS', 'LAXMIMACH.NS', 'MARUTI.NS', 'RELIANCE.NS', 'RTNINDIA.NS', 'SAREGAMA.NS', 'SBIN.NS', 'SOLARINDS.NS', 'UNOMINDA.NS', 'WELCORP.NS'],
'2017-09-01': ['ASAHIINDIA.NS', 'BAJAJHLDNG.NS', 'BBTC.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'GUJALKALI.NS', 'HINDPETRO.NS', 'KANSAINER.NS', 'L&TFH.NS', 'UNOMINDA.NS'],
'2017-10-01': ['BBTC.NS', 'GUJALKALI.NS', 'OIL.NS', 'RAJESHEXPO.NS'],
'2017-11-01': ['ALKYLAMINE.NS', 'AVANTIFEED.NS', 'BBTC.NS', 'COFORGE.NS', 'DEEPAKFERT.NS', 'DELTACORP.NS', 'EMAMILTD.NS', 'ENGINERSIN.NS', 'GILLETTE.NS', 'GNFC.NS', 'GRAPHITE.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'KNRCON.NS', 'KRBL.NS', 'MCDOWELL-N.NS', 'NCC.NS', 'ONGC.NS', 'POLYPLEX.NS', 'SAIL.NS', 'SAREGAMA.NS', 'SOLARINDS.NS', 'SONATSOFTW.NS', 'STLTECH.NS', 'TORNTPOWER.NS', 'TVSMOTOR.NS', 'UBL.NS', 'VAIBHAVGBL.NS'],
'2017-12-01': ['ABBOTINDIA.NS', 'ASTRAL.NS', 'GILLETTE.NS', 'LINDEINDIA.NS', 'LTTS.NS', 'MINDACORP.NS', 'NCC.NS', 'PGHH.NS', 'PIIND.NS', 'PRAJIND.NS', 'SOBHA.NS', 'TATACONSUM.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TV18BRDCST.NS'],
'2018-01-01': ['3MINDIA.NS', 'AARTIIND.NS', 'ADANIPOWER.NS', 'AEGISCHEM.NS', 'ALLCARGO.NS', 'BAYERCROP.NS', 'CHOLAHLDNG.NS', 'ECLERX.NS', 'FDC.NS', 'GMRINFRA.NS', 'JBCHEPHARM.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'KANSAINER.NS', 'LTIM.NS', 'MARUTI.NS', 'MCDOWELL-N.NS', 'NAUKRI.NS', 'NHPC.NS', 'PERSISTENT.NS', 'QUESS.NS', 'SONATSOFTW.NS', 'SUPREMEIND.NS', 'TATACONSUM.NS'],
'2018-02-01': ['LUXIND.NS', 'PFIZER.NS', 'TECHM.NS'],
'2018-03-01': ['3MINDIA.NS', 'ABBOTINDIA.NS', 'MRF.NS', 'PGHH.NS', 'ZFCVINDIA.NS'],
'2018-04-01': ['TITAN.NS'],
'2018-05-01': ['ASHOKLEY.NS', 'BAYERCROP.NS', 'BRITANNIA.NS', 'BSOFT.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'HINDUNILVR.NS', 'KOTAKBANK.NS', 'M&M.NS', 'MPHASIS.NS', 'NESTLEIND.NS', 'PIDILITIND.NS', 'TATAELXSI.NS', 'TCS.NS', 'TEAMLEASE.NS', 'UBL.NS'],
'2018-06-01': ['BRITANNIA.NS', 'HDFCBANK.NS', 'KOTAKBANK.NS', 'MAHLIFE.NS', 'RATNAMANI.NS'],
'2018-07-01': ['3MINDIA.NS', 'ACC.NS', 'AIAENG.NS', 'BAJAJ-AUTO.NS', 'BAJAJHLDNG.NS', 'BAYERCROP.NS', 'BBTC.NS', 'BOSCHLTD.NS', 'COLPAL.NS', 'DMART.NS', 'ECLERX.NS', 'ENDURANCE.NS', 'HONAUT.NS', 'LAXMIMACH.NS', 'MARUTI.NS', 'MRF.NS', 'NAUKRI.NS', 'PIDILITIND.NS', 'SHREECEM.NS', 'SOLARINDS.NS', 'TITAN.NS', 'UBL.NS', 'WHIRLPOOL.NS'],
'2018-08-01': ['BAJFINANCE.NS', 'DABUR.NS', 'RELAXO.NS', 'RELIANCE.NS', 'RHIM.NS', 'WHIRLPOOL.NS'],
'2018-09-01': ['3MINDIA.NS', 'BATAINDIA.NS', 'BOSCHLTD.NS', 'GLAXO.NS', 'HAVELLS.NS', 'LTTS.NS', 'PEL.NS', 'PFIZER.NS', 'PGHL.NS', 'SHREECEM.NS', 'TCS.NS', 'TORNTPHARM.NS'],
'2018-10-01': ['APLAPOLLO.NS', 'BLUEDART.NS', 'BLUESTARCO.NS', 'BSOFT.NS', 'CDSL.NS', 'CENTRALBK.NS', 'CGPOWER.NS', 'DEEPAKFERT.NS', 'ESCORTS.NS', 'IIFL.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'JMFINANCIL.NS', 'MANAPPURAM.NS', 'MHRIL.NS', 'PNB.NS', 'PNBHOUSING.NS', 'SUPREMEIND.NS', 'TV18BRDCST.NS', 'WHIRLPOOL.NS', 'YESBANK.NS'],
'2018-11-01': ['ADANIPOWER.NS'],
'2018-12-01': ['ADANIPOWER.NS', 'EIHOTEL.NS', 'LINDEINDIA.NS'],
'2019-01-01': ['PATANJALI.NS'],
'2019-02-01': ['AJANTPHARM.NS', 'APOLLOTYRE.NS', 'BAJAJ-AUTO.NS', 'CENTURYTEX.NS', 'CHOLAHLDNG.NS', 'GODREJCP.NS', 'GRAPHITE.NS', 'HEROMOTOCO.NS', 'IBULHSGFIN.NS', 'ICICIPRULI.NS', 'KEC.NS', 'LAXMIMACH.NS', 'LINDEINDIA.NS', 'M&M.NS', 'MARUTI.NS', 'MCDOWELL-N.NS', 'MRF.NS', 'NAVINFLUOR.NS', 'PEL.NS', 'QUESS.NS', 'RAYMOND.NS', 'SCHAEFFLER.NS', 'SFL.NS', 'SHRIRAMFIN.NS', 'ULTRACEMCO.NS', 'ZYDUSLIFE.NS'],
'2019-03-01': ['PGHH.NS', 'SUNDARMFIN.NS', 'TATACOMM.NS', 'UPL.NS'],
'2019-04-01': ['BAJAJHLDNG.NS', 'GMRINFRA.NS', 'INDUSINDBK.NS', 'MGL.NS', 'RAJESHEXPO.NS', 'RBLBANK.NS', 'YESBANK.NS'],
'2019-05-01': ['ABB.NS', 'GILLETTE.NS', 'GSPL.NS', 'ULTRACEMCO.NS'],
'2019-06-01': ['ATUL.NS', 'BEL.NS', 'GUJGASLTD.NS', 'INTELLECT.NS', 'KEI.NS', 'MAHLIFE.NS', 'NH.NS', 'PNCINFRA.NS', 'SUNDARMFIN.NS', 'TANLA.NS', 'TATACONSUM.NS', 'TTML.NS', 'VGUARD.NS', 'VINATIORGA.NS'],
'2019-07-01': ['TANLA.NS'],
'2019-08-01': ['3MINDIA.NS', 'ABBOTINDIA.NS', 'AIAENG.NS', 'AMBER.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BANDHANBNK.NS', 'BATAINDIA.NS', 'BEML.NS', 'BHARATFORG.NS', 'BPCL.NS', 'CARBORUNIV.NS', 'CENTURYTEX.NS', 'CIPLA.NS', 'CUMMINSIND.NS', 'DEEPAKNTR.NS', 'DIXON.NS', 'DRREDDY.NS', 'GMMPFAUDLR.NS', 'GODREJIND.NS', 'GRINDWELL.NS', 'HEROMOTOCO.NS', 'HONAUT.NS', 'IGL.NS', 'INGERRAND.NS', 'JUSTDIAL.NS', 'JYOTHYLAB.NS', 'KEI.NS', 'LICHSGFIN.NS', 'LINDEINDIA.NS', 'LT.NS', 'LTIM.NS', 'MRF.NS', 'NATCOPHARM.NS', 'NAVINFLUOR.NS', 'PEL.NS', 'POLYMED.NS', 'PRESTIGE.NS', 'RATNAMANI.NS', 'SBIN.NS', 'SFL.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SRF.NS', 'SUNDARMFIN.NS', 'SUNTV.NS', 'SUPREMEIND.NS', 'SYNGENE.NS', 'TATACHEM.NS', 'TATAINVEST.NS', 'TRENT.NS', 'ULTRACEMCO.NS', 'UNOMINDA.NS', 'UPL.NS', 'WIPRO.NS', 'ZFCVINDIA.NS'],
'2019-09-01': ['ABBOTINDIA.NS', 'HONAUT.NS', 'MRF.NS'],
'2019-10-01': ['BAJFINANCE.NS', 'BATAINDIA.NS', 'BERGEPAINT.NS', 'BPCL.NS', 'CGCL.NS', 'COLPAL.NS', 'DMART.NS', 'JKPAPER.NS', 'PGHH.NS', 'POLYMED.NS', 'SKFINDIA.NS', 'WHIRLPOOL.NS'],
'2019-11-01': ['ABBOTINDIA.NS', 'AMBER.NS', 'AVANTIFEED.NS', 'BAJAJ-AUTO.NS', 'BALKRISIND.NS', 'CENTRALBK.NS', 'DMART.NS', 'EICHERMOT.NS', 'GICRE.NS', 'GILLETTE.NS', 'HINDUNILVR.NS', 'ICICIPRULI.NS', 'ISEC.NS', 'JUBLFOOD.NS', 'KEI.NS', 'MANAPPURAM.NS', 'MGL.NS', 'NAM-INDIA.NS', 'NAVINFLUOR.NS', 'NIACL.NS', 'ORIENTELEC.NS', 'PAGEIND.NS', 'PETRONET.NS', 'SANOFI.NS', 'SBILIFE.NS', 'SIEMENS.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TIMKEN.NS', 'WHIRLPOOL.NS'],
'2019-12-01': ['ABCAPITAL.NS', 'ADANIENT.NS', 'ALKYLAMINE.NS', 'ASTERDM.NS', 'CRISIL.NS', 'DLF.NS', 'ISEC.NS', 'L&TFH.NS', 'ORIENTELEC.NS', 'RELAXO.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TIINDIA.NS'],
'2020-01-01': ['COROMANDEL.NS', 'GPIL.NS', 'IDFC.NS', 'KRBL.NS', 'NMDC.NS', 'VTL.NS'],
'2020-02-01': ['CENTURYTEX.NS', 'CROMPTON.NS', 'DIXON.NS', 'ESCORTS.NS', 'IGL.NS', 'JBCHEPHARM.NS', 'JUBLFOOD.NS', 'NH.NS', 'ORIENTELEC.NS', 'RALLIS.NS', 'SOLARINDS.NS'],
'2020-03-01': ['RTNINDIA.NS'],
'2020-04-01': ['BANKINDIA.NS', 'BLUESTARCO.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'ELGIEQUIP.NS', 'ENDURANCE.NS', 'IDFC.NS', 'IIFL.NS', 'INDIANB.NS', 'INTELLECT.NS', 'KARURVYSYA.NS', 'KPRMILL.NS', 'LEMONTREE.NS', 'M&MFIN.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'MRPL.NS', 'OBEROIRLTY.NS', 'OLECTRA.NS', 'PNBHOUSING.NS', 'POONAWALLA.NS', 'QUESS.NS', 'RAYMOND.NS', 'RTNINDIA.NS', 'SAREGAMA.NS', 'SHOPERSTOP.NS', 'SOBHA.NS', 'SONATSOFTW.NS', 'TIINDIA.NS', 'VARROC.NS', 'VTL.NS', 'WELCORP.NS'],
'2020-05-01': ['ALOKINDS.NS'],
'2020-06-01': ['AARTIDRUGS.NS', 'ADANIGREEN.NS', 'BAYERCROP.NS'],
'2020-07-01': ['AARTIDRUGS.NS', 'BDL.NS', 'BEL.NS', 'BLS.NS', 'CARBORUNIV.NS', 'CGPOWER.NS', 'CYIENT.NS', 'EIDPARRY.NS', 'GODREJIND.NS', 'GUJGASLTD.NS', 'HAL.NS', 'HFCL.NS', 'HINDZINC.NS', 'HUDCO.NS', 'IDBI.NS', 'IOB.NS', 'JINDALSTEL.NS', 'JSL.NS', 'KEC.NS', 'MASTEK.NS', 'POONAWALLA.NS', 'QUESS.NS', 'SUZLON.NS', 'VAIBHAVGBL.NS'],
'2020-08-01': ['AARTIDRUGS.NS', 'COFORGE.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'INTELLECT.NS', 'JUBLPHARMA.NS', 'LTIM.NS', 'MASTEK.NS', 'MCX.NS', 'MPHASIS.NS', 'SYNGENE.NS'],
'2020-09-01': ['ADANIENT.NS', 'ADANIGREEN.NS', 'APLAPOLLO.NS', 'CDSL.NS', 'CHOLAHLDNG.NS', 'CREDITACC.NS', 'EMAMILTD.NS', 'GODREJIND.NS', 'INDIAMART.NS', 'LAURUSLABS.NS', 'SUNDARMFIN.NS', 'TANLA.NS', 'TATACONSUM.NS', 'TATAMOTORS.NS', 'TEAMLEASE.NS', 'TIINDIA.NS', 'VTL.NS', 'WELSPUNLIV.NS'],
'2020-10-01': ['ADANIGREEN.NS', 'KPITTECH.NS', 'PERSISTENT.NS'],
'2020-11-01': ['ADANIGREEN.NS', 'BLUEDART.NS', 'CGPOWER.NS', 'CRISIL.NS', 'JUSTDIAL.NS', 'TANLA.NS'],
'2020-12-01': ['ABCAPITAL.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'ALKYLAMINE.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ATGL.NS', 'BAJFINANCE.NS', 'BATAINDIA.NS', 'BEML.NS', 'BLUESTARCO.NS', 'CERA.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHAMBLFERT.NS', 'CHOLAHLDNG.NS', 'DALBHARAT.NS', 'DIXON.NS', 'EIDPARRY.NS', 'GUJGASLTD.NS', 'ICICIGI.NS', 'IDFC.NS', 'IGL.NS', 'INDIACEM.NS', 'INDUSINDBK.NS', 'KAJARIACER.NS', 'KEI.NS', 'KOTAKBANK.NS', 'M&MFIN.NS', 'MOTHERSON.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NCC.NS', 'PFC.NS', 'QUESS.NS', 'RECLTD.NS', 'RVNL.NS', 'SFL.NS', 'SIEMENS.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'THERMAX.NS', 'TIINDIA.NS', 'UNOMINDA.NS', 'VARROC.NS', 'VBL.NS', 'VIPIND.NS', 'VMART.NS', 'WESTLIFE.NS'],
'2021-01-01': ['APLAPOLLO.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'BEML.NS', 'BERGEPAINT.NS', 'CGCL.NS', 'ENDURANCE.NS', 'LT.NS', 'LTTS.NS', 'MAHLIFE.NS', 'NH.NS', 'OLECTRA.NS', 'PERSISTENT.NS', 'SFL.NS', 'SOBHA.NS', 'SYMPHONY.NS', 'TATASTEEL.NS', 'TITAN.NS', 'USHAMART.NS', 'VAIBHAVGBL.NS', 'VEDL.NS', 'VTL.NS', 'WHIRLPOOL.NS'],
'2021-02-01': ['CGCL.NS', 'IIFL.NS', 'JBMA.NS', 'KAJARIACER.NS'],
'2021-03-01': ['ABCAPITAL.NS', 'ATGL.NS', 'CDSL.NS', 'DEEPAKNTR.NS', 'GESHIP.NS', 'GRAPHITE.NS', 'GUJGASLTD.NS', 'HINDALCO.NS', 'IDFCFIRSTB.NS', 'IIFL.NS', 'MMTC.NS', 'NATIONALUM.NS', 'NBCC.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'PRAJIND.NS', 'SCHAEFFLER.NS', 'SOLARINDS.NS', 'SUNDRMFAST.NS', 'SUPRAJIT.NS', 'TIINDIA.NS', 'TRIVENI.NS', 'VAIBHAVGBL.NS', 'ZENSARTECH.NS'],
'2021-04-01': ['ADANIENT.NS', 'DEEPAKNTR.NS', 'GALAXYSURF.NS', 'GRASIM.NS', 'INTELLECT.NS', 'KSB.NS', 'MAHLIFE.NS', 'PRSMJOHNSN.NS', 'SUNDRMFAST.NS'],
'2021-05-01': ['AARTIIND.NS', 'ALKYLAMINE.NS', 'CDSL.NS', 'CGCL.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'FINEORG.NS', 'FLUOROCHEM.NS', 'GALAXYSURF.NS', 'JBCHEPHARM.NS', 'MASTEK.NS', 'SAIL.NS', 'TATAELXSI.NS', 'TATASTEEL.NS', 'ZYDUSLIFE.NS'],
'2021-06-01': ['ABB.NS', 'BALKRISIND.NS', 'INGERRAND.NS', 'JKLAKSHMI.NS', 'MCDOWELL-N.NS', 'MINDACORP.NS', 'PNBHOUSING.NS', 'PRINCEPIPE.NS', 'RTNINDIA.NS', 'SOLARINDS.NS', 'UPL.NS', 'VGUARD.NS'],
'2021-07-01': ['BEL.NS', 'ECLERX.NS', 'FSL.NS', 'HFCL.NS', 'INFY.NS', 'IOB.NS', 'LAURUSLABS.NS', 'PERSISTENT.NS', 'SAREGAMA.NS', 'TATAELXSI.NS'],
'2021-08-01': ['ACC.NS', 'ALLCARGO.NS', 'BCG.NS', 'JKPAPER.NS', 'JSL.NS', 'JUBLFOOD.NS', 'LAXMIMACH.NS', 'LTTS.NS', 'MANAPPURAM.NS', 'OLECTRA.NS', 'RAIN.NS', 'RTNINDIA.NS', 'SCHAEFFLER.NS', 'SUNPHARMA.NS', 'TATASTEEL.NS', 'TECHM.NS', 'TRIDENT.NS', 'VMART.NS', 'ZENSARTECH.NS'],
'2021-09-01': ['ALKEM.NS', 'APOLLOHOSP.NS', 'ASTERDM.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BRITANNIA.NS', 'GODREJCP.NS', 'HAL.NS', 'HCLTECH.NS', 'IEX.NS', 'LTIM.NS', 'NAUKRI.NS', 'SBICARD.NS', 'TECHM.NS'],
'2021-10-01': ['BCG.NS', 'DELTACORP.NS', 'DLF.NS', 'FINPIPE.NS', 'GMRINFRA.NS', 'GSFC.NS', 'IDBI.NS', 'IDEA.NS', 'IEX.NS', 'INDUSTOWER.NS', 'IOC.NS', 'KRBL.NS', 'NHPC.NS', 'NLCINDIA.NS', 'OLECTRA.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TRIDENT.NS', 'USHAMART.NS', 'WELSPUNLIV.NS', 'ZEEL.NS'],
'2021-11-01': ['ABB.NS', 'MCDOWELL-N.NS', 'TANLA.NS', 'TTKPRESTIG.NS', 'TVSMOTOR.NS'],
'2021-12-01': ['ELGIEQUIP.NS', 'RAJESHEXPO.NS', 'RAYMOND.NS'],
'2022-01-01': ['ALOKINDS.NS'],
'2022-02-01': ['MMTC.NS'],
'2022-03-01': ['AARTIIND.NS', 'ACC.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'APARINDS.NS', 'ASAHIINDIA.NS', 'ASTRAL.NS', 'ATGL.NS', 'AUROPHARMA.NS', 'BALAMINES.NS', 'BATAINDIA.NS', 'BBTC.NS', 'BEML.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BIOCON.NS', 'BLUEDART.NS', 'BPCL.NS', 'BRITANNIA.NS', 'BSOFT.NS', 'CARBORUNIV.NS', 'CDSL.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CHOLAHLDNG.NS', 'COFORGE.NS', 'DEEPAKNTR.NS', 'DIXON.NS', 'ECLERX.NS', 'EIDPARRY.NS', 'ERIS.NS', 'GLAND.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GMMPFAUDLR.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GRANULES.NS', 'GRASIM.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'INDIGO.NS', 'INTELLECT.NS', 'ISEC.NS', 'JBCHEPHARM.NS', 'JUSTDIAL.NS', 'KEI.NS', 'LICHSGFIN.NS', 'LTIM.NS', 'M&M.NS', 'MFSL.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NAUKRI.NS', 'OFSS.NS', 'ORIENTELEC.NS', 'PIIND.NS', 'PNBHOUSING.NS', 'PNCINFRA.NS', 'PRAJIND.NS', 'PRINCEPIPE.NS', 'QUESS.NS', 'RADICO.NS', 'RAJESHEXPO.NS', 'RELAXO.NS', 'ROUTE.NS', 'SAFARI.NS', 'SBICARD.NS', 'SBIN.NS', 'SHRIRAMFIN.NS', 'SOBHA.NS', 'SPARC.NS', 'SYNGENE.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TCS.NS', 'TECHM.NS', 'TIINDIA.NS', 'TORNTPOWER.NS', 'TVSMOTOR.NS', 'UBL.NS', 'UNOMINDA.NS', 'UTIAMC.NS', 'VARROC.NS', 'VMART.NS', 'WESTLIFE.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2022-04-01': ['GNFC.NS', 'INTELLECT.NS', 'LINDEINDIA.NS', 'MAHLIFE.NS', 'POLYPLEX.NS', 'USHAMART.NS'],
'2022-05-01': ['ADANIPOWER.NS', 'BLS.NS', 'MRPL.NS', 'SCHAEFFLER.NS'],
'2022-06-01': ['AIAENG.NS'],
'2022-07-01': ['TVSMOTOR.NS'],
'2022-08-01': ['AEGISCHEM.NS', 'APARINDS.NS', 'APOLLOTYRE.NS', 'ASTERDM.NS', 'BATAINDIA.NS', 'BEL.NS', 'CEATLTD.NS', 'CGPOWER.NS', 'CIEINDIA.NS', 'COALINDIA.NS', 'CONCOR.NS', 'CUB.NS', 'DABUR.NS', 'DLF.NS', 'EXIDEIND.NS', 'FEDERALBNK.NS', 'GESHIP.NS', 'GODREJPROP.NS', 'GRASIM.NS', 'HAL.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'ITC.NS', 'JBCHEPHARM.NS', 'KAJARIACER.NS', 'KARURVYSYA.NS', 'LICHSGFIN.NS', 'LT.NS', 'OBEROIRLTY.NS', 'PIDILITIND.NS', 'RECLTD.NS', 'SAFARI.NS', 'SBIN.NS', 'SHOPERSTOP.NS', 'SUNDARMFIN.NS', 'SUNPHARMA.NS', 'TATASTEEL.NS', 'TVSMOTOR.NS', 'UJJIVANSFB.NS', 'WHIRLPOOL.NS'],
'2022-09-01': ['ADANIENT.NS', 'AJANTPHARM.NS', 'ATGL.NS', 'BAJAJFINSV.NS', 'BEML.NS', 'CEATLTD.NS', 'ELGIEQUIP.NS', 'ESCORTS.NS', 'GRINDWELL.NS', 'HAL.NS', 'KEI.NS', 'KSB.NS', 'LAXMIMACH.NS', 'MAHLIFE.NS', 'PIDILITIND.NS', 'RADICO.NS', 'SAFARI.NS', 'SCHAEFFLER.NS', 'SKFINDIA.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'TITAN.NS', 'WESTLIFE.NS'],
'2022-10-01': ['ADANIPORTS.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'ANGELONE.NS', 'ASIANPAINT.NS', 'ATGL.NS', 'ATUL.NS', 'AUBANK.NS', 'AXISBANK.NS', 'BATAINDIA.NS', 'BBTC.NS', 'BIRLACORPN.NS', 'BRIGADE.NS', 'CDSL.NS', 'CENTURYPLY.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'DCMSHRIRAM.NS', 'ECLERX.NS', 'ENDURANCE.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'HAPPSTMNDS.NS', 'HDFCBANK.NS', 'HINDALCO.NS', 'HONAUT.NS', 'IGL.NS', 'INDIGO.NS', 'INFY.NS', 'JKCEMENT.NS', 'JKPAPER.NS', 'JSWENERGY.NS', 'JUSTDIAL.NS', 'KOTAKBANK.NS', 'LINDEINDIA.NS', 'LT.NS', 'LTIM.NS', 'MARUTI.NS', 'MCX.NS', 'MGL.NS', 'MPHASIS.NS', 'MRF.NS', 'OBEROIRLTY.NS', 'PERSISTENT.NS', 'PGHH.NS', 'PGHL.NS', 'PIDILITIND.NS', 'POWERINDIA.NS', 'RAJESHEXPO.NS', 'RELAXO.NS', 'ROUTE.NS', 'SBILIFE.NS', 'SBIN.NS', 'SFL.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SRF.NS', 'SUVENPHAR.NS', 'SYMPHONY.NS', 'SYNGENE.NS', 'TATAELXSI.NS', 'ULTRACEMCO.NS', 'VINATIORGA.NS', 'VMART.NS'],
'2022-11-01': ['AXISBANK.NS', 'BANKINDIA.NS', 'BHEL.NS', 'CANBK.NS', 'GODFRYPHLP.NS', 'IIFL.NS', 'INDIANB.NS', 'INFIBEAM.NS', 'KARURVYSYA.NS', 'MCX.NS', 'UCOBANK.NS', 'UNIONBANK.NS'],
'2022-12-01': ['BANKINDIA.NS', 'BHEL.NS', 'BRITANNIA.NS', 'GMRINFRA.NS', 'HUDCO.NS', 'IOC.NS', 'NBCC.NS', 'RECLTD.NS', 'RVNL.NS', 'UCOBANK.NS'],
'2023-01-01': ['JSL.NS'],
'2023-02-01': ['PERSISTENT.NS', 'RATNAMANI.NS'],
'2023-03-01': ['EQUITASBNK.NS', 'SYMPHONY.NS'],
'2023-04-01': ['AARTIDRUGS.NS', 'ADANIENT.NS', 'AMBER.NS', 'ASAHIINDIA.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'ATUL.NS', 'AUBANK.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BHARTIARTL.NS', 'BSE.NS', 'CENTURYPLY.NS', 'CHOLAHLDNG.NS', 'CIPLA.NS', 'COFORGE.NS', 'CONCOR.NS', 'CROMPTON.NS', 'DIVISLAB.NS', 'DIXON.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EMAMILTD.NS', 'ENDURANCE.NS', 'ESCORTS.NS', 'FINEORG.NS', 'GMMPFAUDLR.NS', 'GODREJIND.NS', 'HDFCAMC.NS', 'HEROMOTOCO.NS', 'INFY.NS', 'LALPATHLAB.NS', 'LTTS.NS', 'LUPIN.NS', 'MARUTI.NS', 'MASTEK.NS', 'MAZDOCK.NS', 'MFSL.NS', 'MPHASIS.NS', 'MRF.NS', 'PEL.NS', 'PGHH.NS', 'RATNAMANI.NS', 'SBILIFE.NS', 'SKFINDIA.NS', 'SUNTV.NS', 'SUPREMEIND.NS', 'SYMPHONY.NS', 'TCS.NS', 'TIMKEN.NS', 'TTKPRESTIG.NS', 'UTIAMC.NS', 'VARROC.NS', 'VOLTAS.NS'],
'2023-05-01': ['BAJAJ-AUTO.NS', 'GSFC.NS', 'ITC.NS', 'KOTAKBANK.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'OFSS.NS', 'SYNGENE.NS', 'WELSPUNLIV.NS'],
'2023-06-01': ['APOLLOTYRE.NS', 'ASIANPAINT.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'BAJFINANCE.NS', 'BANDHANBNK.NS', 'BATAINDIA.NS', 'BHARTIARTL.NS', 'BSOFT.NS', 'CHOLAFIN.NS', 'CREDITACC.NS', 'DELTACORP.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'EIHOTEL.NS', 'GODREJCP.NS', 'HAPPSTMNDS.NS', 'HEROMOTOCO.NS', 'INDHOTEL.NS', 'INDUSINDBK.NS', 'IOC.NS', 'ITC.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KOTAKBANK.NS', 'KPITTECH.NS', 'L&TFH.NS', 'LUPIN.NS', 'MAHLIFE.NS', 'MASTEK.NS', 'NH.NS', 'OFSS.NS', 'PGHL.NS', 'PIIND.NS', 'PRAJIND.NS', 'RAMCOCEM.NS', 'SAFARI.NS', 'SANOFI.NS', 'SBILIFE.NS', 'SHOPERSTOP.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'TANLA.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TRENT.NS', 'TVSMOTOR.NS'],
'2023-07-01': ['ANGELONE.NS', 'BATAINDIA.NS', 'BLUEDART.NS', 'DRREDDY.NS', 'EXIDEIND.NS', 'GILLETTE.NS', 'HDFCAMC.NS', 'ICICIGI.NS', 'INDIGO.NS', 'LUPIN.NS', 'MFSL.NS', 'MUTHOOTFIN.NS', 'OLECTRA.NS', 'PATANJALI.NS', 'PEL.NS', 'PFC.NS', 'POLYMED.NS', 'ROSSARI.NS', 'SHRIRAMFIN.NS', 'TANLA.NS', 'TITAN.NS', 'TRENT.NS', 'VGUARD.NS', 'ZYDUSLIFE.NS'],
'2023-08-01': ['AARTIDRUGS.NS', 'ACC.NS', 'AJANTPHARM.NS', 'ALKEM.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'ASHOKLEY.NS', 'BHARATFORG.NS', 'BLS.NS', 'BSOFT.NS', 'DRREDDY.NS', 'ESCORTS.NS', 'FINPIPE.NS', 'GMRINFRA.NS', 'GODREJPROP.NS', 'HDFCAMC.NS', 'HINDCOPPER.NS', 'INDIANB.NS', 'LINDEINDIA.NS', 'LT.NS', 'LUPIN.NS', 'MAHLIFE.NS', 'MAZDOCK.NS', 'MPHASIS.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NCC.NS', 'SHRIRAMFIN.NS', 'SUNPHARMA.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'TATASTEEL.NS', 'TORNTPHARM.NS', 'UJJIVANSFB.NS', 'UNIONBANK.NS', 'USHAMART.NS', 'ZENSARTECH.NS', 'ZYDUSLIFE.NS'],
'2023-09-01': ['AMBER.NS', 'BEML.NS', 'BHARATFORG.NS', 'BHEL.NS', 'CHALET.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'EIHOTEL.NS', 'FINPIPE.NS', 'GLAND.NS', 'GMRINFRA.NS', 'IBULHSGFIN.NS', 'JSL.NS', 'KPRMILL.NS', 'KSB.NS', 'LAXMIMACH.NS', 'MASTEK.NS', 'MFSL.NS', 'MHRIL.NS', 'NATCOPHARM.NS', 'NCC.NS', 'POLYCAB.NS', 'PRESTIGE.NS', 'RECLTD.NS', 'RTNINDIA.NS', 'SAFARI.NS', 'STLTECH.NS', 'SUPREMEIND.NS', 'TRENT.NS', 'VAIBHAVGBL.NS', 'VARROC.NS', 'WHIRLPOOL.NS'],
'2023-10-01': ['CENTRALBK.NS', 'COALINDIA.NS', 'GAEL.NS', 'GMMPFAUDLR.NS', 'HUDCO.NS', 'IOB.NS', 'ITI.NS', 'LT.NS', 'MCX.NS', 'RECLTD.NS', 'SUNTECK.NS', 'TATAINVEST.NS'],
'2023-11-01': ['ANGELONE.NS', 'SWANENERGY.NS'],
'2023-12-01': ['BHARTIARTL.NS', 'BPCL.NS', 'BRIGADE.NS', 'BSE.NS', 'CDSL.NS', 'COALINDIA.NS', 'HINDPETRO.NS', 'IPCALAB.NS', 'MCX.NS', 'MUTHOOTFIN.NS', 'PCBL.NS', 'PRESTIGE.NS', 'RTNINDIA.NS', 'SANOFI.NS', 'SUVENPHAR.NS', 'VBL.NS'],
'2024-01-01': ['AARTIIND.NS', 'ALKEM.NS', 'BAJAJ-AUTO.NS', 'BEL.NS', 'BHEL.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'BSOFT.NS', 'CASTROLIND.NS', 'CESC.NS', 'COLPAL.NS', 'DLF.NS', 'FORTIS.NS', 'GAIL.NS', 'GLAXO.NS', 'GMRINFRA.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'HAL.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HUDCO.NS', 'INTELLECT.NS', 'NATIONALUM.NS', 'NMDC.NS', 'NTPC.NS', 'SAIL.NS', 'TATAMOTORS.NS', 'TEAMLEASE.NS', 'ULTRACEMCO.NS', 'VOLTAS.NS', 'WIPRO.NS'],
'2024-02-01': ['AMBER.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'BAJAJ-AUTO.NS', 'BEML.NS', 'BLS.NS', 'BSOFT.NS', 'EIHOTEL.NS', 'ELGIEQUIP.NS', 'GUJGASLTD.NS', 'HEROMOTOCO.NS', 'HUDCO.NS', 'IDBI.NS', 'MGL.NS', 'MMTC.NS', 'MOTILALOFS.NS', 'MRPL.NS', 'OFSS.NS', 'PCBL.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PNB.NS', 'PNCINFRA.NS', 'SHRIRAMFIN.NS', 'SWANENERGY.NS', 'SWSOLAR.NS', 'TATAMOTORS.NS', 'TATAPOWER.NS'],


}



# Initialize lists to store results
ticker_list = []
percentage_returns = []
first_day_closes = []
last_day_closes = []
start_dates = []  # List to store the start dates
end_dates = []    # List to store the end dates

# Loop through the dictionary and download data for each date-ticker pair
for start_date, tickers in date_ticker_dict.items():
    end_date = pd.to_datetime(start_date) + pd.DateOffset(months=1) - pd.DateOffset(days=1)  # Last day of the month

    # Loop through tickers in this iteration
    for ticker in tickers:
        # Download historical stock data using yfinance for the specified ticker and dates
        try:
            stocks = yf.download(ticker, start=start_date, end=end_date)

            # Extracting the closing prices on the first and last day
            first_day_close = stocks['Close'].iloc[0]
            last_day_close = stocks['Close'].iloc[-1]

            # Calculating percentage return for this ticker
            percentage_return = ((last_day_close - first_day_close) / first_day_close) * 100

            # Appending the results to the lists
            ticker_list.append(ticker)
            percentage_returns.append(percentage_return)
            first_day_closes.append(first_day_close)
            last_day_closes.append(last_day_close)
            start_dates.append(pd.to_datetime(start_date))
            end_dates.append(end_date)  # Append end date for each ticker
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

# Creating a DataFrame with ticker symbols, percentage returns, and capital information
returns_df = pd.DataFrame({
    'Start_Date': start_dates,
    'End_Date': end_dates,
    'Ticker': ticker_list,
    'Percentage_Return': percentage_returns,
    'First_Day_Close': first_day_closes,
    'Last_Day_Close': last_day_closes,
})

# Assuming an initial investment of $10,000 for each stock
initial_investment = 10000

# Calculating the capital at the last day
returns_df['Capital_At_Last_Day'] = initial_investment * (1 + returns_df['Percentage_Return'] / 100)

# Calculating the difference between capital at the last day and capital required
returns_df['Capital_Difference'] = returns_df['Capital_At_Last_Day'] - initial_investment

# Total amount invested
total_invested = initial_investment * len(returns_df)

# Total amount returned
total_returned = returns_df['Capital_At_Last_Day'].sum()

# Calculate percentage return
percentage_return = ((total_returned - total_invested) / total_invested) * 100

# Displaying the DataFrame with ticker names, percentage returns, and capital information
print(returns_df[['Start_Date', 'End_Date', 'Ticker', 'Percentage_Return', 'First_Day_Close', 'Last_Day_Close']])

# Display total amount invested and total amount returned in percentage
print("\nTotal Amount Invested: $", total_invested)
print("Total Amount Returned: $", total_returned)
print("Percentage Return: ", percentage_return, "%")

returns_df.to_csv('stock_Cluster8.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %% [markdown]
# # Cluster 9

# %%
import yfinance as yf
import pandas as pd

# Input dictionary
date_ticker_dict =  {  

'2017-04-01': ['RAJESHEXPO.NS', 'RCF.NS', 'RTNINDIA.NS', 'SUNTECK.NS'],
'2017-05-01': ['APLAPOLLO.NS', 'BANKINDIA.NS', 'FEDERALBNK.NS', 'INDIACEM.NS', 'ITI.NS', 'JMFINANCIL.NS', 'PCBL.NS', 'PEL.NS', 'SUNTECK.NS', 'SUNTV.NS'],
'2017-06-01': ['HDFCBANK.NS', 'UNOMINDA.NS'],
'2017-07-01': ['GRAPHITE.NS'],
'2017-08-01': ['BAJAJFINSV.NS', 'BAJFINANCE.NS', 'DEEPAKFERT.NS', 'HDFCBANK.NS', 'L&TFH.NS', 'SPARC.NS', 'TATAINVEST.NS', 'YESBANK.NS'],
'2017-09-01': ['HEG.NS', 'OLECTRA.NS'],
'2017-10-01': ['3MINDIA.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'AIAENG.NS', 'APLLTD.NS', 'BAJAJFINSV.NS', 'BALAMINES.NS', 'BHARATFORG.NS', 'BLUEDART.NS', 'CEATLTD.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CYIENT.NS', 'DABUR.NS', 'EICHERMOT.NS', 'EMAMILTD.NS', 'GESHIP.NS', 'GNFC.NS', 'GODFRYPHLP.NS', 'GODREJCP.NS', 'GRASIM.NS', 'HAVELLS.NS', 'HEROMOTOCO.NS', 'HINDPETRO.NS', 'IBULHSGFIN.NS', 'INFY.NS', 'JUSTDIAL.NS', 'LAXMIMACH.NS', 'LT.NS', 'M&MFIN.NS', 'MASTEK.NS', 'MFSL.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NATCOPHARM.NS', 'PIIND.NS', 'POLYPLEX.NS', 'QUESS.NS', 'RAMCOCEM.NS', 'RAYMOND.NS', 'SHARDACROP.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SUNTV.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TTKPRESTIG.NS', 'VINATIORGA.NS', 'YESBANK.NS', 'ZEEL.NS'],
'2017-11-01': ['BALAMINES.NS', 'BIRLACORPN.NS', 'HEG.NS', 'PNCINFRA.NS', 'RAIN.NS', 'RTNINDIA.NS'],
'2017-12-01': ['LTIM.NS', 'SONATSOFTW.NS', 'UNOMINDA.NS'],
'2018-01-01': ['AARTIDRUGS.NS', 'GPIL.NS', 'SCHAEFFLER.NS', 'SKFINDIA.NS', 'VBL.NS', 'ZYDUSWELL.NS'],
'2018-02-01': ['MPHASIS.NS'],
'2018-03-01': ['AJANTPHARM.NS', 'ASIANPAINT.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BBTC.NS', 'CERA.NS', 'CIPLA.NS', 'CRISIL.NS', 'DIVISLAB.NS', 'DRREDDY.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'GRINDWELL.NS', 'GUJALKALI.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'HONAUT.NS', 'IBULHSGFIN.NS', 'LT.NS', 'M&M.NS', 'MARUTI.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'OFSS.NS', 'PAGEIND.NS', 'PHOENIXLTD.NS', 'PIIND.NS', 'RAYMOND.NS', 'SFL.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SKFINDIA.NS', 'SUNTV.NS', 'SUPREMEIND.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TITAN.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'WHIRLPOOL.NS', 'ZEEL.NS'],
'2018-04-01': ['BAYERCROP.NS', 'CERA.NS', 'HONAUT.NS', 'MRF.NS', 'PAGEIND.NS', 'PGHH.NS', 'SUNDARMFIN.NS', 'TEAMLEASE.NS', 'ZFCVINDIA.NS'],
'2018-05-01': ['LAXMIMACH.NS', 'PGHL.NS', 'SRF.NS', 'ZENSARTECH.NS'],
'2018-06-01': ['COLPAL.NS'],
'2018-07-01': ['ALOKINDS.NS'],
'2018-08-01': ['ADANIENT.NS', 'ADANIPOWER.NS', 'GLAXO.NS', 'SANOFI.NS'],
'2018-09-01': ['ADANIENT.NS', 'CGCL.NS', 'CUB.NS', 'INFIBEAM.NS', 'ITC.NS', 'JBCHEPHARM.NS', 'JSWSTEEL.NS', 'POLYPLEX.NS', 'RHIM.NS', 'SUNTECK.NS', 'TATACHEM.NS', 'VINATIORGA.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'WIPRO.NS', 'ZENSARTECH.NS'],
'2018-10-01': ['ABBOTINDIA.NS', 'ALKEM.NS', 'BAJAJ-AUTO.NS', 'BAYERCROP.NS', 'BOSCHLTD.NS', 'CRISIL.NS', 'GILLETTE.NS', 'HONAUT.NS', 'OFSS.NS', 'PAGEIND.NS', 'PFIZER.NS', 'PGHH.NS', 'SANOFI.NS', 'SHREECEM.NS', 'SUNDARMFIN.NS', 'ULTRACEMCO.NS', 'ZFCVINDIA.NS'],
'2018-11-01': ['ABB.NS', 'ABBOTINDIA.NS', 'AJANTPHARM.NS', 'ASIANPAINT.NS', 'AVANTIFEED.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BBTC.NS', 'BHARATFORG.NS', 'BRITANNIA.NS', 'CARBORUNIV.NS', 'CEATLTD.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CIPLA.NS', 'DMART.NS', 'ECLERX.NS', 'ENDURANCE.NS', 'ESCORTS.NS', 'FINCABLES.NS', 'GILLETTE.NS', 'GLAXO.NS', 'GRINDWELL.NS', 'HONAUT.NS', 'IBULHSGFIN.NS', 'ICICIPRULI.NS', 'IPCALAB.NS', 'LTIM.NS', 'LUXIND.NS', 'MARICO.NS', 'MASTEK.NS', 'MCX.NS', 'MRF.NS', 'NAVINFLUOR.NS', 'PAGEIND.NS', 'PEL.NS', 'PFIZER.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'POLYPLEX.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'RBLBANK.NS', 'SCHAEFFLER.NS', 'SIEMENS.NS', 'SUNPHARMA.NS', 'SUNTV.NS', 'TCS.NS', 'UBL.NS', 'VIPIND.NS', 'ZEEL.NS', 'ZFCVINDIA.NS'],
'2018-12-01': ['3MINDIA.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'AIAENG.NS', 'BBTC.NS', 'BOSCHLTD.NS', 'DIVISLAB.NS', 'GILLETTE.NS', 'GODREJCP.NS', 'HEG.NS', 'INDUSINDBK.NS', 'KSB.NS', 'M&M.NS', 'MARUTI.NS', 'MCX.NS', 'MPHASIS.NS', 'MRF.NS', 'PAGEIND.NS', 'PGHH.NS', 'RBLBANK.NS', 'SANOFI.NS', 'SIEMENS.NS', 'SOLARINDS.NS', 'SUNDARMFIN.NS', 'SYMPHONY.NS', 'TCS.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'VINATIORGA.NS', 'VOLTAS.NS', 'ZFCVINDIA.NS'],
'2019-01-01': ['3MINDIA.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'AIAENG.NS', 'ATUL.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJHLDNG.NS', 'BAYERCROP.NS', 'BBTC.NS', 'BOSCHLTD.NS', 'CERA.NS', 'COFORGE.NS', 'DIVISLAB.NS', 'DRREDDY.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'GILLETTE.NS', 'GODREJPROP.NS', 'HEROMOTOCO.NS', 'HONAUT.NS', 'ICICIGI.NS', 'INDUSINDBK.NS', 'KSB.NS', 'MARUTI.NS', 'MRF.NS', 'NAVINFLUOR.NS', 'PAGEIND.NS', 'PFIZER.NS', 'PIDILITIND.NS', 'RADICO.NS', 'RELIANCE.NS', 'SFL.NS', 'SOBHA.NS', 'SUNDARMFIN.NS', 'SUNTV.NS', 'TATAELXSI.NS', 'ULTRACEMCO.NS', 'VMART.NS', 'VOLTAS.NS', 'WHIRLPOOL.NS'],
'2019-02-01': ['3MINDIA.NS', 'ABB.NS', 'ACC.NS', 'AIAENG.NS', 'ALKEM.NS', 'BOSCHLTD.NS', 'CERA.NS', 'CUMMINSIND.NS', 'ENDURANCE.NS', 'GILLETTE.NS', 'GLAXO.NS', 'HONAUT.NS', 'INDUSINDBK.NS', 'LT.NS', 'LTTS.NS', 'MOTILALOFS.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'SHREECEM.NS', 'SOLARINDS.NS', 'SUNDARMFIN.NS', 'TEAMLEASE.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2019-03-01': ['AARTIIND.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ADANIPORTS.NS', 'AJANTPHARM.NS', 'ALKYLAMINE.NS', 'APOLLOHOSP.NS', 'ATUL.NS', 'AUROPHARMA.NS', 'BBTC.NS', 'CEATLTD.NS', 'CHOLAHLDNG.NS', 'CUMMINSIND.NS', 'EICHERMOT.NS', 'ERIS.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GODREJCP.NS', 'HDFCLIFE.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'IBULHSGFIN.NS', 'INDUSINDBK.NS', 'KOTAKBANK.NS', 'M&M.NS', 'MARUTI.NS', 'MRF.NS', 'NAVINFLUOR.NS', 'NESTLEIND.NS', 'OFSS.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'RATNAMANI.NS', 'SANOFI.NS', 'SBIN.NS', 'SOBHA.NS', 'TATAELXSI.NS', 'TRENT.NS', 'UBL.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS'],
'2019-04-01': ['CGCL.NS'],
'2019-05-01': ['BCG.NS'],
'2019-06-01': ['3MINDIA.NS', 'APOLLOTYRE.NS', 'BAJAJ-AUTO.NS', 'BATAINDIA.NS', 'BHARATFORG.NS', 'CENTURYPLY.NS', 'CHOLAHLDNG.NS', 'CYIENT.NS', 'DIVISLAB.NS', 'DMART.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EXIDEIND.NS', 'HEG.NS', 'INDUSTOWER.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'LUXIND.NS', 'M&M.NS', 'MARUTI.NS', 'MGL.NS', 'MRF.NS', 'NATCOPHARM.NS', 'OFSS.NS', 'PEL.NS', 'RAJESHEXPO.NS', 'SANOFI.NS', 'SCHAEFFLER.NS', 'SHARDACROP.NS', 'SKFINDIA.NS', 'SUNTV.NS', 'SUPRAJIT.NS', 'TATAELXSI.NS', 'TECHM.NS', 'TVSMOTOR.NS', 'UBL.NS', 'UNOMINDA.NS', 'VIPIND.NS', 'VMART.NS', 'VOLTAS.NS', 'VTL.NS', 'ZEEL.NS', 'ZFCVINDIA.NS'],
'2019-07-01': ['3MINDIA.NS', 'ACC.NS', 'APLLTD.NS', 'BERGEPAINT.NS', 'BIRLACORPN.NS', 'CARBORUNIV.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CHOLAFIN.NS', 'CIEINDIA.NS', 'CIPLA.NS', 'COCHINSHIP.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'DIVISLAB.NS', 'DIXON.NS', 'FINCABLES.NS', 'GICRE.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GUJALKALI.NS', 'HONAUT.NS', 'ICICIGI.NS', 'INDIANB.NS', 'INDIGO.NS', 'INFY.NS', 'IPCALAB.NS', 'KAJARIACER.NS', 'KANSAINER.NS', 'KOTAKBANK.NS', 'LALPATHLAB.NS', 'LINDEINDIA.NS', 'LUPIN.NS', 'MOTILALOFS.NS', 'NATCOPHARM.NS', 'NAVINFLUOR.NS', 'OIL.NS', 'ORIENTELEC.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PNBHOUSING.NS', 'PRAJIND.NS', 'RAMCOCEM.NS', 'RBLBANK.NS', 'SHRIRAMFIN.NS', 'SUNPHARMA.NS', 'SUPRAJIT.NS', 'SYMPHONY.NS', 'TEAMLEASE.NS', 'TIINDIA.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'VIPIND.NS', 'ZFCVINDIA.NS', 'ZYDUSWELL.NS'],
'2019-08-01': ['APARINDS.NS', 'BALAMINES.NS', 'BBTC.NS', 'BORORENEW.NS', 'BSE.NS', 'CDSL.NS', 'CENTRALBK.NS', 'CIEINDIA.NS', 'ECLERX.NS', 'GAIL.NS', 'GODFRYPHLP.NS', 'GUJALKALI.NS', 'IDEA.NS', 'INDIANB.NS', 'JBMA.NS', 'LAXMIMACH.NS', 'MASTEK.NS', 'MINDACORP.NS', 'NIACL.NS', 'POONAWALLA.NS', 'RBLBANK.NS', 'SHOPERSTOP.NS', 'TATAELXSI.NS', 'TTKPRESTIG.NS', 'VTL.NS'],
'2019-09-01': ['AARTIIND.NS', 'ACC.NS', 'APARINDS.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BAYERCROP.NS', 'BEML.NS', 'BHARTIARTL.NS', 'BOSCHLTD.NS', 'CRISIL.NS', 'DEEPAKNTR.NS', 'DLF.NS', 'DRREDDY.NS', 'EIDPARRY.NS', 'ENDURANCE.NS', 'FDC.NS', 'GODREJPROP.NS', 'GRINDWELL.NS', 'HAVELLS.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'ICICIBANK.NS', 'INDIANB.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INGERRAND.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'KSB.NS', 'LINDEINDIA.NS', 'LUPIN.NS', 'LUXIND.NS', 'MANAPPURAM.NS', 'MFSL.NS', 'MOTILALOFS.NS', 'MUTHOOTFIN.NS', 'OFSS.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'QUESS.NS', 'RAMCOCEM.NS', 'RATNAMANI.NS', 'RELIANCE.NS', 'SHOPERSTOP.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SRF.NS', 'SUNDARMFIN.NS', 'SYNGENE.NS', 'TEAMLEASE.NS', 'TIMKEN.NS', 'TITAN.NS', 'TTKPRESTIG.NS', 'UPL.NS', 'ZFCVINDIA.NS'],
'2019-10-01': ['ELGIEQUIP.NS', 'SIEMENS.NS', 'TATACOMM.NS'],
'2019-11-01': ['ADANIENT.NS', 'ADANIGREEN.NS', 'BERGEPAINT.NS', 'COROMANDEL.NS', 'GLAXO.NS', 'GMRINFRA.NS', 'PFIZER.NS'],
'2019-12-01': ['ADANIGREEN.NS', 'ALOKINDS.NS'],
'2020-01-01': ['ADANIGREEN.NS', 'APLAPOLLO.NS', 'RATNAMANI.NS'],
'2020-02-01': ['AMBER.NS', 'ATUL.NS', 'AUBANK.NS', 'COROMANDEL.NS', 'RELAXO.NS', 'SRF.NS', 'SUPREMEIND.NS', 'VAIBHAVGBL.NS'],
'2020-03-01': ['3MINDIA.NS', 'ADANIENT.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BBTC.NS', 'CHOLAHLDNG.NS', 'COFORGE.NS', 'DALBHARAT.NS', 'DRREDDY.NS', 'ENDURANCE.NS', 'ERIS.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GRINDWELL.NS', 'HDFCAMC.NS', 'HDFCLIFE.NS', 'IGL.NS', 'INDUSTOWER.NS', 'INFY.NS', 'JUBLPHARMA.NS', 'KEC.NS', 'KEI.NS', 'KOTAKBANK.NS', 'KSB.NS', 'LUXIND.NS', 'MANAPPURAM.NS', 'MOTILALOFS.NS', 'MRF.NS', 'NATCOPHARM.NS', 'NAUKRI.NS', 'OBEROIRLTY.NS', 'PAGEIND.NS', 'PGHH.NS', 'POLYPLEX.NS', 'RAJESHEXPO.NS', 'RAMCOCEM.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SHARDACROP.NS', 'SHREECEM.NS', 'SUNDARMFIN.NS', 'SYNGENE.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TEAMLEASE.NS', 'TTKPRESTIG.NS', 'ULTRACEMCO.NS', 'VINATIORGA.NS', 'WHIRLPOOL.NS'],
'2020-04-01': ['ALOKINDS.NS', 'BCG.NS'],
'2020-05-01': ['PATANJALI.NS'],
'2020-06-01': ['ALOKINDS.NS'],
'2020-07-01': ['BORORENEW.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'SHARDACROP.NS'],
'2020-08-01': ['LAURUSLABS.NS', 'PERSISTENT.NS', 'RTNINDIA.NS'],
'2020-09-01': ['CGPOWER.NS'],
'2020-10-01': ['APOLLOHOSP.NS'],
'2020-11-01': ['TTML.NS'],
'2020-12-01': ['BAJAJFINSV.NS', 'CHOLAFIN.NS', 'CUMMINSIND.NS', 'EMAMILTD.NS', 'L&TFH.NS', 'MGL.NS', 'PGHL.NS', 'RATNAMANI.NS', 'SAIL.NS', 'SHRIRAMFIN.NS', 'TANLA.NS', 'TATACHEM.NS', 'TATASTEEL.NS'],
'2021-01-01': ['BCG.NS', 'BORORENEW.NS', 'SAIL.NS', 'SUZLON.NS'],
'2021-02-01': ['TTML.NS'],
'2021-03-01': ['ADANIENT.NS', 'GNFC.NS', 'HINDCOPPER.NS', 'LINDEINDIA.NS', 'MAHLIFE.NS', 'RCF.NS', 'SUNDARMFIN.NS', 'TATACHEM.NS', 'THERMAX.NS'],
'2021-04-01': ['3MINDIA.NS', 'ATGL.NS', 'GODREJIND.NS'],
'2021-05-01': ['BALAMINES.NS', 'GPIL.NS', 'JSWSTEEL.NS', 'RTNINDIA.NS', 'TRIVENI.NS'],
'2021-06-01': ['BSE.NS', 'CDSL.NS', 'ISEC.NS', 'LUXIND.NS', 'REDINGTON.NS', 'RELAXO.NS', 'SAREGAMA.NS'],
'2021-07-01': ['BCG.NS', 'RENUKA.NS', 'RTNINDIA.NS', 'TTML.NS'],
'2021-08-01': ['ABBOTINDIA.NS', 'AMBUJACEM.NS', 'COFORGE.NS', 'FLUOROCHEM.NS', 'JSWENERGY.NS', 'SRF.NS', 'TEJASNET.NS', 'VTL.NS'],
'2021-09-01': ['ATGL.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'CARBORUNIV.NS', 'DMART.NS', 'HINDUNILVR.NS', 'KNRCON.NS', 'SCHAEFFLER.NS', 'SRF.NS', 'TCS.NS'],
'2021-10-01': ['CGPOWER.NS', 'CHALET.NS', 'COALINDIA.NS', 'GODFRYPHLP.NS', 'GODREJPROP.NS', 'GUJALKALI.NS', 'JSWENERGY.NS', 'MCDOWELL-N.NS', 'NTPC.NS', 'OIL.NS', 'ONGC.NS', 'SOLARINDS.NS', 'TITAN.NS'],
'2021-11-01': ['ALOKINDS.NS', 'PATANJALI.NS'],
'2021-12-01': ['BCG.NS', 'TTML.NS'],
'2022-01-01': ['SUZLON.NS', 'TTML.NS'],
'2022-02-01': ['SHARDACROP.NS'],
'2022-03-01': ['AAVAS.NS', 'ABB.NS', 'ADANIENT.NS', 'ADANIPORTS.NS', 'AFFLE.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'ASIANPAINT.NS', 'ATUL.NS', 'AUBANK.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BHARTIARTL.NS', 'BORORENEW.NS', 'BOSCHLTD.NS', 'BSE.NS', 'CAMS.NS', 'CANFINHOME.NS', 'CENTURYPLY.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'DIVISLAB.NS', 'EICHERMOT.NS', 'FLUOROCHEM.NS', 'HEROMOTOCO.NS', 'HONAUT.NS', 'INDUSINDBK.NS', 'INFY.NS', 'INGERRAND.NS', 'IPCALAB.NS', 'IRCTC.NS', 'JSWSTEEL.NS', 'KOTAKBANK.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KSB.NS', 'LAXMIMACH.NS', 'LT.NS', 'LTTS.NS', 'MARUTI.NS', 'MOTILALOFS.NS', 'NATCOPHARM.NS', 'NAVINFLUOR.NS', 'PATANJALI.NS', 'PERSISTENT.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'POLYCAB.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'RELIANCE.NS', 'SANOFI.NS', 'SHREECEM.NS', 'SIEMENS.NS', 'SKFINDIA.NS', 'SOLARINDS.NS', 'SRF.NS', 'SUPREMEIND.NS', 'SUVENPHAR.NS', 'SYMPHONY.NS', 'TANLA.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TEAMLEASE.NS', 'THERMAX.NS', 'TORNTPHARM.NS', 'VINATIORGA.NS'],
'2022-04-01': ['ADANIPOWER.NS'],
'2022-05-01': ['SWANENERGY.NS'],
'2022-06-01': ['MRF.NS'],
'2022-07-01': ['AARTIDRUGS.NS', 'AAVAS.NS', 'ADANIGREEN.NS', 'ALKEM.NS', 'APLAPOLLO.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'ATUL.NS', 'BAJAJHLDNG.NS', 'BALAMINES.NS', 'BBTC.NS', 'BHARATFORG.NS', 'CAMS.NS', 'CDSL.NS', 'CENTURYPLY.NS', 'CHOLAFIN.NS', 'COFORGE.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DIVISLAB.NS', 'GLAND.NS', 'GLAXO.NS', 'HDFCAMC.NS', 'HDFCLIFE.NS', 'INFY.NS', 'INGERRAND.NS', 'INTELLECT.NS', 'IPCALAB.NS', 'JSWSTEEL.NS', 'KAJARIACER.NS', 'KEI.NS', 'LTIM.NS', 'MCDOWELL-N.NS', 'MOTILALOFS.NS', 'OFSS.NS', 'OLECTRA.NS', 'PAGEIND.NS', 'PERSISTENT.NS', 'PGHH.NS', 'PIDILITIND.NS', 'PIIND.NS', 'POLYCAB.NS', 'POLYPLEX.NS', 'PRINCEPIPE.NS', 'QUESS.NS', 'RAMCOCEM.NS', 'RHIM.NS', 'ROUTE.NS', 'SANOFI.NS', 'SBILIFE.NS', 'SHARDACROP.NS', 'SRF.NS', 'SUMICHEM.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUNTV.NS', 'TATACOMM.NS', 'TATAINVEST.NS', 'TCS.NS', 'TORNTPOWER.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'VOLTAS.NS'],
'2022-08-01': ['ADANIENT.NS', 'ASIANPAINT.NS', 'ATGL.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS', 'BLUEDART.NS', 'CANFINHOME.NS', 'CCL.NS', 'CUMMINSIND.NS', 'HONAUT.NS', 'ICICIBANK.NS', 'INDUSINDBK.NS', 'LAXMIMACH.NS', 'MRF.NS', 'NAVINFLUOR.NS', 'PAGEIND.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SCHAEFFLER.NS', 'SKFINDIA.NS', 'TIMKEN.NS', 'ULTRACEMCO.NS', 'WESTLIFE.NS'],
'2022-09-01': ['ABB.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'GESHIP.NS', 'HUDCO.NS', 'IDFCFIRSTB.NS', 'INDIACEM.NS', 'INGERRAND.NS', 'MAZDOCK.NS', 'RITES.NS', 'TEJASNET.NS'],
'2022-10-01': ['ABBOTINDIA.NS', 'ADANIENT.NS', 'AMBER.NS', 'APARINDS.NS', 'APOLLOHOSP.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BLUEDART.NS', 'BRITANNIA.NS', 'CAMS.NS', 'CERA.NS', 'COLPAL.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DMART.NS', 'DRREDDY.NS', 'HAVELLS.NS', 'KAJARIACER.NS', 'LALPATHLAB.NS', 'LAXMIMACH.NS', 'NAVINFLUOR.NS', 'PAGEIND.NS', 'PFIZER.NS', 'PHOENIXLTD.NS', 'POLYCAB.NS', 'SCHAEFFLER.NS', 'SKFINDIA.NS', 'TIMKEN.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TRENT.NS', 'TVSMOTOR.NS', 'ZFCVINDIA.NS'],
'2022-11-01': ['ABBOTINDIA.NS', 'AIAENG.NS', 'AMBUJACEM.NS', 'APARINDS.NS', 'ATGL.NS', 'BAJAJHLDNG.NS', 'BDL.NS', 'COLPAL.NS', 'DIXON.NS', 'HAL.NS', 'HDFCAMC.NS', 'INFY.NS', 'INGERRAND.NS', 'IRCTC.NS', 'JUSTDIAL.NS', 'KPITTECH.NS', 'KSB.NS', 'LAXMIMACH.NS', 'LT.NS', 'MCDOWELL-N.NS', 'MRF.NS', 'NESTLEIND.NS', 'PIIND.NS', 'POLYCAB.NS', 'RATNAMANI.NS', 'RAYMOND.NS', 'SBIN.NS', 'SHREECEM.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUPREMEIND.NS', 'TATACOMM.NS', 'TITAN.NS', 'TVSMOTOR.NS', 'ULTRACEMCO.NS', 'VMART.NS', 'WESTLIFE.NS', 'ZYDUSWELL.NS'],
'2022-12-01': ['ABCAPITAL.NS', 'PFC.NS', 'UNIONBANK.NS'],
'2023-01-01': ['FACT.NS'],
'2023-02-01': ['ADANIPORTS.NS', 'DIXON.NS'],
'2023-03-01': ['ZFCVINDIA.NS'],
'2023-04-01': ['3MINDIA.NS', 'ADANIGREEN.NS', 'AFFLE.NS', 'APLAPOLLO.NS', 'APOLLOHOSP.NS', 'BAJAJHLDNG.NS', 'BIRLACORPN.NS', 'BLUEDART.NS', 'BRITANNIA.NS', 'CEATLTD.NS', 'COROMANDEL.NS', 'CREDITACC.NS', 'DMART.NS', 'FLUOROCHEM.NS', 'GALAXYSURF.NS', 'GLAND.NS', 'GODFRYPHLP.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'HDFCLIFE.NS', 'HONAUT.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'IPCALAB.NS', 'JSWSTEEL.NS', 'JUSTDIAL.NS', 'KAJARIACER.NS', 'KOTAKBANK.NS', 'LT.NS', 'METROPOLIS.NS', 'MOTILALOFS.NS', 'OBEROIRLTY.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'PERSISTENT.NS', 'PGHL.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PIIND.NS', 'POLYCAB.NS', 'RELIANCE.NS', 'SHRIRAMFIN.NS', 'SOLARINDS.NS', 'SUNDRMFAST.NS', 'TATACHEM.NS', 'TATAMOTORS.NS', 'TEJASNET.NS', 'TIINDIA.NS', 'UPL.NS', 'VINATIORGA.NS', 'WESTLIFE.NS'],
'2023-05-01': ['AUROPHARMA.NS', 'GLENMARK.NS', 'IRCON.NS', 'RVNL.NS'],
'2023-06-01': ['ABB.NS', 'ASTRAL.NS', 'BIRLACORPN.NS', 'CANFINHOME.NS', 'CGPOWER.NS', 'DIXON.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'INDIGO.NS', 'INTELLECT.NS', 'JINDALSAW.NS', 'MCDOWELL-N.NS', 'SBICARD.NS', 'SUZLON.NS', 'SYNGENE.NS', 'TORNTPHARM.NS', 'UJJIVANSFB.NS'],
'2023-07-01': ['GPIL.NS', 'JBMA.NS', 'L&TFH.NS', 'NAM-INDIA.NS'],
'2023-08-01': ['BEML.NS', 'BSE.NS', 'CENTURYTEX.NS', 'CIPLA.NS', 'COLPAL.NS', 'ENGINERSIN.NS', 'ERIS.NS', 'GODFRYPHLP.NS', 'IPCALAB.NS', 'JYOTHYLAB.NS', 'NATCOPHARM.NS', 'NTPC.NS', 'PFC.NS', 'POLYCAB.NS', 'RECLTD.NS', 'SWSOLAR.NS', 'TATAMTRDVR.NS'],
'2023-09-01': ['APARINDS.NS', 'BLS.NS', 'BSE.NS', 'BSOFT.NS', 'CERA.NS', 'ESCORTS.NS', 'JYOTHYLAB.NS', 'LINDEINDIA.NS', 'MAHLIFE.NS', 'SOLARINDS.NS', 'SUNTV.NS'],
'2023-10-01': ['ABBOTINDIA.NS', 'AIAENG.NS', 'ALKEM.NS', 'ASTRAL.NS', 'ATUL.NS', 'BAJAJHLDNG.NS', 'BOSCHLTD.NS', 'CERA.NS', 'CIPLA.NS', 'COFORGE.NS', 'DEEPAKNTR.NS', 'DMART.NS', 'DRREDDY.NS', 'FINEORG.NS', 'HAL.NS', 'HONAUT.NS', 'INFY.NS', 'JKCEMENT.NS', 'LTIM.NS', 'LUXIND.NS', 'M&M.NS', 'MPHASIS.NS', 'MRF.NS', 'OFSS.NS', 'PAGEIND.NS', 'PFIZER.NS', 'RATNAMANI.NS', 'SBILIFE.NS', 'SHREECEM.NS', 'SKFINDIA.NS', 'SUPREMEIND.NS', 'TATAELXSI.NS', 'TECHM.NS', 'TITAN.NS', 'UBL.NS', 'ULTRACEMCO.NS', 'VINATIORGA.NS', 'ZYDUSWELL.NS'],
'2023-11-01': ['BSE.NS'],
'2023-12-01': ['ALKEM.NS', 'BAJAJ-AUTO.NS', 'BHEL.NS', 'GICRE.NS', 'HAL.NS', 'HEROMOTOCO.NS', 'IOC.NS', 'NIACL.NS', 'PFC.NS', 'RATNAMANI.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'TVSMOTOR.NS'],
'2024-01-01': ['BDL.NS', 'FLUOROCHEM.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'NLCINDIA.NS', 'TATACONSUM.NS', 'TRENT.NS'],
'2024-02-01': ['INFIBEAM.NS', 'IRB.NS', 'NBCC.NS', 'NHPC.NS', 'RITES.NS', 'RVNL.NS', 'SJVN.NS', 'TATAINVEST.NS'],


}



# Initialize lists to store results
ticker_list = []
percentage_returns = []
first_day_closes = []
last_day_closes = []
start_dates = []  # List to store the start dates
end_dates = []    # List to store the end dates

# Loop through the dictionary and download data for each date-ticker pair
for start_date, tickers in date_ticker_dict.items():
    end_date = pd.to_datetime(start_date) + pd.DateOffset(months=1) - pd.DateOffset(days=1)  # Last day of the month

    # Loop through tickers in this iteration
    for ticker in tickers:
        # Download historical stock data using yfinance for the specified ticker and dates
        try:
            stocks = yf.download(ticker, start=start_date, end=end_date)

            # Extracting the closing prices on the first and last day
            first_day_close = stocks['Close'].iloc[0]
            last_day_close = stocks['Close'].iloc[-1]

            # Calculating percentage return for this ticker
            percentage_return = ((last_day_close - first_day_close) / first_day_close) * 100

            # Appending the results to the lists
            ticker_list.append(ticker)
            percentage_returns.append(percentage_return)
            first_day_closes.append(first_day_close)
            last_day_closes.append(last_day_close)
            start_dates.append(pd.to_datetime(start_date))
            end_dates.append(end_date)  # Append end date for each ticker
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

# Creating a DataFrame with ticker symbols, percentage returns, and capital information
returns_df = pd.DataFrame({
    'Start_Date': start_dates,
    'End_Date': end_dates,
    'Ticker': ticker_list,
    'Percentage_Return': percentage_returns,
    'First_Day_Close': first_day_closes,
    'Last_Day_Close': last_day_closes,
})

# Assuming an initial investment of $10,000 for each stock
initial_investment = 10000

# Calculating the capital at the last day
returns_df['Capital_At_Last_Day'] = initial_investment * (1 + returns_df['Percentage_Return'] / 100)

# Calculating the difference between capital at the last day and capital required
returns_df['Capital_Difference'] = returns_df['Capital_At_Last_Day'] - initial_investment

# Total amount invested
total_invested = initial_investment * len(returns_df)

# Total amount returned
total_returned = returns_df['Capital_At_Last_Day'].sum()

# Calculate percentage return
percentage_return = ((total_returned - total_invested) / total_invested) * 100

# Displaying the DataFrame with ticker names, percentage returns, and capital information
print(returns_df[['Start_Date', 'End_Date', 'Ticker', 'Percentage_Return', 'First_Day_Close', 'Last_Day_Close']])

# Display total amount invested and total amount returned in percentage
print("\nTotal Amount Invested: $", total_invested)
print("Total Amount Returned: $", total_returned)
print("Percentage Return: ", percentage_return, "%")

returns_df.to_csv('stock_Cluster9.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...
