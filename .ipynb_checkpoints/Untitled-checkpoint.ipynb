# %%
# from statsmodels.regression.rolling import RollingOLS
# import pandas_datareader.data as web
# import matplotlib.pyplot as plt
# import statsmodels.api as sm
# import pandas as pd
# import numpy as np
# import datetime as dt
# import yfinance as yf
# import pandas_ta
# import warnings
# warnings.filterwarnings('ignore')

# %% [markdown]
# #### we added 0 to get one data frame as there were 2 data frame

# %%
# sp500= pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
# sp500['Symbol'] = sp500['Symbol'].str.replace('.','-')
# symbols_list = sp500['Symbol'].unique().tolist()
# symbols_list
# end_date ='2023-09-27'
# start_date= pd.to_datetime(end_date)-pd.DateOffset(365*8) #substraction of 8 yrs
# end_date
# start_date
# df= yf.download(tickers=symbols_list,start=start_date)
# df =df.stack()
# df.index.names=['date','ticker']
# df.columns = df.columns.str.lower()

# %%
df
# Out:
#                     adj close       close        high         low        open  \
# date       ticker
# 2015-09-29 A        31.588047   33.740002   34.060001   33.240002   33.360001
#            AAL      37.361622   39.180000   39.770000   38.790001   39.049999
#            AAPL     24.716070   27.264999   28.377501   26.965000   28.207500
#            ABBV     37.024628   52.790001   54.189999   51.880001   53.099998
#            ABT      33.807281   39.500000   40.150002   39.029999   39.259998
# ...                       ...         ...         ...         ...         ...
# 2023-11-30 YUM     125.550003  125.550003  125.879997  124.459999  125.879997
#            ZBH     116.309998  116.309998  116.489998  113.580002  114.129997
#            ZBRA    236.979996  236.979996  238.259995  235.350006  237.720001
#            ZION     35.630001   35.630001   36.110001   35.070000   35.529999
#            ZTS     176.669998  176.669998  176.860001  173.630005  175.039993
#
#                         volume
# date       ticker
# 2015-09-29 A         2252400.0
#            AAL       7478800.0
#            AAPL    293461600.0
#            ABBV     12842800.0
#            ABT      12287500.0
# ...                        ...
# 2023-11-30 YUM       2608900.0
#            ZBH       2678200.0
#            ZBRA       492400.0
#            ZION      2686100.0
#            ZTS       2581900.0
#
# [1017221 rows x 6 columns]

# %% [markdown]
# ## Calculate features and technical indicators
# ### Garman -klass volatilit
# ### RSI
# ### Bollinger Bands
# ### ATR
# ### MACD
# ### Dollar Volume

# %% [markdown]
# ## Calculate garman_klass_vol

# %%
df['garman_klass_vol']=((np.log(df['high'])-np.log(df['low']))**2)/2-(2*np.log(2)-1)*((np.log(df['adj close'])-np.log(df['open']))**2)

# %%
df
# Out:
#                     adj close       close        high         low        open  \
# date       ticker
# 2015-09-29 A        31.588047   33.740002   34.060001   33.240002   33.360001
#            AAL      37.361622   39.180000   39.770000   38.790001   39.049999
#            AAPL     24.716070   27.264999   28.377501   26.965000   28.207500
#            ABBV     37.024628   52.790001   54.189999   51.880001   53.099998
#            ABT      33.807281   39.500000   40.150002   39.029999   39.259998
# ...                       ...         ...         ...         ...         ...
# 2023-11-30 YUM     125.550003  125.550003  125.879997  124.459999  125.879997
#            ZBH     116.309998  116.309998  116.489998  113.580002  114.129997
#            ZBRA    236.979996  236.979996  238.259995  235.350006  237.720001
#            ZION     35.630001   35.630001   36.110001   35.070000   35.529999
#            ZTS     176.669998  176.669998  176.860001  173.630005  175.039993
#
#                         volume  garman_klass_vol
# date       ticker
# 2015-09-29 A         2252400.0         -0.000854
#            AAL       7478800.0         -0.000443
#            AAPL    293461600.0         -0.005441
#            ABBV     12842800.0         -0.049280
#            ABT      12287500.0         -0.008237
# ...                        ...               ...
# 2023-11-30 YUM       2608900.0          0.000062
#            ZBH       2678200.0          0.000182
#            ZBRA       492400.0          0.000072
#            ZION      2686100.0          0.000424
#            ZTS       2581900.0          0.000137
#
# [1017221 rows x 7 columns]

# %% [markdown]
# # calculate using chat gpt garman_klass_vol

# %%
# import numpy as np

# df['garman_klass_vol'] = np.sqrt(
#     (1 / len(df)) * np.sum((np.log(df['high'] / df['low'])) ** 2) -
#     (2 / len(df)) * np.sum(np.log(df['adj close'] / df['open']) * (np.log(df['high'] / df['low']))) +
#     (1 / len(df)) * np.sum((np.log(df['adj close'] / df['open'])) ** 2)
# )
# df

# %% [markdown]
# # Calculate RSI

# %%
df['rsi']= df.groupby(level=1)['adj close'].transform(lambda x: pandas_ta.rsi(close=x,length=20))

# %%
df
# Out:
#                     adj close       close        high         low        open  \
# date       ticker
# 2015-09-29 A        31.588047   33.740002   34.060001   33.240002   33.360001
#            AAL      37.361622   39.180000   39.770000   38.790001   39.049999
#            AAPL     24.716070   27.264999   28.377501   26.965000   28.207500
#            ABBV     37.024628   52.790001   54.189999   51.880001   53.099998
#            ABT      33.807281   39.500000   40.150002   39.029999   39.259998
# ...                       ...         ...         ...         ...         ...
# 2023-11-30 YUM     125.550003  125.550003  125.879997  124.459999  125.879997
#            ZBH     116.309998  116.309998  116.489998  113.580002  114.129997
#            ZBRA    236.979996  236.979996  238.259995  235.350006  237.720001
#            ZION     35.630001   35.630001   36.110001   35.070000   35.529999
#            ZTS     176.669998  176.669998  176.860001  173.630005  175.039993
#
#                         volume  garman_klass_vol        rsi
# date       ticker
# 2015-09-29 A         2252400.0         -0.000854        NaN
#            AAL       7478800.0         -0.000443        NaN
#            AAPL    293461600.0         -0.005441        NaN
#            ABBV     12842800.0         -0.049280        NaN
#            ABT      12287500.0         -0.008237        NaN
# ...                        ...               ...        ...
# 2023-11-30 YUM       2608900.0          0.000062  52.330801
#            ZBH       2678200.0          0.000182  62.164518
#            ZBRA       492400.0          0.000072  60.911018
#            ZION      2686100.0          0.000424  56.907378
#            ZTS       2581900.0          0.000137  55.481539
#
# [1017221 rows x 8 columns]

# %%
df.xs('AAPL',level=1)['rsi'].plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# # Calculate Bollinger Bands

# %%
pandas_ta.bbands(close=df.xs('AAPL',level=1)['adj close'],length=20)
# Out:
#             BBL_20_2.0  BBM_20_2.0  BBU_20_2.0  BBB_20_2.0  BBP_20_2.0
# date
# 2015-09-29         NaN         NaN         NaN         NaN         NaN
# 2015-09-30         NaN         NaN         NaN         NaN         NaN
# 2015-10-01         NaN         NaN         NaN         NaN         NaN
# 2015-10-02         NaN         NaN         NaN         NaN         NaN
# 2015-10-05         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2023-11-24  167.578443  182.545966  197.513488   16.398635    0.748005
# 2023-11-27  169.944346  183.635532  197.326717   14.911260    0.724760
# 2023-11-28  172.176714  184.652235  197.127755   13.512450    0.730361
# 2023-11-29  174.788592  185.593468  196.398345   11.643596    0.674760
# 2023-11-30  176.926664  186.403913  195.881162   10.168508    0.687084
#
# [2058 rows x 5 columns]

# %% [markdown]
# # ALERT CHECK COMMENT OUT

# %%
# df['bb_low'] = df.groupby(level=1)['adj close'].transform(lambda x: pandas_ta.bbands(close=np.log1p(x), length=20).iloc[:, 0])
# df['bb_mid'] = df.groupby(level=1)['adj close'].transform(lambda x: pandas_ta.bbands(close=np.log1p(x), length=20).iloc[:, 1])
# df['bb_high'] = df.groupby(level=1)['adj close'].transform(lambda x: pandas_ta.bbands(close=np.log1p(x), length=20).iloc[:, 2])

# %%
df
# Out:
#                     adj close       close        high         low        open  \
# date       ticker
# 2015-09-29 A        31.588047   33.740002   34.060001   33.240002   33.360001
#            AAL      37.361622   39.180000   39.770000   38.790001   39.049999
#            AAPL     24.716070   27.264999   28.377501   26.965000   28.207500
#            ABBV     37.024628   52.790001   54.189999   51.880001   53.099998
#            ABT      33.807281   39.500000   40.150002   39.029999   39.259998
# ...                       ...         ...         ...         ...         ...
# 2023-11-30 YUM     125.550003  125.550003  125.879997  124.459999  125.879997
#            ZBH     116.309998  116.309998  116.489998  113.580002  114.129997
#            ZBRA    236.979996  236.979996  238.259995  235.350006  237.720001
#            ZION     35.630001   35.630001   36.110001   35.070000   35.529999
#            ZTS     176.669998  176.669998  176.860001  173.630005  175.039993
#
#                         volume  garman_klass_vol        rsi    bb_low  \
# date       ticker
# 2015-09-29 A         2252400.0         -0.000854        NaN       NaN
#            AAL       7478800.0         -0.000443        NaN       NaN
#            AAPL    293461600.0         -0.005441        NaN       NaN
#            ABBV     12842800.0         -0.049280        NaN       NaN
#            ABT      12287500.0         -0.008237        NaN       NaN
# ...                        ...               ...        ...       ...
# 2023-11-30 YUM       2608900.0          0.000062  52.330801  4.824921
#            ZBH       2678200.0          0.000182  62.164518  4.648358
#            ZBRA       492400.0          0.000072  60.911018  5.285520
#            ZION      2686100.0          0.000424  56.907378  3.503852
#            ZTS       2581900.0          0.000137  55.481539  5.090137
#
#                      bb_mid   bb_high
# date       ticker
# 2015-09-29 A            NaN       NaN
#            AAL          NaN       NaN
#            AAPL         NaN       NaN
#            ABBV         NaN       NaN
#            ABT          NaN       NaN
# ...                     ...       ...
# 2023-11-30 YUM     4.845360  4.865799
#            ZBH     4.711734  4.775109
#            ZBRA    5.386858  5.488196
#            ZION    3.567160  3.630468
#            ZTS     5.156864  5.223591
#
# [1017221 rows x 11 columns]

# %% [markdown]
# ## calculate ATR

# %%
def compute_atr(stock_data):
    atr= pandas_ta.atr(high=stock_data['high'],
                     low=stock_data['low'],
                      close=stock_data['close'],
                      length=14)
    return atr.sub(atr.mean()).div(atr.std())

df['atr'] = df.groupby(level=1,group_keys=False).apply(compute_atr)

# %%
df
# Out:
#                     adj close       close        high         low        open  \
# date       ticker
# 2015-09-29 A        31.588047   33.740002   34.060001   33.240002   33.360001
#            AAL      37.361622   39.180000   39.770000   38.790001   39.049999
#            AAPL     24.716070   27.264999   28.377501   26.965000   28.207500
#            ABBV     37.024628   52.790001   54.189999   51.880001   53.099998
#            ABT      33.807281   39.500000   40.150002   39.029999   39.259998
# ...                       ...         ...         ...         ...         ...
# 2023-11-30 YUM     125.550003  125.550003  125.879997  124.459999  125.879997
#            ZBH     116.309998  116.309998  116.489998  113.580002  114.129997
#            ZBRA    236.979996  236.979996  238.259995  235.350006  237.720001
#            ZION     35.630001   35.630001   36.110001   35.070000   35.529999
#            ZTS     176.669998  176.669998  176.860001  173.630005  175.039993
#
#                         volume  garman_klass_vol        rsi    bb_low  \
# date       ticker
# 2015-09-29 A         2252400.0         -0.000854        NaN       NaN
#            AAL       7478800.0         -0.000443        NaN       NaN
#            AAPL    293461600.0         -0.005441        NaN       NaN
#            ABBV     12842800.0         -0.049280        NaN       NaN
#            ABT      12287500.0         -0.008237        NaN       NaN
# ...                        ...               ...        ...       ...
# 2023-11-30 YUM       2608900.0          0.000062  52.330801  4.824921
#            ZBH       2678200.0          0.000182  62.164518  4.648358
#            ZBRA       492400.0          0.000072  60.911018  5.285520
#            ZION      2686100.0          0.000424  56.907378  3.503852
#            ZTS       2581900.0          0.000137  55.481539  5.090137
#
#                      bb_mid   bb_high       atr
# date       ticker
# 2015-09-29 A            NaN       NaN       NaN
#            AAL          NaN       NaN       NaN
#            AAPL         NaN       NaN       NaN
#            ABBV         NaN       NaN       NaN
#            ABT          NaN       NaN       NaN
# ...                     ...       ...       ...
# 2023-11-30 YUM     4.845360  4.865799 -0.041661
#            ZBH     4.711734  4.775109 -0.582110
#            ZBRA    5.386858  5.488196 -0.204126
#            ZION    3.567160  3.630468 -0.241430
#            ZTS     5.156864  5.223591  0.619120
#
# [1017221 rows x 12 columns]

# %% [markdown]
# # Calculate MACD

# %%
def compute_macd(close):
    macd = pandas_ta.macd(close=close, length=20).iloc[:, 0]
    return (macd - macd.mean()) / macd.std()

df['macd'] = df.groupby(level=1, group_keys=False)['adj close'].apply(compute_macd)

# %%
df
# Out:
#                     adj close       close        high         low        open  \
# date       ticker
# 2015-09-29 A        31.588047   33.740002   34.060001   33.240002   33.360001
#            AAL      37.361622   39.180000   39.770000   38.790001   39.049999
#            AAPL     24.716070   27.264999   28.377501   26.965000   28.207500
#            ABBV     37.024628   52.790001   54.189999   51.880001   53.099998
#            ABT      33.807281   39.500000   40.150002   39.029999   39.259998
# ...                       ...         ...         ...         ...         ...
# 2023-11-30 YUM     125.550003  125.550003  125.879997  124.459999  125.879997
#            ZBH     116.309998  116.309998  116.489998  113.580002  114.129997
#            ZBRA    236.979996  236.979996  238.259995  235.350006  237.720001
#            ZION     35.630001   35.630001   36.110001   35.070000   35.529999
#            ZTS     176.669998  176.669998  176.860001  173.630005  175.039993
#
#                         volume  garman_klass_vol        rsi    bb_low  \
# date       ticker
# 2015-09-29 A         2252400.0         -0.000854        NaN       NaN
#            AAL       7478800.0         -0.000443        NaN       NaN
#            AAPL    293461600.0         -0.005441        NaN       NaN
#            ABBV     12842800.0         -0.049280        NaN       NaN
#            ABT      12287500.0         -0.008237        NaN       NaN
# ...                        ...               ...        ...       ...
# 2023-11-30 YUM       2608900.0          0.000062  52.330801  4.824921
#            ZBH       2678200.0          0.000182  62.164518  4.648358
#            ZBRA       492400.0          0.000072  60.911018  5.285520
#            ZION      2686100.0          0.000424  56.907378  3.503852
#            ZTS       2581900.0          0.000137  55.481539  5.090137
#
#                      bb_mid   bb_high       atr      macd
# date       ticker
# 2015-09-29 A            NaN       NaN       NaN       NaN
#            AAL          NaN       NaN       NaN       NaN
#            AAPL         NaN       NaN       NaN       NaN
#            ABBV         NaN       NaN       NaN       NaN
#            ABT          NaN       NaN       NaN       NaN
# ...                     ...       ...       ...       ...
# 2023-11-30 YUM     4.845360  4.865799 -0.041661  0.626215
#            ZBH     4.711734  4.775109 -0.582110  0.736204
#            ZBRA    5.386858  5.488196 -0.204126  0.640290
#            ZION    3.567160  3.630468 -0.241430  0.545355
#            ZTS     5.156864  5.223591  0.619120  0.968584
#
# [1017221 rows x 13 columns]

# %% [markdown]
# # Dollar volume

# %%
df['dollar_volume']=(df['adj close'])*df['volume']/1e6

# %%
df
# Out:
#                     adj close       close        high         low        open  \
# date       ticker
# 2015-09-29 A        31.588047   33.740002   34.060001   33.240002   33.360001
#            AAL      37.361622   39.180000   39.770000   38.790001   39.049999
#            AAPL     24.716070   27.264999   28.377501   26.965000   28.207500
#            ABBV     37.024628   52.790001   54.189999   51.880001   53.099998
#            ABT      33.807281   39.500000   40.150002   39.029999   39.259998
# ...                       ...         ...         ...         ...         ...
# 2023-11-30 YUM     125.550003  125.550003  125.879997  124.459999  125.879997
#            ZBH     116.309998  116.309998  116.489998  113.580002  114.129997
#            ZBRA    236.979996  236.979996  238.259995  235.350006  237.720001
#            ZION     35.630001   35.630001   36.110001   35.070000   35.529999
#            ZTS     176.669998  176.669998  176.860001  173.630005  175.039993
#
#                         volume  garman_klass_vol        rsi    bb_low  \
# date       ticker
# 2015-09-29 A         2252400.0         -0.000854        NaN       NaN
#            AAL       7478800.0         -0.000443        NaN       NaN
#            AAPL    293461600.0         -0.005441        NaN       NaN
#            ABBV     12842800.0         -0.049280        NaN       NaN
#            ABT      12287500.0         -0.008237        NaN       NaN
# ...                        ...               ...        ...       ...
# 2023-11-30 YUM       2608900.0          0.000062  52.330801  4.824921
#            ZBH       2678200.0          0.000182  62.164518  4.648358
#            ZBRA       492400.0          0.000072  60.911018  5.285520
#            ZION      2686100.0          0.000424  56.907378  3.503852
#            ZTS       2581900.0          0.000137  55.481539  5.090137
#
#                      bb_mid   bb_high       atr      macd  dollar_volume
# date       ticker
# 2015-09-29 A            NaN       NaN       NaN       NaN      71.148917
#            AAL          NaN       NaN       NaN       NaN     279.420098
#            AAPL         NaN       NaN       NaN       NaN    7253.217499
#            ABBV         NaN       NaN       NaN       NaN     475.499888
#            ABT          NaN       NaN       NaN       NaN     415.406971
# ...                     ...       ...       ...       ...            ...
# 2023-11-30 YUM     4.845360  4.865799 -0.041661  0.626215     327.547403
#            ZBH     4.711734  4.775109 -0.582110  0.736204     311.501435
#            ZBRA    5.386858  5.488196 -0.204126  0.640290     116.688950
#            ZION    3.567160  3.630468 -0.241430  0.545355      95.705746
#            ZTS     5.156864  5.223591  0.619120  0.968584     456.144268
#
# [1017221 rows x 14 columns]
